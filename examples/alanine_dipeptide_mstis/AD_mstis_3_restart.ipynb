# %% [markdown]
# # Restart from existing production file and continue

# %% [markdown]
# #### Restarting to generate more data

# %%
import openpathsampling as paths

# %%
storage = paths.Storage("ala_mstis_production.nc", "a")

# %%
mstis_calc = paths.PathSampling(
    storage=storage,
    sample_set=storage.steps.last.active,
    move_scheme=storage.schemes[0]
)

# %%
mstis_calc.storage.snapshots.only_mention = True

# %%
mstis_calc.run(100)
# Out:
# Working on Monte Carlo cycle number 1006
# Running for 0 seconds -  1.00 steps per second
# Expected time to finish: 100 seconds
# ---------------------------------------------------------------------------
# RuntimeWarning                            Traceback (most recent call last)
# <ipython-input-10-7b6bc5b24f1a> in <module>()
# ----> 1 mstis_calc.run(100)
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/pathsimulator.pyc in run(self, n_steps)
#     603
#     604             if self.step % self.save_frequency == 0:
# --> 605                 self.globalstate.sanity_check()
#     606                 self.sync_storage()
#     607
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/sample.pyc in sanity_check(self)
#     224                         " with "+str(sample.trajectory))
#     225             try:
# --> 226                 assert(sample.ensemble(sample.trajectory))
#     227             except AssertionError as e:
#     228                 failmsg = ("Trajectory does not match ensemble for replica "
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/ensemble.pyc in __call__(self, trajectory, trusted)
#    1266     def __call__(self, trajectory, trusted=None):
#    1267         logger.debug("Looking for transitions in trajectory " + str(trajectory))
# -> 1268         transitions = self.transition_frames(trajectory, trusted)
#    1269         logger.debug("Found transitions: " + str(transitions))
#    1270         # if we don't have the right number of transitions, or if the last
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/ensemble.pyc in transition_frames(self, trajectory, trusted)
#    1237             if ens_num <= final_ens:
#    1238                 subtraj_final = self._find_subtraj_final(trajectory,
# -> 1239                                                          subtraj_first, ens_num)
#    1240             else:
#    1241                 return transitions
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/ensemble.pyc in _find_subtraj_final(self, traj, subtraj_first, ens_num, last_checked)
#    1319         # logger.debug("Can-app " + str(ens.can_append(subtraj, trusted=True)))
#    1320         # logger.debug("Call    " + str(ens(subtraj, trusted=True)))
# -> 1321         while ((ens.can_append(subtraj, trusted=True) or
#    1322                 ens(subtraj, trusted=True)
#    1323                 ) and subtraj_final < traj_final):
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/ensemble.pyc in can_append(self, trajectory, trusted)
#    1011                 trajectory=trajectory,
#    1012                 trusted=trusted,
# -> 1013                 fname="can_append"
#    1014             )
#    1015         else:
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/ensemble.pyc in _generalized_short_circuit(self, combo, f1, f2, trajectory, trusted, fname)
#     939         """
#     940         logger.debug("Combination is " + self.__class__.__name__)
# --> 941         a = f1(trajectory, trusted)
#     942         if logger.isEnabledFor(logging.DEBUG):  # pragma: no cover
#     943             logger.debug("Combination." + fname + ": " +
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/ensemble.pyc in can_append(self, trajectory, trusted)
#    1841             return True
#    1842         elif trusted and self._use_cache:
# -> 1843             return self._trusted_call(trajectory, self._cache_can_append)
#    1844         else:
#    1845             return self(trajectory)
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/ensemble.pyc in _trusted_call(self, trajectory, cache)
#    1831             # need to check this frame (no prev traj, or prev traj is True)
#    1832             frame = trajectory.get_as_proxy(frame_num)
# -> 1833             cache.contents['previous'] = self._volume(frame)
#    1834             return cache.contents['previous']
#    1835         else:
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/volume.pyc in __call__(self, snapshot)
#     169
#     170     def __call__(self, snapshot):
# --> 171         return not self.volume(snapshot)
#     172
#     173     def __str__(self):
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/volume.pyc in __call__(self, snapshot)
#     120     def __call__(self, snapshot):
#     121         # short circuit following JHP's implementation in ensemble.py
# --> 122         a = self.volume1(snapshot)
#     123         res_true = self.fnc(a, True)
#     124         res_false = self.fnc(a, False)
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/volume.pyc in __call__(self, snapshot)
#     360
#     361     def __call__(self, snapshot):
# --> 362         l = float(self.collectivevariable(snapshot))
#     363         return l >= self.lambda_min and l <= self.lambda_max
#     364
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/chaindict.pyc in __getitem__(self, items)
#     229
#     230     def __getitem__(self, items):
# --> 231         return self._post[items]
#     232
#     233     __call__ = __getitem__
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/chaindict.pyc in __getitem__(self, items)
#     257     def __getitem__(self, items):
#     258         if type(items) is LoaderProxy:
# --> 259             return self._post[[items]][0]
#     260         if hasattr(items, '__iter__'):
#     261             try:
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/chaindict.pyc in __getitem__(self, items)
#      70                 return results
#      71             else:
# ---> 72                 rep = self._post[nones]
#      73                 self._set_list(nones, rep)
#      74
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/chaindict.pyc in __getitem__(self, items)
#      63         # print 'get %d items using %s' % (len(items), self.__class__.__name__)
#      64
# ---> 65         results = self._get_list(items)
#      66
#      67         if self._post is not None:
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/chaindict.pyc in _get_list(self, items)
#     362
#     363         else:
# --> 364             results = [self._eval(obj) for obj in items]
#     365             if self.scalarize_numpy_singletons and results[0].shape[-1] == 1:
#     366                 results = map(lambda x: x.reshape(x.shape[:-1]), results)
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/collectivevariable.pyc in _eval(self, items)
#     417     def _eval(self, items):
#     418         # here the kwargs are used in the callable when it is evaluated
# --> 419         return self.cv_callable(items, **self.kwargs)
#     420
#     421
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/netcdfplus/dictify.pyc in circle_degree(snapshot, center, phi, psi)
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/chaindict.pyc in __getitem__(self, items)
#     229
#     230     def __getitem__(self, items):
# --> 231         return self._post[items]
#     232
#     233     __call__ = __getitem__
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/chaindict.pyc in __getitem__(self, items)
#     242
#     243     def __getitem__(self, items):
# --> 244         return np.array(self._post[items])
#     245
#     246     __call__ = __getitem__
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/chaindict.pyc in __getitem__(self, items)
#     257     def __getitem__(self, items):
#     258         if type(items) is LoaderProxy:
# --> 259             return self._post[[items]][0]
#     260         if hasattr(items, '__iter__'):
#     261             try:
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/chaindict.pyc in __getitem__(self, items)
#      70                 return results
#      71             else:
# ---> 72                 rep = self._post[nones]
#      73                 self._set_list(nones, rep)
#      74
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/chaindict.pyc in __getitem__(self, items)
#      70                 return results
#      71             else:
# ---> 72                 rep = self._post[nones]
#      73                 self._set_list(nones, rep)
#      74
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/chaindict.pyc in __getitem__(self, items)
#      63         # print 'get %d items using %s' % (len(items), self.__class__.__name__)
#      64
# ---> 65         results = self._get_list(items)
#      66
#      67         if self._post is not None:
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/chaindict.pyc in _get_list(self, items)
#     356
#     357         if self.requires_lists:
# --> 358             results = self._eval(items)
#     359
#     360             if self.scalarize_numpy_singletons and results.shape[-1] == 1:
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/collectivevariable.pyc in _eval(self, items)
#     545         trajectory = peng.Trajectory(items)
#     546
# --> 547         t = trajectory_to_mdtraj(trajectory)
#     548         return self.cv_callable(t, **self.kwargs)
#     549
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/engines/openmm/tools.pyc in trajectory_to_mdtraj(trajectory, md_topology)
#     298             raise ValueError('Either provide a topology object or at least one frame.')
#     299
# --> 300         md_topology = trajectory[0].engine.topology.md
#     301
#     302     # this is pretty cool to create a numpy array from the contained information
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/engines/trajectory.pyc in __getitem__(self, index)
#     267             ret = Trajectory(ret)
#     268         elif hasattr(ret, '_idx'):
# --> 269             ret = ret.__subject__
#     270
#     271         return ret
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/netcdfplus/proxy.pyc in __subject__(self)
#      32                 return obj
#      33
# ---> 34         ref = self._load_()
#      35
#      36         if ref is None:
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/netcdfplus/proxy.pyc in _load_(self)
#     100                 raise RuntimeWarning(
#     101                     'Object %s is not in store. Attach it using fallbacks.' %
# --> 102                     self._idx)
#     103
#     104
#
# RuntimeWarning: Object d5fb5228-4f2a-11e6-b22f-000000009014 is not in store. Attach it using fallbacks.

# %%
storage.file_size_str
# Out:
# '1.07GB'

# %%
storage.close()
