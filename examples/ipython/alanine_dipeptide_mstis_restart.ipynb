# %% [markdown]
# # Restart from existing production file and continue

# %% [markdown]
# #### Restarting to generate more data

# %%
import openpathsampling as paths

# %%
storage = paths.storage.Storage("weina_production.nc", "a")
storage.cvs.cache_all()

# %%
mstis_calc = paths.PathSampling(
    storage=storage,
    globalstate=storage.steps[len(storage.steps) - 2].active,
    move_scheme=storage.schemes[0]
)

# %%
total_samples = 50
while len(storage.steps) < total_samples:
    try:
        mstis_calc.run_until(total_samples)
    except ValueError:
        pass
# Out:
# Working on Monte Carlo cycle number 35.
# ---------------------------------------------------------------------------
# RuntimeWarning                            Traceback (most recent call last)
# <ipython-input-8-ccf01c5bc81c> in <module>()
#       2 while len(storage.steps) < total_samples:
#       3     try:
# ----> 4         mstis_calc.run_until(total_samples)
#       5     except ValueError:
#       6         pass
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/pathsimulator.pyc in run_until(self, nsteps)
#     491                 self.step = len(self.storage.steps)
#     492         nsteps_to_run = nsteps - self.step
# --> 493         self.run(nsteps_to_run)
#     494
#     495     def run(self, nsteps):
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/pathsimulator.pyc in run(self, nsteps)
#     553
#     554             if self.step % self.save_frequency == 0:
# --> 555                 self.globalstate.sanity_check()
#     556                 self.sync_storage()
#     557
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/sample.pyc in sanity_check(self)
#     223                         " with "+str(sample.trajectory))
#     224             try:
# --> 225                 assert(sample.ensemble(sample.trajectory))
#     226             except AssertionError as e:
#     227                 failmsg = ("Trajectory does not match ensemble for replica "
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/ensemble.pyc in __call__(self, trajectory, trusted)
#    1068     def __call__(self, trajectory, trusted=None):
#    1069         logger.debug("Looking for transitions in trajectory " + str(trajectory))
# -> 1070         transitions = self.transition_frames(trajectory, trusted)
#    1071         logger.debug("Found transitions: " + str(transitions))
#    1072         # if we don't have the right number of transitions, or if the last
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/ensemble.pyc in transition_frames(self, trajectory, trusted)
#    1039             if ens_num <= final_ens:
#    1040                 subtraj_final = self._find_subtraj_final(trajectory,
# -> 1041                                                          subtraj_first, ens_num)
#    1042             else:
#    1043                 return transitions
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/ensemble.pyc in _find_subtraj_final(self, traj, subtraj_first, ens_num, last_checked)
#    1121         #logger.debug("Can-app " + str(ens.can_append(subtraj, trusted=True)))
#    1122         #logger.debug("Call    " + str(ens(subtraj, trusted=True)))
# -> 1123         while ( (ens.can_append(subtraj, trusted=True) or
#    1124                  ens(subtraj, trusted=True)
#    1125                 ) and subtraj_final < traj_final):
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/ensemble.pyc in can_append(self, trajectory, trusted)
#     835                 trajectory=trajectory,
#     836                 trusted=trusted,
# --> 837                 fname="can_append"
#     838             )
#     839         else:
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/ensemble.pyc in _generalized_short_circuit(self, combo, f1, f2, trajectory, trusted, fname)
#     763             name of the functions f1 and f2. Only used in debug output.
#     764         """
# --> 765         a = f1(trajectory, trusted)
#     766         if logger.isEnabledFor(logging.DEBUG):  # pragma: no cover
#     767             logger.debug("Combination is " + self.__class__.__name__)
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/ensemble.pyc in can_append(self, trajectory, trusted)
#    1566             return True
#    1567         if trusted == True:
# -> 1568             return self(trajectory[slice(len(trajectory)-1, None)], trusted)
#    1569         else:
#    1570             return self(trajectory)
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/ensemble.pyc in __call__(self, trajectory, trusted)
#    1585             #print "trusted"
#    1586             frame = trajectory.get_as_proxy(-1)
# -> 1587             return self._volume(frame)
#    1588         else:
#    1589             #logger.debug("Calling volume untrusted "+repr(self))
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/volume.pyc in __call__(self, snapshot)
#     360
#     361     def __call__(self, snapshot):
# --> 362         l = float(self.collectivevariable(snapshot))
#     363         return l >= self.lambda_min and l <= self.lambda_max
#     364
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/chaindict.pyc in __call__(self, items)
#     124
#     125     def __call__(self, items):
# --> 126         return self[items]
#     127
#     128     def __gt__(self, other):
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/chaindict.pyc in __getitem__(self, items)
#     222
#     223     def __getitem__(self, items):
# --> 224         return self._post[items]
#     225
#     226     def __setitem__(self, key, value):
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/chaindict.pyc in __getitem__(self, items)
#     246     def __getitem__(self, items):
#     247         if type(items) is LoaderProxy:
# --> 248             return self._post[[items]][0]
#     249         if hasattr(items, '__iter__'):
#     250             try:
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/chaindict.pyc in __getitem__(self, items)
#      65                 return results
#      66             else:
# ---> 67                 rep = self._post[[p for p in nones]]
#      68                 self._set_list(nones, rep)
#      69
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/chaindict.pyc in __getitem__(self, items)
#      65                 return results
#      66             else:
# ---> 67                 rep = self._post[[p for p in nones]]
#      68                 self._set_list(nones, rep)
#      69
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/chaindict.pyc in __getitem__(self, items)
#      58     def __getitem__(self, items):
#      59         # first apply the own _get functions to compute
# ---> 60         results = self._get_list(items)
#      61
#      62         if self._post is not None:
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/chaindict.pyc in _get_list(self, items)
#     341
#     342         else:
# --> 343             results = [self._eval(obj) for obj in items]
#     344             if self.scalarize_numpy_singletons and results[0].shape[-1] == 1:
#     345                 results = map(lambda x : x.reshape(x.shape[:-1]), results)
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/collectivevariable.pyc in _eval(self, items)
#     396     def _eval(self, items):
#     397         # here the kwargs are used in the callable when it is evaluated
# --> 398         return self.cv_callable(items, **self.kwargs)
#     399
#     400
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/netcdfplus/dictify.pyc in circle_degree(snapshot, center, phi, psi)
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/chaindict.pyc in __call__(self, items)
#     124
#     125     def __call__(self, items):
# --> 126         return self[items]
#     127
#     128     def __gt__(self, other):
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/chaindict.pyc in __getitem__(self, items)
#     222
#     223     def __getitem__(self, items):
# --> 224         return self._post[items]
#     225
#     226     def __setitem__(self, key, value):
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/chaindict.pyc in __getitem__(self, items)
#     233
#     234     def __getitem__(self, items):
# --> 235         return np.array(self._post[items])
#     236
#     237     def __setitem__(self, key, value):
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/chaindict.pyc in __getitem__(self, items)
#     246     def __getitem__(self, items):
#     247         if type(items) is LoaderProxy:
# --> 248             return self._post[[items]][0]
#     249         if hasattr(items, '__iter__'):
#     250             try:
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/chaindict.pyc in __getitem__(self, items)
#      65                 return results
#      66             else:
# ---> 67                 rep = self._post[[p for p in nones]]
#      68                 self._set_list(nones, rep)
#      69
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/chaindict.pyc in __getitem__(self, items)
#      65                 return results
#      66             else:
# ---> 67                 rep = self._post[[p for p in nones]]
#      68                 self._set_list(nones, rep)
#      69
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/chaindict.pyc in __getitem__(self, items)
#      58     def __getitem__(self, items):
#      59         # first apply the own _get functions to compute
# ---> 60         results = self._get_list(items)
#      61
#      62         if self._post is not None:
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/chaindict.pyc in _get_list(self, items)
#     335
#     336         if self.requires_lists:
# --> 337             results = self._eval(items)
#     338
#     339             if self.scalarize_numpy_singletons and results.shape[-1] == 1:
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/collectivevariable.pyc in _eval(self, items)
#     529         trajectory = peng.Trajectory(items)
#     530
# --> 531         t = trajectory.md()
#     532         return self.cv_callable(t, **self.kwargs)
#     533
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/engines/trajectory.pyc in md(self, topology)
#     561
#     562         if topology is None:
# --> 563             topology = self.topology.md
#     564
#     565         output = self.xyz
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/engines/trajectory.pyc in topology(self)
#     582         topology = None
#     583
# --> 584         if len(self) > 0 and self[0].topology is not None:
#     585             # if no topology is defined
#     586             topology = self[0].topology
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/engines/trajectory.pyc in __getitem__(self, index)
#     262             ret = Trajectory(ret)
#     263         elif hasattr(ret, '_idx'):
# --> 264             ret = ret.__subject__
#     265
#     266         return ret
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/netcdfplus/proxy.pyc in __subject__(self)
#      29                 return obj
#      30
# ---> 31         ref = self._load_()
#      32
#      33         if ref is None:
#
# /Users/jan-hendrikprinz/Studium/git/openpathsampling/openpathsampling/netcdfplus/proxy.pyc in _load_(self)
#      65                 raise RuntimeWarning('Index %s is not in store. This should never happen!' % self._idx)
#      66             else:
# ---> 67                 raise RuntimeWarning('Object %s is not in store. Attach it using fallbacks.' % self._idx)
#      68
#      69
#
# RuntimeWarning: Object f3dade51-1547-11e6-b3c4-00000002f81e is not in store. Attach it using fallbacks.

# %%
storage.close()
