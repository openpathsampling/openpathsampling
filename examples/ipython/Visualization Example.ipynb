# %% [markdown]
# ## PathTree Visualization Example

# %%
from opentis.storage import Storage
from opentis.visualize import PathTreeBuilder
from IPython.display import SVG

# %% [markdown]
# First load a previously generated trajectory storage object

# %% [markdown]
# TODO: Change example directory at some point

# %%
storage = Storage('../alanine/trajectory.nc')

# %% [markdown]
# Then create a simple tree builder object. The TreeBuilder knows about the way things should be arranged and what to display. It contains a TreeRenderer() object that is in charge of generating the actual SVG output. The renderer knows about zoom levels and scaling, etc.

# %%
tree = PathTreeBuilder(storage)

# %% [markdown]
# Load a set of samples that belong to a specific ensemble (in this case ensemble with ID 4)

# %%
samples = storage.sample.by_ensemble(storage.ensemble.load(0))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-002a9b07ebfd> in <module>()
# ----> 1 samples = storage.sample.by_ensemble(storage.ensemble.load(0))
#
# /Users/jan-hendrikprinz/anaconda/lib/python2.7/site-packages/opentis-0.0.1_alpha-py2.7.egg/opentis/storage/wrapper.pyc in inner(self, idx, *args, **kwargs)
#      66             n_idx = self.idx_from_name(idx)
#      67
# ---> 68         obj = func(self, n_idx, *args, **kwargs)
#      69
#      70         obj.idx[self.storage] = n_idx
#
# /Users/jan-hendrikprinz/anaconda/lib/python2.7/site-packages/opentis-0.0.1_alpha-py2.7.egg/opentis/storage/ensemble_store.pyc in load(self, idx)
#      71
#      72         name = self.storage.variables['ensemble_name'][int(idx)]
# ---> 73         description = self.storage.variables['ensemble_str'][int(idx)]
#      74
#      75         obj = LoadedEnsemble(name=name, description=description)
#
# KeyError: 'ensemble_str'

# %% [markdown]
# Finally set some options
# - show rejected paths
# - show state bars below the snapshot boxes, here for StateA in black
# - use a transformed orderparameter, here use psi angles and convert to degrees
#
# and then create the set of drawing commands for this setting from the list of samples

# %%
tree.rejected = True
tree.states = [('StateA','black')]
tree.op = storage.collectivevariable.load('psi').get_transformed_view(lambda x : int(x / 3.141592653 * 180))
tree.from_samples(samples)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-25af3b2a78e6> in <module>()
#       2 tree.states = [('StateA','black')]
#       3 tree.op = storage.collectivevariable.load('psi').get_transformed_view(lambda x : int(x / 3.141592653 * 180))
# ----> 4 tree.from_samples(samples)
#
# /Users/jan-hendrikprinz/anaconda/lib/python2.7/site-packages/opentis-0.0.1_alpha-py2.7.egg/opentis/visualize.pyc in from_samples(self, samples, clear)
#     400
#     401         op_names = { arg[0] : arg[1] for arg in self.states }
# --> 402         ops = {op : self.storage.cv.load(op) for op in op_names.keys() }
#     403
#     404         matrix = self._to_matrix()
#
# /Users/jan-hendrikprinz/anaconda/lib/python2.7/site-packages/opentis-0.0.1_alpha-py2.7.egg/opentis/visualize.pyc in <dictcomp>((op,))
#     400
#     401         op_names = { arg[0] : arg[1] for arg in self.states }
# --> 402         ops = {op : self.storage.cv.load(op) for op in op_names.keys() }
#     403
#     404         matrix = self._to_matrix()
#
# /Users/jan-hendrikprinz/anaconda/lib/python2.7/site-packages/opentis-0.0.1_alpha-py2.7.egg/opentis/storage/netcdf_storage.pyc in __getattr__(self, item)
#     198
#     199     def __getattr__(self, item):
# --> 200         return self.__dict__[item]
#     201
#     202     def __setattr__(self, key, value):
#
# KeyError: 'cv'

# %% [markdown]
# Last, tweak the output to be a little bigger, increase a fontsize and output the SVG to the ipython notebook

# %%
view = tree.renderer
view.zoom = 1.1
view.font_size = 0.35
SVG(view.to_svg())

# %% [markdown]
# Or more similar to the old style

# %%
tree.rejected = True
tree.states = []
tree.op = None
tree.from_samples(samples)
view = tree.renderer
view.zoom = 1.1
view.horizontal_gap = -0.01
view.scale_y = 15
view.font_size = 0.8
view.font_family = 'Times'
SVG(view.to_svg())

# %% [markdown]
# Let's save the last tree as a pdf (using wkhtmltopdf, which can be downloaded from [wkhtmltopdf.org]())

# %%
#! skip
# this one is skipped because it requires wkhtmltopdf to be installed
view.save_pdf('mypathtree.pdf')
# !open mypathtree.pdf
