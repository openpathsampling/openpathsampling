# %%
# Note: in practice, one should put all the imports at the top of a Python script. 
# But for educational purposes here, I put the import immediately before usage. 
# This Python block is just to set up some plotting stuff.

# Imports for plotting
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
from matplotlib.legend_handler import HandlerLine2D
import numpy as np

# TODO: these visualization classes should be moved into some generic file
from openpathsampling.snapshot import Snapshot

# A little class we use for visualizing these 2D PESs
class CallablePES(object):
    def __init__(self, pes):
        self.pes = pes
    
    def __call__(self, x, y):
        self.positions = [x, y]
        return self.pes.V(self)

class CallableVolume(object):
    def __init__(self, vol):
        self.vol = vol
    
    def __call__(self, x, y):
        snapshot = Snapshot(coordinates=np.array([[x,y,0.0]]))
        return 1.0 if self.vol(snapshot) else 0.0

# plot setup stuff
range_x = np.arange(-1.1, 1.1, 0.01)
range_y = np.arange(-1.1, 0.9, 0.01)
extent = [range_x[0], range_x[-1], range_y[0], range_y[-1]]
X, Y = np.meshgrid(range_x, range_y)
pylab.rcParams['figure.figsize'] = 9, 6

# %% [markdown]
# # Setting up RETIS on a Toy Model
#
# This example shows how to set up a RETIS calculation. We do this on a simple 2D model so it can be fast enough for an interactive example, but the basic approach applies to larger systems as well. Although I'll describe everything here in terms of 2-state systems, all the ideas generalize when setting up multiple-state systems (you just need to find more initial paths).

# %% [markdown]
# ## Getting an initial path
#
# RETIS is a path sampling method: it requires that the user supply an input path for each path ensemble. This means that you must somehow generate a first input path. In general, getting the first input paths for RETIS boils down to solving two problems:
#
# 1. Getting a trajectory that samples the rare event.
# 2. Filling all the path ensembles with acceptable trajectories.
#
# Since transition paths satisfy all the path ensembles between two states, a common approach is to use the same initial path for all path ensembles (reversing it where necessary). This way, once you've solved problem 1, problem 2 is trivial.
#
# The first rare path can come from any number of sources. The obvious approach might be to find a transition path from a committor analysis, because this would give you a path that satisfies the true dynamics. However, the initial path doesn't need to satisfy the true dynamics of the system (later we will equilibrate the path ensemble anyway). This means that other approaches, such as high-temperature trajectories, can be used for the first path. One of the most widely-used methods to get an initial trajectory is to generate a transition trajectory using metadynamics. However, the downside of using paths that don't satisfy the true dynamics is that it might be harder to get them to equilibrate to the correct path ensemble. It seems that this has been more of a problem with paths from high temperature runs than with paths from metadynamics: a path from a modified potential energy surface at the correct temperature seems to equilibrate more easily than a path from the original potential energy surface at an incorrect temperature.
#
# In this example, we use a bootstrapping approach, which does create paths satisfying the true dynamics of the system. This bootstrapping is nice because it is quick and convenient, although it works best on smaller systems with less complicated transitions. It works by running normal MD to generate a path that satisfies the innermost interface, and then performing shooting moves in that interface's path ensemble until we have a path that crosses the next interface. Then we switch to the path ensemble for the next interface, and shoot until the path crossing the interface after that. The process continues until we have paths for all interfaces.

# %% [markdown]
# ### Basic system setup
#
# First we set up our system: for the toy dynamics, this involves defining a potential energy surface (PES), setting up an integrator, and giving the simulation an initial configuration. In real MD systems, the PES is handled by the combination of a topology file and a force field definition, and the initial configuration would come from a file instead of being described by hand.

# %%
from openpathsampling.toy_dynamics.toy_engine import ToyEngine
from openpathsampling.toy_dynamics.toy_integrators import LangevinBAOABIntegrator
from openpathsampling.toy_dynamics.toy_pes import Gaussian, OuterWalls

import logging.config
logging.config.fileConfig("logging.conf", disable_existing_loggers=False)

# %%
# Toy_PES supports adding/subtracting various PESs. The OuterWalls PES type gives an x^6+y^6 boundary to the system
pes = (OuterWalls([1.0, 1.0], [0.0, 0.0]) + 
       Gaussian(2.0, [1.0, 4.0], [0.0,1.0]) + 
       Gaussian(2.0, [25.0, 1.0], [0.0, -1.0])
      )
integ = LangevinBAOABIntegrator(dt=0.02, temperature=0.1, gamma=1.0)
sim = ToyEngine(#filename=None,
                options={'pes' : pes, 
                         'integ' : integ,
                         'n_frames_max' : 5000,
                         'nsteps_per_frame' : 10}
               )

sim.mass = [1.0, 1.0]
sim.current_snapshot = Snapshot(coordinates=[-0.5, 0.0], velocities=[0.0,0.0])

# %% [markdown]
# Now let's take a look at our PES and our initial configuration:

# %%
pes_V = np.vectorize(CallablePES(pes))
# we load the coordinates into a snapshot instead of directly calling them 
# based on their implementation in `toy_simulation`. This is because the 
# snapshot approach will work independently of the underlying MD engine.
snap = sim.current_snapshot

fig, ax = plt.subplots()
CS = ax.contour(X, Y, pes_V(X,Y), levels=np.arange(0.0, 1.5, 0.1), colors='k', zorder=0)
ax.plot(snap.coordinates[0,0], snap.coordinates[0,1], 'ro', zorder=1);

# %% [markdown]
# ### Interface setup
#
# One downside of the bootstrapping approach is that we need to have defined our interfaces before we start. However, we can always easily change our initial interface guesses.
#
# We'll consider a couple different choices of order parameter to define our interfaces. First we'll look at lines at different values of $x$. That set will be called `line_set`. Later we'll also consider circles centered on (-0.5, -0.25), with different radii. We'll call this set of interfaces `circle_set`.
#
# In both cases, we need to define the order parameter, and then we need to create a set of volumes and a set of ensembles associated with those volumes.

# %%
from openpathsampling.orderparameter import OP_Function
from openpathsampling.volume import VolumeFactory as vf
from openpathsampling.volume import LambdaVolume
from openpathsampling.trajectory import Trajectory

# WTF? This is an extremely overcomplicated OP; shouldn't be so hard!
try:
    op_line = OP_Function(name="xval", 
                          fcn=lambda snap : Trajectory([snap])[0].coordinates()[0,0])
except ValueError:
    print "xval already made"
# this defines a set of LambdaVolumes for which the minimum is -1.0 and the maximum is given in the array
line_volume_set = vf.LambdaVolumeSet(op_line, minvals=-1.0, maxvals=[-0.30, -0.25, -0.20, -0.13, -0.05, 0.0])
stateA = LambdaVolume(op_line, -1.0, -0.3)
stateB = LambdaVolume(op_line, 0.3, 1.0)

# %%
stateAmap = np.vectorize(CallableVolume(stateA))(X,Y)
stateBmap = np.vectorize(CallableVolume(stateB))(X,Y)
CS = plt.contour(X, Y, pes_V(X,Y), levels=np.arange(0.0, 1.5, 0.1), colors='k', zorder=0)
plt.imshow(stateAmap+stateBmap, extent=extent, cmap="Blues", interpolation='none', vmin=0.0, vmax=2.0, zorder=-1, aspect='auto')
for iface in line_volume_set:
    plt.contour(X,Y, np.vectorize(CallableVolume(iface))(X,Y), colors='r', interpolation='none', levels=[0.5], zorder=1)
plt.plot(snap.coordinates[0,0], snap.coordinates[0,1], 'ro', zorder=1);

# %% [markdown]
# In this picture, the states are marked in blue, and the interfaces are drawn as red lines. The initial configuration is still the red dot.

# %% [markdown]
# ### First innermost interface path
#
# Now we have to create an initial path. This initial path shoud exit the state, cross the first interface, and then return to the state. We'll create this path by defining a special ensemble that, propagating forward from any initial snapshot, ends when the path ends with a segment in the appropriate interface.

# %%
from openpathsampling.ensemble import EnsembleFactory as ef
from openpathsampling.ensemble import LengthEnsemble, InXEnsemble, OutXEnsemble, SequentialEnsemble, OptionalEnsemble

interface0 = line_volume_set[0]
interface_ensemble_set = ef.TISEnsembleSet(stateA, stateB, line_volume_set)
first_traj_ensemble = SequentialEnsemble([
    OptionalEnsemble(OutXEnsemble(stateA)),
    InXEnsemble(stateA),
    OptionalEnsemble(OutXEnsemble(stateA) & InXEnsemble(interface0)),
    OptionalEnsemble(InXEnsemble(interface0)),
    OutXEnsemble(interface0),
    OptionalEnsemble(OutXEnsemble(stateA)),
    InXEnsemble(stateA) & LengthEnsemble(1)
])

# %% [markdown]
# This ensemble is a bit complicated, but works in the general case. To understand it, we'll look at the `SequentialEnsemble` segment by segment. One preliminary point is that we need the generated path ensemble to be the same as the accepted path ensemble in this case, meaning that we must define the ensemble entirely in terms of which volumes each segment is in (i.e., using `InXEnsemble` and `OutXEnsemble`, but not `LeaveXEnsemble` or `HitXEnsemble`).
#
# Start with the first two segments: we start with an optional ensemble outside the state, and then move to an ensemble that is in the state. Since our TIS segment must start in a state, these two ensembles allow us to either start outside the state and then evolve into the state, or to start inside the state. At the end of these two segments, we have the first frame of the TIS ensemble segment, i.e., the frame inside the state that begins the TIS path.
#
# Next we have a couple of optional ensembles, followed by an ensemble requiring the segment to be outside the interface. The optional interfaces here are only important if `stateA` and `interface0` represent different volumes. If they represent the same volume (which is the case here) these optional ensembles don't matter. However, if they are different volumes, then there is a space which is outside the state but inside the interface. So the first optional interface represents that space. The next optional interface says that you must then be inside `interface0`: this is in case there is a reentry into the state before you cross the interface. Next, we require that we cross the interface. The last optional ensemble is for segments ouside the state. If there is space between the interface and the state, then after you are no longer outside the interface you might still be outside the state. Finally, the path ends with one frame in the state.
#
# Following the logic of that, any path that begins anywhere and ends with a segment satisfying the innermost TIS ensemble will be accepted by this ensemble. Furthermore, since the ensemble is defined exclusively in terms of `InXEnsemble`s and `OutXEnsemble`s, the ensemble of paths generated by forward dynamics (`can_append`) is equivalent to the accepted path ensemble.

# %%
sim.initialized = True
first_traj = sim.generate(snap, [first_traj_ensemble.can_append])
# Out:
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Through frame: 70
# Through frame: 80
# Through frame: 90
# Through frame: 100
# Through frame: 110
# Through frame: 120
# Through frame: 130
# Through frame: 140
# Through frame: 150
# Through frame: 160
# Through frame: 170
# Through frame: 180
# Through frame: 190
# Through frame: 200
# Through frame: 210
# Through frame: 220
# Through frame: 230
# Through frame: 240
# Through frame: 250
# Through frame: 260
# Through frame: 270
# Through frame: 280
# Through frame: 290
# Through frame: 300
# Through frame: 310
# Through frame: 320
# Through frame: 330
# Through frame: 340
# Through frame: 350
# Through frame: 360
# Through frame: 370
# Through frame: 380
# Finished trajectory, length: 381

# %% [markdown]
# Next we use the `Ensemble.split` function to split the trajectory we found into segments satisfying the innermost interface TIS ensemble. There is only one such segment, and so we assign the first (and only) one found to `subtraj`, which is the first trajectory satisfying the innermost TIS interface.

# %%
subtraj = interface_ensemble_set[0].split(first_traj)[0]

# %%
plt.imshow(stateAmap+stateBmap, extent=extent, cmap="Blues", interpolation='nearest', vmin=0.0, vmax=2.0, aspect='auto')
CS = plt.contour(X, Y, pes_V(X,Y), levels=np.arange(0.0, 1.5, 0.1), colors='k')
for iface in line_volume_set:
    plt.contour(X,Y, np.vectorize(CallableVolume(iface))(X,Y), colors='r', interpolation='none', levels=[0.5])
plt.plot(first_traj.coordinates()[1,0,0], first_traj.coordinates()[1,0,1], 'ro');
plt.plot(first_traj.coordinates()[1:,0,0], first_traj.coordinates()[1:,0,1], 'k-', linewidth=2)
plt.plot(subtraj.coordinates()[:,0,0], subtraj.coordinates()[:,0,1], 'r-', linewidth=1);

# %% [markdown]
# Now we see how the initial path evolves on this surface. The last part of the trajectory, which satisfies the path ensemble for the innermost interface, is highlighted in red. The whole trajectory is drawn in black.

# %% [markdown]
# ### Bootstrapping
#
# The bootstrapping approach takes a single trajectory which satisfies the innermost interface, and does shooting moves until it satisfies the next ensemble. Once it satisfies the next ensemble, we start shooting from within that ensemble. We keep building up like that until all ensembles have an initial path.
#
# To do this, we need to first create the appropriate shooting movers (one for each path ensemble). This is done quickly and efficiently with a factory function.

# %%
from openpathsampling.pathmover import PathMoverFactory as mf
from openpathsampling.shooting import UniformSelector

# might be nice to get rid of these two lines somehow
from openpathsampling.pathmover import PathMover
PathMover.engine = sim

shooting_movers = mf.OneWayShootingSet(UniformSelector(), interface_ensemble_set)

# %% [markdown]
# Next we need to set up the Bootstrapping calculation:

# %%
from openpathsampling.calculation import Bootstrapping

# TODO: add storage
bootstrap = Bootstrapping(storage=None,
                          engine=sim,
                          ensembles=interface_ensemble_set,
                          movers=shooting_movers,
                          trajectory=subtraj)

# %%
for rep in bootstrap.globalstate.replica_list():
    traj = bootstrap.globalstate[rep]
    print traj, 
    if traj is not None:
        print (op_line(bootstrap.globalstate[rep]))
    else:
        print
# Out:
# Step: -1
# Replica: 0
# Trajectory: Trajectory[37]
# Ensemble: <openpathsampling.ensemble.SequentialEnsemble object at 0x10c0bf750>
# Details: result = None
# inputs = [Trajectory[37]]
# idx = {}
# trial = Trajectory[37]
# mover_path = []
# mover = <openpathsampling.pathmover.PathMover object at 0x12bc06bd0>
# accepted = True
# acceptance_probability = 1.0
#
#  None

# %% [markdown]
# Now we run the bootstrapping. The number `50` means that we'll allow up to 50 shooting attempts per interface; if it takes more than that, you should probably adjust your interfaces (there's probably not much overlap for replica exchange).

# %%
bootstrap.run(300)
# Out:
# Step: 0   Ensemble: 0  failsteps = 0
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 35 in [0:36]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 31
# Proposal probability 1.12903225806 / random : 0.221226672911
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x10c0bf750> to <openpathsampling.ensemble.SequentialEnsemble object at 0x10c09e210>
# Step: 1   Ensemble: 1  failsteps = 0
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 27 in [0:32]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 20
# Proposal probability 1.29166666667 / random : 0.0682254492941
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x10c09e210> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11c036c50>
# Step: 2   Ensemble: 2  failsteps = 0
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:25]
# Starting trajectory
# Finished trajectory, length: 3
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c036c50> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0>
# Step: 3   Ensemble: 2  failsteps = 1
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 21 in [0:25]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 0.571428571429 / random : 0.339719260567
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c036c50> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0>
# Step: 4   Ensemble: 2  failsteps = 2
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 40 in [0:43]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 0.976744186047 / random : 0.192774381853
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c036c50> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0>
# Step: 5   Ensemble: 2  failsteps = 3
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 23 in [0:44]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 32
# Proposal probability 0.796296296296 / random : 0.415394327414
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c036c50> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0>
# Step: 6   Ensemble: 2  failsteps = 4
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 35 in [0:55]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 21
# Proposal probability 0.981818181818 / random : 0.264074101968
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c036c50> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0>
# Step: 7   Ensemble: 3  failsteps = 0
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 6 in [0:56]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 8   Ensemble: 3  failsteps = 1
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 33 in [0:56]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 30
# Proposal probability 0.887096774194 / random : 0.801946672274
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 9   Ensemble: 3  failsteps = 2
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 20 in [0:63]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 1.29166666667 / random : 0.725864811352
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 10   Ensemble: 3  failsteps = 3
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 21 in [0:49]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 23
# Proposal probability 1.11627906977 / random : 0.647533831112
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 11   Ensemble: 3  failsteps = 4
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 6 in [0:44]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 30
# Proposal probability 0.641791044776 / random : 0.2878101956
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 12   Ensemble: 3  failsteps = 5
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 58 in [0:68]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# Proposal probability 1.86111111111 / random : 0.0137112724271
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 13   Ensemble: 3  failsteps = 6
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 10 in [0:37]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 26
# Proposal probability 0.692307692308 / random : 0.0812882872774
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 14   Ensemble: 3  failsteps = 7
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 33 in [0:53]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 16
# Proposal probability 1.48571428571 / random : 0.823210026224
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 15   Ensemble: 3  failsteps = 8
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 5 in [0:36]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 30
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 16   Ensemble: 3  failsteps = 9
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 30 in [0:36]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 23
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 17   Ensemble: 3  failsteps = 10
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 27 in [0:36]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 28
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 18   Ensemble: 3  failsteps = 11
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 24 in [0:36]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 41
# Proposal probability 0.673076923077 / random : 0.209995460874
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 19   Ensemble: 3  failsteps = 12
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 17 in [0:53]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 1.10638297872 / random : 0.0425081960615
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 20   Ensemble: 3  failsteps = 13
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 45 in [0:48]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 23
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 21   Ensemble: 3  failsteps = 14
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 42 in [0:48]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.02173913043 / random : 0.0849991851853
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 22   Ensemble: 3  failsteps = 15
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:47]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 40
# Proposal probability 0.547619047619 / random : 0.947000843574
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 23   Ensemble: 3  failsteps = 16
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 33 in [0:47]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 1.7037037037 / random : 0.346486500661
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 24   Ensemble: 3  failsteps = 17
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 23 in [0:28]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.0 / random : 0.226860436119
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 25   Ensemble: 3  failsteps = 18
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 24 in [0:28]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 29
# Proposal probability 0.84375 / random : 0.224982688483
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 26   Ensemble: 3  failsteps = 19
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 6 in [0:33]
# Starting trajectory
# Finished trajectory, length: 8
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 27   Ensemble: 3  failsteps = 20
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 19 in [0:33]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Proposal probability 0.969696969697 / random : 0.781634423432
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 28   Ensemble: 3  failsteps = 21
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 29 in [0:34]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.0 / random : 0.0919450406354
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 29   Ensemble: 3  failsteps = 22
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 28 in [0:34]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# Proposal probability 1.03125 / random : 0.328687827645
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 30   Ensemble: 3  failsteps = 23
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 17 in [0:33]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 19
# Proposal probability 0.914285714286 / random : 0.0202229115969
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 31   Ensemble: 3  failsteps = 24
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 32 in [0:36]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 1.0 / random : 0.614071373712
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 32   Ensemble: 3  failsteps = 25
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:36]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.28451422315
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 33   Ensemble: 3  failsteps = 26
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:36]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# Proposal probability 0.625 / random : 0.50403244627
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 34   Ensemble: 3  failsteps = 27
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 50 in [0:57]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 35   Ensemble: 3  failsteps = 28
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 48 in [0:57]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 1.0 / random : 0.0157161765142
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 36   Ensemble: 3  failsteps = 29
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 55 in [0:57]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 28
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 37   Ensemble: 3  failsteps = 30
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 18 in [0:57]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 1.0 / random : 0.709201144672
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 38   Ensemble: 3  failsteps = 31
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:57]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.144142290794
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 39   Ensemble: 3  failsteps = 32
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 31 in [0:57]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 26
# Proposal probability 1.09803921569 / random : 0.0915969106202
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 40   Ensemble: 3  failsteps = 33
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 26 in [0:52]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 23
# Proposal probability 1.0625 / random : 0.445739928381
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 41   Ensemble: 3  failsteps = 34
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 33 in [0:49]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 21
# Proposal probability 1.33333333333 / random : 0.616572843281
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 42   Ensemble: 3  failsteps = 35
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 32 in [0:37]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.0 / random : 0.547000330189
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 43   Ensemble: 3  failsteps = 36
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 34 in [0:37]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 35
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 44   Ensemble: 3  failsteps = 37
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 31 in [0:37]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.02857142857 / random : 0.324467082973
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 45   Ensemble: 3  failsteps = 38
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 15 in [0:36]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Proposal probability 1.0 / random : 0.572057703126
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 46   Ensemble: 3  failsteps = 39
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 8 in [0:36]
# Starting trajectory
# Finished trajectory, length: 7
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 47   Ensemble: 3  failsteps = 40
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 7 in [0:36]
# Starting trajectory
# Finished trajectory, length: 7
# Proposal probability 1.0 / random : 0.00206240123922
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 48   Ensemble: 3  failsteps = 41
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 16 in [0:36]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# Proposal probability 0.795454545455 / random : 0.391473331725
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 49   Ensemble: 3  failsteps = 42
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 5 in [0:45]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 23
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 50   Ensemble: 3  failsteps = 43
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 22 in [0:45]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Proposal probability 1.12820512821 / random : 0.142083760697
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 51   Ensemble: 3  failsteps = 44
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 8 in [0:40]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 0.795918367347 / random : 0.450742118169
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 52   Ensemble: 3  failsteps = 45
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 26 in [0:50]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 20
# Proposal probability 1.13953488372 / random : 0.431464446227
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 53   Ensemble: 3  failsteps = 46
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 12 in [0:44]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 54   Ensemble: 3  failsteps = 47
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:44]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.02380952381 / random : 0.686390512277
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 55   Ensemble: 3  failsteps = 48
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 18 in [0:43]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 1.2 / random : 0.32839828036
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 56   Ensemble: 3  failsteps = 49
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 24 in [0:36]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 1.06060606061 / random : 0.326732235814
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 57   Ensemble: 3  failsteps = 50
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 20 in [0:34]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 0.942857142857 / random : 0.339320754222
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 58   Ensemble: 3  failsteps = 51
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 6 in [0:36]
# Starting trajectory
# Finished trajectory, length: 6
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 59   Ensemble: 3  failsteps = 52
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 15 in [0:36]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 0.972222222222 / random : 0.47732220041
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 60   Ensemble: 3  failsteps = 53
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:37]
# Starting trajectory
# Finished trajectory, length: 2
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 61   Ensemble: 3  failsteps = 54
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 35 in [0:37]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 33
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 62   Ensemble: 3  failsteps = 55
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 35 in [0:37]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 34
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 63   Ensemble: 3  failsteps = 56
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 33 in [0:37]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 28
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 64   Ensemble: 3  failsteps = 57
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 34 in [0:37]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.0 / random : 0.122391672421
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 65   Ensemble: 3  failsteps = 58
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 26 in [0:37]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 23
# Proposal probability 1.09090909091 / random : 0.648778142054
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 66   Ensemble: 3  failsteps = 59
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 18 in [0:34]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 1.0 / random : 0.49312842639
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 67   Ensemble: 3  failsteps = 60
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 14 in [0:34]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 24
# Proposal probability 0.767441860465 / random : 0.175064791827
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 68   Ensemble: 3  failsteps = 61
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 25 in [0:44]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 1.38709677419 / random : 0.198273089793
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 69   Ensemble: 3  failsteps = 62
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 30 in [0:32]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 36
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 70   Ensemble: 3  failsteps = 63
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 6 in [0:32]
# Starting trajectory
# Finished trajectory, length: 7
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 71   Ensemble: 3  failsteps = 64
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 24 in [0:32]
# Starting trajectory
# Finished trajectory, length: 7
# Proposal probability 1.03333333333 / random : 0.982548145415
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 72   Ensemble: 3  failsteps = 65
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 11 in [0:31]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 1.0 / random : 0.5296060131
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 73   Ensemble: 3  failsteps = 66
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:31]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 74   Ensemble: 3  failsteps = 67
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 28 in [0:31]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.0 / random : 0.811957851714
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 75   Ensemble: 3  failsteps = 68
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 9 in [0:31]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 0.967741935484 / random : 0.981727565606
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 76   Ensemble: 3  failsteps = 69
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 27 in [0:31]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 0.967741935484 / random : 0.324337644016
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 77   Ensemble: 3  failsteps = 70
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 8 in [0:32]
# Starting trajectory
# Finished trajectory, length: 9
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 78   Ensemble: 3  failsteps = 71
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 14 in [0:32]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 23
# Proposal probability 0.775 / random : 0.807527245199
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 79   Ensemble: 3  failsteps = 72
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 25 in [0:32]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 43
# Proposal probability 0.632653061224 / random : 0.24807043177
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 80   Ensemble: 3  failsteps = 73
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 34 in [0:50]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 0.890909090909 / random : 0.671124051083
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 81   Ensemble: 3  failsteps = 74
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 8 in [0:56]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 28
# Proposal probability 0.733333333333 / random : 0.0415605815067
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 82   Ensemble: 3  failsteps = 75
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 55 in [0:76]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Proposal probability 2.02702702703 / random : 0.375962006049
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 83   Ensemble: 3  failsteps = 76
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 27 in [0:38]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 1.0 / random : 0.477613561703
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 84   Ensemble: 3  failsteps = 77
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 14 in [0:38]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 1.48 / random : 0.636902283551
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 85   Ensemble: 3  failsteps = 78
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 9 in [0:26]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 34
# Proposal probability 0.595238095238 / random : 0.700321863672
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 86   Ensemble: 3  failsteps = 79
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 8 in [0:26]
# Starting trajectory
# Finished trajectory, length: 9
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 87   Ensemble: 3  failsteps = 80
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 4 in [0:26]
# Starting trajectory
# Finished trajectory, length: 5
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 88   Ensemble: 3  failsteps = 81
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 13 in [0:26]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 1.08695652174 / random : 0.39554811462
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 89   Ensemble: 3  failsteps = 82
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 14 in [0:24]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Finished trajectory, length: 67
# Proposal probability 0.302631578947 / random : 0.325051977844
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 90   Ensemble: 3  failsteps = 83
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 15 in [0:24]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 0.92 / random : 0.628846059809
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 91   Ensemble: 3  failsteps = 84
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 11 in [0:26]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 37
# Proposal probability 0.531914893617 / random : 0.528156607456
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 92   Ensemble: 3  failsteps = 85
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 23 in [0:48]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 1.02173913043 / random : 0.470129213077
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 93   Ensemble: 3  failsteps = 86
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:47]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 30
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 94   Ensemble: 3  failsteps = 87
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 38 in [0:47]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# Proposal probability 0.71875 / random : 0.989763987786
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 95   Ensemble: 3  failsteps = 88
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 28 in [0:47]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 28
# Proposal probability 1.0 / random : 0.97253563688
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 96   Ensemble: 3  failsteps = 89
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 45 in [0:47]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 31
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 97   Ensemble: 3  failsteps = 90
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 5 in [0:47]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 23
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 98   Ensemble: 3  failsteps = 91
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 35 in [0:47]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 23
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 99   Ensemble: 3  failsteps = 92
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 10 in [0:47]
# Starting trajectory
# Finished trajectory, length: 8
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 100   Ensemble: 3  failsteps = 93
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 39 in [0:47]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 101   Ensemble: 3  failsteps = 94
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 20 in [0:47]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 1.24324324324 / random : 0.979813702351
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 102   Ensemble: 3  failsteps = 95
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 35 in [0:38]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.0 / random : 0.879396928254
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 103   Ensemble: 3  failsteps = 96
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 33 in [0:38]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 1.02777777778 / random : 0.478300176751
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 104   Ensemble: 3  failsteps = 97
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 25 in [0:37]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 31
# Proposal probability 0.857142857143 / random : 0.893062486176
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 105   Ensemble: 3  failsteps = 98
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 34 in [0:37]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 106   Ensemble: 3  failsteps = 99
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 29 in [0:37]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 1.0 / random : 0.804314427892
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 107   Ensemble: 3  failsteps = 100
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 36 in [0:37]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.487936221989
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 108   Ensemble: 3  failsteps = 101
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 9 in [0:37]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 109   Ensemble: 3  failsteps = 102
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 5 in [0:37]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.0 / random : 0.0764813640539
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 110   Ensemble: 3  failsteps = 103
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 25 in [0:37]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 1.0 / random : 0.0104743151282
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 111   Ensemble: 3  failsteps = 104
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 12 in [0:37]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# Proposal probability 0.734693877551 / random : 0.447479069453
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 112   Ensemble: 3  failsteps = 105
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 10 in [0:50]
# Starting trajectory
# Finished trajectory, length: 9
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 113   Ensemble: 3  failsteps = 106
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 40 in [0:50]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Proposal probability 0.907407407407 / random : 0.340327508661
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 114   Ensemble: 3  failsteps = 107
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 30 in [0:55]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Proposal probability 1.38461538462 / random : 0.976240521661
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 115   Ensemble: 3  failsteps = 108
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 31 in [0:40]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 36
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 116   Ensemble: 3  failsteps = 109
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:40]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 41
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 117   Ensemble: 3  failsteps = 110
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 22 in [0:40]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 16
# Proposal probability 1.05405405405 / random : 0.700290994155
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 118   Ensemble: 3  failsteps = 111
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 13 in [0:38]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 19
# Proposal probability 0.860465116279 / random : 0.31979613048
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 119   Ensemble: 3  failsteps = 112
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 31 in [0:44]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 1.02380952381 / random : 0.340986757289
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 120   Ensemble: 3  failsteps = 113
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 11 in [0:43]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 0.933333333333 / random : 0.111374407968
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 121   Ensemble: 3  failsteps = 114
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 25 in [0:46]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 16
# Proposal probability 1.25 / random : 0.81652962156
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 122   Ensemble: 3  failsteps = 115
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 31 in [0:37]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 1.0 / random : 0.075517643578
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 123   Ensemble: 3  failsteps = 116
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 20 in [0:37]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 1.125 / random : 0.598630242296
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 124   Ensemble: 3  failsteps = 117
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 22 in [0:33]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 33
# Proposal probability 0.744186046512 / random : 0.937700312075
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 125   Ensemble: 3  failsteps = 118
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 27 in [0:33]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 24
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 126   Ensemble: 3  failsteps = 119
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 13 in [0:33]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 45
# Proposal probability 0.561403508772 / random : 0.389660856585
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 127   Ensemble: 3  failsteps = 120
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 22 in [0:58]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 29
# Proposal probability 1.14 / random : 0.507178747544
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 128   Ensemble: 3  failsteps = 121
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 21 in [0:51]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 1.06382978723 / random : 0.576060827723
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 129   Ensemble: 3  failsteps = 122
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 6 in [0:48]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 24
# Proposal probability 0.723076923077 / random : 0.194662564858
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 130   Ensemble: 3  failsteps = 123
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 9 in [0:66]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 0.955882352941 / random : 0.280295065711
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 131   Ensemble: 3  failsteps = 124
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 25 in [0:69]
# Starting trajectory
# Finished trajectory, length: 7
# Proposal probability 1.36 / random : 0.976230107373
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 132   Ensemble: 3  failsteps = 125
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 11 in [0:51]
# Starting trajectory
# Finished trajectory, length: 7
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 133   Ensemble: 3  failsteps = 126
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 4 in [0:51]
# Starting trajectory
# Finished trajectory, length: 4
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 134   Ensemble: 3  failsteps = 127
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:51]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.13326335283
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 135   Ensemble: 3  failsteps = 128
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 40 in [0:51]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 45
# Proposal probability 0.909090909091 / random : 0.678870802538
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 136   Ensemble: 3  failsteps = 129
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 43 in [0:56]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 45
# Proposal probability 0.964912280702 / random : 0.437791555876
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11c02bbd0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950>
# Step: 137   Ensemble: 4  failsteps = 0
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 22 in [0:58]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 33
# Proposal probability 0.838235294118 / random : 0.705838373121
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11c03fb10>
# Step: 138   Ensemble: 4  failsteps = 1
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 10 in [0:69]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11c03fb10>
# Step: 139   Ensemble: 4  failsteps = 2
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 28 in [0:69]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# Proposal probability 1.04615384615 / random : 0.480631131064
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11c03fb10>
# Step: 140   Ensemble: 4  failsteps = 3
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 61 in [0:66]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.0 / random : 0.987880835807
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11c03fb10>
# Step: 141   Ensemble: 4  failsteps = 4
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 25 in [0:66]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# Proposal probability 0.970149253731 / random : 0.0808874897421
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11c03fb10>
# Step: 142   Ensemble: 4  failsteps = 5
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 27 in [0:68]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 40
# Proposal probability 0.8375 / random : 0.708772692234
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11c03fb10>
# Step: 143   Ensemble: 4  failsteps = 6
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 13 in [0:81]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 1.05263157895 / random : 0.865680251391
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11c03fb10>
# Step: 144   Ensemble: 4  failsteps = 7
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 60 in [0:77]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11c03fb10>
# Step: 145   Ensemble: 4  failsteps = 8
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 13 in [0:77]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 24
# Proposal probability 0.873563218391 / random : 0.360513207446
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11c03fb10>
# Step: 146   Ensemble: 4  failsteps = 9
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 38 in [0:88]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 33
# Proposal probability 1.06097560976 / random : 0.00540887705559
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11c03fb10>
# Step: 147   Ensemble: 4  failsteps = 10
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 71 in [0:83]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Through frame: 70
# Finished trajectory, length: 73
# Proposal probability 0.573426573427 / random : 0.471479072593
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x11f7d9950> to <openpathsampling.ensemble.SequentialEnsemble object at 0x11c03fb10>

# %% [markdown]
# We've stored all the trajectories we generated here; now we want to extract a path for each ensemble to use as a starting point for TIS. We'll choose to take the first path that satisfied each ensemble.

# %%
print "[ ",
for sample in bootstrap.globalstate:
    print str(sample.trajectory)+" ",
print "]"
# Out:
# [  Trajectory[37]  Trajectory[33]  Trajectory[56]  Trajectory[57]  Trajectory[84]  Trajectory[145]  ]

# %% [markdown]
# Let's go ahead and visualize where each of those trajectories are:

# %%
plt.imshow(stateAmap+stateBmap, extent=extent, cmap="Blues", interpolation='nearest', vmin=0.0, vmax=2.0, aspect='auto')
CS = plt.contour(X, Y, pes_V(X,Y), levels=np.arange(0.0, 1.5, 0.1), colors='k')
for iface in line_volume_set:
    plt.contour(X,Y, np.vectorize(CallableVolume(iface))(X,Y), colors='r', interpolation='none', levels=[0.5])
repcolordict = {0 : 'k-', 1 : 'r-', 2 : 'g-', 3 : 'b-', 4 : 'r-', 5 : 'k-'}
for sample in bootstrap.globalstate:
    plt.plot(sample.trajectory.coordinates()[:,0,0], 
             sample.trajectory.coordinates()[:,0,1],
             repcolordict[sample.replica])

# %% [markdown]
# ## Equilibration in the Path Ensemble
#
# At the end of the bootstrapping process, we have a set of paths which we can use to start TIS sampling. Before doing a production run, we should let these paths equilibrate within the ensembles. If you generate your initial path through dynamics that aren't the true dynamics (e.g., using high temperature runs or using metadynamics), this stage is **extremely** important. It's important here as well, but less so than if your initial path is non-physical.
#
# This will be an example of a "normal" TIS run, i.e., TIS without replica exchange. We will sampling using only shooter movers (the same ones defined for the bootstrapping) and path reversal movers. First we define these path reveral movers:

# %%
#reversal_movers = mf.PathReversalSet(interface_ensemble_set)

# %% [markdown]
# Next we define global moves: we'll set this up so that each move either does a shooting move on all replicas, or does a path reversal move on all replicas. You can similarly set it up so that each move operates on only on one replica at a time.

# %%
#equilibration_movers = MixedMover(shooting_movers.extend(MixedMover(reversal_movers)))
from openpathsampling.pathmover import MixedMover
equilibration_movers = MixedMover(shooting_movers)

# %% [markdown]
# Now we're ready to set up a TIS run:

# %%
#equilibration_movers = MixedMover(shooting_movers.extend(MixedMover(reversal_movers)))
from openpathsampling.calculation import PathSampling
equilibration = PathSampling(storage=None, engine=sim, root_mover=equilibration_movers, globalstate=bootstrap.globalstate)

# %% [markdown]
# And now we run it. We'll do 200 equilibration steps.

# %%
equilibration.run(200)
# Out:
# MixedMover selecting mover index 0 (MixedMover)
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0
# MixedMover selecting mover index 4 (MixedMover)
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 29 in [0:49]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 21
# Proposal probability 0.979591836735 / random : 0.661351697453
# MixedMover selecting mover index 2 (MixedMover)
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 9 in [0:36]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 24
# Proposal probability 1.09375 / random : 0.207249523874
# MixedMover selecting mover index 2 (MixedMover)
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 6 in [0:33]
# Starting trajectory
# Finished trajectory, length: 6
# MixedMover selecting mover index 5 (MixedMover)
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 112 in [0:159]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 40
# MixedMover selecting mover index 2 (MixedMover)
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 24 in [0:33]
# Starting trajectory
# Finished trajectory, length: 7
# Proposal probability 1.06666666667 / random : 0.72821465627
# MixedMover selecting mover index 2 (MixedMover)
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 30 in [0:31]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 26
# MixedMover selecting mover index 0 (MixedMover)
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:3]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.264940473037
# MixedMover selecting mover index 2 (MixedMover)
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 15 in [0:31]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 1.11111111111 / random : 0.99624334226
# MixedMover selecting mover index 1 (MixedMover)
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 21 in [0:27]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.04 / random : 0.80524828603
# MixedMover selecting mover index 2 (MixedMover)
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 11 in [0:28]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 0.9 / random : 0.811326357824
# MixedMover selecting mover index 1 (MixedMover)
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 17 in [0:26]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# Proposal probability 0.757575757576 / random : 0.608843952174
# MixedMover selecting mover index 0 (MixedMover)
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:3]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.0507539530944
# MixedMover selecting mover index 1 (MixedMover)
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 20 in [0:34]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 20
# Proposal probability 0.846153846154 / random : 0.767867986948
# MixedMover selecting mover index 2 (MixedMover)
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 14 in [0:31]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 1.03448275862 / random : 0.604785007344
# MixedMover selecting mover index 4 (MixedMover)
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 9 in [0:50]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 35
# MixedMover selecting mover index 3 (MixedMover)
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 10 in [0:39]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 41
# Proposal probability 0.550724637681 / random : 0.571275154328
# MixedMover selecting mover index 5 (MixedMover)
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 112 in [0:159]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 48
# Proposal probability 0.993710691824 / random : 0.910477626055
# MixedMover selecting mover index 5 (MixedMover)
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 76 in [0:160]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Finished trajectory, length: 62
# Proposal probability 1.09655172414 / random : 0.679602550577
# MixedMover selecting mover index 4 (MixedMover)
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 41 in [0:50]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 39
# MixedMover selecting mover index 2 (MixedMover)
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 14 in [0:30]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 1.11538461538 / random : 0.822727160993
# MixedMover selecting mover index 4 (MixedMover)
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 32 in [0:50]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 29
# Proposal probability 1.0652173913 / random : 0.231011901757
# MixedMover selecting mover index 3 (MixedMover)
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 12 in [0:39]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# MixedMover selecting mover index 0 (MixedMover)
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:3]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 0.666666666667 / random : 0.482596357015
# MixedMover selecting mover index 0 (MixedMover)
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:4]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.5 / random : 0.633831788319
# MixedMover selecting mover index 2 (MixedMover)
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 18 in [0:27]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 0.928571428571 / random : 0.268392085855
# MixedMover selecting mover index 0 (MixedMover)
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:3]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 0.133333333333 / random : 0.902188177267
# MixedMover selecting mover index 2 (MixedMover)
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 27 in [0:29]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 35
# Proposal probability 0.777777777778 / random : 0.887430679654
# MixedMover selecting mover index 5 (MixedMover)
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 130 in [0:146]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Finished trajectory, length: 57
# MixedMover selecting mover index 2 (MixedMover)
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 15 in [0:29]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Proposal probability 0.965517241379 / random : 0.434109309806
# MixedMover selecting mover index 3 (MixedMover)
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 7 in [0:39]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 34
# Proposal probability 0.95 / random : 0.971850012332

# %% [markdown]
# Now let's take a look at where the trajectories are after they've had a chance to equilibrate:

# %%
plt.imshow(stateAmap+stateBmap, extent=extent, cmap="Blues", interpolation='nearest', vmin=0.0, vmax=2.0, aspect='auto')
CS = plt.contour(X, Y, pes_V(X,Y), levels=np.arange(0.0, 1.5, 0.1), colors='k')
for iface in line_volume_set:
    plt.contour(X,Y, np.vectorize(CallableVolume(iface))(X,Y), colors='r', interpolation='none', levels=[0.5])
repcolordict = {0 : 'k-', 1 : 'r-', 2 : 'g-', 3 : 'b-', 4 : 'r-', 5 : 'k-'}
for sample in equilibration.globalstate:
    plt.plot(sample.trajectory.coordinates()[:,0,0], 
             sample.trajectory.coordinates()[:,0,1],
             repcolordict[sample.replica])

# %% [markdown]
# ## RETIS: Production run
#
# With everything else set up, we can set up the replica exchange movers, and reuse the other movers.

# %%
#repex_movers = mf.NeighborReplicaExchange(interface_ensemble_set)

# %% [markdown]
# We'll also set up the minus ensemble and minus move:

# %%
# minus_ensemble
# minus_move

# %% [markdown]
# Finally, we set up a production run; this is very similar to the setup for the TIS equilibration run. However, up until now, we have not used file storage; before this run we will set up a storage file. The single storage file will save all the trajectories as well as all the details of the RETIS simulation (what movers are used, the acceptance of each trial, etc.)

# %%
#all_movers = [shooting_movers, repex_movers, reversal_movers]
#production = PathSampling(interface_ensemble_set, all_movers)

# %% [markdown]
# We'll run the production calculation for 50000 MC steps.

# %%
#production.run(50000)
