# %%
# Note: in practice, one should put all the imports at the top of a Python script. 
# But for educational purposes here, I put the import immediately before usage. 
# This Python block is just to set up some plotting stuff.

# Imports for plotting
# %matplotlib inline
import opentis as paths
from toy_plot_helpers import ToyPlot
plot = ToyPlot()

# %% [markdown]
# # Setting up RETIS on a Toy Model
#
# This example shows how to set up a RETIS calculation. We do this on a simple 2D model so it can be fast enough for an interactive example, but the basic approach applies to larger systems as well. Although I'll describe everything here in terms of 2-state systems, all the ideas generalize when setting up multiple-state systems (you just need to find more initial paths).

# %% [markdown]
# ## Getting an initial path
#
# RETIS is a path sampling method: it requires that the user supply an input path for each path ensemble. This means that you must somehow generate a first input path. In general, getting the first input paths for RETIS boils down to solving two problems:
#
# 1. Getting a trajectory that samples the rare event.
# 2. Filling all the path ensembles with acceptable trajectories.
#
# Since transition paths satisfy all the path ensembles between two states, a common approach is to use the same initial path for all path ensembles (reversing it where necessary). This way, once you've solved problem 1, problem 2 is trivial.
#
# The first rare path can come from any number of sources. The obvious approach might be to find a transition path from a committor analysis, because this would give you a path that satisfies the true dynamics. However, the initial path doesn't need to satisfy the true dynamics of the system (later we will equilibrate the path ensemble anyway). This means that other approaches, such as high-temperature trajectories, can be used for the first path. One of the most widely-used methods to get an initial trajectory is to generate a transition trajectory using metadynamics. However, the downside of using paths that don't satisfy the true dynamics is that it might be harder to get them to equilibrate to the correct path ensemble. It seems that this has been more of a problem with paths from high temperature runs than with paths from metadynamics: a path from a modified potential energy surface at the correct temperature seems to equilibrate more easily than a path from the original potential energy surface at an incorrect temperature.
#
# In this example, we use a bootstrapping approach, which does create paths satisfying the true dynamics of the system. This bootstrapping is nice because it is quick and convenient, although it works best on smaller systems with less complicated transitions. It works by running normal MD to generate a path that satisfies the innermost interface, and then performing shooting moves in that interface's path ensemble until we have a path that crosses the next interface. Then we switch to the path ensemble for the next interface, and shoot until the path crossing the interface after that. The process continues until we have paths for all interfaces.

# %% [markdown]
# ### Basic system setup
#
# First we set up our system: for the toy dynamics, this involves defining a potential energy surface (PES), setting up an integrator, and giving the simulation an initial configuration. In real MD systems, the PES is handled by the combination of a topology file and a force field definition, and the initial configuration would come from a file instead of being described by hand.

# %%
from openpathsampling.toy_dynamics.toy_engine import ToyEngine
from openpathsampling.toy_dynamics.toy_integrators import LangevinBAOABIntegrator
from openpathsampling.toy_dynamics.toy_pes import Gaussian, OuterWalls

import logging.config
logging.config.fileConfig("logging.conf", disable_existing_loggers=False)

# %%
# Toy_PES supports adding/subtracting various PESs. The OuterWalls PES type gives an x^6+y^6 boundary to the system
pes = (OuterWalls([1.0, 1.0], [0.0, 0.0]) + 
       Gaussian(2.0, [1.0, 4.0], [0.0,1.0]) + 
       Gaussian(2.0, [25.0, 1.0], [0.0, -1.0])
      )
integ = LangevinBAOABIntegrator(dt=0.02, temperature=0.1, gamma=1.0)
sim = ToyEngine(#filename=None,
                options={'pes' : pes, 
                         'integ' : integ,
                         'n_frames_max' : 5000,
                         'nsteps_per_frame' : 10}
               )

sim.mass = [1.0, 1.0]
sim.current_snapshot = paths.Snapshot(coordinates=[-0.5, 0.0], velocities=[0.0,0.0])

# %% [markdown]
# Now let's take a look at our PES and our initial configuration:

# %%
plot.add_pes(pes)
plot.add_initial_condition(sim.current_snapshot)
plot.plot()

# %% [markdown]
# ### Interface setup
#
# One downside of the bootstrapping approach is that we need to have defined our interfaces before we start. However, we can always easily change our initial interface guesses.
#
# We'll consider a couple different choices of order parameter to define our interfaces. First we'll look at lines at different values of $x$. That set will be called `line_set`. Later we'll also consider circles centered on (-0.5, -0.25), with different radii. We'll call this set of interfaces `circle_set`.
#
# In both cases, we need to define the order parameter, and then we need to create a set of volumes and a set of ensembles associated with those volumes.

# %%
from openpathsampling.orderparameter import OP_Function
from openpathsampling.volume import VolumeFactory as vf
from openpathsampling.volume import LambdaVolume
from openpathsampling.trajectory import Trajectory

# WTF? This is an extremely overcomplicated OP; shouldn't be so hard!
try:
    op_line = OP_Function(name="xval", 
                          fcn=lambda snap : Trajectory([snap])[0].coordinates()[0,0])
except ValueError:
    print "xval already made"
# this defines a set of LambdaVolumes for which the minimum is -1.0 and the maximum is given in the array
line_volume_set = vf.LambdaVolumeSet(op_line, minvals=-1.0, maxvals=[-0.30, -0.25, -0.20, -0.13, -0.05, 0.0])
stateA = LambdaVolume(op_line, -1.0, -0.3)
stateB = LambdaVolume(op_line, 0.3, 1.0)

# %%
plot.add_states([stateA, stateB])
plot.add_interfaces(line_volume_set)
plot.plot()

# %% [markdown]
# In this picture, the states are marked in blue, and the interfaces are drawn as red lines. The initial configuration is still the red dot.

# %% [markdown]
# ### First innermost interface path
#
# Now we have to create an initial path. This initial path shoud exit the state, cross the first interface, and then return to the state. We'll create this path by defining a special ensemble that, propagating forward from any initial snapshot, ends when the path ends with a segment in the appropriate interface.

# %%
from opentis.ensemble import EnsembleFactory as ef
from opentis.ensemble import LengthEnsemble, InXEnsemble, OutXEnsemble, SequentialEnsemble, OptionalEnsemble, SingleFrameEnsemble

interface0 = line_volume_set[0]
interface_ensemble_set = ef.TISEnsembleSet(stateA, stateB, line_volume_set)
first_traj_ensemble = SequentialEnsemble([
    OptionalEnsemble(OutXEnsemble(stateA)),
    InXEnsemble(stateA),
    OptionalEnsemble(OutXEnsemble(stateA) & InXEnsemble(interface0)),
    OptionalEnsemble(InXEnsemble(interface0)),
    OutXEnsemble(interface0),
    OptionalEnsemble(OutXEnsemble(stateA)),
    SingleFrameEnsemble(InXEnsemble(stateA))
])

# %% [markdown]
# This ensemble is a bit complicated, but works in the general case. To understand it, we'll look at the `SequentialEnsemble` segment by segment. One preliminary point is that we need the generated path ensemble to be the same as the accepted path ensemble in this case, meaning that we must define the ensemble entirely in terms of which volumes each segment is in (i.e., using `InXEnsemble` and `OutXEnsemble`, but not `LeaveXEnsemble` or `HitXEnsemble`).
#
# Start with the first two segments: we start with an optional ensemble outside the state, and then move to an ensemble that is in the state. Since our TIS segment must start in a state, these two ensembles allow us to either start outside the state and then evolve into the state, or to start inside the state. At the end of these two segments, we have the first frame of the TIS ensemble segment, i.e., the frame inside the state that begins the TIS path.
#
# Next we have a couple of optional ensembles, followed by an ensemble requiring the segment to be outside the interface. The optional interfaces here are only important if `stateA` and `interface0` represent different volumes. If they represent the same volume (which is the case here) these optional ensembles don't matter. However, if they are different volumes, then there is a space which is outside the state but inside the interface. So the first optional interface represents that space. The next optional interface says that you must then be inside `interface0`: this is in case there is a reentry into the state before you cross the interface. Next, we require that we cross the interface. The last optional ensemble is for segments ouside the state. If there is space between the interface and the state, then after you are no longer outside the interface you might still be outside the state. Finally, the path ends with one frame in the state.
#
# Following the logic of that, any path that begins anywhere and ends with a segment satisfying the innermost TIS ensemble will be accepted by this ensemble. Furthermore, since the ensemble is defined exclusively in terms of `InXEnsemble`s and `OutXEnsemble`s, the ensemble of paths generated by forward dynamics (`can_append`) is equivalent to the accepted path ensemble.

# %%
sim.initialized = True
first_traj = sim.generate(sim.current_snapshot, [first_traj_ensemble.can_append])
# Out:
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Through frame: 70
# Through frame: 80
# Through frame: 90
# Through frame: 100
# Through frame: 110
# Through frame: 120
# Through frame: 130
# Through frame: 140
# Through frame: 150
# Through frame: 160
# Through frame: 170
# Through frame: 180
# Through frame: 190
# Through frame: 200
# Through frame: 210
# Through frame: 220
# Through frame: 230
# Through frame: 240
# Through frame: 250
# Through frame: 260
# Through frame: 270
# Through frame: 280
# Through frame: 290
# Through frame: 300
# Through frame: 310
# Through frame: 320
# Through frame: 330
# Through frame: 340
# Through frame: 350
# Through frame: 360
# Through frame: 370
# Through frame: 380
# Through frame: 390
# Through frame: 400
# Through frame: 410
# Through frame: 420
# Through frame: 430
# Through frame: 440
# Through frame: 450
# Through frame: 460
# Through frame: 470
# Through frame: 480
# Through frame: 490
# Through frame: 500
# Through frame: 510
# Through frame: 520
# Through frame: 530
# Through frame: 540
# Through frame: 550
# Through frame: 560
# Through frame: 570
# Through frame: 580
# Through frame: 590
# Through frame: 600
# Through frame: 610
# Through frame: 620
# Through frame: 630
# Finished trajectory, length: 639

# %% [markdown]
# Next we use the `Ensemble.split` function to split the trajectory we found into segments satisfying the innermost interface TIS ensemble. There is only one such segment, and so we assign the first (and only) one found to `subtraj`, which is the first trajectory satisfying the innermost TIS interface.

# %%
subtraj = interface_ensemble_set[0].split(first_traj)[0]

# %%
plot.plot(bold=[first_traj], trajectories=[subtraj])

# %% [markdown]
# Now we see how the initial path evolves on this surface. The last part of the trajectory, which satisfies the path ensemble for the innermost interface, is highlighted in red. The whole trajectory is drawn in black.

# %% [markdown]
# ### Bootstrapping
#
# The bootstrapping approach takes a single trajectory which satisfies the innermost interface, and does shooting moves until it satisfies the next ensemble. Once it satisfies the next ensemble, we start shooting from within that ensemble. We keep building up like that until all ensembles have an initial path.
#
# To do this, we need to first create the appropriate shooting movers (one for each path ensemble). This is done quickly and efficiently with a factory function.

# %%
from openpathsampling.pathmover import PathMoverFactory as mf
from openpathsampling.shooting import UniformSelector

# might be nice to get rid of these two lines somehow
from openpathsampling.pathmover import PathMover
PathMover.engine = sim

shooting_movers = mf.OneWayShootingSet(UniformSelector(), interface_ensemble_set)

# %% [markdown]
# Next we need to set up the Bootstrapping calculation:

# %%
from openpathsampling.calculation import Bootstrapping

# TODO: add storage
bootstrap = Bootstrapping(storage=None,
                          engine=sim,
                          ensembles=interface_ensemble_set,
                          movers=shooting_movers,
                          trajectory=subtraj)

# %%
for rep in bootstrap.globalstate.replica_list():
    traj = bootstrap.globalstate[rep]
    print traj, 
    if traj is not None:
        print (op_line(bootstrap.globalstate[rep]))
    else:
        print
# Out:
# Step: -1
# Replica: 0
# Trajectory: Trajectory[5]
# Ensemble: <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90>
# Details: result = None
# inputs = [Trajectory[5]]
# trial = Trajectory[5]
# mover_path = []
# mover = <opentis.pathmover.PathMover object at 0x1202ecf90>
# accepted = True
# acceptance_probability = 1.0
#
#  None

# %% [markdown]
# Now we run the bootstrapping. The number `50` means that we'll allow up to 50 shooting attempts per interface; if it takes more than that, you should probably adjust your interfaces (there's probably not much overlap for replica exchange).

# %%
bootstrap.run(300)
# Out:
# Step: 0   Ensemble: 0  failsteps = 0
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:4]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 0.25 / random : 0.541205074149
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 1   Ensemble: 0  failsteps = 1
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:4]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 0.75 / random : 0.193415781193
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 2   Ensemble: 0  failsteps = 2
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:5]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.0 / random : 0.614342837912
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 3   Ensemble: 0  failsteps = 3
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:5]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 0.5 / random : 0.228509651648
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 4   Ensemble: 0  failsteps = 4
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:9]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 0.333333333333 / random : 0.779056891347
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 5   Ensemble: 0  failsteps = 5
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 7 in [0:9]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 0.666666666667 / random : 0.904773130703
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 6   Ensemble: 0  failsteps = 6
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:9]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 0.666666666667 / random : 0.0362934297173
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 7   Ensemble: 0  failsteps = 7
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 8 in [0:13]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 1.5 / random : 0.146575863049
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 8   Ensemble: 0  failsteps = 8
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:9]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.0 / random : 0.991250153347
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 9   Ensemble: 0  failsteps = 9
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:9]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 2.66666666667 / random : 0.0394465288513
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 10   Ensemble: 0  failsteps = 10
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:4]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.0 / random : 0.484018045732
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 11   Ensemble: 0  failsteps = 11
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:4]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 0.375 / random : 0.931895737872
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 12   Ensemble: 0  failsteps = 12
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:4]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.925047276123
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 13   Ensemble: 0  failsteps = 13
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:4]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 0.214285714286 / random : 0.0855744748226
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 14   Ensemble: 0  failsteps = 14
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:15]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 2.33333333333 / random : 0.999738787523
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 15   Ensemble: 0  failsteps = 15
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:7]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.0 / random : 0.958151445087
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 16   Ensemble: 0  failsteps = 16
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 6 in [0:7]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 0.5 / random : 0.647820867028
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 17   Ensemble: 0  failsteps = 17
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:7]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 0.5 / random : 0.828547634079
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 18   Ensemble: 0  failsteps = 18
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:7]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.789026944152
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 19   Ensemble: 0  failsteps = 19
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:7]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 0.6 / random : 0.525201544781
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 20   Ensemble: 0  failsteps = 20
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:11]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 19
# Proposal probability 0.526315789474 / random : 0.791882086034
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 21   Ensemble: 0  failsteps = 21
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 10 in [0:11]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.141632302641
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 22   Ensemble: 0  failsteps = 22
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 7 in [0:11]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.11111111111 / random : 0.0290634758
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 23   Ensemble: 0  failsteps = 23
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 6 in [0:10]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.125 / random : 0.159461935864
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 24   Ensemble: 0  failsteps = 24
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 8 in [0:9]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 0.8 / random : 0.689231077739
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 25   Ensemble: 0  failsteps = 25
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:11]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 0.625 / random : 0.161517410168
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 26   Ensemble: 0  failsteps = 26
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:17]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 5.33333333333 / random : 0.38925589114
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 27   Ensemble: 0  failsteps = 27
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:4]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Proposal probability 0.176470588235 / random : 0.64704778472
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 28   Ensemble: 0  failsteps = 28
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:4]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# Proposal probability 0.12 / random : 0.931889231241
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 29   Ensemble: 0  failsteps = 29
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:4]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 35
# Proposal probability 0.0857142857143 / random : 0.887188939745
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 30   Ensemble: 0  failsteps = 30
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:4]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 34
# Proposal probability 0.0857142857143 / random : 0.286420723512
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 31   Ensemble: 0  failsteps = 31
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:4]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 29
# Proposal probability 0.103448275862 / random : 0.164450096405
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 32   Ensemble: 0  failsteps = 32
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:4]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.316721685462
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 33   Ensemble: 0  failsteps = 33
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:4]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 20
# Proposal probability 0.15 / random : 0.185699995018
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 34   Ensemble: 0  failsteps = 34
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:4]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.254426239962
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 35   Ensemble: 0  failsteps = 35
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:4]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.787508986113
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 36   Ensemble: 0  failsteps = 36
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:4]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 26
# Proposal probability 0.111111111111 / random : 0.796336562924
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 37   Ensemble: 0  failsteps = 37
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:4]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 36
# Proposal probability 0.0810810810811 / random : 0.61189852187
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 38   Ensemble: 0  failsteps = 38
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:4]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.648987953202
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 39   Ensemble: 0  failsteps = 39
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:4]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.5 / random : 0.0234139545202
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 40   Ensemble: 0  failsteps = 40
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:3]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 0.666666666667 / random : 0.704302710098
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 41   Ensemble: 0  failsteps = 41
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:3]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.686229895383
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 42   Ensemble: 0  failsteps = 42
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:3]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.42891881118
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 43   Ensemble: 0  failsteps = 43
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:3]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 16
# Proposal probability 0.125 / random : 0.285909667427
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 44   Ensemble: 0  failsteps = 44
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:3]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 20
# Proposal probability 0.1 / random : 0.990809746099
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 45   Ensemble: 0  failsteps = 45
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:3]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 31
# Proposal probability 0.0645161290323 / random : 0.132967584714
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 46   Ensemble: 0  failsteps = 46
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:3]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.738746879141
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 47   Ensemble: 0  failsteps = 47
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:3]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.377681112963
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 48   Ensemble: 0  failsteps = 48
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:3]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.634838974649
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 49   Ensemble: 0  failsteps = 49
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:3]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 20
# Proposal probability 0.1 / random : 0.938023215923
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 50   Ensemble: 0  failsteps = 50
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:3]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.0066108026909
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 51   Ensemble: 0  failsteps = 51
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:3]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 32
# Proposal probability 0.0625 / random : 0.337282262882
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 52   Ensemble: 0  failsteps = 52
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:3]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 0.0909090909091 / random : 0.281599092771
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 53   Ensemble: 0  failsteps = 53
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:3]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.558310313958
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 54   Ensemble: 0  failsteps = 54
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:3]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 20
# Proposal probability 0.1 / random : 0.76394738729
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 55   Ensemble: 0  failsteps = 55
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:3]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 19
# Proposal probability 0.105263157895 / random : 0.178032923247
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 56   Ensemble: 0  failsteps = 56
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:3]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.42752282958
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 57   Ensemble: 0  failsteps = 57
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:3]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 16
# Proposal probability 0.125 / random : 0.651893686953
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 58   Ensemble: 0  failsteps = 58
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:3]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 26
# Proposal probability 0.0769230769231 / random : 0.0279404151305
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52f90> to <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10>
# Step: 59   Ensemble: 1  failsteps = 0
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 13 in [0:27]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 1.0 / random : 0.419597256465
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60950>
# Step: 60   Ensemble: 1  failsteps = 1
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 19 in [0:27]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 1.36842105263 / random : 0.268480346881
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60950>
# Step: 61   Ensemble: 1  failsteps = 2
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 8 in [0:20]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Proposal probability 0.791666666667 / random : 0.173989968116
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60950>
# Step: 62   Ensemble: 1  failsteps = 3
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 8 in [0:25]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 0.705882352941 / random : 0.838788096057
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60950>
# Step: 63   Ensemble: 1  failsteps = 4
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 16 in [0:25]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 1.04347826087 / random : 0.567419334174
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60950>
# Step: 64   Ensemble: 1  failsteps = 5
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 9 in [0:24]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 1.21052631579 / random : 0.732549004007
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60950>
# Step: 65   Ensemble: 1  failsteps = 6
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 13 in [0:20]
# Starting trajectory
# Finished trajectory, length: 7
# Proposal probability 1.0 / random : 0.860562364714
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60950>
# Step: 66   Ensemble: 1  failsteps = 7
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 19 in [0:20]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60950>
# Step: 67   Ensemble: 1  failsteps = 8
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 17 in [0:20]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60950>
# Step: 68   Ensemble: 1  failsteps = 9
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 18 in [0:20]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 21
# Proposal probability 0.863636363636 / random : 0.644022909463
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60950>
# Step: 69   Ensemble: 1  failsteps = 10
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 16 in [0:23]
# Starting trajectory
# Finished trajectory, length: 8
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60950>
# Step: 70   Ensemble: 1  failsteps = 11
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 11 in [0:23]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Proposal probability 0.785714285714 / random : 0.895851862662
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60950>
# Step: 71   Ensemble: 1  failsteps = 12
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 12 in [0:23]
# Starting trajectory
# Finished trajectory, length: 9
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60950>
# Step: 72   Ensemble: 1  failsteps = 13
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 19 in [0:23]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60950>
# Step: 73   Ensemble: 1  failsteps = 14
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 8 in [0:23]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60950>
# Step: 74   Ensemble: 1  failsteps = 15
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 7 in [0:23]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 0.88 / random : 0.770467182643
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60950>
# Step: 75   Ensemble: 1  failsteps = 16
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 25 in [0:26]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 35
# Proposal probability 0.714285714286 / random : 0.0905692195458
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe52b10> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60950>
# Step: 76   Ensemble: 2  failsteps = 0
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 13 in [0:36]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 1.06060606061 / random : 0.495079516074
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60950> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0>
# Step: 77   Ensemble: 2  failsteps = 1
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 32 in [0:34]
# Starting trajectory
# Finished trajectory, length: 3
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60950> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0>
# Step: 78   Ensemble: 2  failsteps = 2
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 5 in [0:34]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 0.970588235294 / random : 0.481133131883
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60950> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0>
# Step: 79   Ensemble: 2  failsteps = 3
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 9 in [0:35]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 23
# Proposal probability 0.708333333333 / random : 0.561994669727
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60950> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0>
# Step: 80   Ensemble: 2  failsteps = 4
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 21 in [0:49]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 20
# Proposal probability 1.02127659574 / random : 0.605167226325
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60950> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0>
# Step: 81   Ensemble: 2  failsteps = 5
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:48]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 29
# Proposal probability 1.51612903226 / random : 0.75004580842
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60950> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0>
# Step: 82   Ensemble: 2  failsteps = 6
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 27 in [0:32]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 37
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60950> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0>
# Step: 83   Ensemble: 2  failsteps = 7
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 27 in [0:32]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# Proposal probability 1.0 / random : 0.569250480326
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60950> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0>
# Step: 84   Ensemble: 2  failsteps = 8
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 31 in [0:32]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 38
# Proposal probability 0.815789473684 / random : 0.795623501503
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60950> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0>
# Step: 85   Ensemble: 2  failsteps = 9
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 36 in [0:39]
# Starting trajectory
# Finished trajectory, length: 3
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60950> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0>
# Step: 86   Ensemble: 2  failsteps = 10
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:39]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 32
# Proposal probability 0.575757575758 / random : 0.637442299442
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60950> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0>
# Step: 87   Ensemble: 2  failsteps = 11
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:39]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 26
# Proposal probability 0.633333333333 / random : 0.181843952952
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60950> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0>
# Step: 88   Ensemble: 2  failsteps = 12
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 54 in [0:61]
# Starting trajectory
# Finished trajectory, length: 6
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60950> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0>
# Step: 89   Ensemble: 2  failsteps = 13
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 40 in [0:61]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 1.57894736842 / random : 0.440490307055
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60950> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0>
# Step: 90   Ensemble: 2  failsteps = 14
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:39]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.0 / random : 0.674948334587
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60950> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0>
# Step: 91   Ensemble: 2  failsteps = 15
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 13 in [0:39]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# Proposal probability 0.974358974359 / random : 0.0348098735766
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60950> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0>
# Step: 92   Ensemble: 2  failsteps = 16
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 28 in [0:40]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 0.866666666667 / random : 0.658589944275
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60950> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0>
# Step: 93   Ensemble: 2  failsteps = 17
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 7 in [0:46]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# Proposal probability 1.45161290323 / random : 0.598987328192
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60950> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0>
# Step: 94   Ensemble: 2  failsteps = 18
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:32]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.393230306188
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60950> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0>
# Step: 95   Ensemble: 2  failsteps = 19
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 22 in [0:32]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 33
# Proposal probability 0.738095238095 / random : 0.907837816675
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60950> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0>
# Step: 96   Ensemble: 2  failsteps = 20
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 6 in [0:32]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 38
# Proposal probability 0.492063492063 / random : 0.920472823616
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60950> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0>
# Step: 97   Ensemble: 2  failsteps = 21
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 21 in [0:32]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 0.96875 / random : 0.398429093718
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60950> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0>
# Step: 98   Ensemble: 2  failsteps = 22
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 6 in [0:33]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 34
# Proposal probability 0.533333333333 / random : 0.0380445962423
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60950> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0>
# Step: 99   Ensemble: 2  failsteps = 23
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 36 in [0:61]
# Starting trajectory
# Finished trajectory, length: 7
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60950> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0>
# Step: 100   Ensemble: 2  failsteps = 24
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 50 in [0:61]
# Starting trajectory
# Finished trajectory, length: 9
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60950> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0>
# Step: 101   Ensemble: 2  failsteps = 25
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 23 in [0:61]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 1.22448979592 / random : 0.195768179108
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60950> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0>
# Step: 102   Ensemble: 2  failsteps = 26
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 26 in [0:50]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 1.48484848485 / random : 0.617050809478
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60950> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0>
# Step: 103   Ensemble: 2  failsteps = 27
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 11 in [0:34]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60950> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0>
# Step: 104   Ensemble: 2  failsteps = 28
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 19 in [0:34]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 0.916666666667 / random : 0.284094375061
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60950> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0>
# Step: 105   Ensemble: 2  failsteps = 29
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 14 in [0:37]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 1.09090909091 / random : 0.869758652687
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60950> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0>
# Step: 106   Ensemble: 2  failsteps = 30
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 21 in [0:34]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60950> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0>
# Step: 107   Ensemble: 2  failsteps = 31
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:34]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 41
# Proposal probability 0.80487804878 / random : 0.974612740761
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60950> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0>
# Step: 108   Ensemble: 2  failsteps = 32
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 32 in [0:34]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.0 / random : 0.527227143033
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60950> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0>
# Step: 109   Ensemble: 2  failsteps = 33
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 29 in [0:34]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 24
# Proposal probability 1.17857142857 / random : 0.489074073558
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60950> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0>
# Step: 110   Ensemble: 2  failsteps = 34
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:29]
# Starting trajectory
# Finished trajectory, length: 2
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60950> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0>
# Step: 111   Ensemble: 2  failsteps = 35
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:29]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 29
# Proposal probability 0.965517241379 / random : 0.459919302599
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60950> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0>
# Step: 112   Ensemble: 2  failsteps = 36
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 26 in [0:30]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 26
# Proposal probability 1.0 / random : 0.0913726553826
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60950> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0>
# Step: 113   Ensemble: 2  failsteps = 37
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 21 in [0:30]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 0.966666666667 / random : 0.911391555929
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60950> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0>
# Step: 114   Ensemble: 2  failsteps = 38
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 13 in [0:31]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 16
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60950> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0>
# Step: 115   Ensemble: 2  failsteps = 39
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 5 in [0:31]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60950> to <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0>
# Step: 116   Ensemble: 2  failsteps = 40
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 18 in [0:31]
# ...
# Step: 538   Ensemble: 3  failsteps = 166
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:51]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 44
# Proposal probability 1.13636363636 / random : 0.270450720189
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0> to <opentis.ensemble.SequentialEnsemble object at 0x11fe71290>
# Step: 539   Ensemble: 3  failsteps = 167
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 28 in [0:45]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 32
# Proposal probability 0.916666666667 / random : 0.256201370235
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0> to <opentis.ensemble.SequentialEnsemble object at 0x11fe71290>
# Step: 540   Ensemble: 3  failsteps = 168
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 13 in [0:49]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0> to <opentis.ensemble.SequentialEnsemble object at 0x11fe71290>
# Step: 541   Ensemble: 3  failsteps = 169
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 15 in [0:49]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 28
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0> to <opentis.ensemble.SequentialEnsemble object at 0x11fe71290>
# Step: 542   Ensemble: 3  failsteps = 170
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 24 in [0:49]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 19
# Proposal probability 1.11627906977 / random : 0.441063679654
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0> to <opentis.ensemble.SequentialEnsemble object at 0x11fe71290>
# Step: 543   Ensemble: 3  failsteps = 171
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:44]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 37
# Proposal probability 0.565789473684 / random : 0.429318821879
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0> to <opentis.ensemble.SequentialEnsemble object at 0x11fe71290>
# Step: 544   Ensemble: 3  failsteps = 172
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 53 in [0:77]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 1.02702702703 / random : 0.163095433434
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0> to <opentis.ensemble.SequentialEnsemble object at 0x11fe71290>
# Step: 545   Ensemble: 3  failsteps = 173
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 8 in [0:75]
# Starting trajectory
# Finished trajectory, length: 8
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0> to <opentis.ensemble.SequentialEnsemble object at 0x11fe71290>
# Step: 546   Ensemble: 3  failsteps = 174
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 8 in [0:75]
# Starting trajectory
# Finished trajectory, length: 8
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0> to <opentis.ensemble.SequentialEnsemble object at 0x11fe71290>
# Step: 547   Ensemble: 3  failsteps = 175
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 20 in [0:75]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 23
# Proposal probability 1.7619047619 / random : 0.142714635119
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0> to <opentis.ensemble.SequentialEnsemble object at 0x11fe71290>
# Step: 548   Ensemble: 3  failsteps = 176
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 18 in [0:43]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 16
# Proposal probability 1.27272727273 / random : 0.244789554547
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0> to <opentis.ensemble.SequentialEnsemble object at 0x11fe71290>
# Step: 549   Ensemble: 3  failsteps = 177
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 17 in [0:34]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 0.970588235294 / random : 0.511752597124
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0> to <opentis.ensemble.SequentialEnsemble object at 0x11fe71290>
# Step: 550   Ensemble: 3  failsteps = 178
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 12 in [0:35]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# Proposal probability 0.723404255319 / random : 0.413758515763
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0> to <opentis.ensemble.SequentialEnsemble object at 0x11fe71290>
# Step: 551   Ensemble: 3  failsteps = 179
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 32 in [0:48]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Proposal probability 0.979166666667 / random : 0.923207705232
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0> to <opentis.ensemble.SequentialEnsemble object at 0x11fe71290>
# Step: 552   Ensemble: 3  failsteps = 180
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 20 in [0:49]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 32
# Proposal probability 0.941176470588 / random : 0.813330546761
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0> to <opentis.ensemble.SequentialEnsemble object at 0x11fe71290>
# Step: 553   Ensemble: 3  failsteps = 181
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 47 in [0:52]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 36
# Proposal probability 1.275 / random : 0.28699513483
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0> to <opentis.ensemble.SequentialEnsemble object at 0x11fe71290>
# Step: 554   Ensemble: 3  failsteps = 182
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 19 in [0:41]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 1.17647058824 / random : 0.262710272656
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0> to <opentis.ensemble.SequentialEnsemble object at 0x11fe71290>
# Step: 555   Ensemble: 3  failsteps = 183
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:35]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 34
# Proposal probability 0.515151515152 / random : 0.535642599589
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0> to <opentis.ensemble.SequentialEnsemble object at 0x11fe71290>
# Step: 556   Ensemble: 3  failsteps = 184
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:35]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 31
# Proposal probability 0.55737704918 / random : 0.736547767579
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0> to <opentis.ensemble.SequentialEnsemble object at 0x11fe71290>
# Step: 557   Ensemble: 3  failsteps = 185
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 31 in [0:35]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 1.0 / random : 0.437861694016
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0> to <opentis.ensemble.SequentialEnsemble object at 0x11fe71290>
# Step: 558   Ensemble: 3  failsteps = 186
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 8 in [0:35]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0> to <opentis.ensemble.SequentialEnsemble object at 0x11fe71290>
# Step: 559   Ensemble: 3  failsteps = 187
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 26 in [0:35]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 33
# Proposal probability 0.586206896552 / random : 0.614028771564
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0> to <opentis.ensemble.SequentialEnsemble object at 0x11fe71290>
# Step: 560   Ensemble: 3  failsteps = 188
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 29 in [0:35]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Through frame: 70
# Finished trajectory, length: 77
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0> to <opentis.ensemble.SequentialEnsemble object at 0x11fe71290>
# Step: 561   Ensemble: 3  failsteps = 189
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:35]
# Starting trajectory
# Finished trajectory, length: 2
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0> to <opentis.ensemble.SequentialEnsemble object at 0x11fe71290>
# Step: 562   Ensemble: 3  failsteps = 190
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 6 in [0:35]
# Starting trajectory
# Finished trajectory, length: 6
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0> to <opentis.ensemble.SequentialEnsemble object at 0x11fe71290>
# Step: 563   Ensemble: 3  failsteps = 191
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 9 in [0:35]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 28
# Proposal probability 0.944444444444 / random : 0.122367965698
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0> to <opentis.ensemble.SequentialEnsemble object at 0x11fe71290>
# Step: 564   Ensemble: 3  failsteps = 192
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 36 in [0:37]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.341196217454
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0> to <opentis.ensemble.SequentialEnsemble object at 0x11fe71290>
# Step: 565   Ensemble: 3  failsteps = 193
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 25 in [0:37]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 0.972972972973 / random : 0.143235651027
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0> to <opentis.ensemble.SequentialEnsemble object at 0x11fe71290>
# Step: 566   Ensemble: 3  failsteps = 194
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 31 in [0:38]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 0.973684210526 / random : 0.496749068949
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0> to <opentis.ensemble.SequentialEnsemble object at 0x11fe71290>
# Step: 567   Ensemble: 3  failsteps = 195
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 20 in [0:39]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 30
# Proposal probability 0.791666666667 / random : 0.93487860515
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0> to <opentis.ensemble.SequentialEnsemble object at 0x11fe71290>
# Step: 568   Ensemble: 3  failsteps = 196
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 9 in [0:39]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 34
# Proposal probability 0.904761904762 / random : 0.113034466226
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0> to <opentis.ensemble.SequentialEnsemble object at 0x11fe71290>
# Step: 569   Ensemble: 3  failsteps = 197
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:43]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 0.976744186047 / random : 0.765240666791
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0> to <opentis.ensemble.SequentialEnsemble object at 0x11fe71290>
# Step: 570   Ensemble: 3  failsteps = 198
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 33 in [0:44]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 28
# Proposal probability 1.13157894737 / random : 0.835977904537
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0> to <opentis.ensemble.SequentialEnsemble object at 0x11fe71290>
# Step: 571   Ensemble: 3  failsteps = 199
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:39]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 46
# Proposal probability 0.475 / random : 0.123241098612
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0> to <opentis.ensemble.SequentialEnsemble object at 0x11fe71290>
# Step: 572   Ensemble: 3  failsteps = 200
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 43 in [0:81]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 1.6 / random : 0.570141799955
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0> to <opentis.ensemble.SequentialEnsemble object at 0x11fe71290>
# Step: 573   Ensemble: 3  failsteps = 201
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 13 in [0:51]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 43
# Proposal probability 0.909090909091 / random : 0.312260419303
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe60dd0> to <opentis.ensemble.SequentialEnsemble object at 0x11fe71290>
# Step: 574   Ensemble: 4  failsteps = 0
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 12 in [0:56]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Finished trajectory, length: 60
# Proposal probability 0.533980582524 / random : 0.0566600429911
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11fe71290> to <opentis.ensemble.SequentialEnsemble object at 0x11fe71710>

# %% [markdown]
# We've stored all the trajectories we generated here; now we want to extract a path for each ensemble to use as a starting point for TIS. We'll choose to take the first path that satisfied each ensemble.

# %%
print "[ ",
for sample in bootstrap.globalstate:
    print str(sample.trajectory)+" ",
print "]"
# Out:
# [  Trajectory[4]  Trajectory[27]  Trajectory[30]  Trajectory[52]  Trajectory[57]  Trajectory[105]  ]

# %% [markdown]
# Let's go ahead and visualize where each of those trajectories are:

# %%
plot.plot([sample.trajectory for sample in bootstrap.globalstate])

# %% [markdown]
# ## Equilibration in the Path Ensemble
#
# At the end of the bootstrapping process, we have a set of paths which we can use to start TIS sampling. Before doing a production run, we should let these paths equilibrate within the ensembles. If you generate your initial path through dynamics that aren't the true dynamics (e.g., using high temperature runs or using metadynamics), this stage is **extremely** important. It's important here as well, but less so than if your initial path is non-physical.
#
# This will be an example of a "normal" TIS run, i.e., TIS without replica exchange. We will sampling using only shooter movers (the same ones defined for the bootstrapping) and path reversal movers. First we define these path reveral movers:

# %%
from opentis.pathmover import PathReversalSet
reversal_movers = PathReversalSet(interface_ensemble_set)

# %% [markdown]
# Next we define global moves: we'll set this up so that each move either does a shooting move on all replicas, or does a path reversal move on all replicas. You can similarly set it up so that each move operates on only on one replica at a time.

# %%
from opentis.pathmover import RandomChoiceMover
shooting_chooser = RandomChoiceMover(shooting_movers)
reversal_chooser = RandomChoiceMover(reversal_movers)
equilibration_movers = RandomChoiceMover([shooting_chooser, reversal_chooser])

# %% [markdown]
# Now we're ready to set up a TIS run:

# %%
from opentis.calculation import PathSampling
equilibration = PathSampling(storage=None, engine=sim, root_mover=equilibration_movers, globalstate=bootstrap.globalstate)

# %% [markdown]
# And now we run it. We'll do 200 equilibration steps.

# %%
equilibration.run(200)
# Out:
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:26]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 25 in [0:26]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.970605618319
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 70 in [0:104]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 29
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 17 in [0:26]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# Proposal probability 0.757575757576 / random : 0.935478828045
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 10 in [0:56]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Finished trajectory, length: 52
# Proposal probability 0.567010309278 / random : 0.42963798069
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 8 in [0:98]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 35
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 27 in [0:51]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 37
# Proposal probability 0.833333333333 / random : 0.583561550949
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 31 in [0:98]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 21
# Proposal probability 1.90196078431 / random : 0.368257202706
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 46 in [0:52]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 1.0 / random : 0.957360122717
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 19 in [0:52]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 43
# Proposal probability 0.68 / random : 0.675705057627
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:3]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 32
# Proposal probability 0.0625 / random : 0.487264750785
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:3]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.820614203255
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 26 in [0:104]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 35
# Proposal probability 1.71666666667 / random : 0.882392556826
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 14 in [0:29]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 1.07692307692 / random : 0.102999560049
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 38 in [0:76]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 48
# Proposal probability 0.882352941176 / random : 0.569174869556
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 19 in [0:61]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 38
# Proposal probability 0.759493670886 / random : 0.790299490554
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 14 in [0:27]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 1.0 / random : 0.948592384326
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 22 in [0:26]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 20
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 9 in [0:61]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 0.983606557377 / random : 0.148875621768
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 15 in [0:27]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Proposal probability 1.0 / random : 0.414785607423
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 8 in [0:27]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 26
# Proposal probability 0.590909090909 / random : 0.00635412712308
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 17 in [0:86]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 1.0625 / random : 0.16641728192
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 35 in [0:81]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 33
# Proposal probability 1.02564102564 / random : 0.410323821683
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 65 in [0:79]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 18 in [0:45]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 1.57142857143 / random : 0.62913423364
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 37 in [0:61]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 29
# Proposal probability 1.15384615385 / random : 0.503523457324
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 23 in [0:26]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 78 in [0:79]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 32
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 22 in [0:26]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# Proposal probability 0.520833333333 / random : 0.19856484193
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 28 in [0:49]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 36 in [0:49]
# Starting trajectory
# Finished trajectory, length: 7
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 25 in [0:62]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 41
# Proposal probability 0.792207792208 / random : 0.476455777329
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:3]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.099428490373
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 56 in [0:78]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 29
# Proposal probability 0.916666666667 / random : 0.949971429844
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 24 in [0:49]
# Starting trajectory
# Finished trajectory, length: 5
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 13 in [0:49]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 2.18181818182 / random : 0.0170640582941
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:3]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.311705126187
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 44 in [0:79]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 38
# Proposal probability 1.08333333333 / random : 0.0111413946496
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 66 in [0:73]
# Starting trajectory
# Finished trajectory, length: 7
# Proposal probability 1.0 / random : 0.173393290925
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 30 in [0:73]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 30
# Proposal probability 1.0 / random : 0.813297434797
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 12 in [0:23]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 1.22222222222 / random : 0.583399345639
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 36 in [0:73]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# Proposal probability 1.16129032258 / random : 0.127780155859
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 39 in [0:63]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 46
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 15 in [0:63]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Proposal probability 0.96875 / random : 0.555591864252
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:29]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 28
# Proposal probability 0.538461538462 / random : 0.694529112062
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:29]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 0.736842105263 / random : 0.798702965332
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 6 in [0:19]
# Starting trajectory
# Finished trajectory, length: 7
# Proposal probability 0.947368421053 / random : 0.486300785177
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 21 in [0:65]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Proposal probability 1.06666666667 / random : 0.161235704335
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 7 in [0:29]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 75 in [0:78]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 0.974683544304 / random : 0.818279580221
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 21 in [0:29]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 0.666666666667 / random : 0.274019872089
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 23 in [0:61]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 43
# Proposal probability 0.923076923077 / random : 0.11126011102
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 27 in [0:43]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 19
# Proposal probability 0.933333333333 / random : 0.419814231758
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 53 in [0:66]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 1.0 / random : 0.87596142129
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 16 in [0:20]
# Starting trajectory
# Finished trajectory, length: 5
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 45 in [0:46]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 31
# Proposal probability 1.45161290323 / random : 0.800608635071
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 32 in [0:80]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 21
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:3]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.0725584563761
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 16 in [0:53]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 37
# Proposal probability 0.712328767123 / random : 0.511548631906
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 16 in [0:80]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 69 in [0:74]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.0 / random : 0.334333977276
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 22 in [0:32]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 20
# Proposal probability 0.756097560976 / random : 0.1934847231
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 7 in [0:20]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.11764705882 / random : 0.0654495141321
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 54 in [0:80]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 35
# Proposal probability 0.897727272727 / random : 0.380657854858
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:3]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 33
# Proposal probability 0.0606060606061 / random : 0.571862148472
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 14 in [0:74]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 19
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 25 in [0:74]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 1.04285714286 / random : 0.694478640386
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 26 in [0:66]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 23
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 36 in [0:42]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 28
# Proposal probability 1.24242424242 / random : 0.341052569318
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 29 in [0:66]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 33
# Proposal probability 1.06557377049 / random : 0.251377796928
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:3]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 0.666666666667 / random : 0.103752074449
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 12 in [0:18]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 26
# Proposal probability 0.459459459459 / random : 0.128893772798
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 63 in [0:71]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 30
# Proposal probability 0.760869565217 / random : 0.509049406025
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 28 in [0:62]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 1.10909090909 / random : 0.979054701403
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:4]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.237737973007
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 17 in [0:34]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 1.1 / random : 0.0595027063277
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:4]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# Proposal probability 0.111111111111 / random : 0.690677485729
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:4]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 19
# Proposal probability 0.157894736842 / random : 0.186756153775
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 16 in [0:56]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 36 in [0:38]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 31 in [0:38]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Proposal probability 1.7619047619 / random : 0.322422176813
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 26 in [0:31]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# Proposal probability 1.03448275862 / random : 0.486420061964
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 7 in [0:30]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 1.03571428571 / random : 0.583318002391
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 20 in [0:29]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 20
# Proposal probability 1.0 / random : 0.323203248959
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 7 in [0:22]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 24
# Proposal probability 0.7 / random : 0.645980318715
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 15 in [0:89]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 29
# Proposal probability 0.862745098039 / random : 0.0813966511912
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 11 in [0:56]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 46
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)

# %% [markdown]
# Now let's take a look at where the trajectories are after they've had a chance to equilibrate:

# %%
plot.plot([sample.trajectory for sample in equilibration.globalstate])

# %% [markdown]
# ## RETIS: Production run
#
# With everything else set up, we can set up the replica exchange movers, and reuse the other movers.

# %%
from opentis.pathmover import NeighborEnsembleReplicaExchange
repex_movers = NeighborEnsembleReplicaExchange(interface_ensemble_set)
repex_chooser = RandomChoiceMover(repex_movers)

# %% [markdown]
# We'll also set up the minus ensemble and minus move:

# %%
# minus_ensemble
# minus_move

# %% [markdown]
# Finally, we set up a production run; this is very similar to the setup for the TIS equilibration run. However, up until now, we have not used file storage; before this run we will set up a storage file. The single storage file will save all the trajectories as well as all the details of the RETIS simulation (what movers are used, the acceptance of each trial, etc.)

# %%
#storage = paths.storage.Storage(
#    filename="toy_tis.nc",
#    template=sim.current_snapshot # that's an ugly hack
#)

# %%
retis_root_mover = RandomChoiceMover([shooting_chooser, reversal_chooser, repex_chooser])
production = PathSampling(storage=None, engine=sim, root_mover=retis_root_mover, globalstate=equilibration.globalstate)

# %% [markdown]
# We'll run the production calculation for 500 MC steps.

# %%
production.run(500)
# Out:
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 72 in [0:93]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 30
# Proposal probability 1.84 / random : 0.0759939761589
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:4]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 16
# Proposal probability 0.1875 / random : 0.922798965253
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 18 in [0:29]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 1.27272727273 / random : 0.489575885769
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 9 in [0:56]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 39
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 26 in [0:56]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 21
# Proposal probability 1.1 / random : 0.284904108202
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 19 in [0:103]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 34
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 13 in [0:51]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 1.06382978723 / random : 0.445029335187
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 27 in [0:51]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 23
# Proposal probability 1.02040816327 / random : 0.196684310552
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 15 in [0:23]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 1.375 / random : 0.404084108428
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 19 in [0:103]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 0.971428571429 / random : 0.00333641956561
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 7 in [0:17]
# Starting trajectory
# Finished trajectory, length: 7
# Proposal probability 1.0 / random : 0.0597251675623
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 29 in [0:31]
# Starting trajectory
# Finished trajectory, length: 2
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 41 in [0:48]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 42
# Proposal probability 0.979166666667 / random : 0.430932413451
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 8 in [0:49]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 43
# Proposal probability 0.578313253012 / random : 0.724746939277
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 20 in [0:50]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 23
# Proposal probability 0.942307692308 / random : 0.00616755682061
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:31]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 0.967741935484 / random : 0.0830441422808
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 13 in [0:53]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Proposal probability 0.928571428571 / random : 0.806785701272
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 22 in [0:32]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 0.885714285714 / random : 0.641937695759
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:36]
# Starting trajectory
# Finished trajectory, length: 2
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 10 in [0:36]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 1.06060606061 / random : 0.153663599214
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 8 in [0:17]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 0.941176470588 / random : 0.391474083514
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:4]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.5 / random : 0.925944622798
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:3]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 21
# Proposal probability 0.0952380952381 / random : 0.42965447856
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:3]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 23
# Proposal probability 0.0869565217391 / random : 0.288962964332
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:18]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.893133026073
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:3]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 19
# Proposal probability 0.105263157895 / random : 0.260571615022
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 92 in [0:106]
# Starting trajectory
# Finished trajectory, length: 7
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 21 in [0:49]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 1.14285714286 / random : 0.725500910512
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:3]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.816003732394
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 53 in [0:106]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 38
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 53 in [0:57]
# Starting trajectory
# Finished trajectory, length: 4
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 9 in [0:34]
# Starting trajectory
# Finished trajectory, length: 7
# Proposal probability 1.06451612903 / random : 0.210898111065
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 16 in [0:32]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Proposal probability 0.96875 / random : 0.304553975037
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 11 in [0:33]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 0.941176470588 / random : 0.108918860276
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 15 in [0:57]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# Proposal probability 0.823529411765 / random : 0.890805206633
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 7 in [0:43]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 0.976744186047 / random : 0.408987700413
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:3]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 19
# Proposal probability 0.105263157895 / random : 0.787538344792
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 12 in [0:18]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 1.0 / random : 0.867267299967
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 36 in [0:106]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 34
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 39 in [0:57]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# Proposal probability 1.27272727273 / random : 0.49658544597
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 23 in [0:35]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 1.13333333333 / random : 0.450708647748
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 6 in [0:18]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.0625 / random : 0.779858790201
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 16 in [0:17]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# Proposal probability 0.592592592593 / random : 0.503517795179
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 37 in [0:44]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 0.977272727273 / random : 0.154041664937
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:106]
# Starting trajectory
# Finished trajectory, length: 4
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 26 in [0:45]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 30
# Proposal probability 0.8 / random : 0.0488350985276
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:3]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 0.0909090909091 / random : 0.250029764999
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 29 in [0:106]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:3]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.319723172485
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 7 in [0:56]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 40
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 13 in [0:31]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 1.07142857143 / random : 0.888735320414
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 32 in [0:106]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Proposal probability 1.16666666667 / random : 0.936971243327
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:3]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 21
# Proposal probability 0.0952380952381 / random : 0.525870712775
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 38 in [0:45]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 0.95652173913 / random : 0.550080216454
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 16 in [0:47]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 26
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 25 in [0:56]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 40
# Proposal probability 0.785714285714 / random : 0.0309480178393
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 26 in [0:29]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.03703703704 / random : 0.384656433565
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 21 in [0:91]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 1.03448275862 / random : 0.84874749839
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:3]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 23
# Proposal probability 0.0869565217391 / random : 0.436117958016
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 23 in [0:28]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 24
# Proposal probability 0.964285714286 / random : 0.57133041202
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 5 in [0:29]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 34
# Proposal probability 0.736842105263 / random : 0.0954118425383
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 26 in [0:39]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 1.05555555556 / random : 0.48588762372
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 26 in [0:28]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 24
# Proposal probability 1.08 / random : 0.0160621750497
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:26]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 49
# Proposal probability 0.357142857143 / random : 0.501989711828
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 43 in [0:47]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 32 in [0:47]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Finished trajectory, length: 68
# Proposal probability 0.560975609756 / random : 0.303754881481
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 33 in [0:83]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 26
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:3]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Proposal probability 0.133333333333 / random : 0.0524793758915
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 20 in [0:26]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 21
# Proposal probability 0.625 / random : 0.937955488334
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:71]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.277095539803
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 5 in [0:26]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.0 / random : 0.723967883101
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 70 in [0:71]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.0740691761373
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 28 in [0:88]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 26
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 11 in [0:83]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 28
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 7 in [0:83]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 34
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 24 in [0:26]
# Starting trajectory
# Finished trajectory, length: 3
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 28 in [0:83]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 32
# Proposal probability 0.953488372093 / random : 0.686971262463
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 6 in [0:16]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 1.0 / random : 0.740408743474
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 16 in [0:88]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 31
# Proposal probability 0.852941176471 / random : 0.247304268313
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:16]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.0 / random : 0.173351284207
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 13 in [0:16]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 1.07142857143 / random : 0.656153831886
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 38 in [0:71]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 1.27272727273 / random : 0.0202762572464
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 19 in [0:37]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 1.0 / random : 0.0134856421193
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:15]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 0.933333333333 / random : 0.119043693083
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 25 in [0:26]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 34
# Proposal probability 0.735294117647 / random : 0.802408782006
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:26]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 23
# Proposal probability 1.0 / random : 0.811435330497
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:26]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 32
# Proposal probability 0.735294117647 / random : 0.830264506474
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# ...
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 10 in [0:44]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 24
# Proposal probability 1.30303030303 / random : 0.774060858314
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 59 in [0:78]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 29
# Proposal probability 0.885057471264 / random : 0.589308127761
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 13 in [0:43]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 1.0 / random : 0.789220882289
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 9 in [0:34]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 1.03125 / random : 0.675242041668
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 90 in [0:123]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 36
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 22 in [0:33]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 1.06666666667 / random : 0.649018383274
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 14 in [0:31]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 1.0 / random : 0.555468565712
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:27]
# Starting trajectory
# Finished trajectory, length: 7
# Proposal probability 3.71428571429 / random : 0.047670941139
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 6 in [0:31]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 24
# Proposal probability 0.625 / random : 0.443682296595
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 78 in [0:88]
# Starting trajectory
# Finished trajectory, length: 7
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 31 in [0:49]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 1.71428571429 / random : 0.124261582272
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 5 in [0:123]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 30
# Proposal probability 0.829931972789 / random : 0.303961570471
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 26 in [0:148]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 37
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:8]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.220954604556
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:59]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 33
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 23 in [0:43]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 1.05 / random : 0.211350258118
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 6 in [0:8]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.75 / random : 0.547754831317
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 6 in [0:148]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 41
# Proposal probability 3.19565217391 / random : 0.623587225135
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 19 in [0:41]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 1.6 / random : 0.413985429752
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 45 in [0:59]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 39
# Proposal probability 0.698795180723 / random : 0.447358221487
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 25 in [0:84]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 30
# Proposal probability 0.943181818182 / random : 0.0764920213996
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:5]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 35
# Proposal probability 0.114285714286 / random : 0.633379071694
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (ReplicaExchangeMover)
