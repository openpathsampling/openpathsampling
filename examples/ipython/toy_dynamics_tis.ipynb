# %%
# Note: in practice, one should put all the imports at the top of a Python script. 
# But for educational purposes here, I put the import immediately before usage. 
# This Python block is just to set up some plotting stuff.

# Imports for plotting
# %matplotlib inline
import openpathsampling as paths
import numpy as np
from toy_plot_helpers import ToyPlot
plot = ToyPlot()

# %% [markdown]
# # Setting up RETIS on a Toy Model
#
# This example shows how to set up a RETIS calculation. We do this on a simple 2D model so it can be fast enough for an interactive example, but the basic approach applies to larger systems as well. Although I'll describe everything here in terms of 2-state systems, all the ideas generalize when setting up multiple-state systems (you just need to find more initial paths).

# %% [markdown]
# ## Getting an initial path
#
# RETIS is a path sampling method: it requires that the user supply an input path for each path ensemble. This means that you must somehow generate a first input path. In general, getting the first input paths for RETIS boils down to solving two problems:
#
# 1. Getting a trajectory that samples the rare event.
# 2. Filling all the path ensembles with acceptable trajectories.
#
# Since transition paths satisfy all the path ensembles between two states, a common approach is to use the same initial path for all path ensembles (reversing it where necessary). This way, once you've solved problem 1, problem 2 is trivial.
#
# The first rare path can come from any number of sources. The obvious approach might be to find a transition path from a committor analysis, because this would give you a path that satisfies the true dynamics. However, the initial path doesn't need to satisfy the true dynamics of the system (later we will equilibrate the path ensemble anyway). This means that other approaches, such as high-temperature trajectories, can be used for the first path. One of the most widely-used methods to get an initial trajectory is to generate a transition trajectory using metadynamics. However, the downside of using paths that don't satisfy the true dynamics is that it might be harder to get them to equilibrate to the correct path ensemble. It seems that this has been more of a problem with paths from high temperature runs than with paths from metadynamics: a path from a modified potential energy surface at the correct temperature seems to equilibrate more easily than a path from the original potential energy surface at an incorrect temperature.
#
# In this example, we use a bootstrapping approach, which does create paths satisfying the true dynamics of the system. This bootstrapping is nice because it is quick and convenient, although it works best on smaller systems with less complicated transitions. It works by running normal MD to generate a path that satisfies the innermost interface, and then performing shooting moves in that interface's path ensemble until we have a path that crosses the next interface. Then we switch to the path ensemble for the next interface, and shoot until the path crossing the interface after that. The process continues until we have paths for all interfaces.

# %% [markdown]
# ### Basic system setup
#
# First we set up our system: for the toy dynamics, this involves defining a potential energy surface (PES), setting up an integrator, and giving the simulation an initial configuration. In real MD systems, the PES is handled by the combination of a topology file and a force field definition, and the initial configuration would come from a file instead of being described by hand.

# %%
from openpathsampling.toy_dynamics.toy_engine import ToyEngine
from openpathsampling.toy_dynamics.toy_integrators import LangevinBAOABIntegrator
from openpathsampling.toy_dynamics.toy_pes import Gaussian, OuterWalls

import logging.config
logging.config.fileConfig("logging.conf", disable_existing_loggers=False)

# %% [markdown]
# ### Set up the toy system
# This includes the potential energy surface (PES), and an initial configuration

# %%
# Toy_PES supports adding/subtracting various PESs. The OuterWalls PES type gives an x^6+y^6 boundary to the system
pes = (OuterWalls([1.0, 1.0], [0.0, 0.0]) + 
       Gaussian(2.0, [1.0, 4.0], [0.0,1.0]) + 
       Gaussian(2.0, [25.0, 1.0], [0.0, -1.0])
      )
topology=paths.ToyTopology(
    n_spatial = 2,
    masses =[1.0, 1.0],
    pes = pes
)
initial_snapshot = paths.Snapshot(
    coordinates=np.array([[-0.5, 0.0]]), 
    velocities=np.array([[0.0,0.0]]),
    potential_energy = 0.0, # Important to set energies dimensionless otherwise kcal/mol is default
    kinetic_energy = 0.0,
    topology=topology
)

# %% [markdown]
# ### Setup engine

# %%
integ = LangevinBAOABIntegrator(dt=0.02, temperature=0.1, gamma=1.0)
options={'integ' : integ,
         'n_frames_max' : 5000,
         'nsteps_per_frame' : 10
        }
sim = ToyEngine(
        options=options,
        template=initial_snapshot
)

sim.current_snapshot = initial_snapshot

# %% [markdown]
# Now let's take a look at our PES and our initial configuration:

# %%
plot.add_pes(pes)
plot.add_initial_condition(sim.current_snapshot)
plot.plot()

# %% [markdown]
# ### Interface setup
#
# One downside of the bootstrapping approach is that we need to have defined our interfaces before we start. However, we can always easily change our initial interface guesses.
#
# We'll consider a couple different choices of order parameter to define our interfaces. First we'll look at lines at different values of $x$. That set will be called `line_set`. Later we'll also consider circles centered on (-0.5, -0.25), with different radii. We'll call this set of interfaces `circle_set`.
#
# In both cases, we need to define the order parameter, and then we need to create a set of volumes and a set of ensembles associated with those volumes.

# %%
from openpathsampling.orderparameter import OP_Function
from openpathsampling.volume import VolumeFactory as vf
from openpathsampling.volume import LambdaVolume
from openpathsampling.trajectory import Trajectory

try:
    op_line = OP_Function(name="xval", 
                          fcn=lambda snap : snap.coordinates[0,0])
except ValueError:
    print "xval already made"
# this defines a set of LambdaVolumes for which the minimum is -1.0 and the maximum is given in the array
line_volume_set = vf.LambdaVolumeSet(op_line, minvals=-1.0, maxvals=[-0.30, -0.25, -0.20, -0.13, -0.05, 0.0])
stateA = LambdaVolume(op_line, -1.0, -0.3)
stateB = LambdaVolume(op_line, 0.3, 1.0)

# %%
plot.add_states([stateA, stateB])
plot.add_interfaces(line_volume_set)
plot.plot()

# %% [markdown]
# In this picture, the states are marked in blue, and the interfaces are drawn as red lines. The initial configuration is still the red dot.

# %% [markdown]
# ### First innermost interface path
#
# Now we have to create an initial path. This initial path shoud exit the state, cross the first interface, and then return to the state. We'll create this path by defining a special ensemble that, propagating forward from any initial snapshot, ends when the path ends with a segment in the appropriate interface.

# %%
from openpathsampling.ensemble import EnsembleFactory as ef
from openpathsampling.ensemble import LengthEnsemble, InXEnsemble, OutXEnsemble, SequentialEnsemble, OptionalEnsemble, SingleFrameEnsemble

interface0 = line_volume_set[0]
interface_ensemble_set = ef.TISEnsembleSet(stateA, stateB, line_volume_set)
first_traj_ensemble = SequentialEnsemble([
    OptionalEnsemble(OutXEnsemble(stateA)),
    InXEnsemble(stateA),
    OptionalEnsemble(OutXEnsemble(stateA) & InXEnsemble(interface0)),
    OptionalEnsemble(InXEnsemble(interface0)),
    OutXEnsemble(interface0),
    OptionalEnsemble(OutXEnsemble(stateA)),
    SingleFrameEnsemble(InXEnsemble(stateA))
])

# %% [markdown]
# This ensemble is a bit complicated, but works in the general case. To understand it, we'll look at the `SequentialEnsemble` segment by segment. One preliminary point is that we need the generated path ensemble to be the same as the accepted path ensemble in this case, meaning that we must define the ensemble entirely in terms of which volumes each segment is in (i.e., using `InXEnsemble` and `OutXEnsemble`, but not `LeaveXEnsemble` or `HitXEnsemble`).
#
# Start with the first two segments: we start with an optional ensemble outside the state, and then move to an ensemble that is in the state. Since our TIS segment must start in a state, these two ensembles allow us to either start outside the state and then evolve into the state, or to start inside the state. At the end of these two segments, we have the first frame of the TIS ensemble segment, i.e., the frame inside the state that begins the TIS path.
#
# Next we have a couple of optional ensembles, followed by an ensemble requiring the segment to be outside the interface. The optional interfaces here are only important if `stateA` and `interface0` represent different volumes. If they represent the same volume (which is the case here) these optional ensembles don't matter. However, if they are different volumes, then there is a space which is outside the state but inside the interface. So the first optional interface represents that space. The next optional interface says that you must then be inside `interface0`: this is in case there is a reentry into the state before you cross the interface. Next, we require that we cross the interface. The last optional ensemble is for segments ouside the state. If there is space between the interface and the state, then after you are no longer outside the interface you might still be outside the state. Finally, the path ends with one frame in the state.
#
# Following the logic of that, any path that begins anywhere and ends with a segment satisfying the innermost TIS ensemble will be accepted by this ensemble. Furthermore, since the ensemble is defined exclusively in terms of `InXEnsemble`s and `OutXEnsemble`s, the ensemble of paths generated by forward dynamics (`can_append`) is equivalent to the accepted path ensemble.

# %%
sim.initialized = True
first_traj = sim.generate(sim.current_snapshot, [first_traj_ensemble.can_append])
# Out:
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Through frame: 70
# Through frame: 80
# Through frame: 90
# Through frame: 100
# Through frame: 110
# Through frame: 120
# Through frame: 130
# Through frame: 140
# Through frame: 150
# Through frame: 160
# Through frame: 170
# Through frame: 180
# Through frame: 190
# Through frame: 200
# Through frame: 210
# Through frame: 220
# Through frame: 230
# Through frame: 240
# Through frame: 250
# Through frame: 260
# Through frame: 270
# Through frame: 280
# Through frame: 290
# Through frame: 300
# Through frame: 310
# Through frame: 320
# Through frame: 330
# Through frame: 340
# Through frame: 350
# Through frame: 360
# Through frame: 370
# Through frame: 380
# Through frame: 390
# Through frame: 400
# Through frame: 410
# Through frame: 420
# Through frame: 430
# Through frame: 440
# Through frame: 450
# Through frame: 460
# Through frame: 470
# Through frame: 480
# Through frame: 490
# Through frame: 500
# Through frame: 510
# Through frame: 520
# Through frame: 530
# Through frame: 540
# Through frame: 550
# Through frame: 560
# Through frame: 570
# Through frame: 580
# Through frame: 590
# Through frame: 600
# Through frame: 610
# Through frame: 620
# Through frame: 630
# Through frame: 640
# Through frame: 650
# Through frame: 660
# Through frame: 670
# Through frame: 680
# Through frame: 690
# Through frame: 700
# Through frame: 710
# Through frame: 720
# Through frame: 730
# Through frame: 740
# Through frame: 750
# Through frame: 760
# Through frame: 770
# Through frame: 780
# Through frame: 790
# Through frame: 800
# Through frame: 810
# Through frame: 820
# Through frame: 830
# Through frame: 840
# Through frame: 850
# Finished trajectory, length: 852

# %% [markdown]
# Next we use the `Ensemble.split` function to split the trajectory we found into segments satisfying the innermost interface TIS ensemble. There is only one such segment, and so we assign the first (and only) one found to `subtraj`, which is the first trajectory satisfying the innermost TIS interface.

# %%
subtraj = interface_ensemble_set[0].split(first_traj)[0]

# %%
plot.plot(bold=[first_traj], trajectories=[subtraj])

# %% [markdown]
# Now we see how the initial path evolves on this surface. The last part of the trajectory, which satisfies the path ensemble for the innermost interface, is highlighted in red. The whole trajectory is drawn in black.

# %% [markdown]
# ### Bootstrapping
#
# The bootstrapping approach takes a single trajectory which satisfies the innermost interface, and does shooting moves until it satisfies the next ensemble. Once it satisfies the next ensemble, we start shooting from within that ensemble. We keep building up like that until all ensembles have an initial path.
#
# To do this, we need to first create the appropriate shooting movers (one for each path ensemble). This is done quickly and efficiently with a factory function.

# %%
from openpathsampling.pathmover import PathMoverFactory as mf
from openpathsampling.shooting import UniformSelector

# might be nice to get rid of these two lines somehow
from openpathsampling.pathmover import PathMover
PathMover.engine = sim

shooting_movers = mf.OneWayShootingSet(UniformSelector(), interface_ensemble_set)

# %% [markdown]
# Next we need to set up the Bootstrapping calculation:

# %%
from openpathsampling.calculation import Bootstrapping

bootstrap = Bootstrapping(storage=None,
                          engine=sim,
                          ensembles=interface_ensemble_set,
                          movers=shooting_movers,
                          trajectory=subtraj)

# %% [markdown]
# Now we run the bootstrapping. The number `50` means that we'll allow up to 50 shooting attempts per interface; if it takes more than that, you should probably adjust your interfaces (there's probably not much overlap for replica exchange).

# %%
bootstrap.run(500)
# Out:
# Step: 0   Ensemble: 0  failsteps = 0
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:10]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.0 / random : 0.42460240004
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 1   Ensemble: 0  failsteps = 1
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 6 in [0:10]
# Starting trajectory
# Finished trajectory, length: 7
# Proposal probability 0.75 / random : 0.50418875008
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 2   Ensemble: 0  failsteps = 2
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 5 in [0:13]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.33333333333 / random : 0.616541385242
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 3   Ensemble: 0  failsteps = 3
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:10]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.0 / random : 0.135548922355
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 4   Ensemble: 0  failsteps = 4
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 6 in [0:10]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 1.0 / random : 0.550248472618
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 5   Ensemble: 0  failsteps = 5
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:10]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.492470212884
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 6   Ensemble: 0  failsteps = 6
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 4 in [0:10]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 0.6 / random : 0.135999874096
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 7   Ensemble: 0  failsteps = 7
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 12 in [0:16]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.07142857143 / random : 0.927726985094
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 8   Ensemble: 0  failsteps = 8
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:15]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 23
# Proposal probability 0.608695652174 / random : 0.275076496378
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 9   Ensemble: 0  failsteps = 9
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 13 in [0:24]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 1.09523809524 / random : 0.227068762853
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 10   Ensemble: 0  failsteps = 10
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 5 in [0:22]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 1.05 / random : 0.417401309943
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 11   Ensemble: 0  failsteps = 11
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 19 in [0:21]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.0 / random : 0.800956702784
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 12   Ensemble: 0  failsteps = 12
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 15 in [0:21]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 1.53846153846 / random : 0.0166684273544
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 13   Ensemble: 0  failsteps = 13
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:14]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.682274349471
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 14   Ensemble: 0  failsteps = 14
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:14]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 0.565217391304 / random : 0.29982981591
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 15   Ensemble: 0  failsteps = 15
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 14 in [0:24]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.64285714286 / random : 0.682681217312
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 16   Ensemble: 0  failsteps = 16
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 14 in [0:15]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 1.27272727273 / random : 0.281913079888
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 17   Ensemble: 0  failsteps = 17
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:12]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.568592057642
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 18   Ensemble: 0  failsteps = 18
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 8 in [0:12]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 0.916666666667 / random : 0.266369869145
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 19   Ensemble: 0  failsteps = 19
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 6 in [0:13]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 0.705882352941 / random : 0.26897727378
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 20   Ensemble: 0  failsteps = 20
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 16 in [0:18]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.0 / random : 0.0304892806275
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 21   Ensemble: 0  failsteps = 21
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 13 in [0:18]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 2.125 / random : 0.115545777373
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 22   Ensemble: 0  failsteps = 22
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 5 in [0:9]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 0.8 / random : 0.613380013828
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 23   Ensemble: 0  failsteps = 23
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 5 in [0:11]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.11111111111 / random : 0.25415082096
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 24   Ensemble: 0  failsteps = 24
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 6 in [0:10]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 1.28571428571 / random : 0.934912076411
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 25   Ensemble: 0  failsteps = 25
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:8]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Proposal probability 0.35 / random : 0.722570693782
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 26   Ensemble: 0  failsteps = 26
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 7 in [0:8]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 0.538461538462 / random : 0.325435177007
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 27   Ensemble: 0  failsteps = 27
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 11 in [0:14]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 1.08333333333 / random : 0.126121885524
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 28   Ensemble: 0  failsteps = 28
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 7 in [0:13]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 0.705882352941 / random : 0.603389810461
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 29   Ensemble: 0  failsteps = 29
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:18]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.812725815937
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 30   Ensemble: 0  failsteps = 30
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 9 in [0:18]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 1.21428571429 / random : 0.280297429446
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 31   Ensemble: 0  failsteps = 31
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 6 in [0:15]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 1.27272727273 / random : 0.286148807795
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 32   Ensemble: 0  failsteps = 32
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 7 in [0:12]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 0.5 / random : 0.709440899735
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 33   Ensemble: 0  failsteps = 33
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 10 in [0:12]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 0.916666666667 / random : 0.62172971099
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 34   Ensemble: 0  failsteps = 34
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 11 in [0:13]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.09090909091 / random : 0.857335166906
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 35   Ensemble: 0  failsteps = 35
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:12]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 0.44 / random : 0.901099255485
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 36   Ensemble: 0  failsteps = 36
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 9 in [0:12]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 0.916666666667 / random : 0.0577134032566
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 37   Ensemble: 0  failsteps = 37
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 8 in [0:13]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.33333333333 / random : 0.729321629203
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 38   Ensemble: 0  failsteps = 38
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 9 in [0:10]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.375075440256
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 39   Ensemble: 0  failsteps = 39
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 9 in [0:10]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.0841259151058
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 40   Ensemble: 0  failsteps = 40
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:10]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 3.0 / random : 0.49009511126
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 41   Ensemble: 0  failsteps = 41
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:4]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.36197501955
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 42   Ensemble: 0  failsteps = 42
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:4]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 0.157894736842 / random : 0.672617851451
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 43   Ensemble: 0  failsteps = 43
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:4]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.252214700094
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 44   Ensemble: 0  failsteps = 44
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:4]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 0.230769230769 / random : 0.193532751995
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 45   Ensemble: 0  failsteps = 45
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 5 in [0:14]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.18181818182 / random : 0.988987134104
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 46   Ensemble: 0  failsteps = 46
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 11 in [0:12]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 5.5 / random : 0.767285870716
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 47   Ensemble: 0  failsteps = 47
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:3]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 2.0 / random : 0.579351079834
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 48   Ensemble: 0  failsteps = 48
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:2]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.442444981363
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 49   Ensemble: 0  failsteps = 49
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:2]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.655512137151
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 50   Ensemble: 0  failsteps = 50
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:2]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.629127448736
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 51   Ensemble: 0  failsteps = 51
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:2]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 19
# Proposal probability 0.0526315789474 / random : 0.639517616628
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 52   Ensemble: 0  failsteps = 52
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:2]
# Starting trajectory
# Finished trajectory, length: 7
# Proposal probability 0.142857142857 / random : 0.294664342214
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 53   Ensemble: 0  failsteps = 53
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:2]
# Starting trajectory
# Finished trajectory, length: 7
# Proposal probability 0.142857142857 / random : 0.46874271889
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 54   Ensemble: 0  failsteps = 54
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:2]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 0.0833333333333 / random : 0.338555399654
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 55   Ensemble: 0  failsteps = 55
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:2]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.99824753739
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 56   Ensemble: 0  failsteps = 56
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:2]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.711755669394
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 57   Ensemble: 0  failsteps = 57
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:2]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.382265845016
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 58   Ensemble: 0  failsteps = 58
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:2]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.914422591724
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 59   Ensemble: 0  failsteps = 59
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:2]
# Starting trajectory
# Finished trajectory, length: 7
# Proposal probability 0.142857142857 / random : 0.373175273129
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 60   Ensemble: 0  failsteps = 60
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:2]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 0.5 / random : 0.751050841553
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 61   Ensemble: 0  failsteps = 61
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:2]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.913869280369
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 62   Ensemble: 0  failsteps = 62
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:2]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.733197850691
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 63   Ensemble: 0  failsteps = 63
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:2]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.459862086958
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 64   Ensemble: 0  failsteps = 64
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:2]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 0.125 / random : 0.659149158072
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 65   Ensemble: 0  failsteps = 65
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:2]
# Starting trajectory
# Finished trajectory, length: 7
# Proposal probability 0.142857142857 / random : 0.894343577216
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 66   Ensemble: 0  failsteps = 66
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:2]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 0.166666666667 / random : 0.45105248302
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 67   Ensemble: 0  failsteps = 67
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:2]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.086359115037
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 68   Ensemble: 0  failsteps = 68
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:2]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.61561476814
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 69   Ensemble: 0  failsteps = 69
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:2]
# Starting trajectory
# Finished trajectory, length: 7
# Proposal probability 0.142857142857 / random : 0.461568400865
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 70   Ensemble: 0  failsteps = 70
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:2]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 0.25 / random : 0.552173029236
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 71   Ensemble: 0  failsteps = 71
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:2]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 20
# Proposal probability 0.05 / random : 0.77473740721
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 72   Ensemble: 0  failsteps = 72
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:2]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 0.0833333333333 / random : 0.610811527736
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 73   Ensemble: 0  failsteps = 73
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:2]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.258377038776
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 74   Ensemble: 0  failsteps = 74
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:2]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.642417448377
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 75   Ensemble: 0  failsteps = 75
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:2]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.89382108752
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 76   Ensemble: 0  failsteps = 76
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:2]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.221409331513
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 77   Ensemble: 0  failsteps = 77
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:2]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 0.166666666667 / random : 0.835488870645
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 78   Ensemble: 0  failsteps = 78
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:2]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.665220181184
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 79   Ensemble: 0  failsteps = 79
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:2]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 0.166666666667 / random : 0.910825443886
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 80   Ensemble: 0  failsteps = 80
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:2]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 0.111111111111 / random : 0.629933999801
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 81   Ensemble: 0  failsteps = 81
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:2]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 0.111111111111 / random : 0.671507811744
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 82   Ensemble: 0  failsteps = 82
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:2]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 0.111111111111 / random : 0.0379378489101
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 83   Ensemble: 0  failsteps = 83
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 5 in [0:10]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 0.9 / random : 0.82477439852
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 84   Ensemble: 0  failsteps = 84
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 5 in [0:11]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.0 / random : 0.14139985164
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 85   Ensemble: 0  failsteps = 85
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 6 in [0:11]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 0.666666666667 / random : 0.829281494314
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 86   Ensemble: 0  failsteps = 86
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:11]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 0.454545454545 / random : 0.82202163344
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 87   Ensemble: 0  failsteps = 87
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 7 in [0:11]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.66666666667 / random : 0.155441589527
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 88   Ensemble: 0  failsteps = 88
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 5 in [0:7]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.0 / random : 0.28114041925
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 89   Ensemble: 0  failsteps = 89
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 5 in [0:7]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 0.857142857143 / random : 0.0817818127809
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 90   Ensemble: 0  failsteps = 90
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:8]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.16666666667 / random : 0.114730635604
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 91   Ensemble: 0  failsteps = 91
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 4 in [0:7]
# Starting trajectory
# Finished trajectory, length: 7
# Proposal probability 0.6 / random : 0.962599080567
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 92   Ensemble: 0  failsteps = 92
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:7]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 0.428571428571 / random : 0.0138375672612
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 93   Ensemble: 0  failsteps = 93
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 12 in [0:15]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.0 / random : 0.871156625259
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 94   Ensemble: 0  failsteps = 94
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 4 in [0:15]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 0.933333333333 / random : 0.397239371485
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 95   Ensemble: 0  failsteps = 95
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 7 in [0:16]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 0.789473684211 / random : 0.83218823601
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 96   Ensemble: 0  failsteps = 96
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:16]
# Starting trajectory
# Finished trajectory, length: 7
# Proposal probability 1.875 / random : 0.882700742784
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 97   Ensemble: 0  failsteps = 97
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:9]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 0.666666666667 / random : 0.180554462792
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 98   Ensemble: 0  failsteps = 98
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 7 in [0:13]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.5 / random : 0.351678599035
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 99   Ensemble: 0  failsteps = 99
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:9]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 2.0 / random : 0.565687408172
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 100   Ensemble: 0  failsteps = 100
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:5]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.7229315895
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 101   Ensemble: 0  failsteps = 101
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:5]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.0 / random : 0.702105830244
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 102   Ensemble: 0  failsteps = 102
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:5]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.801702901511
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 103   Ensemble: 0  failsteps = 103
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:5]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.0 / random : 0.859075413163
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 104   Ensemble: 0  failsteps = 104
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:5]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 2.0 / random : 0.484979686085
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 105   Ensemble: 0  failsteps = 105
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:3]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 0.5 / random : 0.857307869553
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 106   Ensemble: 0  failsteps = 106
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:3]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 0.4 / random : 0.0660306076688
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117987410> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12442a7d0>
# Step: 107   Ensemble: 0  failsteps = 107
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:6]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.25 / random : 0.646949750597
# ...
# Step: 477   Ensemble: 3  failsteps = 156
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 12 in [0:32]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Finished trajectory, length: 60
# Proposal probability 0.392405063291 / random : 0.0903841126439
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x124439f90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a450>
# Step: 478   Ensemble: 4  failsteps = 0
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 41 in [0:80]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 26
# Proposal probability 1.19696969697 / random : 0.847535076768
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a8d0>
# Step: 479   Ensemble: 4  failsteps = 1
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 34 in [0:67]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 35
# Proposal probability 0.985074626866 / random : 0.743141872473
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a8d0>
# Step: 480   Ensemble: 4  failsteps = 2
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 56 in [0:68]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Finished trajectory, length: 57
# Proposal probability 0.985294117647 / random : 0.775947929623
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a8d0>
# Step: 481   Ensemble: 4  failsteps = 3
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 64 in [0:69]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 28
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a8d0>
# Step: 482   Ensemble: 4  failsteps = 4
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 22 in [0:69]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 37
# Proposal probability 0.819277108434 / random : 0.970438544613
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a8d0>
# Step: 483   Ensemble: 4  failsteps = 5
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 64 in [0:69]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.0 / random : 0.158773276633
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a8d0>
# Step: 484   Ensemble: 4  failsteps = 6
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 50 in [0:69]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 32
# Proposal probability 0.83950617284 / random : 0.782703980252
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a8d0>
# Step: 485   Ensemble: 4  failsteps = 7
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 25 in [0:82]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# Proposal probability 1.0 / random : 0.952993036081
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a8d0>
# Step: 486   Ensemble: 4  failsteps = 8
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 39 in [0:82]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 42
# Proposal probability 0.964285714286 / random : 0.115617463061
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a8d0>
# Step: 487   Ensemble: 4  failsteps = 9
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 28 in [0:85]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 38
# Proposal probability 1.29230769231 / random : 0.1899882439
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a8d0>
# Step: 488   Ensemble: 4  failsteps = 10
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 40 in [0:66]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Finished trajectory, length: 55
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a8d0>
# Step: 489   Ensemble: 4  failsteps = 11
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 13 in [0:66]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 33
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a8d0>
# Step: 490   Ensemble: 4  failsteps = 12
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 14 in [0:66]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a8d0>
# Step: 491   Ensemble: 4  failsteps = 13
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 34 in [0:66]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Finished trajectory, length: 59
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a8d0>
# Step: 492   Ensemble: 4  failsteps = 14
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 30 in [0:66]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 34
# Proposal probability 0.942028985507 / random : 0.857331094848
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a8d0>
# Step: 493   Ensemble: 4  failsteps = 15
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 24 in [0:70]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 40
# Proposal probability 0.811764705882 / random : 0.268919739379
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a8d0>
# Step: 494   Ensemble: 4  failsteps = 16
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 53 in [0:86]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 26
# Proposal probability 1.08974358974 / random : 0.653147651275
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a8d0>
# Step: 495   Ensemble: 4  failsteps = 17
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 44 in [0:79]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 32
# Proposal probability 1.18181818182 / random : 0.928908276807
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a8d0>
# Step: 496   Ensemble: 4  failsteps = 18
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 58 in [0:67]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 38
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a8d0>
# Step: 497   Ensemble: 4  failsteps = 19
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 39 in [0:67]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 28
# Proposal probability 1.0 / random : 0.543747736376
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a8d0>
# Step: 498   Ensemble: 4  failsteps = 20
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 63 in [0:67]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 1.0 / random : 0.383399498261
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a8d0>
# Step: 499   Ensemble: 4  failsteps = 21
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 54 in [0:67]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 19
# Proposal probability 0.916666666667 / random : 0.576686952871
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a8d0>
# Step: 500   Ensemble: 4  failsteps = 22
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 41 in [0:73]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 45
# Proposal probability 0.947368421053 / random : 0.0556835580255
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a8d0>
# Step: 501   Ensemble: 4  failsteps = 23
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 22 in [0:77]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 23
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a8d0>
# Step: 502   Ensemble: 4  failsteps = 24
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 14 in [0:77]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a8d0>
# Step: 503   Ensemble: 4  failsteps = 25
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 44 in [0:77]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 48
# Proposal probability 0.835164835165 / random : 0.449691579343
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a8d0>
# Step: 504   Ensemble: 4  failsteps = 26
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 53 in [0:92]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 21
# Proposal probability 1.24657534247 / random : 0.00171853687853
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a8d0>
# Step: 505   Ensemble: 4  failsteps = 27
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 63 in [0:74]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 46
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a8d0>
# Step: 506   Ensemble: 4  failsteps = 28
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:74]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 43
# Proposal probability 0.651785714286 / random : 0.918930385973
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a8d0>
# Step: 507   Ensemble: 4  failsteps = 29
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 11 in [0:74]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 1.0 / random : 0.412153359227
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a8d0>
# Step: 508   Ensemble: 4  failsteps = 30
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 43 in [0:74]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 41
# Proposal probability 1.02816901408 / random : 0.775537171078
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a8d0>
# Step: 509   Ensemble: 4  failsteps = 31
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 27 in [0:72]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Finished trajectory, length: 58
# Proposal probability 0.845238095238 / random : 0.460217274489
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x12444a8d0>

# %% [markdown]
# We've stored all the trajectories we generated here; now we want to extract a path for each ensemble to use as a starting point for TIS. We'll choose to take the first path that satisfied each ensemble.

# %%
print "[ ",
for sample in bootstrap.globalstate:
    print str(sample.trajectory)+" ",
print "]"
# Out:
# [  Trajectory[19]  Trajectory[29]  Trajectory[37]  Trajectory[33]  Trajectory[73]  Trajectory[86]  ]

# %% [markdown]
# Let's go ahead and visualize where each of those trajectories are:

# %%
plot.plot([sample.trajectory for sample in bootstrap.globalstate])

# %% [markdown]
# ## Equilibration in the Path Ensemble
#
# At the end of the bootstrapping process, we have a set of paths which we can use to start TIS sampling. Before doing a production run, we should let these paths equilibrate within the ensembles. If you generate your initial path through dynamics that aren't the true dynamics (e.g., using high temperature runs or using metadynamics), this stage is **extremely** important. It's important here as well, but less so than if your initial path is non-physical.
#
# This will be an example of a "normal" TIS run, i.e., TIS without replica exchange. We will sampling using only shooter movers (the same ones defined for the bootstrapping) and path reversal movers. First we define these path reveral movers:

# %%
from openpathsampling.pathmover import PathReversalSet
reversal_movers = PathReversalSet(interface_ensemble_set)

# %% [markdown]
# Next we define global moves: we'll set this up so that each move either does a shooting move on all replicas, or does a path reversal move on all replicas. You can similarly set it up so that each move operates on only on one replica at a time.

# %%
from openpathsampling.pathmover import RandomChoiceMover
shooting_chooser = RandomChoiceMover(shooting_movers, name="ShootingChooser")
reversal_chooser = RandomChoiceMover(reversal_movers, name="ReversalChooser")
equilibration_movers = RandomChoiceMover([shooting_chooser, reversal_chooser])

# %% [markdown]
# Now we're ready to set up a TIS run:

# %%
from openpathsampling.calculation import PathSampling
equilibration = PathSampling(storage=None, engine=sim, root_mover=equilibration_movers, globalstate=bootstrap.globalstate)

# %% [markdown]
# And now we run it. We'll do 100 equilibration steps.

# %%
equilibration.run(10)

# %% [markdown]
# Now let's take a look at where the trajectories are after they've had a chance to equilibrate:

# %%
plot.plot([sample.trajectory for sample in equilibration.globalstate])

# %% [markdown]
# ## RETIS: Production run
#
# With everything else set up, we can set up the replica exchange movers, and reuse the other movers.

# %%
from openpathsampling.pathmover import NeighborEnsembleReplicaExchange
repex_movers = NeighborEnsembleReplicaExchange(interface_ensemble_set)
repex_chooser = RandomChoiceMover(repex_movers, name="RepExChooser")

# %% [markdown]
# We'll also set up the minus ensemble and minus move:

# %%
minus_ensemble = paths.MinusInterfaceEnsemble(state_vol=stateA,
                                              innermost_vol=line_volume_set[0],
                                              n_l=2)
minus_move = paths.MinusMover(minus_ensemble=minus_ensemble,
                              innermost_ensemble=interface_ensemble_set[0])

# %% [markdown]
# We also have to create a path which is valid for the minus ensemble.

# %%
minus_segment = equilibration.globalstate[0].trajectory
last_frame = minus_segment[-1]
extension = sim.generate(last_frame, [minus_ensemble.can_append])
first_minus = minus_segment + extension[1:]
minus_samp = paths.Sample(
    replica=-1,
    trajectory=first_minus,
    ensemble=minus_ensemble,
    details=paths.MoveDetails.initialization(first_minus, minus_ensemble)
)
start_gs = equilibration.globalstate.apply_samples([minus_samp])
# Out:
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Through frame: 70
# Through frame: 80
# Through frame: 90
# Through frame: 100
# Through frame: 110
# Through frame: 120
# Through frame: 130
# Through frame: 140
# Through frame: 150
# Through frame: 160
# Through frame: 170
# Through frame: 180
# Through frame: 190
# Through frame: 200
# Through frame: 210
# Through frame: 220
# Through frame: 230
# Through frame: 240
# Through frame: 250
# Through frame: 260
# Through frame: 270
# Through frame: 280
# Through frame: 290
# Through frame: 300
# Through frame: 310
# Through frame: 320
# Through frame: 330
# Through frame: 340
# Through frame: 350
# Through frame: 360
# Through frame: 370
# Through frame: 380
# Through frame: 390
# Through frame: 400
# Through frame: 410
# Through frame: 420
# Through frame: 430
# Through frame: 440
# Through frame: 450
# Through frame: 460
# Through frame: 470
# Through frame: 480
# Through frame: 490
# Through frame: 500
# Through frame: 510
# Through frame: 520
# Through frame: 530
# Through frame: 540
# Through frame: 550
# Through frame: 560
# Through frame: 570
# Through frame: 580
# Through frame: 590
# Through frame: 600
# Through frame: 610
# Through frame: 620
# Through frame: 630
# Through frame: 640
# Through frame: 650
# Through frame: 660
# Through frame: 670
# Through frame: 680
# Through frame: 690
# Through frame: 700
# Through frame: 710
# Through frame: 720
# Through frame: 730
# Through frame: 740
# Through frame: 750
# Through frame: 760
# Through frame: 770
# Through frame: 780
# Through frame: 790
# Through frame: 800
# Through frame: 810
# Through frame: 820
# Through frame: 830
# Through frame: 840
# Through frame: 850
# Through frame: 860
# Through frame: 870
# Through frame: 880
# Through frame: 890
# Through frame: 900
# Through frame: 910
# Through frame: 920
# Through frame: 930
# Through frame: 940
# Through frame: 950
# Through frame: 960
# Through frame: 970
# Through frame: 980
# Through frame: 990
# Through frame: 1000
# Through frame: 1010
# Through frame: 1020
# Through frame: 1030
# Through frame: 1040
# Through frame: 1050
# Through frame: 1060
# Through frame: 1070
# Through frame: 1080
# Through frame: 1090
# Through frame: 1100
# Through frame: 1110
# Through frame: 1120
# Through frame: 1130
# Through frame: 1140
# Through frame: 1150
# Through frame: 1160
# Through frame: 1170
# Through frame: 1180
# Through frame: 1190
# Through frame: 1200
# Through frame: 1210
# Through frame: 1220
# Through frame: 1230
# Through frame: 1240
# Through frame: 1250
# Through frame: 1260
# Through frame: 1270
# Through frame: 1280
# Through frame: 1290
# Through frame: 1300
# Through frame: 1310
# Through frame: 1320
# Through frame: 1330
# Through frame: 1340
# Through frame: 1350
# Through frame: 1360
# Through frame: 1370
# Through frame: 1380
# Through frame: 1390
# Through frame: 1400
# Through frame: 1410
# Through frame: 1420
# Finished trajectory, length: 1420

# %%
plot.plot([first_minus])

# %% [markdown]
# Finally, we set up a production run; this is very similar to the setup for the TIS equilibration run. However, up until now, we have not used file storage; before this run we will set up a storage file. The single storage file will save all the trajectories as well as all the details of the RETIS simulation (what movers are used, the acceptance of each trial, etc.)

# %%
try:
    storage.close()
except NameError:
    pass # close storage if it has been opened; useful in interactive mode

storage = paths.storage.Storage('toy_tis.nc', mode='w', template=initial_snapshot)
# Out:
# Setup netCDF file and create variables
# Saving topology
# Create initial template snapshot
# Finished setting up netCDF file

# %%
retis_root_mover = RandomChoiceMover([shooting_chooser, reversal_chooser, repex_chooser, minus_move])
production = PathSampling(storage=storage, engine=sim, root_mover=retis_root_mover, globalstate=start_gs)

# %% [markdown]
# We'll run the production calculation for 50 MC steps.

# %%
production.run(10)
# Out:
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (ShootingChooser)
# RandomChoiceMover (ShootingChooser) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:22]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 0.875 / random : 0.197024289833
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-ba716a166e33> in <module>()
# ----> 1 production.run(10)
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/calculation.pyc in run(self, nsteps)
#     260                                                               step=step)
#     261             if self.storage is not None:
# --> 262                 self.globalstate.save_samples(self.storage)
#     263                 self.globalstate.save(self.storage)
#     264                 self.storage.sync()
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/sample.pyc in save_samples(self, storage)
#     172             the underlying netcdf file to be used for storage
#     173         """
# --> 174         map(storage.sample.save, self.samples)
#     175
#     176     def sanity_check(self):
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/object_storage.pyc in inner(self, obj, idx, *args, **kwargs)
#     977     def inner(self, obj, idx = None, *args, **kwargs):
#     978         # call the normal storage
# --> 979         func(obj, idx, *args, **kwargs)
#     980         idx = obj.idx[self.storage]
#     981
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/object_storage.pyc in inner(self, obj, idx, *args, **kwargs)
#    1052
#    1053         obj.idx[storage] = idx
# -> 1054         func(obj, idx, *args, **kwargs)
#    1055
#    1056     return inner
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/sample_store.pyc in save(self, sample, idx)
#      20             self.save_variable('sample_replica', idx, sample.replica)
#      21
# ---> 22             self.storage.movedetails.save(sample.details)
#      23             self.set_object('sample_details', idx, sample.details)
#      24
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/object_storage.pyc in inner(self, obj, idx, *args, **kwargs)
#     977     def inner(self, obj, idx = None, *args, **kwargs):
#     978         # call the normal storage
# --> 979         func(obj, idx, *args, **kwargs)
#     980         idx = obj.idx[self.storage]
#     981
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/object_storage.pyc in inner(self, obj, idx, *args, **kwargs)
#    1052
#    1053         obj.idx[storage] = idx
# -> 1054         func(obj, idx, *args, **kwargs)
#    1055
#    1056     return inner
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/object_storage.pyc in save(self, obj, idx)
#     410             self.storage.variables[self.identifier][idx] = obj.name
#     411
# --> 412         self.save_object(self.idx_dimension + '_json', idx, obj)
#     413
#     414     def get_name(self, idx):
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/object_storage.pyc in save_object(self, name, idx, obj)
#     719         """
#     720         if not hasattr(obj,'json'):
# --> 721             setattr(obj, 'json', self.object_to_json(obj))
#     722
#     723         self.storage.variables[name][idx] = obj.json
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/object_storage.pyc in object_to_json(self, obj)
#     740             the JSON string
#     741         """
# --> 742         json_string = self.simplifier.to_json_object(obj, obj.base_cls_name)
#     743
#     744         return json_string
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/todict.pyc in to_json_object(self, obj, base_type)
#     110
#     111     def to_json_object(self, obj, base_type = ''):
# --> 112         simplified = self.simplify_object(obj, base_type)
#     113         return json.dumps(simplified)
#     114
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/todict.pyc in simplify_object(self, obj, base_type)
#      23
#      24     def simplify_object(self, obj, base_type = ''):
# ---> 25         return { '_cls' : obj.__class__.__name__, '_dict' : self.simplify(obj.to_dict(), obj.base_cls_name) }
#      26
#      27     def simplify(self, obj, base_type = ''):
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/storage.pyc in simplify(self, obj, base_type)
#     508                 return { '_idx' : obj.idx[self.storage], '_cls' : obj.__class__.__name__ }
#     509
# --> 510         return super(StorableObjectJSON, self).simplify(obj, base_type)
#     511
#     512     def build(self,obj):
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/todict.pyc in simplify(self, obj, base_type)
#      46             return tuple([self.simplify(o, base_type) for o in obj])
#      47         elif type(obj) is dict:
# ---> 48             result = {key : self.simplify(o, base_type) for key, o in obj.iteritems() if type(key) is str and key not in self.excluded_keys }
#      49             return result
#      50         elif type(obj) is slice:
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/todict.pyc in <dictcomp>((key, o))
#      46             return tuple([self.simplify(o, base_type) for o in obj])
#      47         elif type(obj) is dict:
# ---> 48             result = {key : self.simplify(o, base_type) for key, o in obj.iteritems() if type(key) is str and key not in self.excluded_keys }
#      49             return result
#      50         elif type(obj) is slice:
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/storage.pyc in simplify(self, obj, base_type)
#     508                 return { '_idx' : obj.idx[self.storage], '_cls' : obj.__class__.__name__ }
#     509
# --> 510         return super(StorableObjectJSON, self).simplify(obj, base_type)
#     511
#     512     def build(self,obj):
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/todict.pyc in simplify(self, obj, base_type)
#      42                 return None
#      43         elif type(obj) is list:
# ---> 44             return [self.simplify(o, base_type) for o in obj]
#      45         elif type(obj) is tuple:
#      46             return tuple([self.simplify(o, base_type) for o in obj])
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/storage.pyc in simplify(self, obj, base_type)
#     505                 # store objects only if they are not creatable. If so they will only be created in their
#     506                 # top instance and we use the simplify from the super class ObjectJSON
# --> 507                 self.storage.save(obj)
#     508                 return { '_idx' : obj.idx[self.storage], '_cls' : obj.__class__.__name__ }
#     509
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/storage.pyc in save(self, obj, *args, **kwargs)
#     355             if obj.base_cls in self._storages:
#     356                 store = self._storages[obj.base_cls]
# --> 357                 store.save(obj, *args, **kwargs)
#     358
#     359                 # save has been called, all is good
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/object_storage.pyc in inner(self, obj, idx, *args, **kwargs)
#     977     def inner(self, obj, idx = None, *args, **kwargs):
#     978         # call the normal storage
# --> 979         func(obj, idx, *args, **kwargs)
#     980         idx = obj.idx[self.storage]
#     981
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/object_storage.pyc in inner(self, obj, idx, *args, **kwargs)
#    1052
#    1053         obj.idx[storage] = idx
# -> 1054         func(obj, idx, *args, **kwargs)
#    1055
#    1056     return inner
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/object_storage.pyc in save(self, obj, idx)
#     410             self.storage.variables[self.identifier][idx] = obj.name
#     411
# --> 412         self.save_object(self.idx_dimension + '_json', idx, obj)
#     413
#     414     def get_name(self, idx):
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/object_storage.pyc in save_object(self, name, idx, obj)
#     719         """
#     720         if not hasattr(obj,'json'):
# --> 721             setattr(obj, 'json', self.object_to_json(obj))
#     722
#     723         self.storage.variables[name][idx] = obj.json
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/object_storage.pyc in object_to_json(self, obj)
#     740             the JSON string
#     741         """
# --> 742         json_string = self.simplifier.to_json_object(obj, obj.base_cls_name)
#     743
#     744         return json_string
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/todict.pyc in to_json_object(self, obj, base_type)
#     110
#     111     def to_json_object(self, obj, base_type = ''):
# --> 112         simplified = self.simplify_object(obj, base_type)
#     113         return json.dumps(simplified)
#     114
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/todict.pyc in simplify_object(self, obj, base_type)
#      23
#      24     def simplify_object(self, obj, base_type = ''):
# ---> 25         return { '_cls' : obj.__class__.__name__, '_dict' : self.simplify(obj.to_dict(), obj.base_cls_name) }
#      26
#      27     def simplify(self, obj, base_type = ''):
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/storage.pyc in simplify(self, obj, base_type)
#     508                 return { '_idx' : obj.idx[self.storage], '_cls' : obj.__class__.__name__ }
#     509
# --> 510         return super(StorableObjectJSON, self).simplify(obj, base_type)
#     511
#     512     def build(self,obj):
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/todict.pyc in simplify(self, obj, base_type)
#      46             return tuple([self.simplify(o, base_type) for o in obj])
#      47         elif type(obj) is dict:
# ---> 48             result = {key : self.simplify(o, base_type) for key, o in obj.iteritems() if type(key) is str and key not in self.excluded_keys }
#      49             return result
#      50         elif type(obj) is slice:
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/todict.pyc in <dictcomp>((key, o))
#      46             return tuple([self.simplify(o, base_type) for o in obj])
#      47         elif type(obj) is dict:
# ---> 48             result = {key : self.simplify(o, base_type) for key, o in obj.iteritems() if type(key) is str and key not in self.excluded_keys }
#      49             return result
#      50         elif type(obj) is slice:
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/storage.pyc in simplify(self, obj, base_type)
#     508                 return { '_idx' : obj.idx[self.storage], '_cls' : obj.__class__.__name__ }
#     509
# --> 510         return super(StorableObjectJSON, self).simplify(obj, base_type)
#     511
#     512     def build(self,obj):
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/todict.pyc in simplify(self, obj, base_type)
#      42                 return None
#      43         elif type(obj) is list:
# ---> 44             return [self.simplify(o, base_type) for o in obj]
#      45         elif type(obj) is tuple:
#      46             return tuple([self.simplify(o, base_type) for o in obj])
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/storage.pyc in simplify(self, obj, base_type)
#     505                 # store objects only if they are not creatable. If so they will only be created in their
#     506                 # top instance and we use the simplify from the super class ObjectJSON
# --> 507                 self.storage.save(obj)
#     508                 return { '_idx' : obj.idx[self.storage], '_cls' : obj.__class__.__name__ }
#     509
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/storage.pyc in save(self, obj, *args, **kwargs)
#     355             if obj.base_cls in self._storages:
#     356                 store = self._storages[obj.base_cls]
# --> 357                 store.save(obj, *args, **kwargs)
#     358
#     359                 # save has been called, all is good
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/object_storage.pyc in inner(self, obj, idx, *args, **kwargs)
#     977     def inner(self, obj, idx = None, *args, **kwargs):
#     978         # call the normal storage
# --> 979         func(obj, idx, *args, **kwargs)
#     980         idx = obj.idx[self.storage]
#     981
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/object_storage.pyc in inner(self, obj, idx, *args, **kwargs)
#    1052
#    1053         obj.idx[storage] = idx
# -> 1054         func(obj, idx, *args, **kwargs)
#    1055
#    1056     return inner
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/object_storage.pyc in save(self, obj, idx)
#     410             self.storage.variables[self.identifier][idx] = obj.name
#     411
# --> 412         self.save_object(self.idx_dimension + '_json', idx, obj)
#     413
#     414     def get_name(self, idx):
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/object_storage.pyc in save_object(self, name, idx, obj)
#     719         """
#     720         if not hasattr(obj,'json'):
# --> 721             setattr(obj, 'json', self.object_to_json(obj))
#     722
#     723         self.storage.variables[name][idx] = obj.json
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/object_storage.pyc in object_to_json(self, obj)
#     740             the JSON string
#     741         """
# --> 742         json_string = self.simplifier.to_json_object(obj, obj.base_cls_name)
#     743
#     744         return json_string
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/todict.pyc in to_json_object(self, obj, base_type)
#     110
#     111     def to_json_object(self, obj, base_type = ''):
# --> 112         simplified = self.simplify_object(obj, base_type)
#     113         return json.dumps(simplified)
#     114
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/todict.pyc in simplify_object(self, obj, base_type)
#      23
#      24     def simplify_object(self, obj, base_type = ''):
# ---> 25         return { '_cls' : obj.__class__.__name__, '_dict' : self.simplify(obj.to_dict(), obj.base_cls_name) }
#      26
#      27     def simplify(self, obj, base_type = ''):
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/storage.pyc in simplify(self, obj, base_type)
#     508                 return { '_idx' : obj.idx[self.storage], '_cls' : obj.__class__.__name__ }
#     509
# --> 510         return super(StorableObjectJSON, self).simplify(obj, base_type)
#     511
#     512     def build(self,obj):
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/todict.pyc in simplify(self, obj, base_type)
#      46             return tuple([self.simplify(o, base_type) for o in obj])
#      47         elif type(obj) is dict:
# ---> 48             result = {key : self.simplify(o, base_type) for key, o in obj.iteritems() if type(key) is str and key not in self.excluded_keys }
#      49             return result
#      50         elif type(obj) is slice:
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/todict.pyc in <dictcomp>((key, o))
#      46             return tuple([self.simplify(o, base_type) for o in obj])
#      47         elif type(obj) is dict:
# ---> 48             result = {key : self.simplify(o, base_type) for key, o in obj.iteritems() if type(key) is str and key not in self.excluded_keys }
#      49             return result
#      50         elif type(obj) is slice:
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/storage.pyc in simplify(self, obj, base_type)
#     508                 return { '_idx' : obj.idx[self.storage], '_cls' : obj.__class__.__name__ }
#     509
# --> 510         return super(StorableObjectJSON, self).simplify(obj, base_type)
#     511
#     512     def build(self,obj):
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/todict.pyc in simplify(self, obj, base_type)
#      42                 return None
#      43         elif type(obj) is list:
# ---> 44             return [self.simplify(o, base_type) for o in obj]
#      45         elif type(obj) is tuple:
#      46             return tuple([self.simplify(o, base_type) for o in obj])
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/storage.pyc in simplify(self, obj, base_type)
#     505                 # store objects only if they are not creatable. If so they will only be created in their
#     506                 # top instance and we use the simplify from the super class ObjectJSON
# --> 507                 self.storage.save(obj)
#     508                 return { '_idx' : obj.idx[self.storage], '_cls' : obj.__class__.__name__ }
#     509
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/storage.pyc in save(self, obj, *args, **kwargs)
#     355             if obj.base_cls in self._storages:
#     356                 store = self._storages[obj.base_cls]
# --> 357                 store.save(obj, *args, **kwargs)
#     358
#     359                 # save has been called, all is good
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/object_storage.pyc in inner(self, obj, idx, *args, **kwargs)
#     977     def inner(self, obj, idx = None, *args, **kwargs):
#     978         # call the normal storage
# --> 979         func(obj, idx, *args, **kwargs)
#     980         idx = obj.idx[self.storage]
#     981
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/object_storage.pyc in inner(self, obj, idx, *args, **kwargs)
#    1052
#    1053         obj.idx[storage] = idx
# -> 1054         func(obj, idx, *args, **kwargs)
#    1055
#    1056     return inner
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/object_storage.pyc in save(self, obj, idx)
#     410             self.storage.variables[self.identifier][idx] = obj.name
#     411
# --> 412         self.save_object(self.idx_dimension + '_json', idx, obj)
#     413
#     414     def get_name(self, idx):
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/object_storage.pyc in save_object(self, name, idx, obj)
#     719         """
#     720         if not hasattr(obj,'json'):
# --> 721             setattr(obj, 'json', self.object_to_json(obj))
#     722
#     723         self.storage.variables[name][idx] = obj.json
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/object_storage.pyc in object_to_json(self, obj)
#     740             the JSON string
#     741         """
# --> 742         json_string = self.simplifier.to_json_object(obj, obj.base_cls_name)
#     743
#     744         return json_string
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/todict.pyc in to_json_object(self, obj, base_type)
#     110
#     111     def to_json_object(self, obj, base_type = ''):
# --> 112         simplified = self.simplify_object(obj, base_type)
#     113         return json.dumps(simplified)
#     114
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/todict.pyc in simplify_object(self, obj, base_type)
#      23
#      24     def simplify_object(self, obj, base_type = ''):
# ---> 25         return { '_cls' : obj.__class__.__name__, '_dict' : self.simplify(obj.to_dict(), obj.base_cls_name) }
#      26
#      27     def simplify(self, obj, base_type = ''):
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/storage.pyc in simplify(self, obj, base_type)
#     508                 return { '_idx' : obj.idx[self.storage], '_cls' : obj.__class__.__name__ }
#     509
# --> 510         return super(StorableObjectJSON, self).simplify(obj, base_type)
#     511
#     512     def build(self,obj):
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/todict.pyc in simplify(self, obj, base_type)
#      46             return tuple([self.simplify(o, base_type) for o in obj])
#      47         elif type(obj) is dict:
# ---> 48             result = {key : self.simplify(o, base_type) for key, o in obj.iteritems() if type(key) is str and key not in self.excluded_keys }
#      49             return result
#      50         elif type(obj) is slice:
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/todict.pyc in <dictcomp>((key, o))
#      46             return tuple([self.simplify(o, base_type) for o in obj])
#      47         elif type(obj) is dict:
# ---> 48             result = {key : self.simplify(o, base_type) for key, o in obj.iteritems() if type(key) is str and key not in self.excluded_keys }
#      49             return result
#      50         elif type(obj) is slice:
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/storage.pyc in simplify(self, obj, base_type)
#     508                 return { '_idx' : obj.idx[self.storage], '_cls' : obj.__class__.__name__ }
#     509
# --> 510         return super(StorableObjectJSON, self).simplify(obj, base_type)
#     511
#     512     def build(self,obj):
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/todict.pyc in simplify(self, obj, base_type)
#      42                 return None
#      43         elif type(obj) is list:
# ---> 44             return [self.simplify(o, base_type) for o in obj]
#      45         elif type(obj) is tuple:
#      46             return tuple([self.simplify(o, base_type) for o in obj])
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/storage.pyc in simplify(self, obj, base_type)
#     505                 # store objects only if they are not creatable. If so they will only be created in their
#     506                 # top instance and we use the simplify from the super class ObjectJSON
# --> 507                 self.storage.save(obj)
#     508                 return { '_idx' : obj.idx[self.storage], '_cls' : obj.__class__.__name__ }
#     509
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/storage.pyc in save(self, obj, *args, **kwargs)
#     355             if obj.base_cls in self._storages:
#     356                 store = self._storages[obj.base_cls]
# --> 357                 store.save(obj, *args, **kwargs)
#     358
#     359                 # save has been called, all is good
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/object_storage.pyc in inner(self, obj, idx, *args, **kwargs)
#     977     def inner(self, obj, idx = None, *args, **kwargs):
#     978         # call the normal storage
# --> 979         func(obj, idx, *args, **kwargs)
#     980         idx = obj.idx[self.storage]
#     981
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/object_storage.pyc in inner(self, obj, idx, *args, **kwargs)
#    1052
#    1053         obj.idx[storage] = idx
# -> 1054         func(obj, idx, *args, **kwargs)
#    1055
#    1056     return inner
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/object_storage.pyc in save(self, obj, idx)
#     410             self.storage.variables[self.identifier][idx] = obj.name
#     411
# --> 412         self.save_object(self.idx_dimension + '_json', idx, obj)
#     413
#     414     def get_name(self, idx):
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/object_storage.pyc in save_object(self, name, idx, obj)
#     719         """
#     720         if not hasattr(obj,'json'):
# --> 721             setattr(obj, 'json', self.object_to_json(obj))
#     722
#     723         self.storage.variables[name][idx] = obj.json
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/object_storage.pyc in object_to_json(self, obj)
#     740             the JSON string
#     741         """
# --> 742         json_string = self.simplifier.to_json_object(obj, obj.base_cls_name)
#     743
#     744         return json_string
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/todict.pyc in to_json_object(self, obj, base_type)
#     111     def to_json_object(self, obj, base_type = ''):
#     112         simplified = self.simplify_object(obj, base_type)
# --> 113         return json.dumps(simplified)
#     114
#     115     def from_json(self, json_string):
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/__init__.pyc in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, encoding, default, sort_keys, **kw)
#     241         cls is None and indent is None and separators is None and
#     242         encoding == 'utf-8' and default is None and not sort_keys and not kw):
# --> 243         return _default_encoder.encode(obj)
#     244     if cls is None:
#     245         cls = JSONEncoder
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.pyc in encode(self, o)
#     205         # exceptions aren't as detailed.  The list call should be roughly
#     206         # equivalent to the PySequence_Fast that ''.join() would do.
# --> 207         chunks = self.iterencode(o, _one_shot=True)
#     208         if not isinstance(chunks, (list, tuple)):
#     209             chunks = list(chunks)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.pyc in iterencode(self, o, _one_shot)
#     268                 self.key_separator, self.item_separator, self.sort_keys,
#     269                 self.skipkeys, _one_shot)
# --> 270         return _iterencode(o, 0)
#     271
#     272 def _make_iterencode(markers, _default, _encoder, _indent, _floatstr,
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.pyc in default(self, o)
#     182
#     183         """
# --> 184         raise TypeError(repr(o) + " is not JSON serializable")
#     185
#     186     def encode(self, o):
#
# TypeError: <function <lambda> at 0x12494fb90> is not JSON serializable

# %%
production.run(10)
# Out:
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 0 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 3 (MinusMover)
# MinusMover starting mover index 0 (MinusSubtrajectoryChooser)
# RandomChoiceMover (MinusSubtrajectoryChooser) selecting mover index 0 (FirstSubtrajectorySelectMover)
# MinusMover starting mover index 1 (ReplicaExchangeMover)
# MinusMover starting mover index 2 (ForceEnsembleChangeMover)
# MinusMover starting mover index 3 (MinusExtensionDirectionChooser)
# RandomChoiceMover (MinusExtensionDirectionChooser) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 25 in [0:25]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.0 / random : 0.401917072014
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 0 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RepExChooser)
# RandomChoiceMover (RepExChooser) selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 3 (MinusMover)
# MinusMover starting mover index 0 (MinusSubtrajectoryChooser)
# RandomChoiceMover (MinusSubtrajectoryChooser) selecting mover index 0 (FirstSubtrajectorySelectMover)
# MinusMover starting mover index 1 (ReplicaExchangeMover)
# MinusMover starting mover index 2 (ForceEnsembleChangeMover)
# MinusMover starting mover index 3 (MinusExtensionDirectionChooser)
# RandomChoiceMover (MinusExtensionDirectionChooser) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 22 in [0:22]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Through frame: 70
# Through frame: 80
# Through frame: 90
# Through frame: 100
# Through frame: 110
# Through frame: 120
# Through frame: 130
# Through frame: 140
# Through frame: 150
# Through frame: 160
# Through frame: 170
# Through frame: 180
# Through frame: 190
# Through frame: 200
# Through frame: 210
# Through frame: 220
# Through frame: 230
# Through frame: 240
# Through frame: 250
# Through frame: 260
# Through frame: 270
# Through frame: 280
# Through frame: 290
# Through frame: 300
# Through frame: 310
# Through frame: 320
# Through frame: 330
# Through frame: 340
# Through frame: 350
# Through frame: 360
# Finished trajectory, length: 368
# Proposal probability 1.0 / random : 0.444777058673
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (ShootingChooser)
# RandomChoiceMover (ShootingChooser) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 77 in [0:81]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Finished trajectory, length: 54
# Proposal probability 0.615384615385 / random : 0.0688468628288
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RepExChooser)
# RandomChoiceMover (RepExChooser) selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 3 (MinusMover)
# MinusMover starting mover index 0 (MinusSubtrajectoryChooser)
# RandomChoiceMover (MinusSubtrajectoryChooser) selecting mover index 1 (FinalSubtrajectorySelectMover)
# MinusMover starting mover index 1 (ReplicaExchangeMover)
# MinusMover starting mover index 2 (ForceEnsembleChangeMover)
# MinusMover starting mover index 3 (MinusExtensionDirectionChooser)
# RandomChoiceMover (MinusExtensionDirectionChooser) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 25 in [0:25]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 1.0 / random : 0.976407616202
# RandomChoiceMover (PathSamplingRoot) selecting mover index 3 (MinusMover)
# MinusMover starting mover index 0 (MinusSubtrajectoryChooser)
# RandomChoiceMover (MinusSubtrajectoryChooser) selecting mover index 0 (FirstSubtrajectorySelectMover)
# MinusMover starting mover index 1 (ReplicaExchangeMover)
# MinusMover starting mover index 2 (ForceEnsembleChangeMover)
# MinusMover starting mover index 3 (MinusExtensionDirectionChooser)
# RandomChoiceMover (MinusExtensionDirectionChooser) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 17 in [0:17]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Through frame: 70
# Through frame: 80
# Through frame: 90
# Through frame: 100
# Through frame: 110
# Through frame: 120
# Through frame: 130
# Through frame: 140
# Through frame: 150
# Through frame: 160
# Through frame: 170
# Through frame: 180
# Through frame: 190
# Through frame: 200
# Through frame: 210
# Through frame: 220
# Through frame: 230
# Through frame: 240
# Through frame: 250
# Through frame: 260
# Through frame: 270
# Through frame: 280
# Through frame: 290
# Through frame: 300
# Through frame: 310
# Through frame: 320
# Through frame: 330
# Through frame: 340
# Through frame: 350
# Through frame: 360
# Through frame: 370
# Through frame: 380
# Finished trajectory, length: 382
# Proposal probability 1.0 / random : 0.865317171495
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RepExChooser)
# RandomChoiceMover (RepExChooser) selecting mover index 0 (ReplicaExchangeMover)
