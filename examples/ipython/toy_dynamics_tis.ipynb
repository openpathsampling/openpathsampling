# %%
# Note: in practice, one should put all the imports at the top of a Python script. 
# But for educational purposes here, I put the import immediately before usage. 
# This Python block is just to set up some plotting stuff.

# Imports for plotting
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
from matplotlib.legend_handler import HandlerLine2D
import numpy as np

# TODO: these visualization classes should be moved into some generic file
from opentis.snapshot import Snapshot

# A little class we use for visualizing these 2D PESs
class CallablePES(object):
    def __init__(self, pes):
        self.pes = pes
    
    def __call__(self, x, y):
        self.positions = [x, y]
        return self.pes.V(self)

class CallableVolume(object):
    def __init__(self, vol):
        self.vol = vol
    
    def __call__(self, x, y):
        snapshot = Snapshot(coordinates=np.array([[x,y,0.0]]))
        return 1.0 if self.vol(snapshot) else 0.0

# plot setup stuff
range_x = np.arange(-1.1, 1.1, 0.01)
range_y = np.arange(-1.1, 0.9, 0.01)
extent = [range_x[0], range_x[-1], range_y[0], range_y[-1]]
X, Y = np.meshgrid(range_x, range_y)
pylab.rcParams['figure.figsize'] = 9, 6
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/mpl_toolkits': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/mpl_toolkits': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/mpl_toolkits': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/mpl_toolkits': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/mpl_toolkits': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/mpl_toolkits': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/mpl_toolkits': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/mpl_toolkits': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/mpl_toolkits': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/mpl_toolkits': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/mpl_toolkits': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/mpl_toolkits': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/mpl_toolkits': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/mpl_toolkits': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/mpl_toolkits': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/mpl_toolkits': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/mpl_toolkits': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/PyObjCTools': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/mpl_toolkits': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/PyObjCTools': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/mpl_toolkits': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/PyObjCTools': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/mpl_toolkits': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/PyObjCTools': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/mpl_toolkits': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/PyObjCTools': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/mpl_toolkits': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/PyObjCTools': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/mpl_toolkits': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/PyObjCTools': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/mpl_toolkits': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/PyObjCTools': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/mpl_toolkits': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/PyObjCTools': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/mpl_toolkits': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/PyObjCTools': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/mpl_toolkits': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/PyObjCTools': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/mpl_toolkits': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/PyObjCTools': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/mpl_toolkits': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/PyObjCTools': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/mpl_toolkits': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/PyObjCTools': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/mpl_toolkits': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/PyObjCTools': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/mpl_toolkits': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/PyObjCTools': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/mpl_toolkits': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/PyObjCTools': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/mpl_toolkits': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/PyObjCTools': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/mpl_toolkits': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/PyObjCTools': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/mpl_toolkits': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/PyObjCTools': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/mpl_toolkits': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/PyObjCTools': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/mpl_toolkits': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/PyObjCTools': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/mpl_toolkits': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/PyObjCTools': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/mpl_toolkits': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/PyObjCTools': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/virtualenvwrapper': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)

# %% [markdown]
# # Setting up RETIS on a Toy Model
#
# This example shows how to set up a RETIS calculation. We do this on a simple 2D model so it can be fast enough for an interactive example, but the basic approach applies to larger systems as well. Although I'll describe everything here in terms of 2-state systems, all the ideas generalize when setting up multiple-state systems (you just need to find more initial paths).

# %% [markdown]
# ## Getting an initial path
#
# RETIS is a path sampling method: it requires that the user supply an input path for each path ensemble. This means that you must somehow generate a first input path. In general, getting the first input paths for RETIS boils down to solving two problems:
#
# 1. Getting a trajectory that samples the rare event.
# 2. Filling all the path ensembles with acceptable trajectories.
#
# Since transition paths satisfy all the path ensembles between two states, a common approach is to use the same initial path for all path ensembles (reversing it where necessary). This way, once you've solved problem 1, problem 2 is trivial.
#
# The first rare path can come from any number of sources. The obvious approach might be to find a transition path from a committor analysis, because this would give you a path that satisfies the true dynamics. However, the initial path doesn't need to satisfy the true dynamics of the system (later we will equilibrate the path ensemble anyway). This means that other approaches, such as high-temperature trajectories, can be used for the first path. One of the most widely-used methods to get an initial trajectory is to generate a transition trajectory using metadynamics. However, the downside of using paths that don't satisfy the true dynamics is that it might be harder to get them to equilibrate to the correct path ensemble. It seems that this has been more of a problem with paths from high temperature runs than with paths from metadynamics: a path from a modified potential energy surface at the correct temperature seems to equilibrate more easily than a path from the original potential energy surface at an incorrect temperature.
#
# In this example, we use a bootstrapping approach, which does create paths satisfying the true dynamics of the system. This bootstrapping is nice because it is quick and convenient, although it works best on smaller systems with less complicated transitions. It works by running normal MD to generate a path that satisfies the innermost interface, and then performing shooting moves in that interface's path ensemble until we have a path that crosses the next interface. Then we switch to the path ensemble for the next interface, and shoot until the path crossing the interface after that. The process continues until we have paths for all interfaces.

# %% [markdown]
# ### Basic system setup
#
# First we set up our system: for the toy dynamics, this involves defining a potential energy surface (PES), setting up an integrator, and giving the simulation an initial configuration. In real MD systems, the PES is handled by the combination of a topology file and a force field definition, and the initial configuration would come from a file instead of being described by hand.

# %%
from opentis.toy_dynamics.toy_engine import ToyEngine
from opentis.toy_dynamics.toy_integrators import LangevinBAOABIntegrator
from opentis.toy_dynamics.toy_pes import Gaussian, OuterWalls

import logging.config
logging.config.fileConfig("logging.conf", disable_existing_loggers=False)

# %%
# Toy_PES supports adding/subtracting various PESs. The OuterWalls PES type gives an x^6+y^6 boundary to the system
pes = (OuterWalls([1.0, 1.0], [0.0, 0.0]) + 
       Gaussian(2.0, [1.0, 4.0], [0.0,1.0]) + 
       Gaussian(2.0, [25.0, 1.0], [0.0, -1.0])
      )
integ = LangevinBAOABIntegrator(dt=0.02, temperature=0.1, gamma=1.0)
sim = ToyEngine(filename=None,
                options={'pes' : pes, 
                         'integ' : integ,
                         'n_frames_max' : 5000,
                         'nsteps_per_frame' : 10}
               )

sim.mass = [1.0, 1.0]
sim.current_snapshot = Snapshot(coordinates=[-0.5, 0.0], velocities=[0.0,0.0])

# %% [markdown]
# Now let's take a look at our PES and our initial configuration:

# %%
pes_V = np.vectorize(CallablePES(pes))
# we load the coordinates into a snapshot instead of directly calling them 
# based on their implementation in `toy_simulation`. This is because the 
# snapshot approach will work independently of the underlying MD engine.
snap = sim.current_snapshot

fig, ax = plt.subplots()
CS = ax.contour(X, Y, pes_V(X,Y), levels=np.arange(0.0, 1.5, 0.1), colors='k', zorder=0)
ax.plot(snap.coordinates[0,0], snap.coordinates[0,1], 'ro', zorder=1);

# %% [markdown]
# ### Interface setup
#
# One downside of the bootstrapping approach is that we need to have defined our interfaces before we start. However, we can always easily change our initial interface guesses.
#
# We'll consider a couple different choices of order parameter to define our interfaces. First we'll look at lines at different values of $x$. That set will be called `line_set`. Later we'll also consider circles centered on (-0.5, -0.25), with different radii. We'll call this set of interfaces `circle_set`.
#
# In both cases, we need to define the order parameter, and then we need to create a set of volumes and a set of ensembles associated with those volumes.

# %%
from opentis.orderparameter import OP_Function
from opentis.volume import VolumeFactory as vf
from opentis.volume import LambdaVolume
from opentis.trajectory import Trajectory

# WTF? This is an extremely overcomplicated OP; shouldn't be so hard!
try:
    op_line = OP_Function(name="xval", 
                          fcn=lambda snap : Trajectory([snap])[0].coordinates()[0,0])
except ValueError:
    print "xval already made"
# this defines a set of LambdaVolumes for which the minimum is -1.0 and the maximum is given in the array
line_volume_set = vf.LambdaVolumeSet(op_line, minvals=-1.0, maxvals=[-0.30, -0.25, -0.20, -0.13, -0.05, 0.0])
stateA = LambdaVolume(op_line, -1.0, -0.3)
stateB = LambdaVolume(op_line, 0.3, 1.0)

# %%
stateAmap = np.vectorize(CallableVolume(stateA))(X,Y)
stateBmap = np.vectorize(CallableVolume(stateB))(X,Y)
CS = plt.contour(X, Y, pes_V(X,Y), levels=np.arange(0.0, 1.5, 0.1), colors='k', zorder=0)
plt.imshow(stateAmap+stateBmap, extent=extent, cmap="Blues", interpolation='none', vmin=0.0, vmax=2.0, zorder=-1, aspect='auto')
for iface in line_volume_set:
    plt.contour(X,Y, np.vectorize(CallableVolume(iface))(X,Y), colors='r', interpolation='none', levels=[0.5], zorder=1)
plt.plot(snap.coordinates[0,0], snap.coordinates[0,1], 'ro', zorder=1);

# %% [markdown]
# In this picture, the states are marked in blue, and the interfaces are drawn as red lines. The initial configuration is still the red dot.

# %% [markdown]
# ### First innermost interface path
#
# Now we have to create an initial path. This initial path shoud exit the state, cross the first interface, and then return to the state. We'll create this path by defining a special ensemble that, propagating forward from any initial snapshot, ends when the path ends with a segment in the appropriate interface.

# %%
from opentis.ensemble import EnsembleFactory as ef
from opentis.ensemble import LengthEnsemble, InXEnsemble, OutXEnsemble, SequentialEnsemble, OptionalEnsemble

interface0 = line_volume_set[0]
interface_ensemble_set = ef.TISEnsembleSet(stateA, stateB, line_volume_set)
first_traj_ensemble = SequentialEnsemble([
    OptionalEnsemble(OutXEnsemble(stateA)),
    InXEnsemble(stateA),
    OptionalEnsemble(OutXEnsemble(stateA) & InXEnsemble(interface0)),
    OptionalEnsemble(InXEnsemble(interface0)),
    OutXEnsemble(interface0),
    OptionalEnsemble(OutXEnsemble(stateA)),
    InXEnsemble(stateA) & LengthEnsemble(1)
])

# %% [markdown]
# This ensemble is a bit complicated, but works in the general case. To understand it, we'll look at the `SequentialEnsemble` segment by segment. One preliminary point is that we need the generated path ensemble to be the same as the accepted path ensemble in this case, meaning that we must define the ensemble entirely in terms of which volumes each segment is in (i.e., using `InXEnsemble` and `OutXEnsemble`, but not `LeaveXEnsemble` or `HitXEnsemble`).
#
# Start with the first two segments: we start with an optional ensemble outside the state, and then move to an ensemble that is in the state. Since our TIS segment must start in a state, these two ensembles allow us to either start outside the state and then evolve into the state, or to start inside the state. At the end of these two segments, we have the first frame of the TIS ensemble segment, i.e., the frame inside the state that begins the TIS path.
#
# Next we have a couple of optional ensembles, followed by an ensemble requiring the segment to be outside the interface. The optional interfaces here are only important if `stateA` and `interface0` represent different volumes. If they represent the same volume (which is the case here) these optional ensembles don't matter. However, if they are different volumes, then there is a space which is outside the state but inside the interface. So the first optional interface represents that space. The next optional interface says that you must then be inside `interface0`: this is in case there is a reentry into the state before you cross the interface. Next, we require that we cross the interface. The last optional ensemble is for segments ouside the state. If there is space between the interface and the state, then after you are no longer outside the interface you might still be outside the state. Finally, the path ends with one frame in the state.
#
# Following the logic of that, any path that begins anywhere and ends with a segment satisfying the innermost TIS ensemble will be accepted by this ensemble. Furthermore, since the ensemble is defined exclusively in terms of `InXEnsemble`s and `OutXEnsemble`s, the ensemble of paths generated by forward dynamics (`can_append`) is equivalent to the accepted path ensemble.

# %%
sim.initialized = True
first_traj = sim.generate(snap, [first_traj_ensemble.can_append])
# Out:
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Through frame: 70
# Through frame: 80
# Through frame: 90
# Through frame: 100
# Through frame: 110
# Through frame: 120
# Through frame: 130
# Through frame: 140
# Through frame: 150
# Through frame: 160
# Through frame: 170
# Through frame: 180
# Through frame: 190
# Through frame: 200
# Through frame: 210
# Through frame: 220
# Through frame: 230
# Through frame: 240
# Through frame: 250
# Through frame: 260
# Through frame: 270
# Through frame: 280
# Through frame: 290
# Through frame: 300
# Through frame: 310
# Through frame: 320
# Through frame: 330
# Through frame: 340
# Through frame: 350
# Through frame: 360
# Through frame: 370
# Through frame: 380
# Through frame: 390
# Through frame: 400
# Through frame: 410
# Through frame: 420
# Through frame: 430
# Through frame: 440
# Through frame: 450
# Through frame: 460
# Through frame: 470
# Through frame: 480
# Through frame: 490
# Through frame: 500
# Through frame: 510
# Finished trajectory, length: 519

# %% [markdown]
# Next we use the `Ensemble.split` function to split the trajectory we found into segments satisfying the innermost interface TIS ensemble. There is only one such segment, and so we assign the first (and only) one found to `subtraj`, which is the first trajectory satisfying the innermost TIS interface.

# %%
subtraj = interface_ensemble_set[0].split(first_traj)[0]

# %%
plt.imshow(stateAmap+stateBmap, extent=extent, cmap="Blues", interpolation='nearest', vmin=0.0, vmax=2.0, aspect='auto')
CS = plt.contour(X, Y, pes_V(X,Y), levels=np.arange(0.0, 1.5, 0.1), colors='k')
for iface in line_volume_set:
    plt.contour(X,Y, np.vectorize(CallableVolume(iface))(X,Y), colors='r', interpolation='none', levels=[0.5])
plt.plot(first_traj.coordinates()[1,0,0], first_traj.coordinates()[1,0,1], 'ro');
plt.plot(first_traj.coordinates()[1:,0,0], first_traj.coordinates()[1:,0,1], 'k-', linewidth=2)
plt.plot(subtraj.coordinates()[:,0,0], subtraj.coordinates()[:,0,1], 'r-', linewidth=1);

# %% [markdown]
# Now we see how the initial path evolves on this surface. The last part of the trajectory, which satisfies the path ensemble for the innermost interface, is highlighted in red. The whole trajectory is drawn in black.

# %% [markdown]
# ### Bootstrapping
#
# The bootstrapping approach takes a single trajectory which satisfies the innermost interface, and does shooting moves until it satisfies the next ensemble. Once it satisfies the next ensemble, we start shooting from within that ensemble. We keep building up like that until all ensembles have an initial path.
#
# To do this, we need to first create the appropriate shooting movers (one for each path ensemble). This is done quickly and efficiently with a factory function.

# %%
from opentis.pathmover import PathMoverFactory as mf
from opentis.shooting import UniformSelector

# might be nice to get rid of these two lines somehow
from opentis.pathmover import PathMover
PathMover.engine = sim

shooting_movers = mf.OneWayShootingSet(UniformSelector(), interface_ensemble_set)

# %% [markdown]
# Next we need to set up the Bootstrapping calculation:

# %%
from opentis.calculation import Bootstrapping

# TODO: add storage
bootstrap = Bootstrapping(storage=None,
                          engine=sim,
                          ensembles=interface_ensemble_set,
                          movers=shooting_movers,
                          trajectory=subtraj)

# %%
for rep in bootstrap.globalstate.replica_list():
    traj = bootstrap.globalstate[rep]
    #print traj, 
    if traj is not None:
        print (op_line(bootstrap.globalstate[rep]))
    else:
        print
# Out:
# None

# %% [markdown]
# Now we run the bootstrapping. The number `50` means that we'll allow up to 50 shooting attempts per interface; if it takes more than that, you should probably adjust your interfaces (there's probably not much overlap for replica exchange).

# %%
bootstrap.run(300)
# Out:
# Step: 0   Ensemble: 0  failsteps = 0
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 13 in [0:14]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 0.928571428571 / random : 0.848139383808
# Step: 1   Ensemble: 0  failsteps = 1
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 10 in [0:15]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 1.75 / random : 0.753753662247
# Step: 2   Ensemble: 0  failsteps = 2
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 6 in [0:9]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.6 / random : 0.921003154372
# Step: 3   Ensemble: 0  failsteps = 3
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:6]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 0.3125 / random : 0.139763152827
# Step: 4   Ensemble: 1  failsteps = 0
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 16 in [0:17]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Step: 5   Ensemble: 1  failsteps = 1
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 14 in [0:17]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Step: 6   Ensemble: 1  failsteps = 2
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 10 in [0:17]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 0.888888888889 / random : 0.899017601396
# Step: 7   Ensemble: 1  failsteps = 3
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:17]
# Starting trajectory
# Finished trajectory, length: 2
# Step: 8   Ensemble: 1  failsteps = 4
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 6 in [0:17]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.06666666667 / random : 0.646324829751
# Step: 9   Ensemble: 1  failsteps = 5
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:16]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 0.9375 / random : 0.923584256884
# Step: 10   Ensemble: 1  failsteps = 6
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:17]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.578445604916
# Step: 11   Ensemble: 1  failsteps = 7
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 8 in [0:17]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 1.23076923077 / random : 0.853795511933
# Step: 12   Ensemble: 1  failsteps = 8
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 13 in [0:14]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Step: 13   Ensemble: 1  failsteps = 9
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 13 in [0:14]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Proposal probability 0.764705882353 / random : 0.50316086678
# Step: 14   Ensemble: 1  failsteps = 10
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:18]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Step: 15   Ensemble: 1  failsteps = 11
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 9 in [0:18]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 1.0625 / random : 0.471568015378
# Step: 16   Ensemble: 1  failsteps = 12
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 9 in [0:17]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 1.06666666667 / random : 0.585821557859
# Step: 17   Ensemble: 1  failsteps = 13
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 13 in [0:16]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.0 / random : 0.828548767033
# Step: 18   Ensemble: 1  failsteps = 14
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:16]
# Starting trajectory
# Finished trajectory, length: 2
# Step: 19   Ensemble: 1  failsteps = 15
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 10 in [0:16]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 1.07142857143 / random : 0.209460516412
# Step: 20   Ensemble: 1  failsteps = 16
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 13 in [0:15]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 0.736842105263 / random : 0.79228197514
# Step: 21   Ensemble: 1  failsteps = 17
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:15]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 1.0 / random : 0.613355903217
# Step: 22   Ensemble: 1  failsteps = 18
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:15]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Proposal probability 0.48275862069 / random : 0.908324762663
# Step: 23   Ensemble: 1  failsteps = 19
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 13 in [0:15]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.0 / random : 0.611157576658
# Step: 24   Ensemble: 1  failsteps = 20
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:15]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 0.538461538462 / random : 0.7930662153
# Step: 25   Ensemble: 1  failsteps = 21
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 4 in [0:15]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 16
# Proposal probability 0.736842105263 / random : 0.855452534418
# Step: 26   Ensemble: 1  failsteps = 22
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 12 in [0:15]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 0.933333333333 / random : 0.0260394148712
# Step: 27   Ensemble: 1  failsteps = 23
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:16]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 1.07142857143 / random : 0.830717535116
# Step: 28   Ensemble: 1  failsteps = 24
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:15]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 0.875 / random : 0.528079162206
# Step: 29   Ensemble: 1  failsteps = 25
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 10 in [0:17]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 0.941176470588 / random : 0.945689599765
# Step: 30   Ensemble: 1  failsteps = 26
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 16 in [0:17]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.884126772756
# Step: 31   Ensemble: 1  failsteps = 27
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:17]
# Starting trajectory
# Finished trajectory, length: 2
# Step: 32   Ensemble: 1  failsteps = 28
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 16 in [0:17]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.143105594703
# Step: 33   Ensemble: 1  failsteps = 29
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 16 in [0:17]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 1.23076923077 / random : 0.353044923394
# Step: 34   Ensemble: 1  failsteps = 30
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 9 in [0:14]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 0.928571428571 / random : 0.690266133174
# Step: 35   Ensemble: 1  failsteps = 31
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 9 in [0:15]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 0.875 / random : 0.749221408456
# Step: 36   Ensemble: 1  failsteps = 32
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:17]
# Starting trajectory
# Finished trajectory, length: 2
# Step: 37   Ensemble: 1  failsteps = 33
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 11 in [0:17]
# Starting trajectory
# Finished trajectory, length: 7
# Proposal probability 0.941176470588 / random : 0.693311231364
# Step: 38   Ensemble: 1  failsteps = 34
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 5 in [0:18]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 1.0625 / random : 0.528867353128
# Step: 39   Ensemble: 1  failsteps = 35
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 9 in [0:17]
# Starting trajectory
# Finished trajectory, length: 7
# Proposal probability 1.14285714286 / random : 0.11284575087
# Step: 40   Ensemble: 1  failsteps = 36
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 8 in [0:15]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 0.875 / random : 0.442971077766
# Step: 41   Ensemble: 1  failsteps = 37
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 11 in [0:17]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.06666666667 / random : 0.779361753063
# Step: 42   Ensemble: 1  failsteps = 38
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 13 in [0:16]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.0 / random : 0.556391255057
# Step: 43   Ensemble: 1  failsteps = 39
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 8 in [0:16]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 1.0 / random : 0.95678015504
# Step: 44   Ensemble: 1  failsteps = 40
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 9 in [0:16]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 0.9375 / random : 0.218613310334
# Step: 45   Ensemble: 1  failsteps = 41
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:17]
# Starting trajectory
# Finished trajectory, length: 2
# Step: 46   Ensemble: 1  failsteps = 42
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 6 in [0:17]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 1.45454545455 / random : 0.819110976833
# Step: 47   Ensemble: 1  failsteps = 43
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:12]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 0.578947368421 / random : 0.928090679112
# Step: 48   Ensemble: 1  failsteps = 44
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 6 in [0:12]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 0.6875 / random : 0.305382559655
# Step: 49   Ensemble: 1  failsteps = 45
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 11 in [0:17]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.06666666667 / random : 0.782978873862
# Step: 50   Ensemble: 1  failsteps = 46
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 13 in [0:16]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.0 / random : 0.983381473162
# Step: 51   Ensemble: 1  failsteps = 47
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 13 in [0:16]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.0 / random : 0.123932653881
# Step: 52   Ensemble: 1  failsteps = 48
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 10 in [0:16]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 0.789473684211 / random : 0.380960990663
# Step: 53   Ensemble: 1  failsteps = 49
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 16 in [0:20]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 1.11764705882 / random : 0.847907407302
# Step: 54   Ensemble: 1  failsteps = 50
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:18]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 0.586206896552 / random : 0.0708920234242
# Step: 55   Ensemble: 1  failsteps = 51
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 11 in [0:30]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 1.61111111111 / random : 0.478436652127
# Step: 56   Ensemble: 1  failsteps = 52
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:19]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Proposal probability 0.620689655172 / random : 0.0738982386622
# Step: 57   Ensemble: 1  failsteps = 53
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 19 in [0:30]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 1.07407407407 / random : 0.732381658087
# Step: 58   Ensemble: 1  failsteps = 54
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:28]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.205121822194
# Step: 59   Ensemble: 1  failsteps = 55
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 6 in [0:28]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 0.84375 / random : 0.853762095362
# Step: 60   Ensemble: 1  failsteps = 56
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 10 in [0:28]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 1.35 / random : 0.718235186852
# Step: 61   Ensemble: 1  failsteps = 57
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 11 in [0:21]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 0.952380952381 / random : 0.537889761477
# Step: 62   Ensemble: 1  failsteps = 58
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:22]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Proposal probability 0.617647058824 / random : 0.565893045688
# Step: 63   Ensemble: 1  failsteps = 59
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 27 in [0:35]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 2.0 / random : 0.440693563301
# Step: 64   Ensemble: 1  failsteps = 60
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 16 in [0:18]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 16
# Proposal probability 1.0 / random : 0.753206116182
# Step: 65   Ensemble: 1  failsteps = 61
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 17 in [0:18]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 0.944444444444 / random : 0.943287849664
# Step: 66   Ensemble: 1  failsteps = 62
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 15 in [0:19]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.05882352941 / random : 0.451177975571
# Step: 67   Ensemble: 1  failsteps = 63
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 15 in [0:18]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 1.0625 / random : 0.497385131694
# Step: 68   Ensemble: 1  failsteps = 64
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 12 in [0:17]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 1.6 / random : 0.0455500897145
# Step: 69   Ensemble: 1  failsteps = 65
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:11]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Proposal probability 0.4 / random : 0.451482162114
# Step: 70   Ensemble: 1  failsteps = 66
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 8 in [0:11]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 0.47619047619 / random : 0.944987745381
# Step: 71   Ensemble: 1  failsteps = 67
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:11]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.354581339256
# Step: 72   Ensemble: 1  failsteps = 68
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:11]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 0.526315789474 / random : 0.086094609306
# Step: 73   Ensemble: 1  failsteps = 69
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 18 in [0:20]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 0.95 / random : 0.0475575617984
# Step: 74   Ensemble: 1  failsteps = 70
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:21]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.0 / random : 0.880556528635
# Step: 75   Ensemble: 1  failsteps = 71
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:21]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Proposal probability 0.645161290323 / random : 0.772672522358
# Step: 76   Ensemble: 1  failsteps = 72
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 17 in [0:21]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 0.666666666667 / random : 0.183623356427
# Step: 77   Ensemble: 1  failsteps = 73
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 15 in [0:31]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 1.15384615385 / random : 0.0850460216977
# Step: 78   Ensemble: 1  failsteps = 74
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 21 in [0:27]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 1.625 / random : 0.833671631163
# Step: 79   Ensemble: 1  failsteps = 75
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 11 in [0:17]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 0.842105263158 / random : 0.675157447069
# Step: 80   Ensemble: 1  failsteps = 76
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 18 in [0:20]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Proposal probability 1.1875 / random : 0.659246550017
# Step: 81   Ensemble: 1  failsteps = 77
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 6 in [0:17]
# Starting trajectory
# Finished trajectory, length: 7
# Proposal probability 1.33333333333 / random : 0.932642853797
# Step: 82   Ensemble: 1  failsteps = 78
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:13]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Step: 83   Ensemble: 1  failsteps = 79
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 5 in [0:13]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 0.75 / random : 0.154075871343
# Step: 84   Ensemble: 1  failsteps = 80
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 15 in [0:17]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 1.14285714286 / random : 0.475973597253
# Step: 85   Ensemble: 1  failsteps = 81
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 14 in [0:15]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.832278916658
# Step: 86   Ensemble: 1  failsteps = 82
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 6 in [0:15]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 0.636363636364 / random : 0.489007759306
# Step: 87   Ensemble: 1  failsteps = 83
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:23]
# Starting trajectory
# Finished trajectory, length: 2
# Step: 88   Ensemble: 1  failsteps = 84
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 17 in [0:23]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 1.57142857143 / random : 0.841894505938
# Step: 89   Ensemble: 1  failsteps = 85
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 6 in [0:15]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 1.27272727273 / random : 0.220883671926
# Step: 90   Ensemble: 1  failsteps = 86
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 10 in [0:12]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.0 / random : 0.446202308644
# Step: 91   Ensemble: 1  failsteps = 87
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 5 in [0:12]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.0 / random : 0.743860956662
# Step: 92   Ensemble: 1  failsteps = 88
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 7 in [0:12]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Proposal probability 0.578947368421 / random : 0.0327644213846
# Step: 93   Ensemble: 1  failsteps = 89
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 9 in [0:20]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 1.0 / random : 0.559336851827
# Step: 94   Ensemble: 1  failsteps = 90
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 6 in [0:20]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 1.72727272727 / random : 0.199681281772
# Step: 95   Ensemble: 1  failsteps = 91
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:12]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 0.5 / random : 0.997999784381
# Step: 96   Ensemble: 1  failsteps = 92
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:12]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 16
# Proposal probability 0.44 / random : 0.0143493184367
# Step: 97   Ensemble: 1  failsteps = 93
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 19 in [0:26]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 0.833333333333 / random : 0.79022092221
# Step: 98   Ensemble: 1  failsteps = 94
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 13 in [0:31]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.76470588235 / random : 0.760702557597
# Step: 99   Ensemble: 1  failsteps = 95
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:18]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 0.586206896552 / random : 0.84057213521
# Step: 100   Ensemble: 1  failsteps = 96
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 10 in [0:18]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 1.0625 / random : 0.903215738964
# Step: 101   Ensemble: 1  failsteps = 97
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 8 in [0:17]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 1.0 / random : 0.247911202971
# Step: 102   Ensemble: 1  failsteps = 98
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 9 in [0:17]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 1.0 / random : 0.171217438661
# Step: 103   Ensemble: 1  failsteps = 99
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 15 in [0:17]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 1.14285714286 / random : 0.782661928685
# Step: 104   Ensemble: 1  failsteps = 100
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 14 in [0:15]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Step: 105   Ensemble: 1  failsteps = 101
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 6 in [0:15]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 0.777777777778 / random : 0.319842738907
# Step: 106   Ensemble: 1  failsteps = 102
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 8 in [0:19]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 1.38461538462 / random : 0.93133829319
# Step: 107   Ensemble: 1  failsteps = 103
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 12 in [0:14]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 16
# Proposal probability 0.764705882353 / random : 0.845384907447
# Step: 108   Ensemble: 1  failsteps = 104
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 5 in [0:14]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 1.08333333333 / random : 0.312147942993
# Step: 109   Ensemble: 1  failsteps = 105
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 11 in [0:13]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 0.923076923077 / random : 0.810139469527
# Step: 110   Ensemble: 1  failsteps = 106
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:14]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.0 / random : 0.344886271067
# Step: 111   Ensemble: 1  failsteps = 107
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 13 in [0:14]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Proposal probability 0.866666666667 / random : 0.102533563254
# Step: 112   Ensemble: 1  failsteps = 108
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 10 in [0:16]
# Starting trajectory
# Finished trajectory, length: 5
# Step: 113   Ensemble: 1  failsteps = 109
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:16]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 0.625 / random : 0.737051519791
# Step: 114   Ensemble: 1  failsteps = 110
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 8 in [0:16]
# Starting trajectory
# Finished trajectory, length: 7
# Proposal probability 1.07142857143 / random : 0.129093813369
# Step: 115   Ensemble: 1  failsteps = 111
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:15]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.0 / random : 0.325735267553
# Step: 116   Ensemble: 1  failsteps = 112
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 14 in [0:15]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.109137921689
# Step: 117   Ensemble: 1  failsteps = 113
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 10 in [0:15]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 1.0 / random : 0.958109329022
# Step: 118   Ensemble: 1  failsteps = 114
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 11 in [0:15]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 1.0 / random : 0.666610174781
# Step: 119   Ensemble: 1  failsteps = 115
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 8 in [0:15]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 1.0 / random : 0.103672729759
# Step: 120   Ensemble: 1  failsteps = 116
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 11 in [0:15]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 1.0 / random : 0.950681097175
# Step: 121   Ensemble: 1  failsteps = 117
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 7 in [0:15]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 0.7 / random : 0.908581800081
# Step: 122   Ensemble: 1  failsteps = 118
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 5 in [0:15]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 1.0 / random : 0.275254337108
# Step: 123   Ensemble: 1  failsteps = 119
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 13 in [0:15]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Step: 124   Ensemble: 1  failsteps = 120
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 9 in [0:15]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 1.0 / random : 0.82828274257
# Step: 125   Ensemble: 1  failsteps = 121
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:15]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 0.933333333333 / random : 0.908368042818
# Step: 126   Ensemble: 1  failsteps = 122
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 7 in [0:16]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 1.0 / random : 0.307792669836
# Step: 127   Ensemble: 1  failsteps = 123
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 14 in [0:16]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Proposal probability 0.833333333333 / random : 0.354947998966
# Step: 128   Ensemble: 1  failsteps = 124
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:19]
# Starting trajectory
# Finished trajectory, length: 2
# Step: 129   Ensemble: 1  failsteps = 125
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 5 in [0:19]
# Starting trajectory
# Finished trajectory, length: 7
# Proposal probability 0.9 / random : 0.795974338232
# Step: 130   Ensemble: 1  failsteps = 126
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 5 in [0:21]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 1.42857142857 / random : 0.108116143638
# Step: 131   Ensemble: 1  failsteps = 127
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 12 in [0:15]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 0.933333333333 / random : 0.076410162208
# Step: 132   Ensemble: 1  failsteps = 128
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:16]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Proposal probability 1.0 / random : 0.799908177927
# Step: 133   Ensemble: 1  failsteps = 129
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:16]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Step: 134   Ensemble: 1  failsteps = 130
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:16]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Step: 135   Ensemble: 1  failsteps = 131
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 12 in [0:16]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Step: 136   Ensemble: 1  failsteps = 132
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 11 in [0:16]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 0.9375 / random : 0.698846863356
# Step: 137   Ensemble: 1  failsteps = 133
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 6 in [0:17]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 0.941176470588 / random : 0.538830023506
# Step: 138   Ensemble: 1  failsteps = 134
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 11 in [0:18]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 1.0 / random : 0.0954251403248
# Step: 139   Ensemble: 1  failsteps = 135
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:18]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.125175738277
# Step: 140   Ensemble: 1  failsteps = 136
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 16 in [0:18]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.0 / random : 0.898601397937
# Step: 141   Ensemble: 1  failsteps = 137
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:18]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.0 / random : 0.53454119249
# Step: 142   Ensemble: 1  failsteps = 138
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 9 in [0:18]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 1.21428571429 / random : 0.953528490707
# Step: 143   Ensemble: 1  failsteps = 139
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 14 in [0:15]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Step: 144   Ensemble: 1  failsteps = 140
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 9 in [0:15]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 0.933333333333 / random : 0.131453277434
# Step: 145   Ensemble: 1  failsteps = 141
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 10 in [0:16]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 0.833333333333 / random : 0.791876124048
# Step: 146   Ensemble: 1  failsteps = 142
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 7 in [0:19]
# Starting trajectory
# Finished trajectory, length: 7
# Proposal probability 1.0 / random : 0.859781649798
# Step: 147   Ensemble: 1  failsteps = 143
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 15 in [0:19]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.05882352941 / random : 0.300381609642
# Step: 148   Ensemble: 1  failsteps = 144
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 17 in [0:18]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 1.30769230769 / random : 0.579075542321
# Step: 149   Ensemble: 1  failsteps = 145
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:14]
# Starting trajectory
# Finished trajectory, length: 2
# Step: 150   Ensemble: 1  failsteps = 146
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 4 in [0:14]
# Starting trajectory
# Finished trajectory, length: 5
# Step: 151   Ensemble: 1  failsteps = 147
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 13 in [0:14]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.00533697409248
# Step: 152   Ensemble: 1  failsteps = 148
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 9 in [0:14]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 1.08333333333 / random : 0.57662683706
# Step: 153   Ensemble: 1  failsteps = 149
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:13]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 16
# Proposal probability 0.75 / random : 0.18582428969
# Step: 154   Ensemble: 1  failsteps = 150
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 15 in [0:17]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Proposal probability 0.888888888889 / random : 0.485731600255
# Step: 155   Ensemble: 1  failsteps = 151
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 8 in [0:19]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 0.857142857143 / random : 0.412415553069
# Step: 156   Ensemble: 1  failsteps = 152
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:22]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Proposal probability 1.23529411765 / random : 0.713801240451
# Step: 157   Ensemble: 1  failsteps = 153
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 7 in [0:18]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 0.85 / random : 0.743531584621
# Step: 158   Ensemble: 1  failsteps = 154
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 8 in [0:21]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 0.952380952381 / random : 0.84455527483
# Step: 159   Ensemble: 1  failsteps = 155
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 11 in [0:22]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 1.05 / random : 0.444331276379
# Step: 160   Ensemble: 1  failsteps = 156
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 16 in [0:21]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.0 / random : 0.0118870520758
# Step: 161   Ensemble: 1  failsteps = 157
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 10 in [0:21]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 1.0 / random : 0.826076635811
# Step: 162   Ensemble: 1  failsteps = 158
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:21]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 1.42857142857 / random : 0.558559285954
# Step: 163   Ensemble: 1  failsteps = 159
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 13 in [0:15]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.07692307692 / random : 0.000134464043547
# Step: 164   Ensemble: 1  failsteps = 160
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 9 in [0:14]
# Starting trajectory
# Finished trajectory, length: 9
# Step: 165   Ensemble: 1  failsteps = 161
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 9 in [0:14]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 1.0 / random : 0.121971402838
# Step: 166   Ensemble: 1  failsteps = 162
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 10 in [0:14]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 0.928571428571 / random : 0.74066926588
# Step: 167   Ensemble: 1  failsteps = 163
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 13 in [0:15]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Step: 168   Ensemble: 1  failsteps = 164
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 8 in [0:15]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 1.0 / random : 0.355117930954
# Step: 169   Ensemble: 1  failsteps = 165
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 14 in [0:15]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.507247044474
# Step: 170   Ensemble: 1  failsteps = 166
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 10 in [0:15]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.0 / random : 0.838893468365
# Step: 171   Ensemble: 1  failsteps = 167
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 14 in [0:15]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Proposal probability 0.823529411765 / random : 0.197866733405
# Step: 172   Ensemble: 1  failsteps = 168
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 9 in [0:18]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 1.0625 / random : 0.920609357296
# Step: 173   Ensemble: 1  failsteps = 169
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 11 in [0:17]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 0.8 / random : 0.367435986414
# Step: 174   Ensemble: 1  failsteps = 170
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 5 in [0:21]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 1.05263157895 / random : 0.472894257634
# Step: 175   Ensemble: 1  failsteps = 171
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 7 in [0:20]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 0.95 / random : 0.743780870354
# Step: 176   Ensemble: 1  failsteps = 172
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 5 in [0:21]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 1.17647058824 / random : 0.919063270356
# Step: 177   Ensemble: 1  failsteps = 173
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 10 in [0:18]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 1.0 / random : 0.659154427699
# Step: 178   Ensemble: 1  failsteps = 174
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 15 in [0:18]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Proposal probability 1.0 / random : 0.7136293253
# Step: 179   Ensemble: 1  failsteps = 175
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 11 in [0:18]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 1.0625 / random : 0.577886870648
# Step: 180   Ensemble: 1  failsteps = 176
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 13 in [0:17]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Proposal probability 0.888888888889 / random : 0.146444074131
# Step: 181   Ensemble: 1  failsteps = 177
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 10 in [0:19]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 1.05882352941 / random : 0.977330068725
# Step: 182   Ensemble: 1  failsteps = 178
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 12 in [0:18]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 1.0 / random : 0.963594211051
# Step: 183   Ensemble: 1  failsteps = 179
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:18]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 0.515151515152 / random : 0.228457141988
# Step: 184   Ensemble: 2  failsteps = 0
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 16 in [0:34]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 16
# Proposal probability 1.06451612903 / random : 0.703746915285
# Step: 185   Ensemble: 2  failsteps = 1
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:32]
# Starting trajectory
# Finished trajectory, length: 2
# Step: 186   Ensemble: 2  failsteps = 2
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 31 in [0:32]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Step: 187   Ensemble: 2  failsteps = 3
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 18 in [0:32]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 1.0 / random : 0.150392435295
# Step: 188   Ensemble: 2  failsteps = 4
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 27 in [0:32]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.0 / random : 0.819995590703
# Step: 189   Ensemble: 2  failsteps = 5
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:32]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 0.96875 / random : 0.675627193587
# Step: 190   Ensemble: 2  failsteps = 6
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 8 in [0:33]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 1.6 / random : 0.560724969842
# Step: 191   Ensemble: 2  failsteps = 7
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 11 in [0:21]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 1.11111111111 / random : 0.0247873072799
# Step: 192   Ensemble: 2  failsteps = 8
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 10 in [0:19]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 0.857142857143 / random : 0.53851088753
# Step: 193   Ensemble: 2  failsteps = 9
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 17 in [0:22]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 0.954545454545 / random : 0.946312789263
# Step: 194   Ensemble: 2  failsteps = 10
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 15 in [0:23]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Step: 195   Ensemble: 2  failsteps = 11
# MixedMover selecting mover index 0 (ForwardShootMover)
# ...
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 0.95652173913 / random : 0.182741907497
# Step: 419   Ensemble: 2  failsteps = 235
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 22 in [0:24]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.0 / random : 0.81807944314
# Step: 420   Ensemble: 2  failsteps = 236
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 10 in [0:24]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 1.35294117647 / random : 0.323598840328
# Step: 421   Ensemble: 2  failsteps = 237
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 16 in [0:18]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.0 / random : 0.989591903257
# Step: 422   Ensemble: 2  failsteps = 238
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 12 in [0:18]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 1.0 / random : 0.473175525245
# Step: 423   Ensemble: 2  failsteps = 239
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:18]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 16
# Proposal probability 0.944444444444 / random : 0.270909713567
# Step: 424   Ensemble: 2  failsteps = 240
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 6 in [0:19]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 1.0 / random : 0.297935622926
# Step: 425   Ensemble: 2  failsteps = 241
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 8 in [0:19]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 0.947368421053 / random : 0.494112214009
# Step: 426   Ensemble: 2  failsteps = 242
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 9 in [0:20]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 0.95 / random : 0.791437649609
# Step: 427   Ensemble: 2  failsteps = 243
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:21]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Step: 428   Ensemble: 2  failsteps = 244
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:21]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 21
# Step: 429   Ensemble: 2  failsteps = 245
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 18 in [0:21]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.0 / random : 0.237527551253
# Step: 430   Ensemble: 2  failsteps = 246
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 10 in [0:21]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 1.0 / random : 0.728662294582
# Step: 431   Ensemble: 2  failsteps = 247
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:21]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.620591310124
# Step: 432   Ensemble: 2  failsteps = 248
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 20 in [0:21]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 20
# Proposal probability 1.0 / random : 0.574036824224
# Step: 433   Ensemble: 2  failsteps = 249
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 17 in [0:21]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Proposal probability 1.11111111111 / random : 0.435032236759
# Step: 434   Ensemble: 2  failsteps = 250
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 18 in [0:19]
# Starting trajectory
# Finished trajectory, length: 1
# Step: 435   Ensemble: 2  failsteps = 251
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:19]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Proposal probability 0.545454545455 / random : 0.0495852212571
# Step: 436   Ensemble: 2  failsteps = 252
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 4 in [0:34]
# Starting trajectory
# Finished trajectory, length: 4
# Step: 437   Ensemble: 2  failsteps = 253
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 30 in [0:34]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 1.0 / random : 0.00879712985125
# Step: 438   Ensemble: 2  failsteps = 254
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 7 in [0:34]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 16
# Proposal probability 1.5 / random : 0.757454487215
# Step: 439   Ensemble: 2  failsteps = 255
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 7 in [0:23]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 1.1 / random : 0.19642648135
# Step: 440   Ensemble: 2  failsteps = 256
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 13 in [0:21]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Proposal probability 0.909090909091 / random : 0.473368852018
# Step: 441   Ensemble: 2  failsteps = 257
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 17 in [0:23]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 1.0 / random : 0.647194152655
# Step: 442   Ensemble: 2  failsteps = 258
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 19 in [0:23]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 1.0 / random : 0.472367783565
# Step: 443   Ensemble: 2  failsteps = 259
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 18 in [0:23]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Proposal probability 1.15789473684 / random : 0.66126866921
# Step: 444   Ensemble: 2  failsteps = 260
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 13 in [0:20]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 1.0 / random : 0.65344298929
# Step: 445   Ensemble: 2  failsteps = 261
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:20]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 19
# Step: 446   Ensemble: 2  failsteps = 262
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 10 in [0:20]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 0.95 / random : 0.4362763123
# Step: 447   Ensemble: 2  failsteps = 263
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 20 in [0:21]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.631514244108
# Step: 448   Ensemble: 2  failsteps = 264
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 18 in [0:21]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.0 / random : 0.721369720889
# Step: 449   Ensemble: 2  failsteps = 265
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 15 in [0:21]
# Starting trajectory
# Finished trajectory, length: 6
# Step: 450   Ensemble: 2  failsteps = 266
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 4 in [0:21]
# Starting trajectory
# Finished trajectory, length: 4
# Step: 451   Ensemble: 2  failsteps = 267
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:21]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.124952708457
# Step: 452   Ensemble: 2  failsteps = 268
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 19 in [0:21]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.0 / random : 0.419952076517
# Step: 453   Ensemble: 2  failsteps = 269
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 4 in [0:21]
# Starting trajectory
# Finished trajectory, length: 4
# Step: 454   Ensemble: 2  failsteps = 270
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 5 in [0:21]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 1.05263157895 / random : 0.256693975331
# Step: 455   Ensemble: 2  failsteps = 271
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 11 in [0:20]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 0.95 / random : 0.0527315763966
# Step: 456   Ensemble: 2  failsteps = 272
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 11 in [0:21]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 0.952380952381 / random : 0.96995774399
# Step: 457   Ensemble: 2  failsteps = 273
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:21]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 16
# Proposal probability 0.625 / random : 0.534966141081
# Step: 458   Ensemble: 2  failsteps = 274
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 5 in [0:33]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Step: 459   Ensemble: 2  failsteps = 275
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 29 in [0:33]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 1.0 / random : 0.0636825080326
# Step: 460   Ensemble: 2  failsteps = 276
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 12 in [0:33]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 1.06666666667 / random : 0.210240290413
# Step: 461   Ensemble: 2  failsteps = 277
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 13 in [0:31]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 16
# Proposal probability 0.909090909091 / random : 0.116765375608
# Step: 462   Ensemble: 2  failsteps = 278
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 16 in [0:34]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 1.17857142857 / random : 0.222547315159
# Step: 463   Ensemble: 2  failsteps = 279
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 16 in [0:29]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 1.03703703704 / random : 0.128761499516
# Step: 464   Ensemble: 2  failsteps = 280
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 12 in [0:28]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 1.17391304348 / random : 0.796449089101
# Step: 465   Ensemble: 2  failsteps = 281
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 6 in [0:24]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 0.741935483871 / random : 0.666375602408
# Step: 466   Ensemble: 2  failsteps = 282
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 11 in [0:32]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 0.96875 / random : 0.978706678128
# Step: 467   Ensemble: 2  failsteps = 283
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 25 in [0:32]
# Starting trajectory
# Finished trajectory, length: 7
# Proposal probability 1.0 / random : 0.719229436187
# Step: 468   Ensemble: 2  failsteps = 284
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 20 in [0:32]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 1.47619047619 / random : 0.0106166287976
# Step: 469   Ensemble: 2  failsteps = 285
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 20 in [0:22]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Step: 470   Ensemble: 2  failsteps = 286
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 20 in [0:22]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.0 / random : 0.97505066401
# Step: 471   Ensemble: 2  failsteps = 287
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 6 in [0:22]
# Starting trajectory
# Finished trajectory, length: 7
# Step: 472   Ensemble: 2  failsteps = 288
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 13 in [0:22]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 1.0 / random : 0.570953679354
# Step: 473   Ensemble: 2  failsteps = 289
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 17 in [0:22]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.0 / random : 0.953855096887
# Step: 474   Ensemble: 2  failsteps = 290
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 11 in [0:22]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 1.05 / random : 0.843779395156
# Step: 475   Ensemble: 2  failsteps = 291
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 8 in [0:21]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 0.869565217391 / random : 0.102503085072
# Step: 476   Ensemble: 2  failsteps = 292
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 10 in [0:24]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 1.21052631579 / random : 0.51410147548
# Step: 477   Ensemble: 2  failsteps = 293
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 14 in [0:20]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.05555555556 / random : 0.41389161583
# Step: 478   Ensemble: 2  failsteps = 294
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:19]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.0 / random : 0.268976098379
# Step: 479   Ensemble: 2  failsteps = 295
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 7 in [0:19]
# Starting trajectory
# Finished trajectory, length: 7
# Proposal probability 1.0 / random : 0.276973359974
# Step: 480   Ensemble: 2  failsteps = 296
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:19]
# Starting trajectory
# Finished trajectory, length: 2
# Step: 481   Ensemble: 2  failsteps = 297
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 9 in [0:19]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 0.857142857143 / random : 0.398396138992
# Step: 482   Ensemble: 2  failsteps = 298
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 5 in [0:22]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.0 / random : 0.35188866722
# Step: 483   Ensemble: 2  failsteps = 299
# MixedMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 10 in [0:22]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 1.05 / random : 0.897496138507

# %% [markdown]
# We've stored all the trajectories we generated here; now we want to extract a path for each ensemble to use as a starting point for TIS. We'll choose to take the first path that satisfied each ensemble.

# %%
print "[ ",
for sample in bootstrap.globalstate:
    print str(sample.trajectory)+" ",
print "]"
# Out:
# [  Trajectory[7]  Trajectory[19]  Trajectory[22]  ]

# %% [markdown]
# Let's go ahead and visualize where each of those trajectories are:

# %%
plt.imshow(stateAmap+stateBmap, extent=extent, cmap="Blues", interpolation='nearest', vmin=0.0, vmax=2.0, aspect='auto')
CS = plt.contour(X, Y, pes_V(X,Y), levels=np.arange(0.0, 1.5, 0.1), colors='k')
for iface in line_volume_set:
    plt.contour(X,Y, np.vectorize(CallableVolume(iface))(X,Y), colors='r', interpolation='none', levels=[0.5])
repcolordict = {0 : 'k-', 1 : 'r-', 2 : 'g-', 3 : 'b-', 4 : 'r-', 5 : 'k-'}
for sample in bootstrap.globalstate:
    plt.plot(sample.trajectory.coordinates()[:,0,0], 
             sample.trajectory.coordinates()[:,0,1],
             repcolordict[sample.replica])

# %% [markdown]
# ## Equilibration in the Path Ensemble
#
# At the end of the bootstrapping process, we have a set of paths which we can use to start TIS sampling. Before doing a production run, we should let these paths equilibrate within the ensembles. If you generate your initial path through dynamics that aren't the true dynamics (e.g., using high temperature runs or using metadynamics), this stage is **extremely** important. It's important here as well, but less so than if your initial path is non-physical.
#
# This will be an example of a "normal" TIS run, i.e., TIS without replica exchange. We will sampling using only shooter movers (the same ones defined for the bootstrapping) and path reversal movers. First we define these path reveral movers:

# %%
#reversal_movers = mf.PathReversalSet(interface_ensemble_set)

# %% [markdown]
# Next we define global moves: we'll set this up so that each move either does a shooting move on all replicas, or does a path reversal move on all replicas. You can similarly set it up so that each move operates on only on one replica at a time.

# %%
#equilibration_movers = MixedMover(shooting_movers.extend(MixedMover(reversal_movers)))
from opentis.pathmover import MixedMover
equilibration_movers = MixedMover(shooting_movers)

# %% [markdown]
# Now we're ready to set up a TIS run:

# %%
from opentis.calculation import PathSampling
equilibration = PathSampling(storage=None, engine=sim, root_mover=equilibration_movers, globalstate=bootstrap.globalstate)

# %% [markdown]
# And now we run it. We'll do 1000 equilibration steps.

# %%
equilibration.run(10)
# Out:
# MixedMover selecting mover index 0 (MixedMover)
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:6]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 0.333333333333 / random : 0.765465213003
# MixedMover selecting mover index 2 (MixedMover)
# MixedMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 6 in [0:21]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 0.740740740741 / random : 0.0362812863157
# MixedMover selecting mover index 3 (MixedMover)
# MixedMover selecting mover index 0 (ForwardShootMover)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-9a2ce3e597c4> in <module>()
# ----> 1 equilibration.run(10)
#
# /Users/dwhs/Dropbox/msm-tis/opentis/calculation.pyc in run(self, nsteps)
#     202     def run(self, nsteps):
#     203         for step in range(nsteps):
# --> 204             samples = self.root_mover.move(self.globalstate)
#     205             self.globalstate.apply_samples(samples)
#     206             # TODO: add storage of globalstate
#
# /Users/dwhs/Dropbox/msm-tis/opentis/pathmover.py in move(self, trajectory)
#     432         mover = self.movers[idx]
#     433
# --> 434         sample = mover.move(trajectory)
#     435         setattr(sample.details, 'mover_idx', idx)
#     436
#
# /Users/dwhs/Dropbox/msm-tis/opentis/pathmover.py in move(self, trajectory)
#     432         mover = self.movers[idx]
#     433
# --> 434         sample = mover.move(trajectory)
#     435         setattr(sample.details, 'mover_idx', idx)
#     436
#
# /Users/dwhs/Dropbox/msm-tis/opentis/pathmover.py in move(self, globalstate)
#     293         # select a legal sample, use it to determine the trajectory and the
#     294         # ensemble needed for the dynamics
# --> 295         rep_sample = self.select_sample(globalstate, self.ensembles)
#     296         trajectory = rep_sample.trajectory
#     297         dynamics_ensemble = rep_sample.ensemble
#
# /Users/dwhs/Dropbox/msm-tis/opentis/pathmover.py in select_sample(self, globalstate, ensembles)
#     219         set in ensembles.
#     220         '''
# --> 221         legal = self.legal_sample_set(globalstate, ensembles)
#     222         return random.choice(legal)
#     223
#
# /Users/dwhs/Dropbox/msm-tis/opentis/pathmover.py in legal_sample_set(self, globalstate, ensembles)
#     209                 ensembles = [ensembles]
#     210             for ens in ensembles:
# --> 211                 ens_samples.extend(globalstate.all_from_ensemble(ens))
#     212             legal_samples = list(set(rep_samples) & set(ens_samples))
#     213
#
# /Users/dwhs/Dropbox/msm-tis/opentis/sample.pyc in all_from_ensemble(self, ensemble)
#      99
#     100     def all_from_ensemble(self, ensemble):
# --> 101         return self.ensemble_dict[ensemble]
#     102
#     103     def all_from_replica(self, replica):
#
# KeyError: <opentis.ensemble.SequentialEnsemble object at 0x11ff197d0>

# %% [markdown]
# ## RETIS: Production run
#
# With everything else set up, we can set up the replica exchange movers, and reuse the other movers.

# %%
#repex_movers = mf.NeighborReplicaExchange(interface_ensemble_set)

# %%
#all_movers = [shooting_movers, repex_movers, reversal_movers]
#production = PathSampling(interface_ensemble_set, all_movers)

# %%
#production.run(500000)
