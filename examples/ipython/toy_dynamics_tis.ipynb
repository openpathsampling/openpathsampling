# %%
# Note: in practice, one should put all the imports at the top of a Python script. 
# But for educational purposes here, I put the import immediately before usage. 
# This Python block is just to set up some plotting stuff.

# Imports for plotting
# %matplotlib inline
import openpathsampling as paths
import numpy as np
from toy_plot_helpers import ToyPlot
plot = ToyPlot()

# %% [markdown]
# # Setting up RETIS on a Toy Model
#
# This example shows how to set up a RETIS calculation. We do this on a simple 2D model so it can be fast enough for an interactive example, but the basic approach applies to larger systems as well. Although I'll describe everything here in terms of 2-state systems, all the ideas generalize when setting up multiple-state systems (you just need to find more initial paths).

# %% [markdown]
# ## Getting an initial path
#
# RETIS is a path sampling method: it requires that the user supply an input path for each path ensemble. This means that you must somehow generate a first input path. In general, getting the first input paths for RETIS boils down to solving two problems:
#
# 1. Getting a trajectory that samples the rare event.
# 2. Filling all the path ensembles with acceptable trajectories.
#
# Since transition paths satisfy all the path ensembles between two states, a common approach is to use the same initial path for all path ensembles (reversing it where necessary). This way, once you've solved problem 1, problem 2 is trivial.
#
# The first rare path can come from any number of sources. The obvious approach might be to find a transition path from a committor analysis, because this would give you a path that satisfies the true dynamics. However, the initial path doesn't need to satisfy the true dynamics of the system (later we will equilibrate the path ensemble anyway). This means that other approaches, such as high-temperature trajectories, can be used for the first path. One of the most widely-used methods to get an initial trajectory is to generate a transition trajectory using metadynamics. However, the downside of using paths that don't satisfy the true dynamics is that it might be harder to get them to equilibrate to the correct path ensemble. It seems that this has been more of a problem with paths from high temperature runs than with paths from metadynamics: a path from a modified potential energy surface at the correct temperature seems to equilibrate more easily than a path from the original potential energy surface at an incorrect temperature.
#
# In this example, we use a bootstrapping approach, which does create paths satisfying the true dynamics of the system. This bootstrapping is nice because it is quick and convenient, although it works best on smaller systems with less complicated transitions. It works by running normal MD to generate a path that satisfies the innermost interface, and then performing shooting moves in that interface's path ensemble until we have a path that crosses the next interface. Then we switch to the path ensemble for the next interface, and shoot until the path crossing the interface after that. The process continues until we have paths for all interfaces.

# %% [markdown]
# ### Basic system setup
#
# First we set up our system: for the toy dynamics, this involves defining a potential energy surface (PES), setting up an integrator, and giving the simulation an initial configuration. In real MD systems, the PES is handled by the combination of a topology file and a force field definition, and the initial configuration would come from a file instead of being described by hand.

# %%
from openpathsampling.toy_dynamics.toy_engine import ToyEngine
from openpathsampling.toy_dynamics.toy_integrators import LangevinBAOABIntegrator
from openpathsampling.toy_dynamics.toy_pes import Gaussian, OuterWalls

import logging.config
logging.config.fileConfig("logging.conf", disable_existing_loggers=False)

# %% [markdown]
# ### Set up the toy system
# This includes the potential energy surface (PES), and an initial configuration

# %%
# Toy_PES supports adding/subtracting various PESs. The OuterWalls PES type gives an x^6+y^6 boundary to the system
pes = (OuterWalls([1.0, 1.0], [0.0, 0.0]) + 
       Gaussian(2.0, [1.0, 4.0], [0.0,1.0]) + 
       Gaussian(2.0, [25.0, 1.0], [0.0, -1.0])
      )
topology=paths.ToyTopology(
    n_spatial = 2,
    masses =[1.0, 1.0],
    pes = pes
)
initial_snapshot = paths.Snapshot(
    coordinates=np.array([[-0.5, 0.0]]), 
    velocities=np.array([[0.0,0.0]]),
    potential_energy = 0.0, # Important to set energies dimensionless otherwise kcal/mol is default
    kinetic_energy = 0.0,
    topology=topology
)

# %% [markdown]
# ### Setup engine

# %%
integ = LangevinBAOABIntegrator(dt=0.02, temperature=0.1, gamma=1.0)
options={'integ' : integ,
         'n_frames_max' : 5000,
         'nsteps_per_frame' : 10
        }
sim = ToyEngine(
        options=options,
        template=initial_snapshot
)

sim.current_snapshot = initial_snapshot

# %% [markdown]
# Now let's take a look at our PES and our initial configuration:

# %%
plot.add_pes(pes)
plot.add_initial_condition(sim.current_snapshot)
plot.plot()

# %% [markdown]
# ### Interface setup
#
# One downside of the bootstrapping approach is that we need to have defined our interfaces before we start. However, we can always easily change our initial interface guesses.
#
# We'll consider a couple different choices of order parameter to define our interfaces. First we'll look at lines at different values of $x$. That set will be called `line_set`. Later we'll also consider circles centered on (-0.5, -0.25), with different radii. We'll call this set of interfaces `circle_set`.
#
# In both cases, we need to define the order parameter, and then we need to create a set of volumes and a set of ensembles associated with those volumes.

# %%
from openpathsampling.orderparameter import OP_Function
from openpathsampling.volume import VolumeFactory as vf
from openpathsampling.volume import LambdaVolume
from openpathsampling.trajectory import Trajectory

try:
    op_line = OP_Function(name="xval", 
                          fcn=lambda snap : snap.coordinates[0,0])
except ValueError:
    print "xval already made"
# this defines a set of LambdaVolumes for which the minimum is -1.0 and the maximum is given in the array
line_volume_set = vf.LambdaVolumeSet(op_line, minvals=-1.0, maxvals=[-0.30, -0.25, -0.20, -0.13, -0.05, 0.0])
stateA = LambdaVolume(op_line, -1.0, -0.3)
stateB = LambdaVolume(op_line, 0.3, 1.0)

# %%
plot.add_states([stateA, stateB])
plot.add_interfaces(line_volume_set)
plot.plot()

# %% [markdown]
# In this picture, the states are marked in blue, and the interfaces are drawn as red lines. The initial configuration is still the red dot.

# %% [markdown]
# ### First innermost interface path
#
# Now we have to create an initial path. This initial path shoud exit the state, cross the first interface, and then return to the state. We'll create this path by defining a special ensemble that, propagating forward from any initial snapshot, ends when the path ends with a segment in the appropriate interface.

# %%
from openpathsampling.ensemble import EnsembleFactory as ef
from openpathsampling.ensemble import LengthEnsemble, InXEnsemble, OutXEnsemble, SequentialEnsemble, OptionalEnsemble, SingleFrameEnsemble

interface0 = line_volume_set[0]
interface_ensemble_set = ef.TISEnsembleSet(stateA, stateB, line_volume_set)
first_traj_ensemble = SequentialEnsemble([
    OptionalEnsemble(OutXEnsemble(stateA)),
    InXEnsemble(stateA),
    OptionalEnsemble(OutXEnsemble(stateA) & InXEnsemble(interface0)),
    OptionalEnsemble(InXEnsemble(interface0)),
    OutXEnsemble(interface0),
    OptionalEnsemble(OutXEnsemble(stateA)),
    SingleFrameEnsemble(InXEnsemble(stateA))
])

# %% [markdown]
# This ensemble is a bit complicated, but works in the general case. To understand it, we'll look at the `SequentialEnsemble` segment by segment. One preliminary point is that we need the generated path ensemble to be the same as the accepted path ensemble in this case, meaning that we must define the ensemble entirely in terms of which volumes each segment is in (i.e., using `InXEnsemble` and `OutXEnsemble`, but not `LeaveXEnsemble` or `HitXEnsemble`).
#
# Start with the first two segments: we start with an optional ensemble outside the state, and then move to an ensemble that is in the state. Since our TIS segment must start in a state, these two ensembles allow us to either start outside the state and then evolve into the state, or to start inside the state. At the end of these two segments, we have the first frame of the TIS ensemble segment, i.e., the frame inside the state that begins the TIS path.
#
# Next we have a couple of optional ensembles, followed by an ensemble requiring the segment to be outside the interface. The optional interfaces here are only important if `stateA` and `interface0` represent different volumes. If they represent the same volume (which is the case here) these optional ensembles don't matter. However, if they are different volumes, then there is a space which is outside the state but inside the interface. So the first optional interface represents that space. The next optional interface says that you must then be inside `interface0`: this is in case there is a reentry into the state before you cross the interface. Next, we require that we cross the interface. The last optional ensemble is for segments ouside the state. If there is space between the interface and the state, then after you are no longer outside the interface you might still be outside the state. Finally, the path ends with one frame in the state.
#
# Following the logic of that, any path that begins anywhere and ends with a segment satisfying the innermost TIS ensemble will be accepted by this ensemble. Furthermore, since the ensemble is defined exclusively in terms of `InXEnsemble`s and `OutXEnsemble`s, the ensemble of paths generated by forward dynamics (`can_append`) is equivalent to the accepted path ensemble.

# %%
sim.initialized = True
first_traj = sim.generate(sim.current_snapshot, [first_traj_ensemble.can_append])
# Out:
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Through frame: 70
# Through frame: 80
# Through frame: 90
# Through frame: 100
# Through frame: 110
# Through frame: 120
# Through frame: 130
# Through frame: 140
# Through frame: 150
# Through frame: 160
# Through frame: 170
# Through frame: 180
# Through frame: 190
# Through frame: 200
# Through frame: 210
# Through frame: 220
# Through frame: 230
# Through frame: 240
# Through frame: 250
# Through frame: 260
# Through frame: 270
# Through frame: 280
# Through frame: 290
# Through frame: 300
# Through frame: 310
# Through frame: 320
# Through frame: 330
# Through frame: 340
# Through frame: 350
# Through frame: 360
# Through frame: 370
# Through frame: 380
# Through frame: 390
# Through frame: 400
# Through frame: 410
# Through frame: 420
# Through frame: 430
# Through frame: 440
# Through frame: 450
# Through frame: 460
# Through frame: 470
# Through frame: 480
# Through frame: 490
# Through frame: 500
# Through frame: 510
# Through frame: 520
# Through frame: 530
# Through frame: 540
# Through frame: 550
# Through frame: 560
# Through frame: 570
# Through frame: 580
# Through frame: 590
# Through frame: 600
# Through frame: 610
# Through frame: 620
# Through frame: 630
# Through frame: 640
# Through frame: 650
# Through frame: 660
# Through frame: 670
# Through frame: 680
# Through frame: 690
# Through frame: 700
# Through frame: 710
# Through frame: 720
# Through frame: 730
# Through frame: 740
# Through frame: 750
# Through frame: 760
# Through frame: 770
# Through frame: 780
# Through frame: 790
# Through frame: 800
# Through frame: 810
# Through frame: 820
# Through frame: 830
# Through frame: 840
# Through frame: 850
# Through frame: 860
# Through frame: 870
# Through frame: 880
# Through frame: 890
# Through frame: 900
# Through frame: 910
# Through frame: 920
# Through frame: 930
# Through frame: 940
# Through frame: 950
# Through frame: 960
# Through frame: 970
# Through frame: 980
# Through frame: 990
# Through frame: 1000
# Through frame: 1010
# Through frame: 1020
# Through frame: 1030
# Through frame: 1040
# Through frame: 1050
# Through frame: 1060
# Through frame: 1070
# Through frame: 1080
# Through frame: 1090
# Through frame: 1100
# Through frame: 1110
# Through frame: 1120
# Through frame: 1130
# Through frame: 1140
# Through frame: 1150
# Through frame: 1160
# Through frame: 1170
# Through frame: 1180
# Through frame: 1190
# Through frame: 1200
# Through frame: 1210
# Through frame: 1220
# Through frame: 1230
# Finished trajectory, length: 1237

# %% [markdown]
# Next we use the `Ensemble.split` function to split the trajectory we found into segments satisfying the innermost interface TIS ensemble. There is only one such segment, and so we assign the first (and only) one found to `subtraj`, which is the first trajectory satisfying the innermost TIS interface.

# %%
subtraj = interface_ensemble_set[0].split(first_traj)[0]

# %%
plot.plot(bold=[first_traj], trajectories=[subtraj])

# %% [markdown]
# Now we see how the initial path evolves on this surface. The last part of the trajectory, which satisfies the path ensemble for the innermost interface, is highlighted in red. The whole trajectory is drawn in black.

# %% [markdown]
# ### Bootstrapping
#
# The bootstrapping approach takes a single trajectory which satisfies the innermost interface, and does shooting moves until it satisfies the next ensemble. Once it satisfies the next ensemble, we start shooting from within that ensemble. We keep building up like that until all ensembles have an initial path.
#
# To do this, we need to first create the appropriate shooting movers (one for each path ensemble). This is done quickly and efficiently with a factory function.

# %%
from openpathsampling.pathmover import PathMoverFactory as mf
from openpathsampling.shooting import UniformSelector

# might be nice to get rid of these two lines somehow
from openpathsampling.pathmover import PathMover
PathMover.engine = sim

shooting_movers = mf.OneWayShootingSet(UniformSelector(), interface_ensemble_set)

# %% [markdown]
# Next we need to set up the Bootstrapping calculation:

# %%
from openpathsampling.calculation import Bootstrapping

bootstrap = Bootstrapping(storage=None,
                          engine=sim,
                          ensembles=interface_ensemble_set,
                          movers=shooting_movers,
                          trajectory=subtraj)

# %% [markdown]
# Now we run the bootstrapping. The number `50` means that we'll allow up to 50 shooting attempts per interface; if it takes more than that, you should probably adjust your interfaces (there's probably not much overlap for replica exchange).

# %%
bootstrap.run(500)
# Out:
# Step: 0   Ensemble: 0  failsteps = 0
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 45 in [0:57]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# Proposal probability 1.47368421053 / random : 0.31206797001
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a547d0> to <openpathsampling.ensemble.SequentialEnsemble object at 0x10afb0a10>
# Step: 1   Ensemble: 1  failsteps = 0
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 26 in [0:39]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 26
# Proposal probability 0.745098039216 / random : 0.429444900061
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x10afb0a10> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450>
# Step: 2   Ensemble: 1  failsteps = 1
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 49 in [0:52]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 30
# Proposal probability 1.59375 / random : 0.337373681016
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x10afb0a10> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450>
# Step: 3   Ensemble: 2  failsteps = 0
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 11 in [0:33]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 0.744186046512 / random : 0.337726673839
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90>
# Step: 4   Ensemble: 2  failsteps = 1
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 10 in [0:44]
# Starting trajectory
# Finished trajectory, length: 8
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90>
# Step: 5   Ensemble: 2  failsteps = 2
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 33 in [0:44]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90>
# Step: 6   Ensemble: 2  failsteps = 3
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:44]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 21
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90>
# Step: 7   Ensemble: 2  failsteps = 4
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 7 in [0:44]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 26
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90>
# Step: 8   Ensemble: 2  failsteps = 5
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 13 in [0:44]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 21
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90>
# Step: 9   Ensemble: 2  failsteps = 6
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 10 in [0:44]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90>
# Step: 10   Ensemble: 2  failsteps = 7
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 21 in [0:44]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 24
# Proposal probability 0.977272727273 / random : 0.794900408827
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90>
# Step: 11   Ensemble: 2  failsteps = 8
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 30 in [0:45]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Proposal probability 1.41935483871 / random : 0.300665726894
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90>
# Step: 12   Ensemble: 2  failsteps = 9
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 6 in [0:32]
# Starting trajectory
# Finished trajectory, length: 8
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90>
# Step: 13   Ensemble: 2  failsteps = 10
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 30 in [0:32]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 36
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90>
# Step: 14   Ensemble: 2  failsteps = 11
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 8 in [0:32]
# Starting trajectory
# Finished trajectory, length: 9
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90>
# Step: 15   Ensemble: 2  failsteps = 12
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 11 in [0:32]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 23
# Proposal probability 0.720930232558 / random : 0.130923858054
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90>
# Step: 16   Ensemble: 2  failsteps = 13
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 39 in [0:44]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 0.977272727273 / random : 0.734409588877
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90>
# Step: 17   Ensemble: 2  failsteps = 14
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 11 in [0:45]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90>
# Step: 18   Ensemble: 2  failsteps = 15
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 42 in [0:45]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.0 / random : 0.135737237648
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90>
# Step: 19   Ensemble: 2  failsteps = 16
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 13 in [0:45]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 40
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90>
# Step: 20   Ensemble: 2  failsteps = 17
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:45]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 40
# Proposal probability 0.55 / random : 0.788499032539
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90>
# Step: 21   Ensemble: 2  failsteps = 18
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 20 in [0:45]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 19
# Proposal probability 1.15789473684 / random : 0.569362499466
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90>
# Step: 22   Ensemble: 2  failsteps = 19
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 5 in [0:39]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.0 / random : 0.592078883101
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90>
# Step: 23   Ensemble: 2  failsteps = 20
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:39]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 0.678571428571 / random : 0.353422416602
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90>
# Step: 24   Ensemble: 2  failsteps = 21
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 47 in [0:57]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 23
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90>
# Step: 25   Ensemble: 2  failsteps = 22
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 41 in [0:57]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 20
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90>
# Step: 26   Ensemble: 2  failsteps = 23
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 17 in [0:57]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.27272727273 / random : 0.583742730492
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90>
# Step: 27   Ensemble: 2  failsteps = 24
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 39 in [0:45]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90>
# Step: 28   Ensemble: 2  failsteps = 25
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 44 in [0:45]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Finished trajectory, length: 69
# Proposal probability 0.63768115942 / random : 0.771580796659
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90>
# Step: 29   Ensemble: 2  failsteps = 26
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 11 in [0:45]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 21
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90>
# Step: 30   Ensemble: 2  failsteps = 27
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 24 in [0:45]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 1.15789473684 / random : 0.532405315111
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90>
# Step: 31   Ensemble: 2  failsteps = 28
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 35 in [0:39]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 24
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90>
# Step: 32   Ensemble: 2  failsteps = 29
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 12 in [0:39]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90>
# Step: 33   Ensemble: 2  failsteps = 30
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:39]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.710693599858
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90>
# Step: 34   Ensemble: 2  failsteps = 31
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 33 in [0:39]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 21
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90>
# Step: 35   Ensemble: 2  failsteps = 32
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 32 in [0:39]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90>
# Step: 36   Ensemble: 2  failsteps = 33
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 9 in [0:39]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 44
# Proposal probability 0.730769230769 / random : 0.358672080518
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90>
# Step: 37   Ensemble: 2  failsteps = 34
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 30 in [0:53]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# Proposal probability 1.10638297872 / random : 0.0811206844633
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90>
# Step: 38   Ensemble: 2  failsteps = 35
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 38 in [0:48]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 26
# Proposal probability 1.34285714286 / random : 0.850957368175
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90>
# Step: 39   Ensemble: 2  failsteps = 36
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:36]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 36
# Proposal probability 0.507246376812 / random : 0.527183122272
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90>
# Step: 40   Ensemble: 2  failsteps = 37
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 26 in [0:36]
# Starting trajectory
# Finished trajectory, length: 8
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90>
# Step: 41   Ensemble: 2  failsteps = 38
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 23 in [0:36]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 0.972222222222 / random : 0.389782364441
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90>
# Step: 42   Ensemble: 2  failsteps = 39
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 16 in [0:37]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 0.972972972973 / random : 0.632490294562
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90>
# Step: 43   Ensemble: 2  failsteps = 40
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 16 in [0:38]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# Proposal probability 0.770833333333 / random : 0.525879400245
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90>
# Step: 44   Ensemble: 2  failsteps = 41
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 15 in [0:49]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 21
# Proposal probability 1.37142857143 / random : 0.563541116252
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90>
# Step: 45   Ensemble: 2  failsteps = 42
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 10 in [0:36]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 34
# Proposal probability 0.593220338983 / random : 0.405126771549
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90>
# Step: 46   Ensemble: 2  failsteps = 43
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 28 in [0:60]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 31
# Proposal probability 1.01724137931 / random : 0.342075275678
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90>
# Step: 47   Ensemble: 2  failsteps = 44
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 8 in [0:59]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# Proposal probability 0.753246753247 / random : 0.0878292795021
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90>
# Step: 48   Ensemble: 2  failsteps = 45
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 68 in [0:78]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 1.01315789474 / random : 0.0569475187728
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90>
# Step: 49   Ensemble: 2  failsteps = 46
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 74 in [0:77]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.0 / random : 0.923052799351
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90>
# Step: 50   Ensemble: 2  failsteps = 47
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 60 in [0:77]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 2.0 / random : 0.218566317758
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62450> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90>
# Step: 51   Ensemble: 3  failsteps = 0
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 25 in [0:39]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 26
# Proposal probability 0.974358974359 / random : 0.38576713855
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 52   Ensemble: 3  failsteps = 1
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 13 in [0:40]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Proposal probability 0.906976744186 / random : 0.189048767864
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 53   Ensemble: 3  failsteps = 2
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 11 in [0:44]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 28
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 54   Ensemble: 3  failsteps = 3
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 33 in [0:44]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 37
# Proposal probability 0.914893617021 / random : 0.106932752104
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 55   Ensemble: 3  failsteps = 4
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 40 in [0:48]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 0.94 / random : 0.407596687377
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 56   Ensemble: 3  failsteps = 5
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 9 in [0:51]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 1.02040816327 / random : 0.453626580087
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 57   Ensemble: 3  failsteps = 6
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:50]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.241993373176
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 58   Ensemble: 3  failsteps = 7
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 10 in [0:50]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 33
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 59   Ensemble: 3  failsteps = 8
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 15 in [0:50]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 60   Ensemble: 3  failsteps = 9
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 42 in [0:50]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 32
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 61   Ensemble: 3  failsteps = 10
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 34 in [0:50]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 1.0652173913 / random : 0.847044806029
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 62   Ensemble: 3  failsteps = 11
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 27 in [0:47]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 1.24324324324 / random : 0.219889982655
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 63   Ensemble: 3  failsteps = 12
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 17 in [0:38]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# Proposal probability 0.90243902439 / random : 0.311089101062
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 64   Ensemble: 3  failsteps = 13
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 30 in [0:42]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 1.0 / random : 0.0301578271673
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 65   Ensemble: 3  failsteps = 14
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 22 in [0:42]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 21
# Proposal probability 1.025 / random : 0.826058486599
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 66   Ensemble: 3  failsteps = 15
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 27 in [0:41]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 26
# Proposal probability 0.769230769231 / random : 0.189969975103
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 67   Ensemble: 3  failsteps = 16
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 33 in [0:53]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Proposal probability 1.10638297872 / random : 0.138610450088
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 68   Ensemble: 3  failsteps = 17
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 22 in [0:48]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# Proposal probability 0.903846153846 / random : 0.980238224662
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 69   Ensemble: 3  failsteps = 18
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 32 in [0:48]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Proposal probability 0.979166666667 / random : 0.986716766714
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 70   Ensemble: 3  failsteps = 19
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 10 in [0:48]
# Starting trajectory
# Finished trajectory, length: 9
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 71   Ensemble: 3  failsteps = 20
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 33 in [0:48]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 42
# Proposal probability 0.839285714286 / random : 0.908895880409
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 72   Ensemble: 3  failsteps = 21
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 38 in [0:48]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 0.979166666667 / random : 0.750506036419
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 73   Ensemble: 3  failsteps = 22
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 47 in [0:49]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 46
# Proposal probability 1.02127659574 / random : 0.288555448171
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 74   Ensemble: 3  failsteps = 23
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 42 in [0:48]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Finished trajectory, length: 58
# Proposal probability 0.474747474747 / random : 0.713805711346
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 75   Ensemble: 3  failsteps = 24
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 25 in [0:48]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 31
# Proposal probability 0.88679245283 / random : 0.46297329427
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 76   Ensemble: 3  failsteps = 25
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 34 in [0:54]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 20
# Proposal probability 1.35897435897 / random : 0.585976453651
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 77   Ensemble: 3  failsteps = 26
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 26 in [0:40]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Proposal probability 1.3 / random : 0.407157386953
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 78   Ensemble: 3  failsteps = 27
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 13 in [0:31]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 48
# Proposal probability 0.5 / random : 0.47430426265
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 79   Ensemble: 3  failsteps = 28
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 41 in [0:61]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 16
# Proposal probability 1.07142857143 / random : 0.778626672244
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 80   Ensemble: 3  failsteps = 29
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 50 in [0:57]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Finished trajectory, length: 54
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 81   Ensemble: 3  failsteps = 30
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 51 in [0:57]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Through frame: 70
# Finished trajectory, length: 73
# Proposal probability 0.717948717949 / random : 0.769506889359
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 82   Ensemble: 3  failsteps = 31
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 8 in [0:57]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 29
# Proposal probability 0.727272727273 / random : 0.740070153902
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 83   Ensemble: 3  failsteps = 32
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 7 in [0:57]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Finished trajectory, length: 58
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 84   Ensemble: 3  failsteps = 33
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 50 in [0:57]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 0.982456140351 / random : 0.439528531996
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 85   Ensemble: 3  failsteps = 34
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 9 in [0:58]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 0.98275862069 / random : 0.953463840442
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 86   Ensemble: 3  failsteps = 35
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:59]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 46
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 87   Ensemble: 3  failsteps = 36
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 36 in [0:59]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 26
# Proposal probability 0.950819672131 / random : 0.342443091094
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 88   Ensemble: 3  failsteps = 37
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 52 in [0:62]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 1.03389830508 / random : 0.138868706814
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 89   Ensemble: 3  failsteps = 38
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 18 in [0:60]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# Proposal probability 0.867647058824 / random : 0.884411543396
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 90   Ensemble: 3  failsteps = 39
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 51 in [0:60]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 0.967213114754 / random : 0.716336808514
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 91   Ensemble: 3  failsteps = 40
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 59 in [0:62]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 41
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 92   Ensemble: 3  failsteps = 41
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 58 in [0:62]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 1.0 / random : 0.0410954952986
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 93   Ensemble: 3  failsteps = 42
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:62]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.485388987876
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 94   Ensemble: 3  failsteps = 43
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 14 in [0:62]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 1.03389830508 / random : 0.183224277599
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 95   Ensemble: 3  failsteps = 44
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 52 in [0:60]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 1.0 / random : 0.839026324646
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 96   Ensemble: 3  failsteps = 45
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 40 in [0:60]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 16
# Proposal probability 1.07272727273 / random : 0.706024655439
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 97   Ensemble: 3  failsteps = 46
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 19 in [0:56]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 16
# Proposal probability 1.05769230769 / random : 0.664494799563
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 98   Ensemble: 3  failsteps = 47
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:53]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Finished trajectory, length: 53
# Proposal probability 0.514851485149 / random : 0.908718722797
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 99   Ensemble: 3  failsteps = 48
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 45 in [0:53]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 1.0 / random : 0.741918739632
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 100   Ensemble: 3  failsteps = 49
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 26 in [0:53]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 32
# Proposal probability 0.912280701754 / random : 0.0455380098941
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a62d90> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250>
# Step: 101   Ensemble: 4  failsteps = 0
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 29 in [0:58]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 38
# Proposal probability 0.863636363636 / random : 0.270761203589
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a706d0>
# Step: 102   Ensemble: 4  failsteps = 1
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 19 in [0:67]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 0.95652173913 / random : 0.764212812247
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a706d0>
# Step: 103   Ensemble: 4  failsteps = 2
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:70]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.158850461926
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a706d0>
# Step: 104   Ensemble: 4  failsteps = 3
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 12 in [0:70]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a706d0>
# Step: 105   Ensemble: 4  failsteps = 4
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 31 in [0:70]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 35
# Proposal probability 0.945205479452 / random : 0.896072644192
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a706d0>
# Step: 106   Ensemble: 4  failsteps = 5
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 11 in [0:74]
# Starting trajectory
# Finished trajectory, length: 7
# Proposal probability 1.05797101449 / random : 0.81389361997
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a706d0>
# Step: 107   Ensemble: 4  failsteps = 6
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 7 in [0:70]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 38
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a706d0>
# Step: 108   Ensemble: 4  failsteps = 7
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 31 in [0:70]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 36
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a706d0>
# Step: 109   Ensemble: 4  failsteps = 8
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 58 in [0:70]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Finished trajectory, length: 52
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a706d0>
# Step: 110   Ensemble: 4  failsteps = 9
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:70]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.0268185768249
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a706d0>
# Step: 111   Ensemble: 4  failsteps = 10
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 56 in [0:70]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 1.0 / random : 0.390080120682
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a706d0>
# Step: 112   Ensemble: 4  failsteps = 11
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 35 in [0:70]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# Proposal probability 1.13114754098 / random : 0.558181009324
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a706d0>
# Step: 113   Ensemble: 4  failsteps = 12
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 44 in [0:62]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Proposal probability 1.05172413793 / random : 0.48427096743
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a706d0>
# Step: 114   Ensemble: 4  failsteps = 13
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 5 in [0:59]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.0 / random : 0.157839176261
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a706d0>
# Step: 115   Ensemble: 4  failsteps = 14
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 57 in [0:59]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 38
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a706d0>
# Step: 116   Ensemble: 4  failsteps = 15
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 17 in [0:59]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 0.983050847458 / random : 0.107806117706
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a706d0>
# Step: 117   Ensemble: 4  failsteps = 16
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 14 in [0:60]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 28
# Proposal probability 0.808219178082 / random : 0.200742135248
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a706d0>
# Step: 118   Ensemble: 4  failsteps = 17
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 22 in [0:74]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 23
# Proposal probability 0.986486486486 / random : 0.649712065151
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a706d0>
# Step: 119   Ensemble: 4  failsteps = 18
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 11 in [0:75]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Finished trajectory, length: 54
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a706d0>
# Step: 120   Ensemble: 4  failsteps = 19
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 72 in [0:75]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.0 / random : 0.134290088329
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a706d0>
# Step: 121   Ensemble: 4  failsteps = 20
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 6 in [0:75]
# Starting trajectory
# Finished trajectory, length: 6
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a706d0>
# Step: 122   Ensemble: 4  failsteps = 21
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 14 in [0:75]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 39
# Proposal probability 0.747474747475 / random : 0.476696516347
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a706d0>
# Step: 123   Ensemble: 4  failsteps = 22
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 32 in [0:100]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 19
# Proposal probability 1.1511627907 / random : 0.66786356698
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a706d0>
# Step: 124   Ensemble: 4  failsteps = 23
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 7 in [0:87]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 1.01176470588 / random : 0.635037710017
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a706d0>
# Step: 125   Ensemble: 4  failsteps = 24
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 84 in [0:86]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.0 / random : 0.0744341850933
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a706d0>
# Step: 126   Ensemble: 4  failsteps = 25
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 42 in [0:86]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a706d0>
# Step: 127   Ensemble: 4  failsteps = 26
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 38 in [0:86]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 24
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a706d0>
# Step: 128   Ensemble: 4  failsteps = 27
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 69 in [0:86]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Finished trajectory, length: 51
# Proposal probability 1.26865671642 / random : 0.287041055341
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a706d0>
# Step: 129   Ensemble: 4  failsteps = 28
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 16 in [0:68]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Finished trajectory, length: 50
# Proposal probability 0.663366336634 / random : 0.839168717307
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a706d0>
# Step: 130   Ensemble: 4  failsteps = 29
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 64 in [0:68]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 1.0 / random : 0.926347471037
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a706d0>
# Step: 131   Ensemble: 4  failsteps = 30
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 19 in [0:68]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 29
# Proposal probability 1.42553191489 / random : 0.92972236217
# Attempting ensemble hop from <openpathsampling.ensemble.SequentialEnsemble object at 0x117a70250> to <openpathsampling.ensemble.SequentialEnsemble object at 0x117a706d0>

# %% [markdown]
# We've stored all the trajectories we generated here; now we want to extract a path for each ensemble to use as a starting point for TIS. We'll choose to take the first path that satisfied each ensemble.

# %%
print "[ ",
for sample in bootstrap.globalstate:
    print str(sample.trajectory)+" ",
print "]"
# Out:
# [  Trajectory[58]  Trajectory[53]  Trajectory[78]  Trajectory[54]  Trajectory[69]  Trajectory[49]  ]

# %% [markdown]
# Let's go ahead and visualize where each of those trajectories are:

# %%
plot.plot([sample.trajectory for sample in bootstrap.globalstate])

# %% [markdown]
# ## Equilibration in the Path Ensemble
#
# At the end of the bootstrapping process, we have a set of paths which we can use to start TIS sampling. Before doing a production run, we should let these paths equilibrate within the ensembles. If you generate your initial path through dynamics that aren't the true dynamics (e.g., using high temperature runs or using metadynamics), this stage is **extremely** important. It's important here as well, but less so than if your initial path is non-physical.
#
# This will be an example of a "normal" TIS run, i.e., TIS without replica exchange. We will sampling using only shooter movers (the same ones defined for the bootstrapping) and path reversal movers. First we define these path reveral movers:

# %%
from openpathsampling.pathmover import PathReversalSet
reversal_movers = PathReversalSet(interface_ensemble_set)

# %% [markdown]
# Next we define global moves: we'll set this up so that each move either does a shooting move on all replicas, or does a path reversal move on all replicas. You can similarly set it up so that each move operates on only on one replica at a time.

# %%
from openpathsampling.pathmover import RandomChoiceMover
shooting_chooser = RandomChoiceMover(shooting_movers, name="ShootingChooser")
reversal_chooser = RandomChoiceMover(reversal_movers, name="ReversalChooser")
equilibration_movers = RandomChoiceMover([shooting_chooser, reversal_chooser])

# %% [markdown]
# Now we're ready to set up a TIS run:

# %%
from openpathsampling.calculation import PathSampling
equilibration = PathSampling(storage=None, engine=sim, root_mover=equilibration_movers, globalstate=bootstrap.globalstate)

# %% [markdown]
# And now we run it. We'll do 100 equilibration steps.

# %%
equilibration.run(100)
# Out:
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (ShootingChooser)
# RandomChoiceMover (ShootingChooser) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 19 in [0:48]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 38
# Proposal probability 0.712121212121 / random : 0.452180395314
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (ShootingChooser)
# RandomChoiceMover (ShootingChooser) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 23 in [0:52]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 1.02 / random : 0.209291877864
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 2 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 1 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 2 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (ShootingChooser)
# RandomChoiceMover (ShootingChooser) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 10 in [0:57]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 1.01818181818 / random : 0.673208293399
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (ShootingChooser)
# RandomChoiceMover (ShootingChooser) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 19 in [0:67]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 28
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (ShootingChooser)
# RandomChoiceMover (ShootingChooser) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 71 in [0:77]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 0.974358974359 / random : 0.0674696641623
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 2 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (ShootingChooser)
# RandomChoiceMover (ShootingChooser) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 50 in [0:79]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# Proposal probability 1.02631578947 / random : 0.766301582269
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 2 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 5 (PathReversalMover)
# PathReversal move accepted: False
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 4 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 5 (PathReversalMover)
# PathReversal move accepted: False
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (ShootingChooser)
# RandomChoiceMover (ShootingChooser) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 42 in [0:77]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 24
# Proposal probability 1.31034482759 / random : 0.420804627749
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 2 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 1 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (ShootingChooser)
# RandomChoiceMover (ShootingChooser) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 36 in [0:51]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# Proposal probability 1.28205128205 / random : 0.452897455439
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (ShootingChooser)
# RandomChoiceMover (ShootingChooser) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 24 in [0:67]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# Proposal probability 0.95652173913 / random : 0.100939035915
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 5 (PathReversalMover)
# PathReversal move accepted: False
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (ShootingChooser)
# RandomChoiceMover (ShootingChooser) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 47 in [0:56]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 23
# Proposal probability 0.797101449275 / random : 0.579676689144
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 3 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 0 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (ShootingChooser)
# RandomChoiceMover (ShootingChooser) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 32 in [0:70]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 36
# Proposal probability 1.02985074627 / random : 0.656484584749
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 1 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (ShootingChooser)
# RandomChoiceMover (ShootingChooser) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 4 in [0:68]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 41
# Proposal probability 1.52272727273 / random : 0.0838348584286
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (ShootingChooser)
# RandomChoiceMover (ShootingChooser) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 6 in [0:68]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 39
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (ShootingChooser)
# RandomChoiceMover (ShootingChooser) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:59]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.0 / random : 0.597136171372
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 4 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 3 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 1 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (ShootingChooser)
# RandomChoiceMover (ShootingChooser) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:45]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.02325581395 / random : 0.053904178057
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (ShootingChooser)
# RandomChoiceMover (ShootingChooser) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 13 in [0:53]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 0.912280701754 / random : 0.101197276563
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (ShootingChooser)
# RandomChoiceMover (ShootingChooser) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 12 in [0:40]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 1.95 / random : 0.618580551335
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 4 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 4 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 1 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 0 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 3 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (ShootingChooser)
# RandomChoiceMover (ShootingChooser) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 29 in [0:44]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 1.16216216216 / random : 0.100854685613
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (ShootingChooser)
# RandomChoiceMover (ShootingChooser) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 40 in [0:59]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 1.61111111111 / random : 0.942684842475
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 3 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 4 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 1 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (ShootingChooser)
# RandomChoiceMover (ShootingChooser) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 11 in [0:70]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 4 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (ShootingChooser)
# RandomChoiceMover (ShootingChooser) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 5 in [0:38]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 16
# Proposal probability 1.85 / random : 0.723095724272
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 1 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (ShootingChooser)
# RandomChoiceMover (ShootingChooser) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 33 in [0:68]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 28
# Proposal probability 1.11666666667 / random : 0.953744531117
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 2 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 3 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 5 (PathReversalMover)
# PathReversal move accepted: False
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 4 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 0 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (ShootingChooser)
# RandomChoiceMover (ShootingChooser) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 5 in [0:37]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# Proposal probability 1.16129032258 / random : 0.807168098336
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 5 (PathReversalMover)
# PathReversal move accepted: False
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (ShootingChooser)
# RandomChoiceMover (ShootingChooser) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 19 in [0:21]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 0.952380952381 / random : 0.938013607666
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 5 (PathReversalMover)
# PathReversal move accepted: False
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 3 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (ShootingChooser)
# RandomChoiceMover (ShootingChooser) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 5 in [0:21]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 43
# Proposal probability 0.425531914894 / random : 0.703855542408
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 3 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (ShootingChooser)
# RandomChoiceMover (ShootingChooser) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 26 in [0:58]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 38
# Proposal probability 0.904761904762 / random : 0.656840060649
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 1 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (ShootingChooser)
# RandomChoiceMover (ShootingChooser) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 10 in [0:70]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 2 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (ShootingChooser)
# RandomChoiceMover (ShootingChooser) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 25 in [0:70]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 40
# Proposal probability 0.821428571429 / random : 0.943546185942
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (ShootingChooser)
# RandomChoiceMover (ShootingChooser) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 52 in [0:61]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 0.967741935484 / random : 0.689496260847
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (ShootingChooser)
# RandomChoiceMover (ShootingChooser) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 55 in [0:63]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Finished trajectory, length: 62
# Proposal probability 0.898550724638 / random : 0.313505715909
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 1 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (ShootingChooser)
# RandomChoiceMover (ShootingChooser) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 16 in [0:32]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 23
# Proposal probability 0.815789473684 / random : 0.21887718945
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 3 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (ShootingChooser)
# RandomChoiceMover (ShootingChooser) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 24 in [0:70]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 28
# Proposal probability 1.35294117647 / random : 0.99631546048
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (ShootingChooser)
# RandomChoiceMover (ShootingChooser) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:52]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.0 / random : 0.0291714605428
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (ShootingChooser)
# RandomChoiceMover (ShootingChooser) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 32 in [0:39]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 44
# Proposal probability 0.76 / random : 0.90256479155
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (ShootingChooser)
# RandomChoiceMover (ShootingChooser) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 60 in [0:70]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 1.01470588235 / random : 0.91397609266
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 3 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (ShootingChooser)
# RandomChoiceMover (ShootingChooser) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 60 in [0:69]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 38
# Proposal probability 1.47826086957 / random : 0.317969172943
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 0 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 3 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 2 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (ShootingChooser)
# RandomChoiceMover (ShootingChooser) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:64]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 0.984375 / random : 0.201836129386
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (ShootingChooser)
# RandomChoiceMover (ShootingChooser) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 27 in [0:47]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 24
# Proposal probability 1.06976744186 / random : 0.0452275473799
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (ShootingChooser)
# RandomChoiceMover (ShootingChooser) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 17 in [0:52]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 37
# Proposal probability 0.962264150943 / random : 0.992546574772
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 2 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 3 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (ShootingChooser)
# RandomChoiceMover (ShootingChooser) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 13 in [0:39]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Proposal probability 0.95 / random : 0.46632913045
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 3 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 0 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 0 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 3 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (ShootingChooser)
# RandomChoiceMover (ShootingChooser) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 14 in [0:22]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 0.724137931034 / random : 0.51891669726
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (ShootingChooser)
# RandomChoiceMover (ShootingChooser) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 33 in [0:52]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 20
# Proposal probability 0.980769230769 / random : 0.761808652895
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (ShootingChooser)
# RandomChoiceMover (ShootingChooser) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:21]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.746496811077
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (ShootingChooser)
# RandomChoiceMover (ShootingChooser) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 21 in [0:30]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# Proposal probability 0.878787878788 / random : 0.725223326457
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 1 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 3 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (ShootingChooser)
# RandomChoiceMover (ShootingChooser) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 17 in [0:21]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 0.909090909091 / random : 0.280468807568
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 3 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (ShootingChooser)
# RandomChoiceMover (ShootingChooser) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 6 in [0:23]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (ShootingChooser)
# RandomChoiceMover (ShootingChooser) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 9 in [0:44]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 37

# %% [markdown]
# Now let's take a look at where the trajectories are after they've had a chance to equilibrate:

# %%
plot.plot([sample.trajectory for sample in equilibration.globalstate])

# %% [markdown]
# ## RETIS: Production run
#
# With everything else set up, we can set up the replica exchange movers, and reuse the other movers.

# %%
from openpathsampling.pathmover import NeighborEnsembleReplicaExchange
repex_movers = NeighborEnsembleReplicaExchange(interface_ensemble_set)
repex_chooser = RandomChoiceMover(repex_movers)

# %% [markdown]
# We'll also set up the minus ensemble and minus move:

# %%
minus_ensemble = paths.MinusInterfaceEnsemble(state_vol=stateA,
                                              innermost_vol=line_volume_set[0],
                                              n_l=2)
minus_move = paths.MinusMover(minus_ensemble=minus_ensemble,
                              innermost_ensemble=interface_ensemble_set[0])

# %% [markdown]
# We also have to create a path which is valid for the minus ensemble.

# %%
minus_segment = equilibration.globalstate[0].trajectory
last_frame = minus_segment[-1]
extension = sim.generate(last_frame, [minus_ensemble.can_append])
first_minus = minus_segment + extension[1:]
minus_samp = paths.Sample(
    replica=-1,
    trajectory=first_minus,
    ensemble=minus_ensemble,
    details=paths.MoveDetails.initialization(first_minus, minus_ensemble)
)
start_gs = equilibration.globalstate.apply_samples([minus_samp])
# Out:
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Through frame: 70
# Through frame: 80
# Through frame: 90
# Through frame: 100
# Through frame: 110
# Through frame: 120
# Through frame: 130
# Through frame: 140
# Through frame: 150
# Through frame: 160
# Through frame: 170
# Through frame: 180
# Through frame: 190
# Through frame: 200
# Through frame: 210
# Through frame: 220
# Through frame: 230
# Through frame: 240
# Through frame: 250
# Through frame: 260
# Through frame: 270
# Through frame: 280
# Through frame: 290
# Through frame: 300
# Through frame: 310
# Through frame: 320
# Through frame: 330
# Through frame: 340
# Through frame: 350
# Through frame: 360
# Through frame: 370
# Through frame: 380
# Through frame: 390
# Through frame: 400
# Through frame: 410
# Through frame: 420
# Through frame: 430
# Through frame: 440
# Through frame: 450
# Through frame: 460
# Through frame: 470
# Through frame: 480
# Through frame: 490
# Through frame: 500
# Through frame: 510
# Through frame: 520
# Through frame: 530
# Through frame: 540
# Through frame: 550
# Through frame: 560
# Through frame: 570
# Through frame: 580
# Through frame: 590
# Through frame: 600
# Through frame: 610
# Through frame: 620
# Through frame: 630
# Through frame: 640
# Through frame: 650
# Finished trajectory, length: 659

# %%
plot.plot([first_minus])

# %% [markdown]
# Finally, we set up a production run; this is very similar to the setup for the TIS equilibration run. However, up until now, we have not used file storage; before this run we will set up a storage file. The single storage file will save all the trajectories as well as all the details of the RETIS simulation (what movers are used, the acceptance of each trial, etc.)

# %%
storage = paths.storage.Storage('toy_tis.nc', mode='w', template=initial_snapshot)
# Out:
# Setup netCDF file and create variables
# Saving topology
# Create initial template snapshot
# Finished setting up netCDF file

# %%
retis_root_mover = RandomChoiceMover([shooting_chooser, reversal_chooser, repex_chooser, minus_move])
production = PathSampling(storage=storage, engine=sim, root_mover=retis_root_mover, globalstate=start_gs)

# %% [markdown]
# We'll run the production calculation for 50 MC steps.

# %%
production.run(10)
# Out:
# RandomChoiceMover (PathSamplingRoot) selecting mover index 3 (MinusMover)
# MinusMover starting mover index 0 (MinusSubtrajectoryChooser)
# RandomChoiceMover (MinusSubtrajectoryChooser) selecting mover index 0 (FirstSubtrajectorySelectMover)
# MinusMover starting mover index 1 (ReplicaExchangeMover)
# MinusMover starting mover index 2 (ForceEnsembleChangeMover)
# MinusMover starting mover index 3 (MinusExtensionDirectionChooser)
# RandomChoiceMover (MinusExtensionDirectionChooser) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 34 in [0:34]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Through frame: 70
# Through frame: 80
# Through frame: 90
# Through frame: 100
# Through frame: 110
# Through frame: 120
# Through frame: 130
# Through frame: 140
# Through frame: 150
# Through frame: 160
# Through frame: 170
# Through frame: 180
# Through frame: 190
# Through frame: 200
# Through frame: 210
# Through frame: 220
# Through frame: 230
# Through frame: 240
# Through frame: 250
# Through frame: 260
# Through frame: 270
# Through frame: 280
# Through frame: 290
# Through frame: 300
# Through frame: 310
# Through frame: 320
# Through frame: 330
# Through frame: 340
# Through frame: 350
# Through frame: 360
# Through frame: 370
# Through frame: 380
# Through frame: 390
# Through frame: 400
# Through frame: 410
# Through frame: 420
# Through frame: 430
# Through frame: 440
# Through frame: 450
# Through frame: 460
# Finished trajectory, length: 464
# Proposal probability 1.0 / random : 0.393754101828
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-ba716a166e33> in <module>()
# ----> 1 production.run(10)
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/calculation.pyc in run(self, nsteps)
#     260                                                               step=step)
#     261             if self.storage is not None:
# --> 262                 self.globalstate.save_samples(self.storage)
#     263                 self.globalstate.save(self.storage)
#     264                 self.storage.sync()
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/sample.pyc in save_samples(self, storage)
#     172             the underlying netcdf file to be used for storage
#     173         """
# --> 174         map(storage.sample.save, self.samples)
#     175
#     176     def sanity_check(self):
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/object_storage.pyc in inner(self, obj, idx, *args, **kwargs)
#     977     def inner(self, obj, idx = None, *args, **kwargs):
#     978         # call the normal storage
# --> 979         func(obj, idx, *args, **kwargs)
#     980         idx = obj.idx[self.storage]
#     981
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/object_storage.pyc in inner(self, obj, idx, *args, **kwargs)
#    1052
#    1053         obj.idx[storage] = idx
# -> 1054         func(obj, idx, *args, **kwargs)
#    1055
#    1056     return inner
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/sample_store.pyc in save(self, sample, idx)
#      20             self.save_variable('sample_replica', idx, sample.replica)
#      21
# ---> 22             self.storage.movedetails.save(sample.details)
#      23             self.set_object('sample_details', idx, sample.details)
#      24
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/object_storage.pyc in inner(self, obj, idx, *args, **kwargs)
#     977     def inner(self, obj, idx = None, *args, **kwargs):
#     978         # call the normal storage
# --> 979         func(obj, idx, *args, **kwargs)
#     980         idx = obj.idx[self.storage]
#     981
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/object_storage.pyc in inner(self, obj, idx, *args, **kwargs)
#    1052
#    1053         obj.idx[storage] = idx
# -> 1054         func(obj, idx, *args, **kwargs)
#    1055
#    1056     return inner
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/object_storage.pyc in save(self, obj, idx)
#     410             self.storage.variables[self.identifier][idx] = obj.name
#     411
# --> 412         self.save_object(self.idx_dimension + '_json', idx, obj)
#     413
#     414     def get_name(self, idx):
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/object_storage.pyc in save_object(self, name, idx, obj)
#     719         """
#     720         if not hasattr(obj,'json'):
# --> 721             setattr(obj, 'json', self.object_to_json(obj))
#     722
#     723         self.storage.variables[name][idx] = obj.json
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/object_storage.pyc in object_to_json(self, obj)
#     740             the JSON string
#     741         """
# --> 742         json_string = self.simplifier.to_json_object(obj, obj.base_cls_name)
#     743
#     744         return json_string
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/todict.pyc in to_json_object(self, obj, base_type)
#     110
#     111     def to_json_object(self, obj, base_type = ''):
# --> 112         simplified = self.simplify_object(obj, base_type)
#     113         return json.dumps(simplified)
#     114
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/todict.pyc in simplify_object(self, obj, base_type)
#      23
#      24     def simplify_object(self, obj, base_type = ''):
# ---> 25         return { '_cls' : obj.__class__.__name__, '_dict' : self.simplify(obj.to_dict(), obj.base_cls_name) }
#      26
#      27     def simplify(self, obj, base_type = ''):
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/storage.pyc in simplify(self, obj, base_type)
#     508                 return { '_idx' : obj.idx[self.storage], '_cls' : obj.__class__.__name__ }
#     509
# --> 510         return super(StorableObjectJSON, self).simplify(obj, base_type)
#     511
#     512     def build(self,obj):
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/todict.pyc in simplify(self, obj, base_type)
#      46             return tuple([self.simplify(o, base_type) for o in obj])
#      47         elif type(obj) is dict:
# ---> 48             result = {key : self.simplify(o, base_type) for key, o in obj.iteritems() if type(key) is str and key not in self.excluded_keys }
#      49             return result
#      50         elif type(obj) is slice:
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/todict.pyc in <dictcomp>((key, o))
#      46             return tuple([self.simplify(o, base_type) for o in obj])
#      47         elif type(obj) is dict:
# ---> 48             result = {key : self.simplify(o, base_type) for key, o in obj.iteritems() if type(key) is str and key not in self.excluded_keys }
#      49             return result
#      50         elif type(obj) is slice:
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/storage.pyc in simplify(self, obj, base_type)
#     508                 return { '_idx' : obj.idx[self.storage], '_cls' : obj.__class__.__name__ }
#     509
# --> 510         return super(StorableObjectJSON, self).simplify(obj, base_type)
#     511
#     512     def build(self,obj):
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/todict.pyc in simplify(self, obj, base_type)
#      42                 return None
#      43         elif type(obj) is list:
# ---> 44             return [self.simplify(o, base_type) for o in obj]
#      45         elif type(obj) is tuple:
#      46             return tuple([self.simplify(o, base_type) for o in obj])
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/storage.pyc in simplify(self, obj, base_type)
#     505                 # store objects only if they are not creatable. If so they will only be created in their
#     506                 # top instance and we use the simplify from the super class ObjectJSON
# --> 507                 self.storage.save(obj)
#     508                 return { '_idx' : obj.idx[self.storage], '_cls' : obj.__class__.__name__ }
#     509
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/storage.pyc in save(self, obj, *args, **kwargs)
#     355             if obj.base_cls in self._storages:
#     356                 store = self._storages[obj.base_cls]
# --> 357                 store.save(obj, *args, **kwargs)
#     358
#     359                 # save has been called, all is good
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/object_storage.pyc in inner(self, obj, idx, *args, **kwargs)
#     977     def inner(self, obj, idx = None, *args, **kwargs):
#     978         # call the normal storage
# --> 979         func(obj, idx, *args, **kwargs)
#     980         idx = obj.idx[self.storage]
#     981
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/object_storage.pyc in inner(self, obj, idx, *args, **kwargs)
#    1052
#    1053         obj.idx[storage] = idx
# -> 1054         func(obj, idx, *args, **kwargs)
#    1055
#    1056     return inner
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/object_storage.pyc in save(self, obj, idx)
#     410             self.storage.variables[self.identifier][idx] = obj.name
#     411
# --> 412         self.save_object(self.idx_dimension + '_json', idx, obj)
#     413
#     414     def get_name(self, idx):
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/object_storage.pyc in save_object(self, name, idx, obj)
#     719         """
#     720         if not hasattr(obj,'json'):
# --> 721             setattr(obj, 'json', self.object_to_json(obj))
#     722
#     723         self.storage.variables[name][idx] = obj.json
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/object_storage.pyc in object_to_json(self, obj)
#     740             the JSON string
#     741         """
# --> 742         json_string = self.simplifier.to_json_object(obj, obj.base_cls_name)
#     743
#     744         return json_string
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/todict.pyc in to_json_object(self, obj, base_type)
#     110
#     111     def to_json_object(self, obj, base_type = ''):
# --> 112         simplified = self.simplify_object(obj, base_type)
#     113         return json.dumps(simplified)
#     114
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/todict.pyc in simplify_object(self, obj, base_type)
#      23
#      24     def simplify_object(self, obj, base_type = ''):
# ---> 25         return { '_cls' : obj.__class__.__name__, '_dict' : self.simplify(obj.to_dict(), obj.base_cls_name) }
#      26
#      27     def simplify(self, obj, base_type = ''):
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/storage.pyc in simplify(self, obj, base_type)
#     508                 return { '_idx' : obj.idx[self.storage], '_cls' : obj.__class__.__name__ }
#     509
# --> 510         return super(StorableObjectJSON, self).simplify(obj, base_type)
#     511
#     512     def build(self,obj):
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/todict.pyc in simplify(self, obj, base_type)
#      46             return tuple([self.simplify(o, base_type) for o in obj])
#      47         elif type(obj) is dict:
# ---> 48             result = {key : self.simplify(o, base_type) for key, o in obj.iteritems() if type(key) is str and key not in self.excluded_keys }
#      49             return result
#      50         elif type(obj) is slice:
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/todict.pyc in <dictcomp>((key, o))
#      46             return tuple([self.simplify(o, base_type) for o in obj])
#      47         elif type(obj) is dict:
# ---> 48             result = {key : self.simplify(o, base_type) for key, o in obj.iteritems() if type(key) is str and key not in self.excluded_keys }
#      49             return result
#      50         elif type(obj) is slice:
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/storage.pyc in simplify(self, obj, base_type)
#     508                 return { '_idx' : obj.idx[self.storage], '_cls' : obj.__class__.__name__ }
#     509
# --> 510         return super(StorableObjectJSON, self).simplify(obj, base_type)
#     511
#     512     def build(self,obj):
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/todict.pyc in simplify(self, obj, base_type)
#      42                 return None
#      43         elif type(obj) is list:
# ---> 44             return [self.simplify(o, base_type) for o in obj]
#      45         elif type(obj) is tuple:
#      46             return tuple([self.simplify(o, base_type) for o in obj])
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/storage.pyc in simplify(self, obj, base_type)
#     505                 # store objects only if they are not creatable. If so they will only be created in their
#     506                 # top instance and we use the simplify from the super class ObjectJSON
# --> 507                 self.storage.save(obj)
#     508                 return { '_idx' : obj.idx[self.storage], '_cls' : obj.__class__.__name__ }
#     509
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/storage.pyc in save(self, obj, *args, **kwargs)
#     355             if obj.base_cls in self._storages:
#     356                 store = self._storages[obj.base_cls]
# --> 357                 store.save(obj, *args, **kwargs)
#     358
#     359                 # save has been called, all is good
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/object_storage.pyc in inner(self, obj, idx, *args, **kwargs)
#     977     def inner(self, obj, idx = None, *args, **kwargs):
#     978         # call the normal storage
# --> 979         func(obj, idx, *args, **kwargs)
#     980         idx = obj.idx[self.storage]
#     981
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/object_storage.pyc in inner(self, obj, idx, *args, **kwargs)
#    1052
#    1053         obj.idx[storage] = idx
# -> 1054         func(obj, idx, *args, **kwargs)
#    1055
#    1056     return inner
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/object_storage.pyc in save(self, obj, idx)
#     410             self.storage.variables[self.identifier][idx] = obj.name
#     411
# --> 412         self.save_object(self.idx_dimension + '_json', idx, obj)
#     413
#     414     def get_name(self, idx):
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/object_storage.pyc in save_object(self, name, idx, obj)
#     719         """
#     720         if not hasattr(obj,'json'):
# --> 721             setattr(obj, 'json', self.object_to_json(obj))
#     722
#     723         self.storage.variables[name][idx] = obj.json
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/object_storage.pyc in object_to_json(self, obj)
#     740             the JSON string
#     741         """
# --> 742         json_string = self.simplifier.to_json_object(obj, obj.base_cls_name)
#     743
#     744         return json_string
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/todict.pyc in to_json_object(self, obj, base_type)
#     110
#     111     def to_json_object(self, obj, base_type = ''):
# --> 112         simplified = self.simplify_object(obj, base_type)
#     113         return json.dumps(simplified)
#     114
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/todict.pyc in simplify_object(self, obj, base_type)
#      23
#      24     def simplify_object(self, obj, base_type = ''):
# ---> 25         return { '_cls' : obj.__class__.__name__, '_dict' : self.simplify(obj.to_dict(), obj.base_cls_name) }
#      26
#      27     def simplify(self, obj, base_type = ''):
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/storage.pyc in simplify(self, obj, base_type)
#     508                 return { '_idx' : obj.idx[self.storage], '_cls' : obj.__class__.__name__ }
#     509
# --> 510         return super(StorableObjectJSON, self).simplify(obj, base_type)
#     511
#     512     def build(self,obj):
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/todict.pyc in simplify(self, obj, base_type)
#      46             return tuple([self.simplify(o, base_type) for o in obj])
#      47         elif type(obj) is dict:
# ---> 48             result = {key : self.simplify(o, base_type) for key, o in obj.iteritems() if type(key) is str and key not in self.excluded_keys }
#      49             return result
#      50         elif type(obj) is slice:
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/todict.pyc in <dictcomp>((key, o))
#      46             return tuple([self.simplify(o, base_type) for o in obj])
#      47         elif type(obj) is dict:
# ---> 48             result = {key : self.simplify(o, base_type) for key, o in obj.iteritems() if type(key) is str and key not in self.excluded_keys }
#      49             return result
#      50         elif type(obj) is slice:
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/storage.pyc in simplify(self, obj, base_type)
#     508                 return { '_idx' : obj.idx[self.storage], '_cls' : obj.__class__.__name__ }
#     509
# --> 510         return super(StorableObjectJSON, self).simplify(obj, base_type)
#     511
#     512     def build(self,obj):
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/todict.pyc in simplify(self, obj, base_type)
#      42                 return None
#      43         elif type(obj) is list:
# ---> 44             return [self.simplify(o, base_type) for o in obj]
#      45         elif type(obj) is tuple:
#      46             return tuple([self.simplify(o, base_type) for o in obj])
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/storage.pyc in simplify(self, obj, base_type)
#     505                 # store objects only if they are not creatable. If so they will only be created in their
#     506                 # top instance and we use the simplify from the super class ObjectJSON
# --> 507                 self.storage.save(obj)
#     508                 return { '_idx' : obj.idx[self.storage], '_cls' : obj.__class__.__name__ }
#     509
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/storage.pyc in save(self, obj, *args, **kwargs)
#     355             if obj.base_cls in self._storages:
#     356                 store = self._storages[obj.base_cls]
# --> 357                 store.save(obj, *args, **kwargs)
#     358
#     359                 # save has been called, all is good
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/object_storage.pyc in inner(self, obj, idx, *args, **kwargs)
#     977     def inner(self, obj, idx = None, *args, **kwargs):
#     978         # call the normal storage
# --> 979         func(obj, idx, *args, **kwargs)
#     980         idx = obj.idx[self.storage]
#     981
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/object_storage.pyc in inner(self, obj, idx, *args, **kwargs)
#    1052
#    1053         obj.idx[storage] = idx
# -> 1054         func(obj, idx, *args, **kwargs)
#    1055
#    1056     return inner
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/object_storage.pyc in save(self, obj, idx)
#     410             self.storage.variables[self.identifier][idx] = obj.name
#     411
# --> 412         self.save_object(self.idx_dimension + '_json', idx, obj)
#     413
#     414     def get_name(self, idx):
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/object_storage.pyc in save_object(self, name, idx, obj)
#     719         """
#     720         if not hasattr(obj,'json'):
# --> 721             setattr(obj, 'json', self.object_to_json(obj))
#     722
#     723         self.storage.variables[name][idx] = obj.json
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/storage/object_storage.pyc in object_to_json(self, obj)
#     740             the JSON string
#     741         """
# --> 742         json_string = self.simplifier.to_json_object(obj, obj.base_cls_name)
#     743
#     744         return json_string
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/todict.pyc in to_json_object(self, obj, base_type)
#     111     def to_json_object(self, obj, base_type = ''):
#     112         simplified = self.simplify_object(obj, base_type)
# --> 113         return json.dumps(simplified)
#     114
#     115     def from_json(self, json_string):
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/__init__.pyc in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, encoding, default, sort_keys, **kw)
#     241         cls is None and indent is None and separators is None and
#     242         encoding == 'utf-8' and default is None and not sort_keys and not kw):
# --> 243         return _default_encoder.encode(obj)
#     244     if cls is None:
#     245         cls = JSONEncoder
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.pyc in encode(self, o)
#     205         # exceptions aren't as detailed.  The list call should be roughly
#     206         # equivalent to the PySequence_Fast that ''.join() would do.
# --> 207         chunks = self.iterencode(o, _one_shot=True)
#     208         if not isinstance(chunks, (list, tuple)):
#     209             chunks = list(chunks)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.pyc in iterencode(self, o, _one_shot)
#     268                 self.key_separator, self.item_separator, self.sort_keys,
#     269                 self.skipkeys, _one_shot)
# --> 270         return _iterencode(o, 0)
#     271
#     272 def _make_iterencode(markers, _default, _encoder, _indent, _floatstr,
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.pyc in default(self, o)
#     182
#     183         """
# --> 184         raise TypeError(repr(o) + " is not JSON serializable")
#     185
#     186     def encode(self, o):
#
# TypeError: <function <lambda> at 0x118ab9b90> is not JSON serializable

# %%
production.run(10)
# Out:
# RandomChoiceMover (PathSamplingRoot) selecting mover index 3 (MinusMover)
# MinusMover starting mover index 0 (MinusSubtrajectoryChooser)
# RandomChoiceMover (MinusSubtrajectoryChooser) selecting mover index 1 (FinalSubtrajectorySelectMover)
# MinusMover starting mover index 1 (ReplicaExchangeMover)
# MinusMover starting mover index 2 (ForceEnsembleChangeMover)
# MinusMover starting mover index 3 (MinusExtensionDirectionChooser)
# RandomChoiceMover (MinusExtensionDirectionChooser) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 34 in [0:34]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Through frame: 70
# Through frame: 80
# Through frame: 90
# Through frame: 100
# Through frame: 110
# Through frame: 120
# Through frame: 130
# Through frame: 140
# Through frame: 150
# Through frame: 160
# Through frame: 170
# Through frame: 180
# Through frame: 190
# Through frame: 200
# Through frame: 210
# Through frame: 220
# Through frame: 230
# Through frame: 240
# Finished trajectory, length: 243
# Proposal probability 1.0 / random : 0.465119738388
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 5 (PathReversalMover)
# PathReversal move accepted: False
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 3 (MinusMover)
# MinusMover starting mover index 0 (MinusSubtrajectoryChooser)
# RandomChoiceMover (MinusSubtrajectoryChooser) selecting mover index 1 (FinalSubtrajectorySelectMover)
# MinusMover starting mover index 1 (ReplicaExchangeMover)
# MinusMover starting mover index 2 (ForceEnsembleChangeMover)
# MinusMover starting mover index 3 (MinusExtensionDirectionChooser)
# RandomChoiceMover (MinusExtensionDirectionChooser) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 8 in [0:8]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Through frame: 70
# Through frame: 80
# Through frame: 90
# Through frame: 100
# Through frame: 110
# Through frame: 120
# Through frame: 130
# Through frame: 140
# Through frame: 150
# Through frame: 160
# Through frame: 170
# Through frame: 180
# Through frame: 190
# Through frame: 200
# Through frame: 210
# Through frame: 220
# Through frame: 230
# Through frame: 240
# Through frame: 250
# Through frame: 260
# Through frame: 270
# Through frame: 280
# Through frame: 290
# Through frame: 300
# Through frame: 310
# Through frame: 320
# Through frame: 330
# Through frame: 340
# Through frame: 350
# Through frame: 360
# Through frame: 370
# Through frame: 380
# Through frame: 390
# Through frame: 400
# Finished trajectory, length: 403
# Proposal probability 1.0 / random : 0.782441691238
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 0 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 3 (MinusMover)
# MinusMover starting mover index 0 (MinusSubtrajectoryChooser)
# RandomChoiceMover (MinusSubtrajectoryChooser) selecting mover index 0 (FirstSubtrajectorySelectMover)
# MinusMover starting mover index 1 (ReplicaExchangeMover)
# MinusMover starting mover index 2 (ForceEnsembleChangeMover)
# MinusMover starting mover index 3 (MinusExtensionDirectionChooser)
# RandomChoiceMover (MinusExtensionDirectionChooser) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 16 in [0:16]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Through frame: 70
# Through frame: 80
# Through frame: 90
# Finished trajectory, length: 97
# Proposal probability 1.0 / random : 0.209088346572
# RandomChoiceMover (PathSamplingRoot) selecting mover index 3 (MinusMover)
# MinusMover starting mover index 0 (MinusSubtrajectoryChooser)
# RandomChoiceMover (MinusSubtrajectoryChooser) selecting mover index 1 (FinalSubtrajectorySelectMover)
# MinusMover starting mover index 1 (ReplicaExchangeMover)
# MinusMover starting mover index 2 (ForceEnsembleChangeMover)
# MinusMover starting mover index 3 (MinusExtensionDirectionChooser)
# RandomChoiceMover (MinusExtensionDirectionChooser) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 8 in [0:8]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Through frame: 70
# Through frame: 80
# Through frame: 90
# Through frame: 100
# Through frame: 110
# Through frame: 120
# Through frame: 130
# Through frame: 140
# Through frame: 150
# Through frame: 160
# Through frame: 170
# Through frame: 180
# Through frame: 190
# Through frame: 200
# Through frame: 210
# Through frame: 220
# Through frame: 230
# Through frame: 240
# Through frame: 250
# Through frame: 260
# Through frame: 270
# Through frame: 280
# Through frame: 290
# Through frame: 300
# Finished trajectory, length: 304
# Proposal probability 1.0 / random : 0.635149125206
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (ReversalChooser)
# RandomChoiceMover (ReversalChooser) selecting mover index 1 (PathReversalMover)
# PathReversal move accepted: True
