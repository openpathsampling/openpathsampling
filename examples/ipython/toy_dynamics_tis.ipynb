# %%
# Note: in practice, one should put all the imports at the top of a Python script. 
# But for educational purposes here, I put the import immediately before usage. 
# This Python block is just to set up some plotting stuff.

# Imports for plotting
# %matplotlib inline
import opentis as paths
from toy_plot_helpers import ToyPlot
plot = ToyPlot()

# %% [markdown]
# # Setting up RETIS on a Toy Model
#
# This example shows how to set up a RETIS calculation. We do this on a simple 2D model so it can be fast enough for an interactive example, but the basic approach applies to larger systems as well. Although I'll describe everything here in terms of 2-state systems, all the ideas generalize when setting up multiple-state systems (you just need to find more initial paths).

# %% [markdown]
# ## Getting an initial path
#
# RETIS is a path sampling method: it requires that the user supply an input path for each path ensemble. This means that you must somehow generate a first input path. In general, getting the first input paths for RETIS boils down to solving two problems:
#
# 1. Getting a trajectory that samples the rare event.
# 2. Filling all the path ensembles with acceptable trajectories.
#
# Since transition paths satisfy all the path ensembles between two states, a common approach is to use the same initial path for all path ensembles (reversing it where necessary). This way, once you've solved problem 1, problem 2 is trivial.
#
# The first rare path can come from any number of sources. The obvious approach might be to find a transition path from a committor analysis, because this would give you a path that satisfies the true dynamics. However, the initial path doesn't need to satisfy the true dynamics of the system (later we will equilibrate the path ensemble anyway). This means that other approaches, such as high-temperature trajectories, can be used for the first path. One of the most widely-used methods to get an initial trajectory is to generate a transition trajectory using metadynamics. However, the downside of using paths that don't satisfy the true dynamics is that it might be harder to get them to equilibrate to the correct path ensemble. It seems that this has been more of a problem with paths from high temperature runs than with paths from metadynamics: a path from a modified potential energy surface at the correct temperature seems to equilibrate more easily than a path from the original potential energy surface at an incorrect temperature.
#
# In this example, we use a bootstrapping approach, which does create paths satisfying the true dynamics of the system. This bootstrapping is nice because it is quick and convenient, although it works best on smaller systems with less complicated transitions. It works by running normal MD to generate a path that satisfies the innermost interface, and then performing shooting moves in that interface's path ensemble until we have a path that crosses the next interface. Then we switch to the path ensemble for the next interface, and shoot until the path crossing the interface after that. The process continues until we have paths for all interfaces.

# %% [markdown]
# ### Basic system setup
#
# First we set up our system: for the toy dynamics, this involves defining a potential energy surface (PES), setting up an integrator, and giving the simulation an initial configuration. In real MD systems, the PES is handled by the combination of a topology file and a force field definition, and the initial configuration would come from a file instead of being described by hand.

# %%
from opentis.toy_dynamics.toy_engine import ToyEngine
from opentis.toy_dynamics.toy_integrators import LangevinBAOABIntegrator
from opentis.toy_dynamics.toy_pes import Gaussian, OuterWalls

import logging.config
logging.config.fileConfig("logging.conf", disable_existing_loggers=False)

# %%
# Toy_PES supports adding/subtracting various PESs. The OuterWalls PES type gives an x^6+y^6 boundary to the system
pes = (OuterWalls([1.0, 1.0], [0.0, 0.0]) + 
       Gaussian(2.0, [1.0, 4.0], [0.0,1.0]) + 
       Gaussian(2.0, [25.0, 1.0], [0.0, -1.0])
      )
integ = LangevinBAOABIntegrator(dt=0.02, temperature=0.1, gamma=1.0)
sim = ToyEngine(#filename=None,
                options={'pes' : pes, 
                         'integ' : integ,
                         'n_frames_max' : 5000,
                         'nsteps_per_frame' : 10}
               )

sim.mass = [1.0, 1.0]
sim.current_snapshot = paths.Snapshot(coordinates=[-0.5, 0.0], velocities=[0.0,0.0])

# %% [markdown]
# Now let's take a look at our PES and our initial configuration:

# %%
plot.add_pes(pes)
plot.add_initial_condition(sim.current_snapshot)
plot.plot()

# %% [markdown]
# ### Interface setup
#
# One downside of the bootstrapping approach is that we need to have defined our interfaces before we start. However, we can always easily change our initial interface guesses.
#
# We'll consider a couple different choices of order parameter to define our interfaces. First we'll look at lines at different values of $x$. That set will be called `line_set`. Later we'll also consider circles centered on (-0.5, -0.25), with different radii. We'll call this set of interfaces `circle_set`.
#
# In both cases, we need to define the order parameter, and then we need to create a set of volumes and a set of ensembles associated with those volumes.

# %%
from opentis.orderparameter import OP_Function
from opentis.volume import VolumeFactory as vf
from opentis.volume import LambdaVolume
from opentis.trajectory import Trajectory

# WTF? This is an extremely overcomplicated OP; shouldn't be so hard!
try:
    op_line = OP_Function(name="xval", 
                          fcn=lambda snap : Trajectory([snap])[0].coordinates()[0,0])
except ValueError:
    print "xval already made"
# this defines a set of LambdaVolumes for which the minimum is -1.0 and the maximum is given in the array
line_volume_set = vf.LambdaVolumeSet(op_line, minvals=-1.0, maxvals=[-0.30, -0.25, -0.20, -0.13, -0.05, 0.0])
stateA = LambdaVolume(op_line, -1.0, -0.3)
stateB = LambdaVolume(op_line, 0.3, 1.0)

# %%
plot.add_states([stateA, stateB])
plot.add_interfaces(line_volume_set)
plot.plot()

# %% [markdown]
# In this picture, the states are marked in blue, and the interfaces are drawn as red lines. The initial configuration is still the red dot.

# %% [markdown]
# ### First innermost interface path
#
# Now we have to create an initial path. This initial path shoud exit the state, cross the first interface, and then return to the state. We'll create this path by defining a special ensemble that, propagating forward from any initial snapshot, ends when the path ends with a segment in the appropriate interface.

# %%
from opentis.ensemble import EnsembleFactory as ef
from opentis.ensemble import LengthEnsemble, InXEnsemble, OutXEnsemble, SequentialEnsemble, OptionalEnsemble, SingleFrameEnsemble

interface0 = line_volume_set[0]
interface_ensemble_set = ef.TISEnsembleSet(stateA, stateB, line_volume_set)
first_traj_ensemble = SequentialEnsemble([
    OptionalEnsemble(OutXEnsemble(stateA)),
    InXEnsemble(stateA),
    OptionalEnsemble(OutXEnsemble(stateA) & InXEnsemble(interface0)),
    OptionalEnsemble(InXEnsemble(interface0)),
    OutXEnsemble(interface0),
    OptionalEnsemble(OutXEnsemble(stateA)),
    SingleFrameEnsemble(InXEnsemble(stateA))
])

# %% [markdown]
# This ensemble is a bit complicated, but works in the general case. To understand it, we'll look at the `SequentialEnsemble` segment by segment. One preliminary point is that we need the generated path ensemble to be the same as the accepted path ensemble in this case, meaning that we must define the ensemble entirely in terms of which volumes each segment is in (i.e., using `InXEnsemble` and `OutXEnsemble`, but not `LeaveXEnsemble` or `HitXEnsemble`).
#
# Start with the first two segments: we start with an optional ensemble outside the state, and then move to an ensemble that is in the state. Since our TIS segment must start in a state, these two ensembles allow us to either start outside the state and then evolve into the state, or to start inside the state. At the end of these two segments, we have the first frame of the TIS ensemble segment, i.e., the frame inside the state that begins the TIS path.
#
# Next we have a couple of optional ensembles, followed by an ensemble requiring the segment to be outside the interface. The optional interfaces here are only important if `stateA` and `interface0` represent different volumes. If they represent the same volume (which is the case here) these optional ensembles don't matter. However, if they are different volumes, then there is a space which is outside the state but inside the interface. So the first optional interface represents that space. The next optional interface says that you must then be inside `interface0`: this is in case there is a reentry into the state before you cross the interface. Next, we require that we cross the interface. The last optional ensemble is for segments ouside the state. If there is space between the interface and the state, then after you are no longer outside the interface you might still be outside the state. Finally, the path ends with one frame in the state.
#
# Following the logic of that, any path that begins anywhere and ends with a segment satisfying the innermost TIS ensemble will be accepted by this ensemble. Furthermore, since the ensemble is defined exclusively in terms of `InXEnsemble`s and `OutXEnsemble`s, the ensemble of paths generated by forward dynamics (`can_append`) is equivalent to the accepted path ensemble.

# %%
sim.initialized = True
first_traj = sim.generate(sim.current_snapshot, [first_traj_ensemble.can_append])
# Out:
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Finished trajectory, length: 63

# %% [markdown]
# Next we use the `Ensemble.split` function to split the trajectory we found into segments satisfying the innermost interface TIS ensemble. There is only one such segment, and so we assign the first (and only) one found to `subtraj`, which is the first trajectory satisfying the innermost TIS interface.

# %%
subtraj = interface_ensemble_set[0].split(first_traj)[0]

# %%
plot.plot(bold=[first_traj], trajectories=[subtraj])

# %% [markdown]
# Now we see how the initial path evolves on this surface. The last part of the trajectory, which satisfies the path ensemble for the innermost interface, is highlighted in red. The whole trajectory is drawn in black.

# %% [markdown]
# ### Bootstrapping
#
# The bootstrapping approach takes a single trajectory which satisfies the innermost interface, and does shooting moves until it satisfies the next ensemble. Once it satisfies the next ensemble, we start shooting from within that ensemble. We keep building up like that until all ensembles have an initial path.
#
# To do this, we need to first create the appropriate shooting movers (one for each path ensemble). This is done quickly and efficiently with a factory function.

# %%
from opentis.pathmover import PathMoverFactory as mf
from opentis.shooting import UniformSelector

# might be nice to get rid of these two lines somehow
from opentis.pathmover import PathMover
PathMover.engine = sim

shooting_movers = mf.OneWayShootingSet(UniformSelector(), interface_ensemble_set)

# %% [markdown]
# Next we need to set up the Bootstrapping calculation:

# %%
from opentis.calculation import Bootstrapping

# TODO: add storage
bootstrap = Bootstrapping(storage=None,
                          engine=sim,
                          ensembles=interface_ensemble_set,
                          movers=shooting_movers,
                          trajectory=subtraj)

# %%
for rep in bootstrap.globalstate.replica_list():
    traj = bootstrap.globalstate[rep]
    print traj, 
    if traj is not None:
        print (op_line(bootstrap.globalstate[rep]))
    else:
        print
# Out:
# Step: -1
# Replica: 0
# Trajectory: Trajectory[30]
# Ensemble: <opentis.ensemble.SequentialEnsemble object at 0x124295150>
# Details: result = None
# inputs = [Trajectory[30]]
# trial = Trajectory[30]
# mover_path = []
# mover = <opentis.pathmover.PathMover object at 0x1242b6690>
# accepted = True
# acceptance_probability = 1.0
#
#  None

# %% [markdown]
# Now we run the bootstrapping. The number `50` means that we'll allow up to 50 shooting attempts per interface; if it takes more than that, you should probably adjust your interfaces (there's probably not much overlap for replica exchange).

# %%
bootstrap.run(300)
# Out:
# Step: 0   Ensemble: 0  failsteps = 0
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:29]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Proposal probability 1.64705882353 / random : 0.326923808371
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124295150> to <opentis.ensemble.SequentialEnsemble object at 0x12427e990>
# Step: 1   Ensemble: 0  failsteps = 1
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 12 in [0:18]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 1.0 / random : 0.0544991169903
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124295150> to <opentis.ensemble.SequentialEnsemble object at 0x12427e990>
# Step: 2   Ensemble: 0  failsteps = 2
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 16 in [0:18]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.0 / random : 0.461390874719
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124295150> to <opentis.ensemble.SequentialEnsemble object at 0x12427e990>
# Step: 3   Ensemble: 0  failsteps = 3
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:18]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 29
# Proposal probability 0.586206896552 / random : 0.498233873277
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124295150> to <opentis.ensemble.SequentialEnsemble object at 0x12427e990>
# Step: 4   Ensemble: 1  failsteps = 0
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 4 in [0:30]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x12427e990> to <opentis.ensemble.SequentialEnsemble object at 0x124313190>
# Step: 5   Ensemble: 1  failsteps = 1
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 27 in [0:30]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.0 / random : 0.16674838088
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x12427e990> to <opentis.ensemble.SequentialEnsemble object at 0x124313190>
# Step: 6   Ensemble: 1  failsteps = 2
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 12 in [0:30]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Proposal probability 1.11538461538 / random : 0.0829570465851
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x12427e990> to <opentis.ensemble.SequentialEnsemble object at 0x124313190>
# Step: 7   Ensemble: 1  failsteps = 3
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 20 in [0:27]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 0.928571428571 / random : 0.647388191844
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x12427e990> to <opentis.ensemble.SequentialEnsemble object at 0x124313190>
# Step: 8   Ensemble: 1  failsteps = 4
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 8 in [0:29]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 21
# Proposal probability 1.0 / random : 0.599103619068
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x12427e990> to <opentis.ensemble.SequentialEnsemble object at 0x124313190>
# Step: 9   Ensemble: 1  failsteps = 5
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 12 in [0:29]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 16
# Proposal probability 1.03703703704 / random : 0.792307217447
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x12427e990> to <opentis.ensemble.SequentialEnsemble object at 0x124313190>
# Step: 10   Ensemble: 1  failsteps = 6
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 9 in [0:28]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 1.125 / random : 0.494071382454
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x12427e990> to <opentis.ensemble.SequentialEnsemble object at 0x124313190>
# Step: 11   Ensemble: 1  failsteps = 7
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 22 in [0:25]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 31
# Proposal probability 0.727272727273 / random : 0.810066085783
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x12427e990> to <opentis.ensemble.SequentialEnsemble object at 0x124313190>
# Step: 12   Ensemble: 1  failsteps = 8
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 4 in [0:25]
# Starting trajectory
# Finished trajectory, length: 3
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x12427e990> to <opentis.ensemble.SequentialEnsemble object at 0x124313190>
# Step: 13   Ensemble: 1  failsteps = 9
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 10 in [0:25]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 1.09090909091 / random : 0.999894656589
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x12427e990> to <opentis.ensemble.SequentialEnsemble object at 0x124313190>
# Step: 14   Ensemble: 1  failsteps = 10
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 9 in [0:23]
# Starting trajectory
# Finished trajectory, length: 7
# Proposal probability 1.1 / random : 0.2557630256
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x12427e990> to <opentis.ensemble.SequentialEnsemble object at 0x124313190>
# Step: 15   Ensemble: 1  failsteps = 11
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 17 in [0:21]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 21
# Proposal probability 0.833333333333 / random : 0.890764989224
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x12427e990> to <opentis.ensemble.SequentialEnsemble object at 0x124313190>
# Step: 16   Ensemble: 1  failsteps = 12
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 9 in [0:21]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 16
# Proposal probability 0.833333333333 / random : 0.299302969191
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x12427e990> to <opentis.ensemble.SequentialEnsemble object at 0x124313190>
# Step: 17   Ensemble: 1  failsteps = 13
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 21 in [0:25]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.04347826087 / random : 0.50171821372
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x12427e990> to <opentis.ensemble.SequentialEnsemble object at 0x124313190>
# Step: 18   Ensemble: 1  failsteps = 14
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 14 in [0:24]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 20
# Proposal probability 0.69696969697 / random : 0.927010994527
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x12427e990> to <opentis.ensemble.SequentialEnsemble object at 0x124313190>
# Step: 19   Ensemble: 1  failsteps = 15
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 6 in [0:24]
# Starting trajectory
# Finished trajectory, length: 6
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x12427e990> to <opentis.ensemble.SequentialEnsemble object at 0x124313190>
# Step: 20   Ensemble: 1  failsteps = 16
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 14 in [0:24]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 16
# Proposal probability 0.92 / random : 0.636436668914
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x12427e990> to <opentis.ensemble.SequentialEnsemble object at 0x124313190>
# Step: 21   Ensemble: 1  failsteps = 17
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 25 in [0:26]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# Proposal probability 0.925925925926 / random : 0.590424633779
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x12427e990> to <opentis.ensemble.SequentialEnsemble object at 0x124313190>
# Step: 22   Ensemble: 2  failsteps = 0
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 25 in [0:28]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 24
# Proposal probability 1.03846153846 / random : 0.603814950447
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 23   Ensemble: 2  failsteps = 1
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:27]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.04 / random : 0.393102380622
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 24   Ensemble: 2  failsteps = 2
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 14 in [0:26]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 0.961538461538 / random : 0.485834487302
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 25   Ensemble: 2  failsteps = 3
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 6 in [0:27]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 1.0 / random : 0.95086622355
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 26   Ensemble: 2  failsteps = 4
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 5 in [0:27]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 1.0 / random : 0.857175265912
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 27   Ensemble: 2  failsteps = 5
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 25 in [0:27]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 29
# Proposal probability 0.866666666667 / random : 0.453684001139
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 28   Ensemble: 2  failsteps = 6
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 28 in [0:31]
# Starting trajectory
# Finished trajectory, length: 3
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 29   Ensemble: 2  failsteps = 7
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:31]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 24
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 30   Ensemble: 2  failsteps = 8
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 5 in [0:31]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 0.967741935484 / random : 0.832542219602
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 31   Ensemble: 2  failsteps = 9
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 29 in [0:32]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 35
# Proposal probability 0.492063492063 / random : 0.76366832958
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 32   Ensemble: 2  failsteps = 10
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:32]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.359388653576
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 33   Ensemble: 2  failsteps = 11
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:32]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.998860841451
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 34   Ensemble: 2  failsteps = 12
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 15 in [0:32]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Proposal probability 1.06896551724 / random : 0.58894603224
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 35   Ensemble: 2  failsteps = 13
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 5 in [0:30]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.0 / random : 0.537421531372
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 36   Ensemble: 2  failsteps = 14
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 22 in [0:30]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 0.90625 / random : 0.913044145762
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 37   Ensemble: 2  failsteps = 15
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 10 in [0:30]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 20
# Proposal probability 1.0 / random : 0.572688479706
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 38   Ensemble: 2  failsteps = 16
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 12 in [0:30]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 20
# Proposal probability 0.935483870968 / random : 0.0638089548281
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 39   Ensemble: 2  failsteps = 17
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 19 in [0:32]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 20
# Proposal probability 0.96875 / random : 0.959467649251
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 40   Ensemble: 2  failsteps = 18
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 17 in [0:33]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 16
# Proposal probability 1.0 / random : 0.340064336646
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 41   Ensemble: 2  failsteps = 19
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 24 in [0:33]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 1.0 / random : 0.747059422882
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 42   Ensemble: 2  failsteps = 20
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 18 in [0:33]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Proposal probability 0.941176470588 / random : 0.893331793778
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 43   Ensemble: 2  failsteps = 21
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:35]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 19
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 44   Ensemble: 2  failsteps = 22
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 34 in [0:35]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.680245408483
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 45   Ensemble: 2  failsteps = 23
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 34 in [0:35]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.148701439371
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 46   Ensemble: 2  failsteps = 24
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:35]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.0 / random : 0.819406695623
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 47   Ensemble: 2  failsteps = 25
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 12 in [0:35]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 48   Ensemble: 2  failsteps = 26
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 9 in [0:35]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 20
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 49   Ensemble: 2  failsteps = 27
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:35]
# Starting trajectory
# Finished trajectory, length: 2
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 50   Ensemble: 2  failsteps = 28
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 13 in [0:35]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 28
# Proposal probability 0.85 / random : 0.880519142118
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 51   Ensemble: 2  failsteps = 29
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 15 in [0:35]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Proposal probability 1.09677419355 / random : 0.0830910233686
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 52   Ensemble: 2  failsteps = 30
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 5 in [0:32]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 32
# Proposal probability 0.861111111111 / random : 0.134323401242
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 53   Ensemble: 2  failsteps = 31
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 21 in [0:37]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 1.24137931034 / random : 0.877161809363
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 54   Ensemble: 2  failsteps = 32
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 12 in [0:30]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 0.935483870968 / random : 0.254040536731
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 55   Ensemble: 2  failsteps = 33
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 31 in [0:32]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.974022479979
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 56   Ensemble: 2  failsteps = 34
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 17 in [0:32]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Proposal probability 1.0 / random : 0.226270624386
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 57   Ensemble: 2  failsteps = 35
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 25 in [0:32]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 0.96875 / random : 0.494556500632
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 58   Ensemble: 2  failsteps = 36
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 26 in [0:33]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 21
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 59   Ensemble: 2  failsteps = 37
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 8 in [0:33]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Proposal probability 0.780487804878 / random : 0.56246494701
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 60   Ensemble: 2  failsteps = 38
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 11 in [0:42]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 0.953488372093 / random : 0.394234786257
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 61   Ensemble: 2  failsteps = 39
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 42 in [0:44]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 20
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 62   Ensemble: 2  failsteps = 40
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 34 in [0:44]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 1.0 / random : 0.527970668051
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 63   Ensemble: 2  failsteps = 41
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 43 in [0:44]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.963954945477
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 64   Ensemble: 2  failsteps = 42
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 43 in [0:44]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 65   Ensemble: 2  failsteps = 43
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 24 in [0:44]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Proposal probability 1.26470588235 / random : 0.693491442263
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 66   Ensemble: 2  failsteps = 44
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 19 in [0:35]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 1.0625 / random : 0.0713204639843
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 67   Ensemble: 2  failsteps = 45
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 15 in [0:33]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 1.18518518519 / random : 0.717468430015
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 68   Ensemble: 2  failsteps = 46
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 7 in [0:28]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 1.03846153846 / random : 0.522074291358
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 69   Ensemble: 2  failsteps = 47
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 19 in [0:27]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 0.962962962963 / random : 0.509674303822
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 70   Ensemble: 2  failsteps = 48
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 17 in [0:28]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 0.964285714286 / random : 0.112797514441
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 71   Ensemble: 2  failsteps = 49
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 26 in [0:29]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 31
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 72   Ensemble: 2  failsteps = 50
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 14 in [0:29]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 1.07692307692 / random : 0.906524979115
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 73   Ensemble: 2  failsteps = 51
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 20 in [0:27]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 0.962962962963 / random : 0.622579793005
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 74   Ensemble: 2  failsteps = 52
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 10 in [0:28]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 0.964285714286 / random : 0.377726956271
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 75   Ensemble: 2  failsteps = 53
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 5 in [0:29]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.0 / random : 0.734786882344
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 76   Ensemble: 2  failsteps = 54
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 8 in [0:29]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 77   Ensemble: 2  failsteps = 55
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 12 in [0:29]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 78   Ensemble: 2  failsteps = 56
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 15 in [0:29]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 1.03703703704 / random : 0.0206739636631
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 79   Ensemble: 2  failsteps = 57
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 13 in [0:28]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 1.03846153846 / random : 0.57367942276
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 80   Ensemble: 2  failsteps = 58
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 7 in [0:27]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 1.04 / random : 0.149865471011
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 81   Ensemble: 2  failsteps = 59
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 17 in [0:26]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 1.0 / random : 0.0473623625925
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 82   Ensemble: 2  failsteps = 60
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 7 in [0:26]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 16
# Proposal probability 0.735294117647 / random : 0.11069863498
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 83   Ensemble: 2  failsteps = 61
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 21 in [0:35]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 1.30769230769 / random : 0.345843320873
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 84   Ensemble: 2  failsteps = 62
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 6 in [0:27]
# Starting trajectory
# Finished trajectory, length: 8
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 85   Ensemble: 2  failsteps = 63
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:27]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.451908873338
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 86   Ensemble: 2  failsteps = 64
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 14 in [0:27]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 1.18181818182 / random : 0.809839715048
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 87   Ensemble: 2  failsteps = 65
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 18 in [0:23]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 0.95652173913 / random : 0.158304275875
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 88   Ensemble: 2  failsteps = 66
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 21 in [0:24]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# Proposal probability 0.851851851852 / random : 0.10313670343
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 89   Ensemble: 2  failsteps = 67
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 25 in [0:28]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 20
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 90   Ensemble: 2  failsteps = 68
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 16 in [0:28]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 0.931034482759 / random : 0.630200321708
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 91   Ensemble: 2  failsteps = 69
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:30]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 16
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 92   Ensemble: 2  failsteps = 70
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 23 in [0:30]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 23
# Proposal probability 1.0 / random : 0.984860347014
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 93   Ensemble: 2  failsteps = 71
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:30]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 21
# Proposal probability 1.26086956522 / random : 0.995601314737
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 94   Ensemble: 2  failsteps = 72
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 9 in [0:24]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 20
# Proposal probability 0.821428571429 / random : 0.843820447864
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 95   Ensemble: 2  failsteps = 73
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 14 in [0:24]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 0.851851851852 / random : 0.842069464186
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 96   Ensemble: 2  failsteps = 74
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 25 in [0:28]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 19
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 97   Ensemble: 2  failsteps = 75
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 16 in [0:28]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 98   Ensemble: 2  failsteps = 76
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 10 in [0:28]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Proposal probability 0.84375 / random : 0.218128743229
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 99   Ensemble: 2  failsteps = 77
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 28 in [0:33]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 0.969696969697 / random : 0.420779740221
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 100   Ensemble: 2  failsteps = 78
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 7 in [0:34]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 101   Ensemble: 2  failsteps = 79
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 24 in [0:34]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 23
# Proposal probability 1.03125 / random : 0.401329298801
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 102   Ensemble: 2  failsteps = 80
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 21 in [0:33]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 1.06666666667 / random : 0.562766798818
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 103   Ensemble: 2  failsteps = 81
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 5 in [0:31]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 23
# Proposal probability 1.11111111111 / random : 0.406424241485
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 104   Ensemble: 2  failsteps = 82
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 8 in [0:28]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 1.0 / random : 0.308665418884
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 105   Ensemble: 2  failsteps = 83
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 23 in [0:28]
# Starting trajectory
# Finished trajectory, length: 7
# Proposal probability 0.931034482759 / random : 0.274966252604
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 106   Ensemble: 2  failsteps = 84
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 7 in [0:30]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 107   Ensemble: 2  failsteps = 85
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 5 in [0:30]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.0 / random : 0.27541541859
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 108   Ensemble: 2  failsteps = 86
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 18 in [0:30]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 1.07407407407 / random : 0.597389638796
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 109   Ensemble: 2  failsteps = 87
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 18 in [0:28]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 16
# Proposal probability 1.08 / random : 0.272541690822
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 110   Ensemble: 2  failsteps = 88
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 20 in [0:26]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 28
# Proposal probability 0.757575757576 / random : 0.688204939304
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313190> to <opentis.ensemble.SequentialEnsemble object at 0x124313610>
# Step: 111   Ensemble: 2  failsteps = 89
# ...
# Shooting backward from frame 5 in [0:59]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.0 / random : 0.476474412729
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313610> to <opentis.ensemble.SequentialEnsemble object at 0x124313a90>
# Step: 238   Ensemble: 3  failsteps = 50
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 51 in [0:59]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 1.0 / random : 0.0476342726928
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313610> to <opentis.ensemble.SequentialEnsemble object at 0x124313a90>
# Step: 239   Ensemble: 3  failsteps = 51
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 43 in [0:59]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 1.05454545455 / random : 0.795083132523
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313610> to <opentis.ensemble.SequentialEnsemble object at 0x124313a90>
# Step: 240   Ensemble: 3  failsteps = 52
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 48 in [0:56]
# Starting trajectory
# Finished trajectory, length: 7
# Proposal probability 1.01851851852 / random : 0.501542121512
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313610> to <opentis.ensemble.SequentialEnsemble object at 0x124313a90>
# Step: 241   Ensemble: 3  failsteps = 53
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 12 in [0:55]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 34
# Proposal probability 1.2 / random : 0.297239265255
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313610> to <opentis.ensemble.SequentialEnsemble object at 0x124313a90>
# Step: 242   Ensemble: 3  failsteps = 54
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 22 in [0:46]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 21
# Proposal probability 1.07142857143 / random : 0.94560062815
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313610> to <opentis.ensemble.SequentialEnsemble object at 0x124313a90>
# Step: 243   Ensemble: 3  failsteps = 55
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 39 in [0:43]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 1.0 / random : 0.738144336326
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313610> to <opentis.ensemble.SequentialEnsemble object at 0x124313a90>
# Step: 244   Ensemble: 3  failsteps = 56
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 9 in [0:43]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 43
# Proposal probability 0.823529411765 / random : 0.862895443611
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313610> to <opentis.ensemble.SequentialEnsemble object at 0x124313a90>
# Step: 245   Ensemble: 3  failsteps = 57
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 33 in [0:43]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 34
# Proposal probability 0.976744186047 / random : 0.0153783588035
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313610> to <opentis.ensemble.SequentialEnsemble object at 0x124313a90>
# Step: 246   Ensemble: 3  failsteps = 58
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 21 in [0:44]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 34
# Proposal probability 0.796296296296 / random : 0.721329047311
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313610> to <opentis.ensemble.SequentialEnsemble object at 0x124313a90>
# Step: 247   Ensemble: 3  failsteps = 59
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 23 in [0:55]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 26
# Proposal probability 1.125 / random : 0.400871980231
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313610> to <opentis.ensemble.SequentialEnsemble object at 0x124313a90>
# Step: 248   Ensemble: 3  failsteps = 60
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 18 in [0:49]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 35
# Proposal probability 0.738461538462 / random : 0.405253340883
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313610> to <opentis.ensemble.SequentialEnsemble object at 0x124313a90>
# Step: 249   Ensemble: 3  failsteps = 61
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 46 in [0:66]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 23
# Proposal probability 0.955882352941 / random : 0.0417697324059
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313610> to <opentis.ensemble.SequentialEnsemble object at 0x124313a90>
# Step: 250   Ensemble: 3  failsteps = 62
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 11 in [0:69]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 39
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313610> to <opentis.ensemble.SequentialEnsemble object at 0x124313a90>
# Step: 251   Ensemble: 3  failsteps = 63
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 50 in [0:69]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 34
# Proposal probability 1.30769230769 / random : 0.717541735035
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313610> to <opentis.ensemble.SequentialEnsemble object at 0x124313a90>
# Step: 252   Ensemble: 3  failsteps = 64
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 10 in [0:53]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# Proposal probability 0.753623188406 / random : 0.934425827255
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313610> to <opentis.ensemble.SequentialEnsemble object at 0x124313a90>
# Step: 253   Ensemble: 3  failsteps = 65
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 35 in [0:53]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 42
# Proposal probability 0.881355932203 / random : 0.329931746216
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313610> to <opentis.ensemble.SequentialEnsemble object at 0x124313a90>
# Step: 254   Ensemble: 3  failsteps = 66
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 44 in [0:60]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 1.0350877193 / random : 0.735704308642
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313610> to <opentis.ensemble.SequentialEnsemble object at 0x124313a90>
# Step: 255   Ensemble: 3  failsteps = 67
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 9 in [0:58]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 1.01785714286 / random : 0.576658803856
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313610> to <opentis.ensemble.SequentialEnsemble object at 0x124313a90>
# Step: 256   Ensemble: 3  failsteps = 68
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 46 in [0:57]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 1.01818181818 / random : 0.983001821064
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313610> to <opentis.ensemble.SequentialEnsemble object at 0x124313a90>
# Step: 257   Ensemble: 3  failsteps = 69
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 22 in [0:56]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 26
# Proposal probability 0.932203389831 / random : 0.299654402715
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313610> to <opentis.ensemble.SequentialEnsemble object at 0x124313a90>
# Step: 258   Ensemble: 3  failsteps = 70
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 16 in [0:60]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Finished trajectory, length: 58
# Proposal probability 0.584158415842 / random : 0.040126392502
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313610> to <opentis.ensemble.SequentialEnsemble object at 0x124313a90>
# Step: 259   Ensemble: 4  failsteps = 0
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 46 in [0:102]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 31
# Proposal probability 1.32894736842 / random : 0.0989829052873
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313a90> to <opentis.ensemble.SequentialEnsemble object at 0x124313f10>
# Step: 260   Ensemble: 4  failsteps = 1
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 13 in [0:77]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 48
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313a90> to <opentis.ensemble.SequentialEnsemble object at 0x124313f10>
# Step: 261   Ensemble: 4  failsteps = 2
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 32 in [0:77]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 31
# Proposal probability 1.22580645161 / random : 0.238038605323
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313a90> to <opentis.ensemble.SequentialEnsemble object at 0x124313f10>
# Step: 262   Ensemble: 4  failsteps = 3
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 6 in [0:63]
# Starting trajectory
# Finished trajectory, length: 6
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313a90> to <opentis.ensemble.SequentialEnsemble object at 0x124313f10>
# Step: 263   Ensemble: 4  failsteps = 4
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 53 in [0:63]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 40
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313a90> to <opentis.ensemble.SequentialEnsemble object at 0x124313f10>
# Step: 264   Ensemble: 4  failsteps = 5
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 61 in [0:63]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 31
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313a90> to <opentis.ensemble.SequentialEnsemble object at 0x124313f10>
# Step: 265   Ensemble: 4  failsteps = 6
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 11 in [0:63]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 0.984126984127 / random : 0.816988253016
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313a90> to <opentis.ensemble.SequentialEnsemble object at 0x124313f10>
# Step: 266   Ensemble: 4  failsteps = 7
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 10 in [0:64]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 49
# Proposal probability 0.617647058824 / random : 0.80896211805
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313a90> to <opentis.ensemble.SequentialEnsemble object at 0x124313f10>
# Step: 267   Ensemble: 4  failsteps = 8
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:64]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Finished trajectory, length: 67
# Proposal probability 0.940298507463 / random : 0.149933798413
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313a90> to <opentis.ensemble.SequentialEnsemble object at 0x124313f10>
# Step: 268   Ensemble: 4  failsteps = 9
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 64 in [0:68]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 39
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313a90> to <opentis.ensemble.SequentialEnsemble object at 0x124313f10>
# Step: 269   Ensemble: 4  failsteps = 10
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 31 in [0:68]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# Proposal probability 1.21818181818 / random : 0.230098602045
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313a90> to <opentis.ensemble.SequentialEnsemble object at 0x124313f10>
# Step: 270   Ensemble: 4  failsteps = 11
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 55 in [0:56]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.548380934986
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313a90> to <opentis.ensemble.SequentialEnsemble object at 0x124313f10>
# Step: 271   Ensemble: 4  failsteps = 12
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 25 in [0:56]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# Proposal probability 1.07843137255 / random : 0.809320291039
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x124313a90> to <opentis.ensemble.SequentialEnsemble object at 0x124313f10>

# %% [markdown]
# We've stored all the trajectories we generated here; now we want to extract a path for each ensemble to use as a starting point for TIS. We'll choose to take the first path that satisfied each ensemble.

# %%
print "[ ",
for sample in bootstrap.globalstate:
    print str(sample.trajectory)+" ",
print "]"
# Out:
# [  Trajectory[19]  Trajectory[27]  Trajectory[43]  Trajectory[61]  Trajectory[57]  Trajectory[53]  ]

# %% [markdown]
# Let's go ahead and visualize where each of those trajectories are:

# %%
plot.plot([sample.trajectory for sample in bootstrap.globalstate])

# %% [markdown]
# ## Equilibration in the Path Ensemble
#
# At the end of the bootstrapping process, we have a set of paths which we can use to start TIS sampling. Before doing a production run, we should let these paths equilibrate within the ensembles. If you generate your initial path through dynamics that aren't the true dynamics (e.g., using high temperature runs or using metadynamics), this stage is **extremely** important. It's important here as well, but less so than if your initial path is non-physical.
#
# This will be an example of a "normal" TIS run, i.e., TIS without replica exchange. We will sampling using only shooter movers (the same ones defined for the bootstrapping) and path reversal movers. First we define these path reveral movers:

# %%
from opentis.pathmover import PathReversalSet
reversal_movers = PathReversalSet(interface_ensemble_set)

# %% [markdown]
# Next we define global moves: we'll set this up so that each move either does a shooting move on all replicas, or does a path reversal move on all replicas. You can similarly set it up so that each move operates on only on one replica at a time.

# %%
from opentis.pathmover import RandomChoiceMover
shooting_chooser = RandomChoiceMover(shooting_movers)
reversal_chooser = RandomChoiceMover(reversal_movers)
equilibration_movers = RandomChoiceMover([shooting_chooser, reversal_chooser])

# %% [markdown]
# Now we're ready to set up a TIS run:

# %%
from opentis.calculation import PathSampling
equilibration = PathSampling(storage=None, engine=sim, root_mover=equilibration_movers, globalstate=bootstrap.globalstate)

# %% [markdown]
# And now we run it. We'll do 200 equilibration steps.

# %%
equilibration.run(200)
# Out:
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 14 in [0:18]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 2.83333333333 / random : 0.215908100632
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 22 in [0:42]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 1.24242424242 / random : 0.173958064465
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:34]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 0.647058823529 / random : 0.937348903137
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 5 in [0:7]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 21
# Proposal probability 0.24 / random : 0.263701380746
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 4 in [0:60]
# Starting trajectory
# Finished trajectory, length: 3
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 47 in [0:52]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 40
# Proposal probability 0.593023255814 / random : 0.995399700705
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 7 in [0:34]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# Proposal probability 1.06451612903 / random : 0.797625117901
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 6 in [0:7]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.440133618946
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 26 in [0:60]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# Proposal probability 1.18 / random : 0.281201699319
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 31 in [0:56]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Finished trajectory, length: 55
# Proposal probability 0.696202531646 / random : 0.372676897419
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:26]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 1.08695652174 / random : 0.822293163429
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 20 in [0:80]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Finished trajectory, length: 59
# Proposal probability 1.01282051282 / random : 0.116071740218
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 15 in [0:32]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Proposal probability 1.0 / random : 0.429985631223
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 14 in [0:51]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 35
# Proposal probability 1.04166666667 / random : 0.530601754811
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 72 in [0:79]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 29
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 48 in [0:49]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Finished trajectory, length: 58
# Proposal probability 0.827586206897 / random : 0.26342986298
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:52]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Finished trajectory, length: 52
# Proposal probability 0.515151515152 / random : 0.809550500263
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 17 in [0:59]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 19
# Proposal probability 0.966666666667 / random : 0.14389108391
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 42 in [0:52]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 1.0 / random : 0.596164701506
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 18 in [0:24]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 1.0 / random : 0.744734620743
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 8 in [0:61]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 0.967741935484 / random : 0.592849058108
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:7]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.2 / random : 0.10283935479
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 57 in [0:79]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 43
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 29 in [0:63]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 23
# Proposal probability 1.21568627451 / random : 0.537985041243
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:32]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 1.0 / random : 0.234640860788
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 43 in [0:52]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:52]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 45
# Proposal probability 0.542553191489 / random : 0.656626607197
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 42 in [0:52]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 38 in [0:52]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 21
# Proposal probability 0.879310344828 / random : 0.169696446527
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 5 in [0:6]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 19
# Proposal probability 0.263157894737 / random : 0.793922513339
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 42 in [0:52]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 1.0 / random : 0.596116544104
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 6 in [0:24]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 1.0 / random : 0.658494085491
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 51 in [0:59]
# Starting trajectory
# Finished trajectory, length: 8
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 9 in [0:32]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 34
# Proposal probability 0.738095238095 / random : 0.732582623986
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:6]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 19
# Proposal probability 0.238095238095 / random : 0.523241788187
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:59]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Finished trajectory, length: 59
# Proposal probability 0.508771929825 / random : 0.400466084578
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:6]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.25 / random : 0.99300731644
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 38 in [0:79]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 30
# Proposal probability 1.11428571429 / random : 0.310732339836
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 17 in [0:24]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 0.821428571429 / random : 0.114873217834
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 88 in [0:115]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 1.04587155963 / random : 0.781811489753
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 7 in [0:110]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 32
# Proposal probability 0.813432835821 / random : 0.924880893987
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 34 in [0:52]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 1.0 / random : 0.982496229682
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 15 in [0:43]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 21
# Proposal probability 1.2 / random : 0.592995869441
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 49 in [0:71]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 1.0 / random : 0.872763673972
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 42 in [0:71]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 46
# Proposal probability 0.804597701149 / random : 0.562929288566
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:5]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.33333333333 / random : 0.0896096607296
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:4]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.419324733292
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 29 in [0:36]
# Starting trajectory
# Finished trajectory, length: 7
# Proposal probability 1.0 / random : 0.926656521847
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:4]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 19
# Proposal probability 0.157894736842 / random : 0.213089022561
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 37 in [0:52]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 38
# Proposal probability 0.980769230769 / random : 0.620049897739
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 28 in [0:29]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# Proposal probability 1.12 / random : 0.258203932521
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 7 in [0:53]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 48
# Proposal probability 0.962962962963 / random : 0.248197644443
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 8 in [0:26]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 0.714285714286 / random : 0.282101676145
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 14 in [0:36]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Proposal probability 0.972222222222 / random : 0.508703523872
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 97 in [0:110]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 1.00925925926 / random : 0.549054918147
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 16 in [0:109]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 34
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 54 in [0:88]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 43
# Proposal probability 1.14473684211 / random : 0.649170283254
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 10 in [0:55]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 32
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 13 in [0:37]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 1.0 / random : 0.147437068477
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:37]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 19
# Proposal probability 0.705882352941 / random : 0.25415757374
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:4]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.0 / random : 0.745966484331
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 8 in [0:55]
# Starting trajectory
# Finished trajectory, length: 8
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 47 in [0:77]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 40
# Proposal probability 0.883720930233 / random : 0.759680354978
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:4]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 21
# Proposal probability 0.136363636364 / random : 0.366996521551
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:4]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 0.75 / random : 0.875116561815
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 78 in [0:109]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 33
# Proposal probability 1.71428571429 / random : 0.0251646236672
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 32 in [0:36]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 28
# Proposal probability 0.593220338983 / random : 0.662488617833
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 44 in [0:52]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 1.04081632653 / random : 0.817354521614
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 8 in [0:87]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 32
# Proposal probability 0.781818181818 / random : 0.609786979014
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:4]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 0.75 / random : 0.860099429626
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:4]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 0.214285714286 / random : 0.447135253282
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:64]
# Starting trajectory
# Finished trajectory, length: 2
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 22 in [0:50]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 28
# Proposal probability 1.0 / random : 0.72825685227
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 61 in [0:64]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.0 / random : 0.462665040159
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:4]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 0.75 / random : 0.173670875382
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 16 in [0:55]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Finished trajectory, length: 53
# Proposal probability 0.593406593407 / random : 0.260621131194
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:5]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.0 / random : 0.944926407533
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 65 in [0:92]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 26
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:5]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.0 / random : 0.86875711393
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 22 in [0:64]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 37
# Proposal probability 0.807692307692 / random : 0.0299968595106
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 94 in [0:111]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 24
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:36]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.74637860954
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:5]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 16
# Proposal probability 0.25 / random : 0.819500727252
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 37 in [0:92]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 39
# Proposal probability 0.978494623656 / random : 0.124796442621
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 4 in [0:5]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.249391965943
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 78 in [0:79]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.380996072878
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 31 in [0:111]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 37
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 12 in [0:36]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 24
# Proposal probability 1.0 / random : 0.728813878302
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 94 in [0:111]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 45
# Proposal probability 0.797101449275 / random : 0.164034747925
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:5]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 0.4 / random : 0.757469293461
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 68 in [0:79]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 34
# Proposal probability 0.772277227723 / random : 0.0196981805924
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 79 in [0:139]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 40
# Proposal probability 1.16949152542 / random : 0.775456992715
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 24 in [0:94]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 40
# Proposal probability 0.853211009174 / random : 0.533787545169
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 28 in [0:50]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 19
# Proposal probability 1.0652173913 / random : 0.257397480313
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 16 in [0:47]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 31 in [0:47]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 19
# Proposal probability 1.35294117647 / random : 0.624755991925
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 75 in [0:110]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Finished trajectory, length: 55
# Proposal probability 1.22471910112 / random : 0.434059934076
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:5]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.33333333333 / random : 0.569329802459

# %% [markdown]
# Now let's take a look at where the trajectories are after they've had a chance to equilibrate:

# %%
plot.plot([sample.trajectory for sample in equilibration.globalstate])

# %% [markdown]
# ## RETIS: Production run
#
# With everything else set up, we can set up the replica exchange movers, and reuse the other movers.

# %%
from opentis.pathmover import NeighborEnsembleReplicaExchange
repex_movers = NeighborEnsembleReplicaExchange(interface_ensemble_set)
repex_chooser = RandomChoiceMover(repex_movers)

# %% [markdown]
# We'll also set up the minus ensemble and minus move:

# %%
# minus_ensemble
# minus_move

# %% [markdown]
# Finally, we set up a production run; this is very similar to the setup for the TIS equilibration run. However, up until now, we have not used file storage; before this run we will set up a storage file. The single storage file will save all the trajectories as well as all the details of the RETIS simulation (what movers are used, the acceptance of each trial, etc.)

# %%
#storage = paths.storage.Storage(
#    filename="toy_tis.nc",
#    template=sim.current_snapshot # that's an ugly hack
#)

# %%
retis_root_mover = RandomChoiceMover([shooting_chooser, reversal_chooser, repex_chooser])
production = PathSampling(storage=None, engine=sim, root_mover=retis_root_mover, globalstate=equilibration.globalstate)

# %% [markdown]
# We'll run the production calculation for 500 MC steps.

# %%
production.run(500)
# Out:
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:4]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.0486291505839
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 22 in [0:36]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 1.52173913043 / random : 0.700763763689
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 105 in [0:119]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 38
# Proposal probability 0.830985915493 / random : 0.447575064402
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 61 in [0:102]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 1.23170731707 / random : 0.9906661004
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 23 in [0:83]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 21
# Proposal probability 1.90697674419 / random : 0.875767522605
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:4]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.0 / random : 0.77554522169
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 5 in [0:35]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 0.971428571429 / random : 0.454514347627
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 67 in [0:143]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Finished trajectory, length: 51
# Proposal probability 1.21367521368 / random : 0.674538523125
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 70 in [0:90]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 20
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 105 in [0:118]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 1.0 / random : 0.413108459366
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 83 in [0:90]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 28 in [0:36]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 34
# Proposal probability 0.853658536585 / random : 0.345749744859
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 14 in [0:24]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 1.15 / random : 0.494582272834
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:4]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 19
# Proposal probability 0.15 / random : 0.00677366046798
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 14 in [0:21]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 0.833333333333 / random : 0.396546946837
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 18 in [0:25]
# Starting trajectory
# Finished trajectory, length: 7
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 39 in [0:44]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 43
# Proposal probability 0.530864197531 / random : 0.922260546888
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 20 in [0:21]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 20
# Proposal probability 1.0 / random : 0.287831782678
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 43 in [0:90]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# Proposal probability 1.28985507246 / random : 0.130946663005
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 14 in [0:42]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 21
# Proposal probability 0.854166666667 / random : 0.285244046083
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 44 in [0:70]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Finished trajectory, length: 51
# Proposal probability 0.734042553191 / random : 0.095448879487
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 21 in [0:118]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 19
# Proposal probability 3.0 / random : 0.33823212304
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:21]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.771203621278
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 39 in [0:95]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 33
# Proposal probability 1.06818181818 / random : 0.81346098108
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 6 in [0:44]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Through frame: 70
# Through frame: 80
# Finished trajectory, length: 88
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 8 in [0:25]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 19
# Proposal probability 0.923076923077 / random : 0.979785125521
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 6 in [0:21]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 1.05263157895 / random : 0.58724279077
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 4 in [0:25]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 3.0 / random : 0.0362860270625
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:44]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 40
# Proposal probability 0.530864197531 / random : 0.537637332661
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 25 in [0:40]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 0.928571428571 / random : 0.193926614122
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 8 in [0:9]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.453922104585
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 40 in [0:49]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 1.02127659574 / random : 0.671588167759
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 6 in [0:44]
# Starting trajectory
# Finished trajectory, length: 5
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:9]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 0.888888888889 / random : 0.169908465842
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 29 in [0:48]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 21
# Proposal probability 1.20512820513 / random : 0.142261431361
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 6 in [0:10]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 46
# Proposal probability 0.183673469388 / random : 0.798234778827
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:43]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Finished trajectory, length: 55
# Proposal probability 0.763636363636 / random : 0.810361541108
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 6 in [0:10]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 21
# Proposal probability 0.375 / random : 0.229759736879
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 38 in [0:44]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 1.0 / random : 0.277131134571
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 24 in [0:44]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 47
# Proposal probability 0.614285714286 / random : 0.626947521293
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:20]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.05555555556 / random : 0.295091411671
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 19 in [0:89]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 35
# Proposal probability 0.846153846154 / random : 0.143927166778
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 60 in [0:105]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 19
# Proposal probability 1.33333333333 / random : 0.423393099226
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 10 in [0:79]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 1.02631578947 / random : 0.377844516387
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 28 in [0:40]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 5 in [0:19]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 0.947368421053 / random : 0.704537013326
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 9 in [0:77]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Finished trajectory, length: 58
# Proposal probability 1.15151515152 / random : 0.00976080822597
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 11 in [0:25]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 16
# Proposal probability 0.827586206897 / random : 0.690098046293
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:20]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 0.95 / random : 0.0694820913451
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 13 in [0:44]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 1.02380952381 / random : 0.712415124477
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 29 in [0:30]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.278614844441
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 16 in [0:43]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 47
# Proposal probability 0.677419354839 / random : 0.311763151113
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 15 in [0:63]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 43
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 8 in [0:21]
# Starting trajectory
# Finished trajectory, length: 7
# Proposal probability 1.05263157895 / random : 0.702603488986
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# ...
# Proposal probability 0.542553191489 / random : 0.0904247421656
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 72 in [0:95]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 28
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:6]
# Starting trajectory
# Finished trajectory, length: 7
# Proposal probability 0.625 / random : 0.482998731455
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 25 in [0:29]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 1.0 / random : 0.00864784082143
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 14 in [0:55]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 1.54285714286 / random : 0.891366287228
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 5 in [0:29]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 28
# Proposal probability 0.875 / random : 0.0366810225059
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:40]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 24
# Proposal probability 1.56 / random : 0.697346647145
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:36]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 34
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 12 in [0:36]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 26
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 23 in [0:33]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 33
# Proposal probability 0.581818181818 / random : 0.69099600943
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:9]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.14285714286 / random : 0.777843641347
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:26]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 21
# Proposal probability 1.08695652174 / random : 0.764717224474
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 41 in [0:95]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 26 in [0:33]
# Starting trajectory
# Finished trajectory, length: 7
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:33]
# Starting trajectory
# Finished trajectory, length: 3
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 5 in [0:8]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 0.875 / random : 0.995452125326
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 23 in [0:24]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 42
# Proposal probability 0.547619047619 / random : 0.770138408724
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:8]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.664092575402
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 24 in [0:33]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 21
# Proposal probability 1.10344827586 / random : 0.913237027728
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:36]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 36
# Proposal probability 0.5 / random : 0.162551712935
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 86 in [0:95]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 30
# Proposal probability 0.817391304348 / random : 0.551531349679
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:30]
# Starting trajectory
# Finished trajectory, length: 2
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:8]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 1.16666666667 / random : 0.927578592234
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:7]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 0.6 / random : 0.366976629147
