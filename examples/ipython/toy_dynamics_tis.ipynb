# %%
# Note: in practice, one should put all the imports at the top of a Python script. 
# But for educational purposes here, I put the import immediately before usage. 
# This Python block is just to set up some plotting stuff.

# Imports for plotting
# %matplotlib inline
import opentis as paths
from toy_plot_helpers import ToyPlot
plot = ToyPlot()

# %% [markdown]
# # Setting up RETIS on a Toy Model
#
# This example shows how to set up a RETIS calculation. We do this on a simple 2D model so it can be fast enough for an interactive example, but the basic approach applies to larger systems as well. Although I'll describe everything here in terms of 2-state systems, all the ideas generalize when setting up multiple-state systems (you just need to find more initial paths).

# %% [markdown]
# ## Getting an initial path
#
# RETIS is a path sampling method: it requires that the user supply an input path for each path ensemble. This means that you must somehow generate a first input path. In general, getting the first input paths for RETIS boils down to solving two problems:
#
# 1. Getting a trajectory that samples the rare event.
# 2. Filling all the path ensembles with acceptable trajectories.
#
# Since transition paths satisfy all the path ensembles between two states, a common approach is to use the same initial path for all path ensembles (reversing it where necessary). This way, once you've solved problem 1, problem 2 is trivial.
#
# The first rare path can come from any number of sources. The obvious approach might be to find a transition path from a committor analysis, because this would give you a path that satisfies the true dynamics. However, the initial path doesn't need to satisfy the true dynamics of the system (later we will equilibrate the path ensemble anyway). This means that other approaches, such as high-temperature trajectories, can be used for the first path. One of the most widely-used methods to get an initial trajectory is to generate a transition trajectory using metadynamics. However, the downside of using paths that don't satisfy the true dynamics is that it might be harder to get them to equilibrate to the correct path ensemble. It seems that this has been more of a problem with paths from high temperature runs than with paths from metadynamics: a path from a modified potential energy surface at the correct temperature seems to equilibrate more easily than a path from the original potential energy surface at an incorrect temperature.
#
# In this example, we use a bootstrapping approach, which does create paths satisfying the true dynamics of the system. This bootstrapping is nice because it is quick and convenient, although it works best on smaller systems with less complicated transitions. It works by running normal MD to generate a path that satisfies the innermost interface, and then performing shooting moves in that interface's path ensemble until we have a path that crosses the next interface. Then we switch to the path ensemble for the next interface, and shoot until the path crossing the interface after that. The process continues until we have paths for all interfaces.

# %% [markdown]
# ### Basic system setup
#
# First we set up our system: for the toy dynamics, this involves defining a potential energy surface (PES), setting up an integrator, and giving the simulation an initial configuration. In real MD systems, the PES is handled by the combination of a topology file and a force field definition, and the initial configuration would come from a file instead of being described by hand.

# %%
from opentis.toy_dynamics.toy_engine import ToyEngine
from opentis.toy_dynamics.toy_integrators import LangevinBAOABIntegrator
from opentis.toy_dynamics.toy_pes import Gaussian, OuterWalls

import logging.config
logging.config.fileConfig("logging.conf", disable_existing_loggers=False)

# %%
# Toy_PES supports adding/subtracting various PESs. The OuterWalls PES type gives an x^6+y^6 boundary to the system
pes = (OuterWalls([1.0, 1.0], [0.0, 0.0]) + 
       Gaussian(2.0, [1.0, 4.0], [0.0,1.0]) + 
       Gaussian(2.0, [25.0, 1.0], [0.0, -1.0])
      )
integ = LangevinBAOABIntegrator(dt=0.02, temperature=0.1, gamma=1.0)
sim = ToyEngine(#filename=None,
                options={'pes' : pes, 
                         'integ' : integ,
                         'n_frames_max' : 5000,
                         'nsteps_per_frame' : 10}
               )

sim.mass = [1.0, 1.0]
sim.current_snapshot = paths.Snapshot(coordinates=[-0.5, 0.0], velocities=[0.0,0.0])

# %% [markdown]
# Now let's take a look at our PES and our initial configuration:

# %%
plot.add_pes(pes)
plot.add_initial_condition(sim.current_snapshot)
plot.plot()

# %% [markdown]
# ### Interface setup
#
# One downside of the bootstrapping approach is that we need to have defined our interfaces before we start. However, we can always easily change our initial interface guesses.
#
# We'll consider a couple different choices of order parameter to define our interfaces. First we'll look at lines at different values of $x$. That set will be called `line_set`. Later we'll also consider circles centered on (-0.5, -0.25), with different radii. We'll call this set of interfaces `circle_set`.
#
# In both cases, we need to define the order parameter, and then we need to create a set of volumes and a set of ensembles associated with those volumes.

# %%
from opentis.orderparameter import OP_Function
from opentis.volume import VolumeFactory as vf
from opentis.volume import LambdaVolume
from opentis.trajectory import Trajectory

# WTF? This is an extremely overcomplicated OP; shouldn't be so hard!
try:
    op_line = OP_Function(name="xval", 
                          fcn=lambda snap : Trajectory([snap])[0].coordinates()[0,0])
except ValueError:
    print "xval already made"
# this defines a set of LambdaVolumes for which the minimum is -1.0 and the maximum is given in the array
line_volume_set = vf.LambdaVolumeSet(op_line, minvals=-1.0, maxvals=[-0.30, -0.25, -0.20, -0.13, -0.05, 0.0])
stateA = LambdaVolume(op_line, -1.0, -0.3)
stateB = LambdaVolume(op_line, 0.3, 1.0)

# %%
plot.add_states([stateA, stateB])
plot.add_interfaces(line_volume_set)
plot.plot()

# %% [markdown]
# In this picture, the states are marked in blue, and the interfaces are drawn as red lines. The initial configuration is still the red dot.

# %% [markdown]
# ### First innermost interface path
#
# Now we have to create an initial path. This initial path shoud exit the state, cross the first interface, and then return to the state. We'll create this path by defining a special ensemble that, propagating forward from any initial snapshot, ends when the path ends with a segment in the appropriate interface.

# %%
from opentis.ensemble import EnsembleFactory as ef
from opentis.ensemble import LengthEnsemble, InXEnsemble, OutXEnsemble, SequentialEnsemble, OptionalEnsemble, SingleFrameEnsemble

interface0 = line_volume_set[0]
interface_ensemble_set = ef.TISEnsembleSet(stateA, stateB, line_volume_set)
first_traj_ensemble = SequentialEnsemble([
    OptionalEnsemble(OutXEnsemble(stateA)),
    InXEnsemble(stateA),
    OptionalEnsemble(OutXEnsemble(stateA) & InXEnsemble(interface0)),
    OptionalEnsemble(InXEnsemble(interface0)),
    OutXEnsemble(interface0),
    OptionalEnsemble(OutXEnsemble(stateA)),
    SingleFrameEnsemble(InXEnsemble(stateA))
])

# %% [markdown]
# This ensemble is a bit complicated, but works in the general case. To understand it, we'll look at the `SequentialEnsemble` segment by segment. One preliminary point is that we need the generated path ensemble to be the same as the accepted path ensemble in this case, meaning that we must define the ensemble entirely in terms of which volumes each segment is in (i.e., using `InXEnsemble` and `OutXEnsemble`, but not `LeaveXEnsemble` or `HitXEnsemble`).
#
# Start with the first two segments: we start with an optional ensemble outside the state, and then move to an ensemble that is in the state. Since our TIS segment must start in a state, these two ensembles allow us to either start outside the state and then evolve into the state, or to start inside the state. At the end of these two segments, we have the first frame of the TIS ensemble segment, i.e., the frame inside the state that begins the TIS path.
#
# Next we have a couple of optional ensembles, followed by an ensemble requiring the segment to be outside the interface. The optional interfaces here are only important if `stateA` and `interface0` represent different volumes. If they represent the same volume (which is the case here) these optional ensembles don't matter. However, if they are different volumes, then there is a space which is outside the state but inside the interface. So the first optional interface represents that space. The next optional interface says that you must then be inside `interface0`: this is in case there is a reentry into the state before you cross the interface. Next, we require that we cross the interface. The last optional ensemble is for segments ouside the state. If there is space between the interface and the state, then after you are no longer outside the interface you might still be outside the state. Finally, the path ends with one frame in the state.
#
# Following the logic of that, any path that begins anywhere and ends with a segment satisfying the innermost TIS ensemble will be accepted by this ensemble. Furthermore, since the ensemble is defined exclusively in terms of `InXEnsemble`s and `OutXEnsemble`s, the ensemble of paths generated by forward dynamics (`can_append`) is equivalent to the accepted path ensemble.

# %%
sim.initialized = True
first_traj = sim.generate(sim.current_snapshot, [first_traj_ensemble.can_append])
# Out:
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Through frame: 70
# Through frame: 80
# Through frame: 90
# Through frame: 100
# Through frame: 110
# Through frame: 120
# Through frame: 130
# Through frame: 140
# Through frame: 150
# Through frame: 160
# Through frame: 170
# Through frame: 180
# Through frame: 190
# Through frame: 200
# Through frame: 210
# Through frame: 220
# Through frame: 230
# Finished trajectory, length: 230

# %% [markdown]
# Next we use the `Ensemble.split` function to split the trajectory we found into segments satisfying the innermost interface TIS ensemble. There is only one such segment, and so we assign the first (and only) one found to `subtraj`, which is the first trajectory satisfying the innermost TIS interface.

# %%
subtraj = interface_ensemble_set[0].split(first_traj)[0]

# %%
plot.plot(bold=[first_traj], trajectories=[subtraj])

# %% [markdown]
# Now we see how the initial path evolves on this surface. The last part of the trajectory, which satisfies the path ensemble for the innermost interface, is highlighted in red. The whole trajectory is drawn in black.

# %% [markdown]
# ### Bootstrapping
#
# The bootstrapping approach takes a single trajectory which satisfies the innermost interface, and does shooting moves until it satisfies the next ensemble. Once it satisfies the next ensemble, we start shooting from within that ensemble. We keep building up like that until all ensembles have an initial path.
#
# To do this, we need to first create the appropriate shooting movers (one for each path ensemble). This is done quickly and efficiently with a factory function.

# %%
from opentis.pathmover import PathMoverFactory as mf
from opentis.shooting import UniformSelector

# might be nice to get rid of these two lines somehow
from opentis.pathmover import PathMover
PathMover.engine = sim

shooting_movers = mf.OneWayShootingSet(UniformSelector(), interface_ensemble_set)

# %% [markdown]
# Next we need to set up the Bootstrapping calculation:

# %%
from opentis.calculation import Bootstrapping

# TODO: add storage
bootstrap = Bootstrapping(storage=None,
                          engine=sim,
                          ensembles=interface_ensemble_set,
                          movers=shooting_movers,
                          trajectory=subtraj)

# %%
for rep in bootstrap.globalstate.replica_list():
    traj = bootstrap.globalstate[rep]
    print traj, 
    if traj is not None:
        print (op_line(bootstrap.globalstate[rep]))
    else:
        print
# Out:
# Step: -1
# Replica: 0
# Trajectory: Trajectory[7]
# Ensemble: <opentis.ensemble.SequentialEnsemble object at 0x108648850>
# Details: result = None
# inputs = [Trajectory[7]]
# trial = Trajectory[7]
# mover_path = []
# mover = <opentis.pathmover.PathMover object at 0x115897f10>
# accepted = True
# acceptance_probability = 1.0
#
#  None

# %% [markdown]
# Now we run the bootstrapping. The number `50` means that we'll allow up to 50 shooting attempts per interface; if it takes more than that, you should probably adjust your interfaces (there's probably not much overlap for replica exchange).

# %%
bootstrap.run(300)
# Out:
# Step: 0   Ensemble: 0  failsteps = 0
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 5 in [0:6]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.419244501763
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 1   Ensemble: 0  failsteps = 1
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:6]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 0.555555555556 / random : 0.985632055032
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 2   Ensemble: 0  failsteps = 2
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:6]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.540386639903
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 3   Ensemble: 0  failsteps = 3
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:6]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.0 / random : 0.110861416006
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 4   Ensemble: 0  failsteps = 4
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:6]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 0.277777777778 / random : 0.831701199595
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 5   Ensemble: 0  failsteps = 5
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:6]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 0.3125 / random : 0.808867109503
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 6   Ensemble: 0  failsteps = 6
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:6]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 0.714285714286 / random : 0.933448790432
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 7   Ensemble: 0  failsteps = 7
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:6]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.66666666667 / random : 0.895998986921
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 8   Ensemble: 0  failsteps = 8
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:4]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.657377734008
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 9   Ensemble: 0  failsteps = 9
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:4]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 0.75 / random : 0.802624352834
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 10   Ensemble: 0  failsteps = 10
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:4]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 0.75 / random : 0.719314463968
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 11   Ensemble: 0  failsteps = 11
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:5]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.361162590304
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 12   Ensemble: 0  failsteps = 12
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:5]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 0.4 / random : 0.57240127685
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 13   Ensemble: 0  failsteps = 13
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:5]
# Starting trajectory
# Finished trajectory, length: 7
# Proposal probability 0.444444444444 / random : 0.482778175633
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 14   Ensemble: 0  failsteps = 14
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:5]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.491234719009
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 15   Ensemble: 0  failsteps = 15
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:5]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 0.4 / random : 0.962469844411
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 16   Ensemble: 0  failsteps = 16
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:5]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.33333333333 / random : 0.0666908273152
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 17   Ensemble: 0  failsteps = 17
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:4]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 0.75 / random : 0.485959245784
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 18   Ensemble: 0  failsteps = 18
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:5]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 0.571428571429 / random : 0.176463340805
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 19   Ensemble: 0  failsteps = 19
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:8]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.4 / random : 0.922509298566
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 20   Ensemble: 0  failsteps = 20
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 5 in [0:6]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Proposal probability 0.333333333333 / random : 0.437081774649
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 21   Ensemble: 0  failsteps = 21
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:6]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.25 / random : 0.544893680297
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 22   Ensemble: 0  failsteps = 22
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:5]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 0.333333333333 / random : 0.729230971546
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 23   Ensemble: 0  failsteps = 23
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:5]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 2.0 / random : 0.0618533910941
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 24   Ensemble: 0  failsteps = 24
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:3]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 0.142857142857 / random : 0.553138456047
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 25   Ensemble: 0  failsteps = 25
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:3]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 0.666666666667 / random : 0.749840628927
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 26   Ensemble: 0  failsteps = 26
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:3]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 0.666666666667 / random : 0.0155128772822
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 27   Ensemble: 0  failsteps = 27
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:4]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 0.5 / random : 0.218783978816
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 28   Ensemble: 0  failsteps = 28
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 6 in [0:7]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.298425373196
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 29   Ensemble: 0  failsteps = 29
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:7]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.5 / random : 0.521298109745
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 30   Ensemble: 0  failsteps = 30
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:5]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 0.333333333333 / random : 0.929793379147
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 31   Ensemble: 0  failsteps = 31
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:5]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 0.444444444444 / random : 0.369646844582
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 32   Ensemble: 0  failsteps = 32
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 4 in [0:10]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 0.642857142857 / random : 0.136759741114
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 33   Ensemble: 0  failsteps = 33
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 4 in [0:15]
# Starting trajectory
# Finished trajectory, length: 7
# Proposal probability 1.4 / random : 0.174984239558
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 34   Ensemble: 0  failsteps = 34
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 4 in [0:11]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Finished trajectory, length: 61
# Proposal probability 0.15625 / random : 0.693763054481
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 35   Ensemble: 0  failsteps = 35
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 9 in [0:11]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 1.0 / random : 0.961907499654
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 36   Ensemble: 0  failsteps = 36
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 7 in [0:11]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# Proposal probability 0.357142857143 / random : 0.567346816631
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 37   Ensemble: 0  failsteps = 37
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:11]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.930758888183
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 38   Ensemble: 0  failsteps = 38
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 7 in [0:11]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 0.588235294118 / random : 0.790065939912
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 39   Ensemble: 0  failsteps = 39
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:11]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.861717935583
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 40   Ensemble: 0  failsteps = 40
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 6 in [0:11]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 1.25 / random : 0.416502888304
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 41   Ensemble: 0  failsteps = 41
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:9]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 0.615384615385 / random : 0.557653521192
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 42   Ensemble: 0  failsteps = 42
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 12 in [0:14]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 1.18181818182 / random : 0.863096177838
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 43   Ensemble: 0  failsteps = 43
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 8 in [0:12]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 1.57142857143 / random : 0.149739560179
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 44   Ensemble: 0  failsteps = 44
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:8]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# Proposal probability 0.259259259259 / random : 0.531201664019
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 45   Ensemble: 0  failsteps = 45
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 7 in [0:8]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 1.16666666667 / random : 0.730245846764
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 46   Ensemble: 0  failsteps = 46
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:7]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 16
# Proposal probability 0.375 / random : 0.829908967372
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 47   Ensemble: 0  failsteps = 47
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:7]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.0 / random : 0.988333815782
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 48   Ensemble: 0  failsteps = 48
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:7]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Proposal probability 0.4 / random : 0.304233949515
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 49   Ensemble: 0  failsteps = 49
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 4 in [0:16]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 1.66666666667 / random : 0.582239600429
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 50   Ensemble: 0  failsteps = 50
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 5 in [0:10]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 0.9 / random : 0.790477952922
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 51   Ensemble: 0  failsteps = 51
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:11]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.0 / random : 0.402277368165
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 52   Ensemble: 0  failsteps = 52
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 6 in [0:11]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.0 / random : 0.426050922566
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 53   Ensemble: 0  failsteps = 53
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 9 in [0:11]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 0.909090909091 / random : 0.495763597328
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 54   Ensemble: 0  failsteps = 54
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:12]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.18823013238
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 55   Ensemble: 0  failsteps = 55
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 9 in [0:12]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 0.846153846154 / random : 0.199840570784
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 56   Ensemble: 0  failsteps = 56
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 12 in [0:14]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 3.25 / random : 0.54175697264
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 57   Ensemble: 0  failsteps = 57
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:5]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# Proposal probability 0.148148148148 / random : 0.720101201857
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 58   Ensemble: 0  failsteps = 58
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:5]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 0.571428571429 / random : 0.584541967878
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 59   Ensemble: 0  failsteps = 59
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:5]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 2.0 / random : 0.208027592825
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 60   Ensemble: 0  failsteps = 60
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:3]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.419945236058
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 61   Ensemble: 0  failsteps = 61
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:3]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.858348090158
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 62   Ensemble: 0  failsteps = 62
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:3]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 0.666666666667 / random : 0.324104027688
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 63   Ensemble: 0  failsteps = 63
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:4]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 0.5 / random : 0.214077915158
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 64   Ensemble: 0  failsteps = 64
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:7]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.2 / random : 0.974932309499
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 65   Ensemble: 0  failsteps = 65
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:6]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.885275063139
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 66   Ensemble: 0  failsteps = 66
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 5 in [0:6]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 0.384615384615 / random : 0.648342018068
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 67   Ensemble: 0  failsteps = 67
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:6]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.25 / random : 0.0892768471071
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 68   Ensemble: 0  failsteps = 68
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:5]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.0 / random : 0.562604225358
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 69   Ensemble: 0  failsteps = 69
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 4 in [0:5]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.0577818146487
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 70   Ensemble: 0  failsteps = 70
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 4 in [0:5]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 0.8 / random : 0.214663348609
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 71   Ensemble: 0  failsteps = 71
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:6]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 0.416666666667 / random : 0.125038121624
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 72   Ensemble: 0  failsteps = 72
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:13]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 0.666666666667 / random : 0.790178924949
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 73   Ensemble: 0  failsteps = 73
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 10 in [0:13]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 0.705882352941 / random : 0.808801777133
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 74   Ensemble: 0  failsteps = 74
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 6 in [0:13]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 1.2 / random : 0.391391578429
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 75   Ensemble: 0  failsteps = 75
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:11]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 3.33333333333 / random : 0.201844908196
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 76   Ensemble: 0  failsteps = 76
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:4]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 0.75 / random : 0.890495080946
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 77   Ensemble: 0  failsteps = 77
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:4]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 0.3 / random : 0.701855526903
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 78   Ensemble: 0  failsteps = 78
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:4]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 0.75 / random : 0.135455161212
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 79   Ensemble: 0  failsteps = 79
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:5]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 0.4 / random : 0.911417521999
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 80   Ensemble: 0  failsteps = 80
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:5]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 0.285714285714 / random : 0.911203069404
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 81   Ensemble: 0  failsteps = 81
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:5]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.0 / random : 0.868091833551
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 82   Ensemble: 0  failsteps = 82
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:5]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.33333333333 / random : 0.572221532941
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 83   Ensemble: 0  failsteps = 83
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:4]
# Starting trajectory
# Finished trajectory, length: 7
# Proposal probability 0.428571428571 / random : 0.321803316167
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 84   Ensemble: 0  failsteps = 84
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:8]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 0.875 / random : 0.350559733539
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 85   Ensemble: 0  failsteps = 85
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 6 in [0:9]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Proposal probability 0.421052631579 / random : 0.143453066032
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 86   Ensemble: 0  failsteps = 86
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 4 in [0:20]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 2.375 / random : 0.0575377665937
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 87   Ensemble: 0  failsteps = 87
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:9]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 0.444444444444 / random : 0.403727822346
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 88   Ensemble: 0  failsteps = 88
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:19]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Proposal probability 0.58064516129 / random : 0.487852470875
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x108648850> to <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10>
# Step: 89   Ensemble: 1  failsteps = 0
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 9 in [0:32]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 0.96875 / random : 0.665220864489
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10> to <opentis.ensemble.SequentialEnsemble object at 0x121a97350>
# Step: 90   Ensemble: 1  failsteps = 1
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 12 in [0:33]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 1.33333333333 / random : 0.387756152389
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10> to <opentis.ensemble.SequentialEnsemble object at 0x121a97350>
# Step: 91   Ensemble: 1  failsteps = 2
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 22 in [0:25]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10> to <opentis.ensemble.SequentialEnsemble object at 0x121a97350>
# Step: 92   Ensemble: 1  failsteps = 3
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:25]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.0 / random : 0.337708326141
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10> to <opentis.ensemble.SequentialEnsemble object at 0x121a97350>
# Step: 93   Ensemble: 1  failsteps = 4
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 7 in [0:25]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10> to <opentis.ensemble.SequentialEnsemble object at 0x121a97350>
# Step: 94   Ensemble: 1  failsteps = 5
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 22 in [0:25]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10> to <opentis.ensemble.SequentialEnsemble object at 0x121a97350>
# Step: 95   Ensemble: 1  failsteps = 6
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 16 in [0:25]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10> to <opentis.ensemble.SequentialEnsemble object at 0x121a97350>
# Step: 96   Ensemble: 1  failsteps = 7
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 12 in [0:25]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 23
# Proposal probability 0.705882352941 / random : 0.556482308862
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10> to <opentis.ensemble.SequentialEnsemble object at 0x121a97350>
# Step: 97   Ensemble: 1  failsteps = 8
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 21 in [0:35]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 1.47826086957 / random : 0.439770925787
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10> to <opentis.ensemble.SequentialEnsemble object at 0x121a97350>
# Step: 98   Ensemble: 1  failsteps = 9
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:24]
# Starting trajectory
# Finished trajectory, length: 2
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10> to <opentis.ensemble.SequentialEnsemble object at 0x121a97350>
# Step: 99   Ensemble: 1  failsteps = 10
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 22 in [0:24]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.0 / random : 0.387876464837
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10> to <opentis.ensemble.SequentialEnsemble object at 0x121a97350>
# Step: 100   Ensemble: 1  failsteps = 11
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 16 in [0:24]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.15 / random : 0.495572987738
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10> to <opentis.ensemble.SequentialEnsemble object at 0x121a97350>
# Step: 101   Ensemble: 1  failsteps = 12
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 14 in [0:21]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10> to <opentis.ensemble.SequentialEnsemble object at 0x121a97350>
# Step: 102   Ensemble: 1  failsteps = 13
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 12 in [0:21]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 20
# Proposal probability 0.714285714286 / random : 0.43309608799
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10> to <opentis.ensemble.SequentialEnsemble object at 0x121a97350>
# Step: 103   Ensemble: 1  failsteps = 14
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 16 in [0:29]
# Starting trajectory
# Finished trajectory, length: 7
# Proposal probability 1.47368421053 / random : 0.410438941061
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10> to <opentis.ensemble.SequentialEnsemble object at 0x121a97350>
# Step: 104   Ensemble: 1  failsteps = 15
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 5 in [0:20]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.0 / random : 0.198321662594
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10> to <opentis.ensemble.SequentialEnsemble object at 0x121a97350>
# Step: 105   Ensemble: 1  failsteps = 16
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 17 in [0:20]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10> to <opentis.ensemble.SequentialEnsemble object at 0x121a97350>
# Step: 106   Ensemble: 1  failsteps = 17
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 13 in [0:20]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 1.05555555556 / random : 0.523064990978
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10> to <opentis.ensemble.SequentialEnsemble object at 0x121a97350>
# Step: 107   Ensemble: 1  failsteps = 18
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:19]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.749124652069
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10> to <opentis.ensemble.SequentialEnsemble object at 0x121a97350>
# Step: 108   Ensemble: 1  failsteps = 19
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:19]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# Proposal probability 0.620689655172 / random : 0.744395861274
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10> to <opentis.ensemble.SequentialEnsemble object at 0x121a97350>
# Step: 109   Ensemble: 1  failsteps = 20
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:19]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 0.9 / random : 0.703627185677
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10> to <opentis.ensemble.SequentialEnsemble object at 0x121a97350>
# Step: 110   Ensemble: 1  failsteps = 21
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 8 in [0:21]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 19
# Proposal probability 0.769230769231 / random : 0.510782905806
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x121a9ec10> to <opentis.ensemble.SequentialEnsemble object at 0x121a97350>
# Step: 111   Ensemble: 2  failsteps = 0
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 24 in [0:27]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 23
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x121a97350> to <opentis.ensemble.SequentialEnsemble object at 0x10d09e310>
# Step: 112   Ensemble: 2  failsteps = 1
# ...
# Step: 297   Ensemble: 4  failsteps = 44
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 20 in [0:51]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Through frame: 70
# Through frame: 80
# Finished trajectory, length: 81
# Proposal probability 0.5 / random : 0.655700617459
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x110427bd0> to <opentis.ensemble.SequentialEnsemble object at 0x110435750>
# Step: 298   Ensemble: 4  failsteps = 45
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 5 in [0:51]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.0 / random : 0.124795647948
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x110427bd0> to <opentis.ensemble.SequentialEnsemble object at 0x110435750>
# Step: 299   Ensemble: 4  failsteps = 46
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 16 in [0:51]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 34
# Proposal probability 1.02040816327 / random : 0.973453960685
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x110427bd0> to <opentis.ensemble.SequentialEnsemble object at 0x110435750>
# Step: 300   Ensemble: 4  failsteps = 47
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 31 in [0:50]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 1.02083333333 / random : 0.0498231095014
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x110427bd0> to <opentis.ensemble.SequentialEnsemble object at 0x110435750>
# Step: 301   Ensemble: 4  failsteps = 48
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 40 in [0:49]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 35
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x110427bd0> to <opentis.ensemble.SequentialEnsemble object at 0x110435750>
# Step: 302   Ensemble: 4  failsteps = 49
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 8 in [0:49]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# Proposal probability 0.716417910448 / random : 0.00433504866854
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x110427bd0> to <opentis.ensemble.SequentialEnsemble object at 0x110435750>
# Step: 303   Ensemble: 4  failsteps = 50
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 36 in [0:68]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 1.48888888889 / random : 0.0571226200196
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x110427bd0> to <opentis.ensemble.SequentialEnsemble object at 0x110435750>
# Step: 304   Ensemble: 4  failsteps = 51
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 9 in [0:46]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 0.978260869565 / random : 0.182715210565
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x110427bd0> to <opentis.ensemble.SequentialEnsemble object at 0x110435750>
# Step: 305   Ensemble: 4  failsteps = 52
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 6 in [0:47]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 0.741935483871 / random : 0.840680022133
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x110427bd0> to <opentis.ensemble.SequentialEnsemble object at 0x110435750>
# Step: 306   Ensemble: 4  failsteps = 53
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 33 in [0:47]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 30
# Proposal probability 1.06976744186 / random : 0.0655779566126
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x110427bd0> to <opentis.ensemble.SequentialEnsemble object at 0x110435750>
# Step: 307   Ensemble: 4  failsteps = 54
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 19 in [0:44]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 23
# Proposal probability 1.0487804878 / random : 0.333879694135
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x110427bd0> to <opentis.ensemble.SequentialEnsemble object at 0x110435750>
# Step: 308   Ensemble: 4  failsteps = 55
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 20 in [0:42]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 40
# Proposal probability 0.694915254237 / random : 0.461212660698
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x110427bd0> to <opentis.ensemble.SequentialEnsemble object at 0x110435750>
# Step: 309   Ensemble: 4  failsteps = 56
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 9 in [0:60]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 1.0 / random : 0.230771643758
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x110427bd0> to <opentis.ensemble.SequentialEnsemble object at 0x110435750>
# Step: 310   Ensemble: 4  failsteps = 57
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 26 in [0:60]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 36
# Proposal probability 0.967213114754 / random : 0.0713585650181
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x110427bd0> to <opentis.ensemble.SequentialEnsemble object at 0x110435750>
# Step: 311   Ensemble: 4  failsteps = 58
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 58 in [0:62]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 1.0 / random : 0.890208525457
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x110427bd0> to <opentis.ensemble.SequentialEnsemble object at 0x110435750>
# Step: 312   Ensemble: 4  failsteps = 59
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 58 in [0:62]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x110427bd0> to <opentis.ensemble.SequentialEnsemble object at 0x110435750>
# Step: 313   Ensemble: 4  failsteps = 60
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 15 in [0:62]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 16
# Proposal probability 0.983870967742 / random : 0.280909991008
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x110427bd0> to <opentis.ensemble.SequentialEnsemble object at 0x110435750>
# Step: 314   Ensemble: 4  failsteps = 61
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 24 in [0:63]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 24
# Proposal probability 1.31914893617 / random : 0.928215817988
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x110427bd0> to <opentis.ensemble.SequentialEnsemble object at 0x110435750>
# Step: 315   Ensemble: 4  failsteps = 62
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 35 in [0:48]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Finished trajectory, length: 50
# Proposal probability 0.758064516129 / random : 0.866592266197
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x110427bd0> to <opentis.ensemble.SequentialEnsemble object at 0x110435750>
# Step: 316   Ensemble: 4  failsteps = 63
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 7 in [0:48]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 0.959183673469 / random : 0.601813943691
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x110427bd0> to <opentis.ensemble.SequentialEnsemble object at 0x110435750>
# Step: 317   Ensemble: 4  failsteps = 64
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 24 in [0:50]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 21
# Proposal probability 1.11363636364 / random : 0.363179539185
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x110427bd0> to <opentis.ensemble.SequentialEnsemble object at 0x110435750>
# Step: 318   Ensemble: 4  failsteps = 65
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 26 in [0:45]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 34
# Proposal probability 0.846153846154 / random : 0.840307097996
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x110427bd0> to <opentis.ensemble.SequentialEnsemble object at 0x110435750>
# Step: 319   Ensemble: 4  failsteps = 66
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 39 in [0:53]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 34
# Proposal probability 1.10638297872 / random : 0.00284579442149
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x110427bd0> to <opentis.ensemble.SequentialEnsemble object at 0x110435750>
# Step: 320   Ensemble: 4  failsteps = 67
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 44 in [0:48]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 0.979166666667 / random : 0.816069237961
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x110427bd0> to <opentis.ensemble.SequentialEnsemble object at 0x110435750>
# Step: 321   Ensemble: 4  failsteps = 68
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 25 in [0:49]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 20
# Proposal probability 1.09090909091 / random : 0.190926546522
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x110427bd0> to <opentis.ensemble.SequentialEnsemble object at 0x110435750>
# Step: 322   Ensemble: 4  failsteps = 69
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 26 in [0:45]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Proposal probability 1.04761904762 / random : 0.860748344132
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x110427bd0> to <opentis.ensemble.SequentialEnsemble object at 0x110435750>
# Step: 323   Ensemble: 4  failsteps = 70
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 20 in [0:43]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 19
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x110427bd0> to <opentis.ensemble.SequentialEnsemble object at 0x110435750>
# Step: 324   Ensemble: 4  failsteps = 71
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 10 in [0:43]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 32
# Proposal probability 0.65625 / random : 0.268645774449
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x110427bd0> to <opentis.ensemble.SequentialEnsemble object at 0x110435750>
# Step: 325   Ensemble: 4  failsteps = 72
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 49 in [0:65]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# Proposal probability 1.52380952381 / random : 0.829249960368
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x110427bd0> to <opentis.ensemble.SequentialEnsemble object at 0x110435750>
# Step: 326   Ensemble: 4  failsteps = 73
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 9 in [0:43]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 1.0 / random : 0.0808110465899
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x110427bd0> to <opentis.ensemble.SequentialEnsemble object at 0x110435750>
# Step: 327   Ensemble: 4  failsteps = 74
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 32 in [0:43]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 0.954545454545 / random : 0.292362259634
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x110427bd0> to <opentis.ensemble.SequentialEnsemble object at 0x110435750>
# Step: 328   Ensemble: 4  failsteps = 75
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 38 in [0:45]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x110427bd0> to <opentis.ensemble.SequentialEnsemble object at 0x110435750>
# Step: 329   Ensemble: 4  failsteps = 76
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 39 in [0:45]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 21
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x110427bd0> to <opentis.ensemble.SequentialEnsemble object at 0x110435750>
# Step: 330   Ensemble: 4  failsteps = 77
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 26 in [0:45]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 34
# Proposal probability 0.745762711864 / random : 0.102095901476
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x110427bd0> to <opentis.ensemble.SequentialEnsemble object at 0x110435750>
# Step: 331   Ensemble: 4  failsteps = 78
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 13 in [0:60]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 37
# Proposal probability 1.20408163265 / random : 0.68398767433
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x110427bd0> to <opentis.ensemble.SequentialEnsemble object at 0x110435750>

# %% [markdown]
# We've stored all the trajectories we generated here; now we want to extract a path for each ensemble to use as a starting point for TIS. We'll choose to take the first path that satisfied each ensemble.

# %%
print "[ ",
for sample in bootstrap.globalstate:
    print str(sample.trajectory)+" ",
print "]"
# Out:
# [  Trajectory[20]  Trajectory[22]  Trajectory[20]  Trajectory[45]  Trajectory[61]  Trajectory[51]  ]

# %% [markdown]
# Let's go ahead and visualize where each of those trajectories are:

# %%
plot.plot([sample.trajectory for sample in bootstrap.globalstate])

# %% [markdown]
# ## Equilibration in the Path Ensemble
#
# At the end of the bootstrapping process, we have a set of paths which we can use to start TIS sampling. Before doing a production run, we should let these paths equilibrate within the ensembles. If you generate your initial path through dynamics that aren't the true dynamics (e.g., using high temperature runs or using metadynamics), this stage is **extremely** important. It's important here as well, but less so than if your initial path is non-physical.
#
# This will be an example of a "normal" TIS run, i.e., TIS without replica exchange. We will sampling using only shooter movers (the same ones defined for the bootstrapping) and path reversal movers. First we define these path reveral movers:

# %%
from opentis.pathmover import PathReversalSet
reversal_movers = PathReversalSet(interface_ensemble_set)

# %% [markdown]
# Next we define global moves: we'll set this up so that each move either does a shooting move on all replicas, or does a path reversal move on all replicas. You can similarly set it up so that each move operates on only on one replica at a time.

# %%
from opentis.pathmover import RandomChoiceMover
shooting_chooser = RandomChoiceMover(shooting_movers)
reversal_chooser = RandomChoiceMover(reversal_movers)
equilibration_movers = RandomChoiceMover([shooting_chooser, reversal_chooser])

# %% [markdown]
# Now we're ready to set up a TIS run:

# %%
from opentis.calculation import PathSampling
equilibration = PathSampling(storage=None, engine=sim, root_mover=equilibration_movers, globalstate=bootstrap.globalstate)

# %% [markdown]
# And now we run it. We'll do 200 equilibration steps.

# %%
equilibration.run(200)
# Out:
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 24 in [0:60]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 33
# Proposal probability 1.05357142857 / random : 0.119324480341
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 11 in [0:19]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 0.642857142857 / random : 0.404572978757
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 32 in [0:57]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# Proposal probability 1.14285714286 / random : 0.901085245282
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 24 in [0:50]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 24
# Proposal probability 1.04255319149 / random : 0.88232248795
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 7 in [0:29]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# Proposal probability 0.848484848485 / random : 0.901481794758
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:29]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 28
# Proposal probability 0.933333333333 / random : 0.12188709885
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 6 in [0:50]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Through frame: 70
# Through frame: 80
# Through frame: 90
# Through frame: 100
# Finished trajectory, length: 105
# Proposal probability 0.445454545455 / random : 0.21443527463
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 5 in [0:48]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 0.979166666667 / random : 0.0609787974979
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 11 in [0:19]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 1.0 / random : 0.735754214141
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 14 in [0:19]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 0.514285714286 / random : 0.553563428813
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 23 in [0:44]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 1.075 / random : 0.582596267546
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 17 in [0:31]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 1.03448275862 / random : 0.0476370312029
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 26 in [0:41]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Proposal probability 1.29032258065 / random : 0.160256255763
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:21]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 24
# Proposal probability 0.47619047619 / random : 0.485693907361
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 63 in [0:111]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 44
# Proposal probability 1.20879120879 / random : 0.0540983670339
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 82 in [0:92]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 1.02247191011 / random : 0.607705553469
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 13 in [0:21]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 16
# Proposal probability 0.869565217391 / random : 0.283928071356
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 7 in [0:24]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 16
# Proposal probability 1.04545454545 / random : 0.521425619166
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 19 in [0:49]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 19
# Proposal probability 1.0 / random : 0.152295805965
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 22 in [0:32]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 0.939393939394 / random : 0.0284199996869
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 8 in [0:23]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 0.846153846154 / random : 0.180567184311
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 18 in [0:27]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 1.0 / random : 0.774318280502
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 48 in [0:49]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 24
# Proposal probability 0.676056338028 / random : 0.438493390151
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 48 in [0:90]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Finished trajectory, length: 53
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 24 in [0:72]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 48
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 29 in [0:30]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.0242765000338
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 41 in [0:72]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# Proposal probability 1.09230769231 / random : 0.213058685355
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:19]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 1.125 / random : 0.793574920009
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 37 in [0:90]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 1.2027027027 / random : 0.267465578338
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 38 in [0:75]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 43
# Proposal probability 0.925 / random : 0.600870661952
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 26 in [0:34]
# Starting trajectory
# Finished trajectory, length: 9
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 11 in [0:17]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 19
# Proposal probability 0.666666666667 / random : 0.913252799743
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 5 in [0:17]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 20
# Proposal probability 0.666666666667 / random : 0.687754213604
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 10 in [0:34]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 24
# Proposal probability 0.702127659574 / random : 0.11952958945
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 14 in [0:66]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 13 in [0:27]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 0.866666666667 / random : 0.567934386757
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 12 in [0:30]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Proposal probability 1.03571428571 / random : 0.421391951175
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 40 in [0:48]
# Starting trajectory
# Finished trajectory, length: 7
# Proposal probability 1.02173913043 / random : 0.522090096463
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 12 in [0:31]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 1.42857142857 / random : 0.562259936049
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 7 in [0:47]
# Starting trajectory
# Finished trajectory, length: 7
# Proposal probability 1.0 / random : 0.00360198815255
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 32 in [0:81]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Finished trajectory, length: 50
# Proposal probability 0.987654320988 / random : 0.0912426822184
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 73 in [0:82]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 0.987804878049 / random : 0.295028919018
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 14 in [0:47]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 1.76923076923 / random : 0.454206680042
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 5 in [0:27]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 25 in [0:27]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 19 in [0:22]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 23
# Proposal probability 0.84 / random : 0.52437450542
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 9 in [0:66]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 33
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 46 in [0:83]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 35
# Proposal probability 1.15492957746 / random : 0.313066769037
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:27]
# Starting trajectory
# Finished trajectory, length: 2
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 21 in [0:27]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 1.0 / random : 0.68568609702
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 9 in [0:27]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 1.04 / random : 0.292715452056
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 24 in [0:26]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 8 in [0:72]
# Starting trajectory
# Finished trajectory, length: 8
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 50 in [0:72]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 47
# Proposal probability 1.04411764706 / random : 0.64560713904
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 44 in [0:69]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 37
# Proposal probability 1.11475409836 / random : 0.847282162518
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 6 in [0:26]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Proposal probability 0.735294117647 / random : 0.0222930347785
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 33 in [0:35]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 20
# Proposal probability 0.653846153846 / random : 0.868062395604
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 23 in [0:35]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 1.36 / random : 0.586357402259
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 11 in [0:26]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Proposal probability 1.0 / random : 0.141602786322
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 5 in [0:17]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.0 / random : 0.443486509177
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 48 in [0:66]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 1.06557377049 / random : 0.839324340083
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 37 in [0:62]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 40
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 6 in [0:29]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.03703703704 / random : 0.732549481312
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 58 in [0:62]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 29
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 50 in [0:62]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# Proposal probability 0.802631578947 / random : 0.228992884186
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 23 in [0:26]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 21
# Proposal probability 1.08695652174 / random : 0.55245813882
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:17]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 24
# Proposal probability 0.64 / random : 0.769981174055
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:28]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 26
# Proposal probability 0.529411764706 / random : 0.994882921169
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 7 in [0:17]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 0.8 / random : 0.548426525079
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 15 in [0:28]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 1.125 / random : 0.0550989802366
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:26]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.135034300552
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 58 in [0:62]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 1.0 / random : 0.74553613552
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 8 in [0:24]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 1.53333333333 / random : 0.91504879162
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 6 in [0:16]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 1.36363636364 / random : 0.0666888817054
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 21 in [0:25]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 26
# Proposal probability 0.521739130435 / random : 0.887080054386
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:62]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 32
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 9 in [0:12]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.0 / random : 0.22601190818
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 6 in [0:21]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 0.909090909091 / random : 0.699115995166
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 42 in [0:77]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 40
# Proposal probability 1.02702702703 / random : 0.917481961341
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:12]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 24
# Proposal probability 0.333333333333 / random : 0.183010430648
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 12 in [0:23]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 0.95652173913 / random : 0.62501469347
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 15 in [0:24]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 1.04545454545 / random : 0.422977819896
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 36 in [0:75]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 23
# Proposal probability 1.27586206897 / random : 0.362389345126
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 6 in [0:26]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 26
# Proposal probability 0.555555555556 / random : 0.397381573186
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 38 in [0:59]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 32
# Proposal probability 1.11538461538 / random : 0.997588344426
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 42 in [0:62]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 26
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 40 in [0:46]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 26
# Proposal probability 0.692307692308 / random : 0.213093655388
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 52 in [0:53]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.0554504906894
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 18 in [0:25]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 23
# Proposal probability 0.827586206897 / random : 0.365113262008
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 24 in [0:34]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 1.73684210526 / random : 0.33437415246
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 13 in [0:53]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 49
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 6 in [0:66]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 20
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 16 in [0:23]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 0.846153846154 / random : 0.700869620062
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 32 in [0:53]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 39
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:62]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.01666666667 / random : 0.697452534916
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 26 in [0:53]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 30
# Proposal probability 0.928571428571 / random : 0.159514679593
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 18 in [0:20]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Proposal probability 0.558823529412 / random : 0.404540190191
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 32 in [0:61]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Proposal probability 1.30434782609 / random : 0.165674208525
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 16 in [0:30]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Proposal probability 0.966666666667 / random : 0.946974654795
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 28 in [0:66]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 24
# Proposal probability 1.06557377049 / random : 0.6939277496
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 45 in [0:47]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 31
# Proposal probability 0.613333333333 / random : 0.8986513578
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 10 in [0:31]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 26
# Proposal probability 0.857142857143 / random : 0.770578868883
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 28 in [0:62]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 1.24489795918 / random : 0.785011061579
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:57]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.0 / random : 0.907755933278
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 44 in [0:50]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 1.0 / random : 0.968870345298
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 15 in [0:27]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 0.928571428571 / random : 0.160207815682
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 43 in [0:57]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 39
# Proposal probability 0.691358024691 / random : 0.53603388021
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 19 in [0:29]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Proposal probability 1.07692307692 / random : 0.396466577997
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 11 in [0:35]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Proposal probability 0.85 / random : 0.954941982667
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 18 in [0:27]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 1.18181818182 / random : 0.0303090716536
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 51 in [0:82]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Finished trajectory, length: 53
# Proposal probability 0.78640776699 / random : 0.551021174764
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 25 in [0:47]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 26
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 6 in [0:104]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Finished trajectory, length: 50
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 22 in [0:36]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 1.09375 / random : 0.00417756322357
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 16 in [0:35]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.47826086957 / random : 0.892836163164
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 23 in [0:24]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.854722714205
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 22 in [0:24]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 0.53488372093 / random : 0.139240636307
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 75 in [0:104]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 35
# Proposal probability 1.63492063492 / random : 0.325848827597
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)

# %% [markdown]
# Now let's take a look at where the trajectories are after they've had a chance to equilibrate:

# %%
plot.plot([sample.trajectory for sample in equilibration.globalstate])

# %%
for s in equilibration.globalstate[1].trajectory:
    print s.coordinates[0,0], s.coordinates[0,1]
# Out:
# -0.30563767557 -0.149423462668
# -0.29697664939 -0.158780299402
# -0.286348971925 -0.167147162898
# -0.274750980775 -0.175404989429
# -0.264292751623 -0.182902570259
# -0.255872829566 -0.188986313202
# -0.2487593854 -0.193909926438
# -0.242570225697 -0.19787342469
# -0.236944286388 -0.201890387575
# -0.232441484434 -0.204895379689
# -0.230721718814 -0.206388209063
# -0.232274316943 -0.207637365718
# -0.236319790715 -0.208523799625
# -0.2416947855 -0.209196054102
# -0.248948532488 -0.210961333147
# -0.258170079253 -0.213704210659
# -0.268480787135 -0.216810308894
# -0.278865260053 -0.22031500159
# -0.268874923794 -0.21840537608
# -0.258749362813 -0.217632280134
# -0.268478900817 -0.219414563461
# -0.27753390264 -0.222445764351
# -0.286746473414 -0.226427768533
# -0.277630453606 -0.222447984336
# -0.269058143667 -0.218868585863
# -0.260231637449 -0.215577945922
# -0.252313035425 -0.211412828727
# -0.245973018469 -0.206208135225
# -0.239644224581 -0.200610453492
# -0.23404266501 -0.194893530419
# -0.23039011764 -0.188858837911
# -0.228175459222 -0.183063319918
# -0.2269684237 -0.177946510465
# -0.227334013757 -0.17350790696
# -0.229782302642 -0.169026965813
# -0.233890559693 -0.164703992948
# -0.238072694586 -0.161399033587
# -0.242222873491 -0.159027309335
# -0.24766515976 -0.156412863394
# -0.254690133432 -0.152457412062
# -0.263222070183 -0.148052348066
# -0.273137088073 -0.143507540808
# -0.283247548639 -0.138891997443
# -0.293647067638 -0.133560355868
# -0.30479789246 -0.127380530233

# %% [markdown]
# ## RETIS: Production run
#
# With everything else set up, we can set up the replica exchange movers, and reuse the other movers.

# %%
from opentis.pathmover import NeighborEnsembleReplicaExchange
repex_movers = NeighborEnsembleReplicaExchange(interface_ensemble_set)
repex_chooser = RandomChoiceMover(repex_movers)

# %% [markdown]
# We'll also set up the minus ensemble and minus move:

# %%
# minus_ensemble
# minus_move

# %% [markdown]
# Finally, we set up a production run; this is very similar to the setup for the TIS equilibration run. However, up until now, we have not used file storage; before this run we will set up a storage file. The single storage file will save all the trajectories as well as all the details of the RETIS simulation (what movers are used, the acceptance of each trial, etc.)

# %%
#storage = paths.storage.Storage(
#    filename="toy_tis.nc",
#    template=sim.current_snapshot # that's an ugly hack
#)

# %%
retis_root_mover = RandomChoiceMover([shooting_chooser, reversal_chooser, repex_chooser])
production = PathSampling(storage=None, engine=sim, root_mover=retis_root_mover, globalstate=equilibration.globalstate)

# %% [markdown]
# We'll run the production calculation for 500 MC steps.

# %%
production.run(500)
# Out:
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 21 in [0:42]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 23
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:42]
# Starting trajectory
# Finished trajectory, length: 3
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 33 in [0:37]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 30
# Proposal probability 0.58064516129 / random : 0.103038831881
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 28 in [0:61]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 1.57894736842 / random : 0.288903759713
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 45 in [0:85]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 49
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 32 in [0:42]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 31
# Proposal probability 0.661290322581 / random : 0.0549477567228
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 43 in [0:85]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 45 in [0:63]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 1.77142857143 / random : 0.111301097562
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:4]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.918266466668
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 7 in [0:30]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 1.03571428571 / random : 0.0658124072832
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 16 in [0:39]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Proposal probability 1.26666666667 / random : 0.652681378122
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 8 in [0:31]
# Starting trajectory
# Finished trajectory, length: 7
# Proposal probability 1.03448275862 / random : 0.0224139389735
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 32 in [0:36]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 28
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:4]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.0 / random : 0.453181345155
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:4]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 32
# Proposal probability 0.09375 / random : 0.016339852797
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 7 in [0:29]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 2.0 / random : 0.0627132589134
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 13 in [0:36]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 0.972222222222 / random : 0.84691404768
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 43 in [0:85]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 19
# Proposal probability 1.37704918033 / random : 0.408531759553
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 12 in [0:33]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# Proposal probability 0.888888888889 / random : 0.471192489997
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:15]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 28
# Proposal probability 0.368421052632 / random : 0.555443500406
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 56 in [0:62]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 37
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 9 in [0:30]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 0.966666666667 / random : 0.229298788827
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 8 in [0:37]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 21
# Proposal probability 1.28571428571 / random : 0.779611855738
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 23 in [0:31]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 21
# Proposal probability 1.07142857143 / random : 0.949176910023
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 27 in [0:29]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 38
# Proposal probability 0.4375 / random : 0.796176279196
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 9 in [0:29]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 1.0 / random : 0.501059136259
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 12 in [0:62]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Finished trajectory, length: 67
# Proposal probability 0.782051282051 / random : 0.504860111571
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 12 in [0:29]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 26
# Proposal probability 0.756756756757 / random : 0.315894295799
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:63]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 39
# Proposal probability 1.58974358974 / random : 0.556052805978
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 20 in [0:40]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 24
# Proposal probability 0.906976744186 / random : 0.0977397429985
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 31 in [0:44]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 32
# Proposal probability 0.977272727273 / random : 0.932507020427
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 9 in [0:29]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 24
# Proposal probability 0.651162790698 / random : 0.641129713688
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:44]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.0 / random : 0.645074718889
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 36 in [0:44]
# Starting trajectory
# Finished trajectory, length: 8
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 36 in [0:45]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 1.0 / random : 0.541626075716
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 7 in [0:15]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 1.07692307692 / random : 0.888217007054
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 8 in [0:45]
# Starting trajectory
# Finished trajectory, length: 7
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 78 in [0:79]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.00691609726841
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 32 in [0:44]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 32
# Proposal probability 0.68253968254 / random : 0.638309347885
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:14]
# Starting trajectory
# Finished trajectory, length: 2
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:45]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.02325581395 / random : 0.347106377598
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 8 in [0:14]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 26
# Proposal probability 0.393939393939 / random : 0.16888299504
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 26 in [0:38]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Proposal probability 1.32142857143 / random : 0.754285471031
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 18 in [0:37]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 19
# Proposal probability 1.0 / random : 0.789435807074
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 23 in [0:44]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 20
# Proposal probability 1.02380952381 / random : 0.199969636458
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 14 in [0:64]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 30
# Proposal probability 1.46511627907 / random : 0.699874752745
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 31 in [0:34]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# Proposal probability 1.22222222222 / random : 0.211287755583
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 7 in [0:37]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 0.972972972973 / random : 0.327104942454
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 20 in [0:44]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 1.16216216216 / random : 0.145764149408
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 29 in [0:43]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 37
# Proposal probability 0.84 / random : 0.33235618748
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 6 in [0:28]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 2.7 / random : 0.54767108947
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 26 in [0:38]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# Proposal probability 0.973684210526 / random : 0.857652325357
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 37 in [0:38]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 20 in [0:51]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 13 in [0:38]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 1.08823529412 / random : 0.0571665840612
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 26 in [0:51]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 29
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 26 in [0:51]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 43
# Proposal probability 0.746268656716 / random : 0.695556930557
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 35 in [0:39]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 35
# Proposal probability 0.550724637681 / random : 0.369822762959
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 9 in [0:79]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 1.0 / random : 0.24199345289
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:11]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 29
# Proposal probability 0.322580645161 / random : 0.98407887983
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 11 in [0:29]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 0.903225806452 / random : 0.241460110914
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 24 in [0:70]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 1.09523809524 / random : 0.33851764088
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 30 in [0:35]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.0 / random : 0.256274537951
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 15 in [0:32]
# Starting trajectory
# Through frame: 10
# ...
# Shooting forward from frame 62 in [0:95]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 28
# Proposal probability 1.05617977528 / random : 0.48140679827
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 52 in [0:72]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 45
# Proposal probability 0.739583333333 / random : 0.111348190543
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 14 in [0:30]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 1.0 / random : 0.832311859178
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 40 in [0:41]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.11900366816
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 7 in [0:41]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 32
# Proposal probability 1.05263157895 / random : 0.640951310854
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 12 in [0:97]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 16
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 29 in [0:30]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 13 in [0:30]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 0.852941176471 / random : 0.012796294007
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 56 in [0:97]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 18 in [0:33]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 21
# Proposal probability 0.914285714286 / random : 0.246898226719
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 85 in [0:90]
# Starting trajectory
# Finished trajectory, length: 5
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 10 in [0:97]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:30]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.0533026338976
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 13 in [0:30]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 21
# Proposal probability 0.878787878788 / random : 0.219073427295
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 8 in [0:36]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 2.1875 / random : 0.0419190191244
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 8 in [0:35]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 0.772727272727 / random : 0.295343693299
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 13 in [0:17]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 24
# Proposal probability 0.444444444444 / random : 0.253817264794
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 84 in [0:97]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 39 in [0:45]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 0.785714285714 / random : 0.137125668221
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 23 in [0:37]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Proposal probability 0.923076923077 / random : 0.505813823102
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
