# %%
# Note: in practice, one should put all the imports at the top of a Python script. 
# But for educational purposes here, I put the import immediately before usage. 
# This Python block is just to set up some plotting stuff.

# Imports for plotting
# %matplotlib inline
import opentis as paths
from toy_plot_helpers import ToyPlot
plot = ToyPlot()

# %% [markdown]
# # Setting up RETIS on a Toy Model
#
# This example shows how to set up a RETIS calculation. We do this on a simple 2D model so it can be fast enough for an interactive example, but the basic approach applies to larger systems as well. Although I'll describe everything here in terms of 2-state systems, all the ideas generalize when setting up multiple-state systems (you just need to find more initial paths).

# %% [markdown]
# ## Getting an initial path
#
# RETIS is a path sampling method: it requires that the user supply an input path for each path ensemble. This means that you must somehow generate a first input path. In general, getting the first input paths for RETIS boils down to solving two problems:
#
# 1. Getting a trajectory that samples the rare event.
# 2. Filling all the path ensembles with acceptable trajectories.
#
# Since transition paths satisfy all the path ensembles between two states, a common approach is to use the same initial path for all path ensembles (reversing it where necessary). This way, once you've solved problem 1, problem 2 is trivial.
#
# The first rare path can come from any number of sources. The obvious approach might be to find a transition path from a committor analysis, because this would give you a path that satisfies the true dynamics. However, the initial path doesn't need to satisfy the true dynamics of the system (later we will equilibrate the path ensemble anyway). This means that other approaches, such as high-temperature trajectories, can be used for the first path. One of the most widely-used methods to get an initial trajectory is to generate a transition trajectory using metadynamics. However, the downside of using paths that don't satisfy the true dynamics is that it might be harder to get them to equilibrate to the correct path ensemble. It seems that this has been more of a problem with paths from high temperature runs than with paths from metadynamics: a path from a modified potential energy surface at the correct temperature seems to equilibrate more easily than a path from the original potential energy surface at an incorrect temperature.
#
# In this example, we use a bootstrapping approach, which does create paths satisfying the true dynamics of the system. This bootstrapping is nice because it is quick and convenient, although it works best on smaller systems with less complicated transitions. It works by running normal MD to generate a path that satisfies the innermost interface, and then performing shooting moves in that interface's path ensemble until we have a path that crosses the next interface. Then we switch to the path ensemble for the next interface, and shoot until the path crossing the interface after that. The process continues until we have paths for all interfaces.

# %% [markdown]
# ### Basic system setup
#
# First we set up our system: for the toy dynamics, this involves defining a potential energy surface (PES), setting up an integrator, and giving the simulation an initial configuration. In real MD systems, the PES is handled by the combination of a topology file and a force field definition, and the initial configuration would come from a file instead of being described by hand.

# %%
from opentis.toy_dynamics.toy_engine import ToyEngine
from opentis.toy_dynamics.toy_integrators import LangevinBAOABIntegrator
from opentis.toy_dynamics.toy_pes import Gaussian, OuterWalls

import logging.config
logging.config.fileConfig("logging.conf", disable_existing_loggers=False)

# %%
# Toy_PES supports adding/subtracting various PESs. The OuterWalls PES type gives an x^6+y^6 boundary to the system
pes = (OuterWalls([1.0, 1.0], [0.0, 0.0]) + 
       Gaussian(2.0, [1.0, 4.0], [0.0,1.0]) + 
       Gaussian(2.0, [25.0, 1.0], [0.0, -1.0])
      )
integ = LangevinBAOABIntegrator(dt=0.02, temperature=0.1, gamma=1.0)
sim = ToyEngine(#filename=None,
                options={'pes' : pes, 
                         'integ' : integ,
                         'n_frames_max' : 5000,
                         'nsteps_per_frame' : 10}
               )

sim.mass = [1.0, 1.0]
sim.current_snapshot = paths.Snapshot(coordinates=[-0.5, 0.0], velocities=[0.0,0.0])

# %% [markdown]
# Now let's take a look at our PES and our initial configuration:

# %%
plot.add_pes(pes)
plot.add_initial_condition(sim.current_snapshot)
plot.plot()

# %% [markdown]
# ### Interface setup
#
# One downside of the bootstrapping approach is that we need to have defined our interfaces before we start. However, we can always easily change our initial interface guesses.
#
# We'll consider a couple different choices of order parameter to define our interfaces. First we'll look at lines at different values of $x$. That set will be called `line_set`. Later we'll also consider circles centered on (-0.5, -0.25), with different radii. We'll call this set of interfaces `circle_set`.
#
# In both cases, we need to define the order parameter, and then we need to create a set of volumes and a set of ensembles associated with those volumes.

# %%
from opentis.orderparameter import OP_Function
from opentis.volume import VolumeFactory as vf
from opentis.volume import LambdaVolume
from opentis.trajectory import Trajectory

# WTF? This is an extremely overcomplicated OP; shouldn't be so hard!
try:
    op_line = OP_Function(name="xval", 
                          fcn=lambda snap : Trajectory([snap])[0].coordinates()[0,0])
except ValueError:
    print "xval already made"
# this defines a set of LambdaVolumes for which the minimum is -1.0 and the maximum is given in the array
line_volume_set = vf.LambdaVolumeSet(op_line, minvals=-1.0, maxvals=[-0.30, -0.25, -0.20, -0.13, -0.05, 0.0])
stateA = LambdaVolume(op_line, -1.0, -0.3)
stateB = LambdaVolume(op_line, 0.3, 1.0)

# %%
plot.add_states([stateA, stateB])
plot.add_interfaces(line_volume_set)
plot.plot()

# %% [markdown]
# In this picture, the states are marked in blue, and the interfaces are drawn as red lines. The initial configuration is still the red dot.

# %% [markdown]
# ### First innermost interface path
#
# Now we have to create an initial path. This initial path shoud exit the state, cross the first interface, and then return to the state. We'll create this path by defining a special ensemble that, propagating forward from any initial snapshot, ends when the path ends with a segment in the appropriate interface.

# %%
from opentis.ensemble import EnsembleFactory as ef
from opentis.ensemble import LengthEnsemble, InXEnsemble, OutXEnsemble, SequentialEnsemble, OptionalEnsemble, SingleFrameEnsemble

interface0 = line_volume_set[0]
interface_ensemble_set = ef.TISEnsembleSet(stateA, stateB, line_volume_set)
first_traj_ensemble = SequentialEnsemble([
    OptionalEnsemble(OutXEnsemble(stateA)),
    InXEnsemble(stateA),
    OptionalEnsemble(OutXEnsemble(stateA) & InXEnsemble(interface0)),
    OptionalEnsemble(InXEnsemble(interface0)),
    OutXEnsemble(interface0),
    OptionalEnsemble(OutXEnsemble(stateA)),
    SingleFrameEnsemble(InXEnsemble(stateA))
])

# %% [markdown]
# This ensemble is a bit complicated, but works in the general case. To understand it, we'll look at the `SequentialEnsemble` segment by segment. One preliminary point is that we need the generated path ensemble to be the same as the accepted path ensemble in this case, meaning that we must define the ensemble entirely in terms of which volumes each segment is in (i.e., using `InXEnsemble` and `OutXEnsemble`, but not `LeaveXEnsemble` or `HitXEnsemble`).
#
# Start with the first two segments: we start with an optional ensemble outside the state, and then move to an ensemble that is in the state. Since our TIS segment must start in a state, these two ensembles allow us to either start outside the state and then evolve into the state, or to start inside the state. At the end of these two segments, we have the first frame of the TIS ensemble segment, i.e., the frame inside the state that begins the TIS path.
#
# Next we have a couple of optional ensembles, followed by an ensemble requiring the segment to be outside the interface. The optional interfaces here are only important if `stateA` and `interface0` represent different volumes. If they represent the same volume (which is the case here) these optional ensembles don't matter. However, if they are different volumes, then there is a space which is outside the state but inside the interface. So the first optional interface represents that space. The next optional interface says that you must then be inside `interface0`: this is in case there is a reentry into the state before you cross the interface. Next, we require that we cross the interface. The last optional ensemble is for segments ouside the state. If there is space between the interface and the state, then after you are no longer outside the interface you might still be outside the state. Finally, the path ends with one frame in the state.
#
# Following the logic of that, any path that begins anywhere and ends with a segment satisfying the innermost TIS ensemble will be accepted by this ensemble. Furthermore, since the ensemble is defined exclusively in terms of `InXEnsemble`s and `OutXEnsemble`s, the ensemble of paths generated by forward dynamics (`can_append`) is equivalent to the accepted path ensemble.

# %%
sim.initialized = True
first_traj = sim.generate(sim.current_snapshot, [first_traj_ensemble.can_append])
# Out:
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Through frame: 70
# Through frame: 80
# Through frame: 90
# Through frame: 100
# Through frame: 110
# Through frame: 120
# Through frame: 130
# Through frame: 140
# Through frame: 150
# Through frame: 160
# Through frame: 170
# Through frame: 180
# Through frame: 190
# Through frame: 200
# Through frame: 210
# Through frame: 220
# Through frame: 230
# Through frame: 240
# Through frame: 250
# Through frame: 260
# Through frame: 270
# Through frame: 280
# Through frame: 290
# Through frame: 300
# Through frame: 310
# Through frame: 320
# Through frame: 330
# Through frame: 340
# Through frame: 350
# Through frame: 360
# Through frame: 370
# Through frame: 380
# Through frame: 390
# Through frame: 400
# Through frame: 410
# Through frame: 420
# Through frame: 430
# Through frame: 440
# Through frame: 450
# Through frame: 460
# Through frame: 470
# Through frame: 480
# Through frame: 490
# Through frame: 500
# Through frame: 510
# Through frame: 520
# Through frame: 530
# Through frame: 540
# Through frame: 550
# Through frame: 560
# Through frame: 570
# Through frame: 580
# Through frame: 590
# Through frame: 600
# Through frame: 610
# Through frame: 620
# Through frame: 630
# Through frame: 640
# Through frame: 650
# Through frame: 660
# Through frame: 670
# Through frame: 680
# Through frame: 690
# Through frame: 700
# Through frame: 710
# Through frame: 720
# Through frame: 730
# Through frame: 740
# Through frame: 750
# Through frame: 760
# Through frame: 770
# Through frame: 780
# Through frame: 790
# Through frame: 800
# Through frame: 810
# Through frame: 820
# Through frame: 830
# Through frame: 840
# Through frame: 850
# Through frame: 860
# Through frame: 870
# Through frame: 880
# Through frame: 890
# Through frame: 900
# Through frame: 910
# Through frame: 920
# Through frame: 930
# Through frame: 940
# Through frame: 950
# Through frame: 960
# Through frame: 970
# Through frame: 980
# Through frame: 990
# Through frame: 1000
# Through frame: 1010
# Through frame: 1020
# Finished trajectory, length: 1020

# %% [markdown]
# Next we use the `Ensemble.split` function to split the trajectory we found into segments satisfying the innermost interface TIS ensemble. There is only one such segment, and so we assign the first (and only) one found to `subtraj`, which is the first trajectory satisfying the innermost TIS interface.

# %%
subtraj = interface_ensemble_set[0].split(first_traj)[0]

# %%
plot.plot(bold=[first_traj], trajectories=[subtraj])

# %% [markdown]
# Now we see how the initial path evolves on this surface. The last part of the trajectory, which satisfies the path ensemble for the innermost interface, is highlighted in red. The whole trajectory is drawn in black.

# %% [markdown]
# ### Bootstrapping
#
# The bootstrapping approach takes a single trajectory which satisfies the innermost interface, and does shooting moves until it satisfies the next ensemble. Once it satisfies the next ensemble, we start shooting from within that ensemble. We keep building up like that until all ensembles have an initial path.
#
# To do this, we need to first create the appropriate shooting movers (one for each path ensemble). This is done quickly and efficiently with a factory function.

# %%
from opentis.pathmover import PathMoverFactory as mf
from opentis.shooting import UniformSelector

# might be nice to get rid of these two lines somehow
from opentis.pathmover import PathMover
PathMover.engine = sim

shooting_movers = mf.OneWayShootingSet(UniformSelector(), interface_ensemble_set)

# %% [markdown]
# Next we need to set up the Bootstrapping calculation:

# %%
from opentis.calculation import Bootstrapping

# TODO: add storage
bootstrap = Bootstrapping(storage=None,
                          engine=sim,
                          ensembles=interface_ensemble_set,
                          movers=shooting_movers,
                          trajectory=subtraj)

# %% [markdown]
# Now we run the bootstrapping. The number `50` means that we'll allow up to 50 shooting attempts per interface; if it takes more than that, you should probably adjust your interfaces (there's probably not much overlap for replica exchange).

# %%
bootstrap.run(300)
# Out:
# Step: 0   Ensemble: 0  failsteps = 0
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 5 in [0:13]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 1.2 / random : 0.98276338504
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 1   Ensemble: 0  failsteps = 1
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:11]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.799288742644
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 2   Ensemble: 0  failsteps = 2
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:11]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.11111111111 / random : 0.23400064626
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 3   Ensemble: 0  failsteps = 3
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:10]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.650620287089
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 4   Ensemble: 0  failsteps = 4
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:10]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 3.0 / random : 0.316171841843
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 5   Ensemble: 0  failsteps = 5
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:4]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 0.6 / random : 0.138467995944
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 6   Ensemble: 0  failsteps = 6
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:6]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 0.5 / random : 0.324079694762
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 7   Ensemble: 0  failsteps = 7
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:11]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 0.588235294118 / random : 0.0529147315484
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 8   Ensemble: 0  failsteps = 8
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 8 in [0:18]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.7 / random : 0.860772216572
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 9   Ensemble: 0  failsteps = 9
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 4 in [0:11]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 1.42857142857 / random : 0.926995226986
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 10   Ensemble: 0  failsteps = 10
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:8]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.75 / random : 0.1136486233
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 11   Ensemble: 0  failsteps = 11
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:5]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.0 / random : 0.342366481146
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 12   Ensemble: 0  failsteps = 12
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:5]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.0 / random : 0.0161033917549
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 13   Ensemble: 0  failsteps = 13
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:5]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 0.5 / random : 0.267560652531
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 14   Ensemble: 0  failsteps = 14
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 5 in [0:9]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 0.888888888889 / random : 0.168787752101
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 15   Ensemble: 0  failsteps = 15
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:10]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.572336754616
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 16   Ensemble: 0  failsteps = 16
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:10]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 4.5 / random : 0.621228357121
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 17   Ensemble: 0  failsteps = 17
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:3]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.384227091197
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 18   Ensemble: 0  failsteps = 18
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:3]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 0.153846153846 / random : 0.415734209214
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 19   Ensemble: 0  failsteps = 19
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:3]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.955384596559
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 20   Ensemble: 0  failsteps = 20
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:3]
# Starting trajectory
# Finished trajectory, length: 7
# Proposal probability 0.285714285714 / random : 0.53631211204
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 21   Ensemble: 0  failsteps = 21
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:3]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.588999566991
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 22   Ensemble: 0  failsteps = 22
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:3]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 0.222222222222 / random : 0.391006387454
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 23   Ensemble: 0  failsteps = 23
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:3]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.758302343181
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 24   Ensemble: 0  failsteps = 24
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:3]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.927693783033
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 25   Ensemble: 0  failsteps = 25
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:3]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.716513101128
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 26   Ensemble: 0  failsteps = 26
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:3]
# Starting trajectory
# Finished trajectory, length: 7
# Proposal probability 0.285714285714 / random : 0.413802477424
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 27   Ensemble: 0  failsteps = 27
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:3]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.54403100057
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 28   Ensemble: 0  failsteps = 28
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:3]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 0.4 / random : 0.852791627715
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 29   Ensemble: 0  failsteps = 29
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:3]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 0.153846153846 / random : 0.810289443301
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 30   Ensemble: 0  failsteps = 30
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:3]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 0.5 / random : 0.749009450978
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 31   Ensemble: 0  failsteps = 31
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:3]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.101426100236
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 32   Ensemble: 0  failsteps = 32
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:3]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 0.333333333333 / random : 0.834954507853
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 33   Ensemble: 0  failsteps = 33
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:3]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 0.142857142857 / random : 0.558356624172
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 34   Ensemble: 0  failsteps = 34
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:3]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 0.222222222222 / random : 0.635991949215
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 35   Ensemble: 0  failsteps = 35
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:3]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 26
# Proposal probability 0.0769230769231 / random : 0.568105661422
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 36   Ensemble: 0  failsteps = 36
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:3]
# Starting trajectory
# Finished trajectory, length: 7
# Proposal probability 0.285714285714 / random : 0.32923851615
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 37   Ensemble: 0  failsteps = 37
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:3]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 0.2 / random : 0.108309201328
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 38   Ensemble: 0  failsteps = 38
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:11]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.11111111111 / random : 0.891975829391
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 39   Ensemble: 0  failsteps = 39
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:10]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 1.0 / random : 0.787357933851
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 40   Ensemble: 0  failsteps = 40
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 9 in [0:10]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.343209324792
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 41   Ensemble: 0  failsteps = 41
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:10]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 1.5 / random : 0.497544203153
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 42   Ensemble: 0  failsteps = 42
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 5 in [0:7]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.0 / random : 0.288174490056
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 43   Ensemble: 0  failsteps = 43
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:7]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 2.0 / random : 0.544368783421
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 44   Ensemble: 0  failsteps = 44
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:4]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.161525499327
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 45   Ensemble: 0  failsteps = 45
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:4]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 0.136363636364 / random : 0.923804325674
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 46   Ensemble: 0  failsteps = 46
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:4]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 0.272727272727 / random : 0.794793032176
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 47   Ensemble: 0  failsteps = 47
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:4]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.769807163722
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 48   Ensemble: 0  failsteps = 48
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:4]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.540400934834
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 49   Ensemble: 0  failsteps = 49
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:4]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.0 / random : 0.311168748658
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 50   Ensemble: 0  failsteps = 50
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:4]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 0.375 / random : 0.296056503527
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 51   Ensemble: 0  failsteps = 51
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:9]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 0.727272727273 / random : 0.926236250634
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 52   Ensemble: 0  failsteps = 52
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 7 in [0:9]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 1.14285714286 / random : 0.764924957295
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 53   Ensemble: 0  failsteps = 53
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:8]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 0.875 / random : 0.0562498312393
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 54   Ensemble: 0  failsteps = 54
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 6 in [0:9]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 0.888888888889 / random : 0.324858161137
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 55   Ensemble: 0  failsteps = 55
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 5 in [0:10]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 0.9 / random : 0.957920840923
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 56   Ensemble: 0  failsteps = 56
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 7 in [0:10]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.125 / random : 0.644486916107
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 57   Ensemble: 0  failsteps = 57
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:9]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 0.444444444444 / random : 0.540789600394
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 58   Ensemble: 0  failsteps = 58
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:9]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.14285714286 / random : 0.777231875487
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 59   Ensemble: 0  failsteps = 59
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 5 in [0:8]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 0.636363636364 / random : 0.195806315453
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 60   Ensemble: 0  failsteps = 60
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:12]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 3.66666666667 / random : 0.205969889434
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 61   Ensemble: 0  failsteps = 61
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:4]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 0.375 / random : 0.512194994917
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 62   Ensemble: 0  failsteps = 62
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:4]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.984569028414
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 63   Ensemble: 0  failsteps = 63
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:4]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 0.75 / random : 0.251643638848
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 64   Ensemble: 0  failsteps = 64
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 4 in [0:5]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.452715581777
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 65   Ensemble: 0  failsteps = 65
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:5]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.33333333333 / random : 0.863485119028
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 66   Ensemble: 0  failsteps = 66
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:4]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 0.230769230769 / random : 0.0070248879143
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 67   Ensemble: 0  failsteps = 67
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 5 in [0:14]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.18181818182 / random : 0.607681003536
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 68   Ensemble: 0  failsteps = 68
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 9 in [0:12]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.0 / random : 0.35894079628
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 69   Ensemble: 0  failsteps = 69
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 8 in [0:12]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 0.578947368421 / random : 0.745649332463
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 70   Ensemble: 0  failsteps = 70
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 4 in [0:12]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 0.6875 / random : 0.767027438122
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 71   Ensemble: 0  failsteps = 71
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:12]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 0.5 / random : 0.686002501901
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 72   Ensemble: 0  failsteps = 72
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 6 in [0:12]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 0.578947368421 / random : 0.182935246876
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 73   Ensemble: 0  failsteps = 73
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:20]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.16201323329
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 74   Ensemble: 0  failsteps = 74
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 15 in [0:20]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.0 / random : 0.246480665536
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 75   Ensemble: 0  failsteps = 75
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 15 in [0:20]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 1.05555555556 / random : 0.238104870594
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 76   Ensemble: 0  failsteps = 76
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:19]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 6.0 / random : 0.116308040765
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 77   Ensemble: 0  failsteps = 77
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:4]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 0.2 / random : 0.991294828723
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 78   Ensemble: 0  failsteps = 78
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:4]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 0.25 / random : 0.674385072219
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 79   Ensemble: 0  failsteps = 79
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:4]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.225643728374
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 80   Ensemble: 0  failsteps = 80
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:4]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.0 / random : 0.281816750238
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 81   Ensemble: 0  failsteps = 81
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:4]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.338161778197
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 82   Ensemble: 0  failsteps = 82
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:4]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.761689553795
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 83   Ensemble: 0  failsteps = 83
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:4]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.161589490039
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 84   Ensemble: 0  failsteps = 84
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:4]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 0.230769230769 / random : 0.296581318813
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 85   Ensemble: 0  failsteps = 85
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:4]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 0.3 / random : 0.258481079974
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 86   Ensemble: 0  failsteps = 86
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 10 in [0:11]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.0177383198986
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 87   Ensemble: 0  failsteps = 87
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 7 in [0:11]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 0.416666666667 / random : 0.237306258601
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 88   Ensemble: 0  failsteps = 88
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:25]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 0.705882352941 / random : 0.524051851436
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 89   Ensemble: 0  failsteps = 89
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 7 in [0:35]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 2.0 / random : 0.824391546698
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 90   Ensemble: 0  failsteps = 90
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 16 in [0:18]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.0 / random : 0.790861856519
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 91   Ensemble: 0  failsteps = 91
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 17 in [0:18]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 1.88888888889 / random : 0.740043472756
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 92   Ensemble: 0  failsteps = 92
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:10]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 0.692307692308 / random : 0.819241910153
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 93   Ensemble: 0  failsteps = 93
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:10]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 16
# Proposal probability 0.391304347826 / random : 0.299351944333
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 94   Ensemble: 0  failsteps = 94
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 21 in [0:24]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.0 / random : 0.998102659366
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 95   Ensemble: 0  failsteps = 95
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 14 in [0:24]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 1.76923076923 / random : 0.626167844227
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 96   Ensemble: 0  failsteps = 96
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 12 in [0:14]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 0.866666666667 / random : 0.685495356662
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 97   Ensemble: 0  failsteps = 97
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 10 in [0:16]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.5 / random : 0.4964973291
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 98   Ensemble: 0  failsteps = 98
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:11]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 0.416666666667 / random : 0.426047831586
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 99   Ensemble: 0  failsteps = 99
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 9 in [0:11]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 0.555555555556 / random : 0.169412589642
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 100   Ensemble: 0  failsteps = 100
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 16 in [0:19]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 1.63636363636 / random : 0.116882420476
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 101   Ensemble: 0  failsteps = 101
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 5 in [0:12]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.0 / random : 0.0140537671172
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 102   Ensemble: 0  failsteps = 102
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 9 in [0:12]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.0 / random : 0.153211168112
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 103   Ensemble: 0  failsteps = 103
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 7 in [0:12]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 0.785714285714 / random : 0.112852600303
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 104   Ensemble: 0  failsteps = 104
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 14 in [0:15]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 16
# Proposal probability 0.875 / random : 0.429795981177
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 105   Ensemble: 0  failsteps = 105
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 9 in [0:17]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 1.0 / random : 0.98984430805
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 106   Ensemble: 0  failsteps = 106
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 4 in [0:17]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 2.28571428571 / random : 0.809585453296
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 107   Ensemble: 0  failsteps = 107
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:8]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 2.33333333333 / random : 0.374512990015
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 108   Ensemble: 0  failsteps = 108
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:4]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.443288460886
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 109   Ensemble: 0  failsteps = 109
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:4]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 16
# Proposal probability 0.176470588235 / random : 0.915073311346
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 110   Ensemble: 0  failsteps = 110
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:4]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 0.3 / random : 0.109962189718
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 111   Ensemble: 0  failsteps = 111
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 8 in [0:11]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 1.66666666667 / random : 0.512580783017
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10d669c90> to <opentis.ensemble.SequentialEnsemble object at 0x11a148950>
# Step: 112   Ensemble: 0  failsteps = 112
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# ...
# Step: 369   Ensemble: 3  failsteps = 83
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 23 in [0:32]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 0.911764705882 / random : 0.636434348251
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11a16d790> to <opentis.ensemble.SequentialEnsemble object at 0x11a16dc10>
# Step: 370   Ensemble: 3  failsteps = 84
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 16 in [0:35]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 0.944444444444 / random : 0.0622862383934
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11a16d790> to <opentis.ensemble.SequentialEnsemble object at 0x11a16dc10>
# Step: 371   Ensemble: 3  failsteps = 85
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 35 in [0:37]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.0 / random : 0.386560331913
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11a16d790> to <opentis.ensemble.SequentialEnsemble object at 0x11a16dc10>
# Step: 372   Ensemble: 3  failsteps = 86
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 11 in [0:37]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 1.0 / random : 0.205861074625
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11a16d790> to <opentis.ensemble.SequentialEnsemble object at 0x11a16dc10>
# Step: 373   Ensemble: 3  failsteps = 87
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 18 in [0:37]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 1.2 / random : 0.358559200537
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11a16d790> to <opentis.ensemble.SequentialEnsemble object at 0x11a16dc10>
# Step: 374   Ensemble: 3  failsteps = 88
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 19 in [0:31]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 1.07142857143 / random : 0.708153621884
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11a16d790> to <opentis.ensemble.SequentialEnsemble object at 0x11a16dc10>
# Step: 375   Ensemble: 3  failsteps = 89
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 6 in [0:29]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 23
# Proposal probability 0.622222222222 / random : 0.395945135094
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11a16d790> to <opentis.ensemble.SequentialEnsemble object at 0x11a16dc10>
# Step: 376   Ensemble: 3  failsteps = 90
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 44 in [0:46]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 28
# Proposal probability 1.55172413793 / random : 0.547751160392
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11a16d790> to <opentis.ensemble.SequentialEnsemble object at 0x11a16dc10>
# Step: 377   Ensemble: 3  failsteps = 91
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 4 in [0:30]
# Starting trajectory
# Finished trajectory, length: 4
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11a16d790> to <opentis.ensemble.SequentialEnsemble object at 0x11a16dc10>
# Step: 378   Ensemble: 3  failsteps = 92
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 6 in [0:30]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 31
# Proposal probability 0.537037037037 / random : 0.241944969297
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11a16d790> to <opentis.ensemble.SequentialEnsemble object at 0x11a16dc10>
# Step: 379   Ensemble: 3  failsteps = 93
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 33 in [0:55]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 30
# Proposal probability 1.05882352941 / random : 0.986079585936
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11a16d790> to <opentis.ensemble.SequentialEnsemble object at 0x11a16dc10>
# Step: 380   Ensemble: 3  failsteps = 94
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 26 in [0:52]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 20
# Proposal probability 1.13333333333 / random : 0.425542329686
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11a16d790> to <opentis.ensemble.SequentialEnsemble object at 0x11a16dc10>
# Step: 381   Ensemble: 3  failsteps = 95
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 37 in [0:46]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 1.0 / random : 0.393603399945
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11a16d790> to <opentis.ensemble.SequentialEnsemble object at 0x11a16dc10>
# Step: 382   Ensemble: 3  failsteps = 96
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 34 in [0:46]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 20
# Proposal probability 1.45161290323 / random : 0.675828143376
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11a16d790> to <opentis.ensemble.SequentialEnsemble object at 0x11a16dc10>
# Step: 383   Ensemble: 3  failsteps = 97
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 14 in [0:32]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11a16d790> to <opentis.ensemble.SequentialEnsemble object at 0x11a16dc10>
# Step: 384   Ensemble: 3  failsteps = 98
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 10 in [0:32]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11a16d790> to <opentis.ensemble.SequentialEnsemble object at 0x11a16dc10>
# Step: 385   Ensemble: 3  failsteps = 99
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 14 in [0:32]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11a16d790> to <opentis.ensemble.SequentialEnsemble object at 0x11a16dc10>
# Step: 386   Ensemble: 3  failsteps = 100
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 14 in [0:32]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 19
# Proposal probability 0.861111111111 / random : 0.083529985354
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11a16d790> to <opentis.ensemble.SequentialEnsemble object at 0x11a16dc10>
# Step: 387   Ensemble: 3  failsteps = 101
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 27 in [0:37]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 0.972972972973 / random : 0.3868390777
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11a16d790> to <opentis.ensemble.SequentialEnsemble object at 0x11a16dc10>
# Step: 388   Ensemble: 3  failsteps = 102
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 5 in [0:38]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 30
# Proposal probability 1.08823529412 / random : 0.428118006881
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11a16d790> to <opentis.ensemble.SequentialEnsemble object at 0x11a16dc10>
# Step: 389   Ensemble: 3  failsteps = 103
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 9 in [0:35]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11a16d790> to <opentis.ensemble.SequentialEnsemble object at 0x11a16dc10>
# Step: 390   Ensemble: 3  failsteps = 104
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 8 in [0:35]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 0.971428571429 / random : 0.246262004891
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11a16d790> to <opentis.ensemble.SequentialEnsemble object at 0x11a16dc10>
# Step: 391   Ensemble: 3  failsteps = 105
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 31 in [0:36]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 32
# Proposal probability 0.972222222222 / random : 0.396058808819
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11a16d790> to <opentis.ensemble.SequentialEnsemble object at 0x11a16dc10>
# Step: 392   Ensemble: 3  failsteps = 106
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:37]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 28
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11a16d790> to <opentis.ensemble.SequentialEnsemble object at 0x11a16dc10>
# Step: 393   Ensemble: 3  failsteps = 107
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 10 in [0:37]
# Starting trajectory
# Finished trajectory, length: 9
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11a16d790> to <opentis.ensemble.SequentialEnsemble object at 0x11a16dc10>
# Step: 394   Ensemble: 3  failsteps = 108
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 32 in [0:37]
# Starting trajectory
# Finished trajectory, length: 5
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11a16d790> to <opentis.ensemble.SequentialEnsemble object at 0x11a16dc10>
# Step: 395   Ensemble: 3  failsteps = 109
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 20 in [0:37]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Proposal probability 1.09090909091 / random : 0.965445426112
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11a16d790> to <opentis.ensemble.SequentialEnsemble object at 0x11a16dc10>
# Step: 396   Ensemble: 3  failsteps = 110
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 16 in [0:34]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 0.942857142857 / random : 0.102241413907
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11a16d790> to <opentis.ensemble.SequentialEnsemble object at 0x11a16dc10>
# Step: 397   Ensemble: 3  failsteps = 111
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:36]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 32
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11a16d790> to <opentis.ensemble.SequentialEnsemble object at 0x11a16dc10>
# Step: 398   Ensemble: 3  failsteps = 112
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 27 in [0:36]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 0.729166666667 / random : 0.948672563421
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11a16d790> to <opentis.ensemble.SequentialEnsemble object at 0x11a16dc10>
# Step: 399   Ensemble: 3  failsteps = 113
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 34 in [0:36]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.0 / random : 0.0493478120678
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11a16d790> to <opentis.ensemble.SequentialEnsemble object at 0x11a16dc10>
# Step: 400   Ensemble: 3  failsteps = 114
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 7 in [0:36]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 33
# Proposal probability 0.897435897436 / random : 0.1843271373
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11a16d790> to <opentis.ensemble.SequentialEnsemble object at 0x11a16dc10>
# Step: 401   Ensemble: 3  failsteps = 115
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 14 in [0:40]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 1.0 / random : 0.952049866501
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11a16d790> to <opentis.ensemble.SequentialEnsemble object at 0x11a16dc10>
# Step: 402   Ensemble: 3  failsteps = 116
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 39 in [0:40]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.578807175638
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11a16d790> to <opentis.ensemble.SequentialEnsemble object at 0x11a16dc10>
# Step: 403   Ensemble: 3  failsteps = 117
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 30 in [0:40]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Through frame: 70
# Finished trajectory, length: 77
# Proposal probability 0.453488372093 / random : 0.0667256474625
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11a16d790> to <opentis.ensemble.SequentialEnsemble object at 0x11a16dc10>
# Step: 404   Ensemble: 4  failsteps = 0
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 35 in [0:87]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 37
# Proposal probability 1.21126760563 / random : 0.684071743981
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x11a16dc10> to <opentis.ensemble.SequentialEnsemble object at 0x11a1710d0>

# %% [markdown]
# We've stored all the trajectories we generated here; now we want to extract a path for each ensemble to use as a starting point for TIS. We'll choose to take the first path that satisfied each ensemble.

# %%
print "[ ",
for sample in bootstrap.globalstate:
    print str(sample.trajectory)+" ",
print "]"
# Out:
# [  Trajectory[16]  Trajectory[28]  Trajectory[58]  Trajectory[41]  Trajectory[88]  Trajectory[73]  ]

# %% [markdown]
# Let's go ahead and visualize where each of those trajectories are:

# %%
plot.plot([sample.trajectory for sample in bootstrap.globalstate])

# %% [markdown]
# ## Equilibration in the Path Ensemble
#
# At the end of the bootstrapping process, we have a set of paths which we can use to start TIS sampling. Before doing a production run, we should let these paths equilibrate within the ensembles. If you generate your initial path through dynamics that aren't the true dynamics (e.g., using high temperature runs or using metadynamics), this stage is **extremely** important. It's important here as well, but less so than if your initial path is non-physical.
#
# This will be an example of a "normal" TIS run, i.e., TIS without replica exchange. We will sampling using only shooter movers (the same ones defined for the bootstrapping) and path reversal movers. First we define these path reveral movers:

# %%
from opentis.pathmover import PathReversalSet
reversal_movers = PathReversalSet(interface_ensemble_set)

# %% [markdown]
# Next we define global moves: we'll set this up so that each move either does a shooting move on all replicas, or does a path reversal move on all replicas. You can similarly set it up so that each move operates on only on one replica at a time.

# %%
from opentis.pathmover import RandomChoiceMover
shooting_chooser = RandomChoiceMover(shooting_movers)
shooting_chooser.name="ShootingChooser"
reversal_chooser = RandomChoiceMover(reversal_movers)
reversal_chooser.name="ReversalChooser"
equilibration_movers = RandomChoiceMover([shooting_chooser, reversal_chooser])

# %% [markdown]
# Now we're ready to set up a TIS run:

# %%
from opentis.calculation import PathSampling
equilibration = PathSampling(storage=None, engine=sim, root_mover=equilibration_movers, globalstate=bootstrap.globalstate)

# %% [markdown]
# And now we run it. We'll do 200 equilibration steps.

# %%
equilibration.run(200)
# Out:
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 22 in [0:37]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Proposal probability 0.947368421053 / random : 0.0109995303157
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 43 in [0:56]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 39
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 20 in [0:56]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 40 in [0:56]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Finished trajectory, length: 53
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:20]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 0.5 / random : 0.485341377098
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 26 in [0:56]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 20
# Proposal probability 1.12244897959 / random : 0.565027947557
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 28 in [0:39]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 2.11111111111 / random : 0.875641443074
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 34 in [0:44]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 26
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 13 in [0:44]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 1.02380952381 / random : 0.27120402405
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 48 in [0:50]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 48
# Proposal probability 0.515789473684 / random : 0.80160296501
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:19]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 19
# Proposal probability 0.514285714286 / random : 0.732844783142
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:19]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 0.5625 / random : 0.802873038036
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 6 in [0:19]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Proposal probability 0.620689655172 / random : 0.714683762329
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 33 in [0:39]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 1.0 / random : 0.0972995050072
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 32 in [0:43]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 29
# Proposal probability 1.07692307692 / random : 0.60515661011
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 50 in [0:52]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Finished trajectory, length: 52
# Proposal probability 0.50495049505 / random : 0.406658714044
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 28 in [0:39]
# Starting trajectory
# Finished trajectory, length: 9
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 35 in [0:39]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 0.974358974359 / random : 0.565256257108
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 28 in [0:31]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 1.25 / random : 0.561016852862
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 30 in [0:102]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 24
# Proposal probability 1.06315789474 / random : 0.575333762807
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 12 in [0:40]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 0.975 / random : 0.010362324149
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 12 in [0:19]
# Starting trajectory
# Finished trajectory, length: 7
# Proposal probability 1.0 / random : 0.4194278774
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 10 in [0:50]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 33
# Proposal probability 0.680555555556 / random : 0.871595106474
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 94 in [0:96]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.0 / random : 0.293719818647
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 26 in [0:96]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 1.09195402299 / random : 0.14599983036
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 4 in [0:25]
# Starting trajectory
# Finished trajectory, length: 3
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 5 in [0:50]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.0 / random : 0.383696827586
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 34 in [0:40]
# Starting trajectory
# Finished trajectory, length: 7
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 37 in [0:41]
# Starting trajectory
# Finished trajectory, length: 5
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 5 in [0:19]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 1.05882352941 / random : 0.495156680281
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:41]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 20
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 4 in [0:18]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 2.42857142857 / random : 0.327769099198
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 63 in [0:88]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Through frame: 70
# Finished trajectory, length: 72
# Proposal probability 0.90625 / random : 0.235183258034
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 22 in [0:25]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.04347826087 / random : 0.414421270761
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 39 in [0:40]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 30
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:8]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 0.259259259259 / random : 0.459328925005
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 6 in [0:8]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 0.875 / random : 0.194057365588
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 13 in [0:24]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 1.0 / random : 0.203999044527
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 4 in [0:9]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.0 / random : 0.923130373023
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 8 in [0:97]
# Starting trajectory
# Finished trajectory, length: 7
# Proposal probability 1.01052631579 / random : 0.285516185586
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 24 in [0:41]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 23
# Proposal probability 1.02564102564 / random : 0.899550785454
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:9]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.0 / random : 0.0294315655056
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 60 in [0:96]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 45
# Proposal probability 1.1875 / random : 0.580170415285
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 18 in [0:40]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 23
# Proposal probability 0.886363636364 / random : 0.799785631934
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 12 in [0:24]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Proposal probability 0.821428571429 / random : 0.287748534904
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 25 in [0:40]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 19
# Proposal probability 1.18181818182 / random : 0.316592289919
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:34]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 41 in [0:50]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 0.960784313725 / random : 0.885742116879
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 69 in [0:81]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Through frame: 70
# Finished trajectory, length: 79
# Proposal probability 0.544217687075 / random : 0.0418567174914
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 11 in [0:29]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Proposal probability 0.875 / random : 0.549627883148
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 26 in [0:34]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 19
# Proposal probability 0.75 / random : 0.874449957009
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:9]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.0 / random : 0.543716237833
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 15 in [0:34]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 0.916666666667 / random : 0.0345311442019
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 14 in [0:52]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 16
# Proposal probability 0.962264150943 / random : 0.192283394163
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 30 in [0:45]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 1.22222222222 / random : 0.15384185185
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 5 in [0:37]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:33]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.932776949187
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 11 in [0:33]
# Starting trajectory
# Finished trajectory, length: 7
# Proposal probability 1.14285714286 / random : 0.905731154831
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:54]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 9 in [0:37]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 1.0 / random : 0.144532414089
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 23 in [0:37]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# Proposal probability 0.765957446809 / random : 0.596272553792
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 134 in [0:148]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 40
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 16 in [0:37]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 29
# Proposal probability 0.734693877551 / random : 0.132165125645
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 7 in [0:9]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 0.333333333333 / random : 0.403776403992
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 32 in [0:54]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 1.0 / random : 0.997797752536
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 15 in [0:48]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 24
# Proposal probability 0.839285714286 / random : 0.910220048685
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 29 in [0:54]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 16
# Proposal probability 1.20454545455 / random : 0.41514954273
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 8 in [0:9]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 19
# Proposal probability 0.421052631579 / random : 0.824550023784
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 7 in [0:45]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 37
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 9 in [0:48]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 30
# Proposal probability 1.23684210526 / random : 0.863649416238
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:148]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Finished trajectory, length: 53
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 24 in [0:29]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 1.03703703704 / random : 0.796025801255
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:9]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 2.66666666667 / random : 0.966318638841
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:39]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 1.0 / random : 0.445542389119
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 23 in [0:45]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 32
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 22 in [0:50]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# Proposal probability 1.02083333333 / random : 0.456263071623
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 28 in [0:49]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 1.14285714286 / random : 0.415248955504
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 25 in [0:43]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 1.13513513514 / random : 0.346574980237
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 9 in [0:45]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 26
# Proposal probability 1.29411764706 / random : 0.741099679203
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 5 in [0:35]
# Starting trajectory
# Finished trajectory, length: 4
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 18 in [0:39]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 1.26666666667 / random : 0.823307413533
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:4]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 23
# Proposal probability 0.130434782609 / random : 0.992426545533
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 13 in [0:38]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 28
# Proposal probability 0.925 / random : 0.608075995781
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 12 in [0:28]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Proposal probability 0.9 / random : 0.960275787697
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 34 in [0:35]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 45
# Proposal probability 0.435897435897 / random : 0.439653575256
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 14 in [0:31]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 0.789473684211 / random : 0.86326968162
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 5 in [0:35]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Finished trajectory, length: 67
# Proposal probability 0.478873239437 / random : 0.364261053355
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:28]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# Proposal probability 1.08 / random : 0.225114661625
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 45 in [0:72]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 28
# Proposal probability 1.31481481481 / random : 0.939160596986
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 33 in [0:41]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 12 in [0:55]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 6 in [0:31]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 30
# Proposal probability 0.857142857143 / random : 0.823095866585
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:4]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Proposal probability 0.176470588235 / random : 0.871095391874
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 43 in [0:55]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 31
# Proposal probability 0.739726027397 / random : 0.230964657975
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 29 in [0:74]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# Proposal probability 1.37735849057 / random : 0.0922967244244
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 46 in [0:54]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 1.0 / random : 0.68431532027
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 19 in [0:41]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 19
# Proposal probability 1.08108108108 / random : 0.488296161736
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 15 in [0:54]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 26
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (ReversalChooser) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 123 in [0:148]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 38
# Proposal probability 0.91875 / random : 0.054204681303

# %% [markdown]
# Now let's take a look at where the trajectories are after they've had a chance to equilibrate:

# %%
#plot.plot([sample.trajectory for sample in equilibration.globalstate])
plot.plot([equilibration.globalstate[5].trajectory])

# %% [markdown]
# ## RETIS: Production run
#
# With everything else set up, we can set up the replica exchange movers, and reuse the other movers.

# %%
from opentis.pathmover import NeighborEnsembleReplicaExchange
repex_movers = NeighborEnsembleReplicaExchange(interface_ensemble_set)
repex_chooser = RandomChoiceMover(repex_movers)

# %% [markdown]
# We'll also set up the minus ensemble and minus move:

# %%
# minus_ensemble
# minus_move

# %% [markdown]
# Finally, we set up a production run; this is very similar to the setup for the TIS equilibration run. However, up until now, we have not used file storage; before this run we will set up a storage file. The single storage file will save all the trajectories as well as all the details of the RETIS simulation (what movers are used, the acceptance of each trial, etc.)

# %%
#storage = paths.storage.Storage(
#    filename="toy_tis.nc",
#    template=sim.current_snapshot # that's an ugly hack
#)

# %%
retis_root_mover = RandomChoiceMover([shooting_chooser, reversal_chooser, repex_chooser])
production = PathSampling(storage=None, engine=sim, root_mover=retis_root_mover, globalstate=equilibration.globalstate)

# %% [markdown]
# We'll run the production calculation for 500 MC steps.

# %%
production.run(500)
# Out:
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 21 in [0:42]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 23
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:42]
# Starting trajectory
# Finished trajectory, length: 3
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 33 in [0:37]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 30
# Proposal probability 0.58064516129 / random : 0.103038831881
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 28 in [0:61]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 1.57894736842 / random : 0.288903759713
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 45 in [0:85]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 49
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 32 in [0:42]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 31
# Proposal probability 0.661290322581 / random : 0.0549477567228
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 43 in [0:85]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 45 in [0:63]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 1.77142857143 / random : 0.111301097562
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:4]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.918266466668
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 7 in [0:30]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 1.03571428571 / random : 0.0658124072832
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 16 in [0:39]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Proposal probability 1.26666666667 / random : 0.652681378122
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 8 in [0:31]
# Starting trajectory
# Finished trajectory, length: 7
# Proposal probability 1.03448275862 / random : 0.0224139389735
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 32 in [0:36]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 28
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:4]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.0 / random : 0.453181345155
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:4]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 32
# Proposal probability 0.09375 / random : 0.016339852797
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 7 in [0:29]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 2.0 / random : 0.0627132589134
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 13 in [0:36]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 0.972222222222 / random : 0.84691404768
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 43 in [0:85]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 19
# Proposal probability 1.37704918033 / random : 0.408531759553
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 12 in [0:33]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# Proposal probability 0.888888888889 / random : 0.471192489997
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:15]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 28
# Proposal probability 0.368421052632 / random : 0.555443500406
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 56 in [0:62]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 37
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 9 in [0:30]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 0.966666666667 / random : 0.229298788827
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 8 in [0:37]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 21
# Proposal probability 1.28571428571 / random : 0.779611855738
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 23 in [0:31]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 21
# Proposal probability 1.07142857143 / random : 0.949176910023
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 27 in [0:29]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 38
# Proposal probability 0.4375 / random : 0.796176279196
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 9 in [0:29]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 1.0 / random : 0.501059136259
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 12 in [0:62]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Finished trajectory, length: 67
# Proposal probability 0.782051282051 / random : 0.504860111571
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 12 in [0:29]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 26
# Proposal probability 0.756756756757 / random : 0.315894295799
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:63]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 39
# Proposal probability 1.58974358974 / random : 0.556052805978
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 20 in [0:40]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 24
# Proposal probability 0.906976744186 / random : 0.0977397429985
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 31 in [0:44]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 32
# Proposal probability 0.977272727273 / random : 0.932507020427
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 9 in [0:29]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 24
# Proposal probability 0.651162790698 / random : 0.641129713688
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:44]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.0 / random : 0.645074718889
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 36 in [0:44]
# Starting trajectory
# Finished trajectory, length: 8
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 36 in [0:45]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 1.0 / random : 0.541626075716
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 7 in [0:15]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 1.07692307692 / random : 0.888217007054
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 8 in [0:45]
# Starting trajectory
# Finished trajectory, length: 7
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 78 in [0:79]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.00691609726841
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 32 in [0:44]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 32
# Proposal probability 0.68253968254 / random : 0.638309347885
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:14]
# Starting trajectory
# Finished trajectory, length: 2
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:45]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.02325581395 / random : 0.347106377598
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 8 in [0:14]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 26
# Proposal probability 0.393939393939 / random : 0.16888299504
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 26 in [0:38]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Proposal probability 1.32142857143 / random : 0.754285471031
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 18 in [0:37]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 19
# Proposal probability 1.0 / random : 0.789435807074
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 23 in [0:44]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 20
# Proposal probability 1.02380952381 / random : 0.199969636458
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 14 in [0:64]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 30
# Proposal probability 1.46511627907 / random : 0.699874752745
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 31 in [0:34]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# Proposal probability 1.22222222222 / random : 0.211287755583
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 7 in [0:37]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 0.972972972973 / random : 0.327104942454
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 20 in [0:44]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 1.16216216216 / random : 0.145764149408
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 29 in [0:43]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 37
# Proposal probability 0.84 / random : 0.33235618748
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 6 in [0:28]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 2.7 / random : 0.54767108947
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 26 in [0:38]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# Proposal probability 0.973684210526 / random : 0.857652325357
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 37 in [0:38]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 20 in [0:51]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 13 in [0:38]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 1.08823529412 / random : 0.0571665840612
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 26 in [0:51]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 29
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 26 in [0:51]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 43
# Proposal probability 0.746268656716 / random : 0.695556930557
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 35 in [0:39]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 35
# Proposal probability 0.550724637681 / random : 0.369822762959
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 9 in [0:79]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 1.0 / random : 0.24199345289
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:11]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 29
# Proposal probability 0.322580645161 / random : 0.98407887983
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 11 in [0:29]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 0.903225806452 / random : 0.241460110914
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 24 in [0:70]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 1.09523809524 / random : 0.33851764088
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 30 in [0:35]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.0 / random : 0.256274537951
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 15 in [0:32]
# Starting trajectory
# Through frame: 10
# ...
# Shooting forward from frame 62 in [0:95]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 28
# Proposal probability 1.05617977528 / random : 0.48140679827
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 52 in [0:72]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 45
# Proposal probability 0.739583333333 / random : 0.111348190543
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 14 in [0:30]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 1.0 / random : 0.832311859178
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 40 in [0:41]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.11900366816
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 7 in [0:41]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 32
# Proposal probability 1.05263157895 / random : 0.640951310854
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 12 in [0:97]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 16
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 29 in [0:30]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 13 in [0:30]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 0.852941176471 / random : 0.012796294007
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 56 in [0:97]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 18 in [0:33]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 21
# Proposal probability 0.914285714286 / random : 0.246898226719
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 85 in [0:90]
# Starting trajectory
# Finished trajectory, length: 5
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 10 in [0:97]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:30]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.0533026338976
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 13 in [0:30]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 21
# Proposal probability 0.878787878788 / random : 0.219073427295
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 8 in [0:36]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 2.1875 / random : 0.0419190191244
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 8 in [0:35]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 0.772727272727 / random : 0.295343693299
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 13 in [0:17]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 24
# Proposal probability 0.444444444444 / random : 0.253817264794
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 84 in [0:97]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 39 in [0:45]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 0.785714285714 / random : 0.137125668221
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 23 in [0:37]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Proposal probability 0.923076923077 / random : 0.505813823102
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
