# %%
# Note: in practice, one should put all the imports at the top of a Python script. 
# But for educational purposes here, I put the import immediately before usage. 
# This Python block is just to set up some plotting stuff.

# Imports for plotting
# %matplotlib inline
import opentis as paths
import numpy as np
from toy_plot_helpers import ToyPlot
plot = ToyPlot()

# %% [markdown]
# # Setting up RETIS on a Toy Model
#
# This example shows how to set up a RETIS calculation. We do this on a simple 2D model so it can be fast enough for an interactive example, but the basic approach applies to larger systems as well. Although I'll describe everything here in terms of 2-state systems, all the ideas generalize when setting up multiple-state systems (you just need to find more initial paths).

# %% [markdown]
# ## Getting an initial path
#
# RETIS is a path sampling method: it requires that the user supply an input path for each path ensemble. This means that you must somehow generate a first input path. In general, getting the first input paths for RETIS boils down to solving two problems:
#
# 1. Getting a trajectory that samples the rare event.
# 2. Filling all the path ensembles with acceptable trajectories.
#
# Since transition paths satisfy all the path ensembles between two states, a common approach is to use the same initial path for all path ensembles (reversing it where necessary). This way, once you've solved problem 1, problem 2 is trivial.
#
# The first rare path can come from any number of sources. The obvious approach might be to find a transition path from a committor analysis, because this would give you a path that satisfies the true dynamics. However, the initial path doesn't need to satisfy the true dynamics of the system (later we will equilibrate the path ensemble anyway). This means that other approaches, such as high-temperature trajectories, can be used for the first path. One of the most widely-used methods to get an initial trajectory is to generate a transition trajectory using metadynamics. However, the downside of using paths that don't satisfy the true dynamics is that it might be harder to get them to equilibrate to the correct path ensemble. It seems that this has been more of a problem with paths from high temperature runs than with paths from metadynamics: a path from a modified potential energy surface at the correct temperature seems to equilibrate more easily than a path from the original potential energy surface at an incorrect temperature.
#
# In this example, we use a bootstrapping approach, which does create paths satisfying the true dynamics of the system. This bootstrapping is nice because it is quick and convenient, although it works best on smaller systems with less complicated transitions. It works by running normal MD to generate a path that satisfies the innermost interface, and then performing shooting moves in that interface's path ensemble until we have a path that crosses the next interface. Then we switch to the path ensemble for the next interface, and shoot until the path crossing the interface after that. The process continues until we have paths for all interfaces.

# %% [markdown]
# ### Basic system setup
#
# First we set up our system: for the toy dynamics, this involves defining a potential energy surface (PES), setting up an integrator, and giving the simulation an initial configuration. In real MD systems, the PES is handled by the combination of a topology file and a force field definition, and the initial configuration would come from a file instead of being described by hand.

# %%
from opentis.toy_dynamics.toy_engine import ToyEngine
from opentis.toy_dynamics.toy_integrators import LangevinBAOABIntegrator
from opentis.toy_dynamics.toy_pes import Gaussian, OuterWalls

import logging.config
logging.config.fileConfig("logging.conf", disable_existing_loggers=False)

# %% [markdown]
# ### Set up the toy system
# This includes the potential energy surface (PES), and an initial configuration

# %%
# Toy_PES supports adding/subtracting various PESs. The OuterWalls PES type gives an x^6+y^6 boundary to the system
pes = (OuterWalls([1.0, 1.0], [0.0, 0.0]) + 
       Gaussian(2.0, [1.0, 4.0], [0.0,1.0]) + 
       Gaussian(2.0, [25.0, 1.0], [0.0, -1.0])
      )
topology=paths.ToyTopology(
    n_spatial = 2,
    masses =[1.0, 1.0],
    pes = pes
)
initial_snapshot = paths.Snapshot(
    coordinates=np.array([[-0.5, 0.0]]), 
    velocities=np.array([[0.0,0.0]]),
    potential_energy = 0.0, # Important to set energies dimensionless otherwise kcal/mol is default
    kinetic_energy = 0.0,
    topology=topology
)

# %% [markdown]
# ### Setup engine

# %%
integ = LangevinBAOABIntegrator(dt=0.02, temperature=0.1, gamma=1.0)
options={'integ' : integ,
         'n_frames_max' : 5000,
         'nsteps_per_frame' : 10
        }
sim = ToyEngine(
        options=options,
        template=initial_snapshot
)

sim.current_snapshot = initial_snapshot

# %% [markdown]
# Now let's take a look at our PES and our initial configuration:

# %%
plot.add_pes(pes)
plot.add_initial_condition(sim.current_snapshot)
plot.plot()

# %% [markdown]
# ### Interface setup
#
# One downside of the bootstrapping approach is that we need to have defined our interfaces before we start. However, we can always easily change our initial interface guesses.
#
# We'll consider a couple different choices of order parameter to define our interfaces. First we'll look at lines at different values of $x$. That set will be called `line_set`. Later we'll also consider circles centered on (-0.5, -0.25), with different radii. We'll call this set of interfaces `circle_set`.
#
# In both cases, we need to define the order parameter, and then we need to create a set of volumes and a set of ensembles associated with those volumes.

# %%
from opentis.orderparameter import OP_Function
from opentis.volume import VolumeFactory as vf
from opentis.volume import LambdaVolume
from opentis.trajectory import Trajectory

try:
    op_line = OP_Function(name="xval", 
                          fcn=lambda snap : snap.coordinates[0,0])
except ValueError:
    print "xval already made"
# this defines a set of LambdaVolumes for which the minimum is -1.0 and the maximum is given in the array
line_volume_set = vf.LambdaVolumeSet(op_line, minvals=-1.0, maxvals=[-0.30, -0.25, -0.20, -0.13, -0.05, 0.0])
stateA = LambdaVolume(op_line, -1.0, -0.3)
stateB = LambdaVolume(op_line, 0.3, 1.0)

# %%
plot.add_states([stateA, stateB])
plot.add_interfaces(line_volume_set)
plot.plot()

# %% [markdown]
# In this picture, the states are marked in blue, and the interfaces are drawn as red lines. The initial configuration is still the red dot.

# %% [markdown]
# ### First innermost interface path
#
# Now we have to create an initial path. This initial path shoud exit the state, cross the first interface, and then return to the state. We'll create this path by defining a special ensemble that, propagating forward from any initial snapshot, ends when the path ends with a segment in the appropriate interface.

# %%
from opentis.ensemble import EnsembleFactory as ef
from opentis.ensemble import LengthEnsemble, InXEnsemble, OutXEnsemble, SequentialEnsemble, OptionalEnsemble, SingleFrameEnsemble

interface0 = line_volume_set[0]
interface_ensemble_set = ef.TISEnsembleSet(stateA, stateB, line_volume_set)
first_traj_ensemble = SequentialEnsemble([
    OptionalEnsemble(OutXEnsemble(stateA)),
    InXEnsemble(stateA),
    OptionalEnsemble(OutXEnsemble(stateA) & InXEnsemble(interface0)),
    OptionalEnsemble(InXEnsemble(interface0)),
    OutXEnsemble(interface0),
    OptionalEnsemble(OutXEnsemble(stateA)),
    SingleFrameEnsemble(InXEnsemble(stateA))
])

# %% [markdown]
# This ensemble is a bit complicated, but works in the general case. To understand it, we'll look at the `SequentialEnsemble` segment by segment. One preliminary point is that we need the generated path ensemble to be the same as the accepted path ensemble in this case, meaning that we must define the ensemble entirely in terms of which volumes each segment is in (i.e., using `InXEnsemble` and `OutXEnsemble`, but not `LeaveXEnsemble` or `HitXEnsemble`).
#
# Start with the first two segments: we start with an optional ensemble outside the state, and then move to an ensemble that is in the state. Since our TIS segment must start in a state, these two ensembles allow us to either start outside the state and then evolve into the state, or to start inside the state. At the end of these two segments, we have the first frame of the TIS ensemble segment, i.e., the frame inside the state that begins the TIS path.
#
# Next we have a couple of optional ensembles, followed by an ensemble requiring the segment to be outside the interface. The optional interfaces here are only important if `stateA` and `interface0` represent different volumes. If they represent the same volume (which is the case here) these optional ensembles don't matter. However, if they are different volumes, then there is a space which is outside the state but inside the interface. So the first optional interface represents that space. The next optional interface says that you must then be inside `interface0`: this is in case there is a reentry into the state before you cross the interface. Next, we require that we cross the interface. The last optional ensemble is for segments ouside the state. If there is space between the interface and the state, then after you are no longer outside the interface you might still be outside the state. Finally, the path ends with one frame in the state.
#
# Following the logic of that, any path that begins anywhere and ends with a segment satisfying the innermost TIS ensemble will be accepted by this ensemble. Furthermore, since the ensemble is defined exclusively in terms of `InXEnsemble`s and `OutXEnsemble`s, the ensemble of paths generated by forward dynamics (`can_append`) is equivalent to the accepted path ensemble.

# %%
sim.initialized = True
first_traj = sim.generate(sim.current_snapshot, [first_traj_ensemble.can_append])
# Out:
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Through frame: 70
# Through frame: 80
# Through frame: 90
# Through frame: 100
# Through frame: 110
# Through frame: 120
# Through frame: 130
# Through frame: 140
# Through frame: 150
# Through frame: 160
# Through frame: 170
# Through frame: 180
# Through frame: 190
# Through frame: 200
# Through frame: 210
# Through frame: 220
# Through frame: 230
# Through frame: 240
# Through frame: 250
# Through frame: 260
# Through frame: 270
# Through frame: 280
# Through frame: 290
# Through frame: 300
# Through frame: 310
# Through frame: 320
# Through frame: 330
# Through frame: 340
# Through frame: 350
# Through frame: 360
# Through frame: 370
# Through frame: 380
# Through frame: 390
# Through frame: 400
# Through frame: 410
# Through frame: 420
# Through frame: 430
# Through frame: 440
# Through frame: 450
# Through frame: 460
# Through frame: 470
# Through frame: 480
# Through frame: 490
# Finished trajectory, length: 490

# %% [markdown]
# Next we use the `Ensemble.split` function to split the trajectory we found into segments satisfying the innermost interface TIS ensemble. There is only one such segment, and so we assign the first (and only) one found to `subtraj`, which is the first trajectory satisfying the innermost TIS interface.

# %%
subtraj = interface_ensemble_set[0].split(first_traj)[0]

# %%
plot.plot(bold=[first_traj], trajectories=[subtraj])

# %% [markdown]
# Now we see how the initial path evolves on this surface. The last part of the trajectory, which satisfies the path ensemble for the innermost interface, is highlighted in red. The whole trajectory is drawn in black.

# %% [markdown]
# ### Bootstrapping
#
# The bootstrapping approach takes a single trajectory which satisfies the innermost interface, and does shooting moves until it satisfies the next ensemble. Once it satisfies the next ensemble, we start shooting from within that ensemble. We keep building up like that until all ensembles have an initial path.
#
# To do this, we need to first create the appropriate shooting movers (one for each path ensemble). This is done quickly and efficiently with a factory function.

# %%
from opentis.pathmover import PathMoverFactory as mf
from opentis.shooting import UniformSelector

# might be nice to get rid of these two lines somehow
from opentis.pathmover import PathMover
PathMover.engine = sim

shooting_movers = mf.OneWayShootingSet(UniformSelector(), interface_ensemble_set)

# %% [markdown]
# Next we need to set up the Bootstrapping calculation:

# %%
from opentis.calculation import Bootstrapping

bootstrap = Bootstrapping(storage=None,
                          engine=sim,
                          ensembles=interface_ensemble_set,
                          movers=shooting_movers,
                          trajectory=subtraj)

# %% [markdown]
# Now we run the bootstrapping. The number `50` means that we'll allow up to 50 shooting attempts per interface; if it takes more than that, you should probably adjust your interfaces (there's probably not much overlap for replica exchange).

# %%
bootstrap.run(500)
# Out:
# Step: 0   Ensemble: 0  failsteps = 0
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 34 in [0:40]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 1.05405405405 / random : 0.551152396042
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x10934cbd0> to <opentis.ensemble.SequentialEnsemble object at 0x115dfaa10>
# Step: 1   Ensemble: 1  failsteps = 0
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 12 in [0:38]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 1.08823529412 / random : 0.150240681527
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x115dfaa10> to <opentis.ensemble.SequentialEnsemble object at 0x115defa10>
# Step: 2   Ensemble: 1  failsteps = 1
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 30 in [0:35]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 0.971428571429 / random : 0.0730392632114
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x115dfaa10> to <opentis.ensemble.SequentialEnsemble object at 0x115defa10>
# Step: 3   Ensemble: 1  failsteps = 2
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 34 in [0:36]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.0 / random : 0.195512616969
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x115dfaa10> to <opentis.ensemble.SequentialEnsemble object at 0x115defa10>
# Step: 4   Ensemble: 1  failsteps = 3
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 14 in [0:36]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 26
# Proposal probability 0.744680851064 / random : 0.668970667217
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x115dfaa10> to <opentis.ensemble.SequentialEnsemble object at 0x115defa10>
# Step: 5   Ensemble: 1  failsteps = 4
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:48]
# Starting trajectory
# Finished trajectory, length: 9
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x115dfaa10> to <opentis.ensemble.SequentialEnsemble object at 0x115defa10>
# Step: 6   Ensemble: 1  failsteps = 5
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 29 in [0:48]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 1.14634146341 / random : 0.910018600689
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x115dfaa10> to <opentis.ensemble.SequentialEnsemble object at 0x115defa10>
# Step: 7   Ensemble: 1  failsteps = 6
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 23 in [0:42]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 1.025 / random : 0.964431779052
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x115dfaa10> to <opentis.ensemble.SequentialEnsemble object at 0x115defa10>
# Step: 8   Ensemble: 1  failsteps = 7
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 24 in [0:41]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 19
# Proposal probability 0.952380952381 / random : 0.970761217155
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x115dfaa10> to <opentis.ensemble.SequentialEnsemble object at 0x115defa10>
# Step: 9   Ensemble: 1  failsteps = 8
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 14 in [0:41]
# Starting trajectory
# Finished trajectory, length: 8
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x115dfaa10> to <opentis.ensemble.SequentialEnsemble object at 0x115defa10>
# Step: 10   Ensemble: 1  failsteps = 9
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 30 in [0:41]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 31
# Proposal probability 0.975609756098 / random : 0.168733108853
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x115dfaa10> to <opentis.ensemble.SequentialEnsemble object at 0x115defa10>
# Step: 11   Ensemble: 2  failsteps = 0
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 35 in [0:42]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x115defa10> to <opentis.ensemble.SequentialEnsemble object at 0x115e0c890>
# Step: 12   Ensemble: 2  failsteps = 1
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 10 in [0:42]
# Starting trajectory
# Finished trajectory, length: 8
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x115defa10> to <opentis.ensemble.SequentialEnsemble object at 0x115e0c890>
# Step: 13   Ensemble: 2  failsteps = 2
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 40 in [0:42]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 41
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x115defa10> to <opentis.ensemble.SequentialEnsemble object at 0x115e0c890>
# Step: 14   Ensemble: 2  failsteps = 3
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 41 in [0:42]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 34
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x115defa10> to <opentis.ensemble.SequentialEnsemble object at 0x115e0c890>
# Step: 15   Ensemble: 2  failsteps = 4
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 7 in [0:42]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 1.025 / random : 0.0361273424477
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x115defa10> to <opentis.ensemble.SequentialEnsemble object at 0x115e0c890>
# Step: 16   Ensemble: 2  failsteps = 5
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 5 in [0:41]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 1.02564102564 / random : 0.808878014286
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x115defa10> to <opentis.ensemble.SequentialEnsemble object at 0x115e0c890>
# Step: 17   Ensemble: 2  failsteps = 6
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 9 in [0:40]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 33
# Proposal probability 0.951219512195 / random : 0.229576155176
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x115defa10> to <opentis.ensemble.SequentialEnsemble object at 0x115e0c890>
# Step: 18   Ensemble: 2  failsteps = 7
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 10 in [0:42]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 1.0 / random : 0.408513430203
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x115defa10> to <opentis.ensemble.SequentialEnsemble object at 0x115e0c890>
# Step: 19   Ensemble: 2  failsteps = 8
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:42]
# Starting trajectory
# Finished trajectory, length: 2
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x115defa10> to <opentis.ensemble.SequentialEnsemble object at 0x115e0c890>
# Step: 20   Ensemble: 2  failsteps = 9
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 19 in [0:42]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 20
# Proposal probability 1.07894736842 / random : 0.547463092104
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x115defa10> to <opentis.ensemble.SequentialEnsemble object at 0x115e0c890>
# Step: 21   Ensemble: 2  failsteps = 10
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 12 in [0:39]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 31
# Proposal probability 0.904761904762 / random : 0.37530183882
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x115defa10> to <opentis.ensemble.SequentialEnsemble object at 0x115e0c890>
# Step: 22   Ensemble: 2  failsteps = 11
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 15 in [0:43]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# Proposal probability 0.777777777778 / random : 0.0858388703265
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x115defa10> to <opentis.ensemble.SequentialEnsemble object at 0x115e0c890>
# Step: 23   Ensemble: 2  failsteps = 12
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 7 in [0:55]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Finished trajectory, length: 54
# Proposal probability 0.9 / random : 0.452574082552
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x115defa10> to <opentis.ensemble.SequentialEnsemble object at 0x115e0c890>
# Step: 24   Ensemble: 3  failsteps = 0
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 30 in [0:61]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Through frame: 70
# Through frame: 80
# Finished trajectory, length: 82
# Proposal probability 0.540540540541 / random : 0.506448798696
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x115e0c890> to <opentis.ensemble.SequentialEnsemble object at 0x115e0cd10>
# Step: 25   Ensemble: 4  failsteps = 0
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 62 in [0:112]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x115e0cd10> to <opentis.ensemble.SequentialEnsemble object at 0x115e131d0>
# Step: 26   Ensemble: 4  failsteps = 1
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 87 in [0:112]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 32
# Proposal probability 1.98214285714 / random : 0.323984145156
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x115e0cd10> to <opentis.ensemble.SequentialEnsemble object at 0x115e131d0>
# Step: 27   Ensemble: 4  failsteps = 2
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 32 in [0:57]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 43
# Proposal probability 0.756756756757 / random : 0.043908884824
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x115e0cd10> to <opentis.ensemble.SequentialEnsemble object at 0x115e131d0>
# Step: 28   Ensemble: 4  failsteps = 3
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 50 in [0:75]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 20
# Proposal probability 1.07246376812 / random : 0.180322442874
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x115e0cd10> to <opentis.ensemble.SequentialEnsemble object at 0x115e131d0>
# Step: 29   Ensemble: 4  failsteps = 4
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 35 in [0:70]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# Proposal probability 1.13114754098 / random : 0.112217537898
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x115e0cd10> to <opentis.ensemble.SequentialEnsemble object at 0x115e131d0>
# Step: 30   Ensemble: 4  failsteps = 5
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 22 in [0:62]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x115e0cd10> to <opentis.ensemble.SequentialEnsemble object at 0x115e131d0>
# Step: 31   Ensemble: 4  failsteps = 6
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 59 in [0:62]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 44
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x115e0cd10> to <opentis.ensemble.SequentialEnsemble object at 0x115e131d0>
# Step: 32   Ensemble: 4  failsteps = 7
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 61 in [0:62]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.438400113386
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x115e0cd10> to <opentis.ensemble.SequentialEnsemble object at 0x115e131d0>
# Step: 33   Ensemble: 4  failsteps = 8
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 9 in [0:62]
# Starting trajectory
# Finished trajectory, length: 7
# Proposal probability 1.03389830508 / random : 0.34753363907
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x115e0cd10> to <opentis.ensemble.SequentialEnsemble object at 0x115e131d0>
# Step: 34   Ensemble: 4  failsteps = 9
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 52 in [0:60]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 0.967213114754 / random : 0.119922031316
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x115e0cd10> to <opentis.ensemble.SequentialEnsemble object at 0x115e131d0>
# Step: 35   Ensemble: 4  failsteps = 10
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 39 in [0:62]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 46
# Proposal probability 0.72619047619 / random : 0.402139349344
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x115e0cd10> to <opentis.ensemble.SequentialEnsemble object at 0x115e131d0>
# Step: 36   Ensemble: 4  failsteps = 11
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 80 in [0:85]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 44
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x115e0cd10> to <opentis.ensemble.SequentialEnsemble object at 0x115e131d0>
# Step: 37   Ensemble: 4  failsteps = 12
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 54 in [0:85]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 44
# Proposal probability 1.13513513514 / random : 0.561759726319
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x115e0cd10> to <opentis.ensemble.SequentialEnsemble object at 0x115e131d0>
# Step: 38   Ensemble: 4  failsteps = 13
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 67 in [0:75]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x115e0cd10> to <opentis.ensemble.SequentialEnsemble object at 0x115e131d0>
# Step: 39   Ensemble: 4  failsteps = 14
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 55 in [0:75]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 1.08823529412 / random : 0.143025005769
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x115e0cd10> to <opentis.ensemble.SequentialEnsemble object at 0x115e131d0>
# Step: 40   Ensemble: 4  failsteps = 15
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 25 in [0:69]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 21
# Proposal probability 1.0625 / random : 0.885830251199
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x115e0cd10> to <opentis.ensemble.SequentialEnsemble object at 0x115e131d0>
# Step: 41   Ensemble: 4  failsteps = 16
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 13 in [0:65]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 41
# Proposal probability 1.20754716981 / random : 0.909673825095
# Attempting ensemble hop from <opentis.ensemble.SequentialEnsemble object at 0x115e0cd10> to <opentis.ensemble.SequentialEnsemble object at 0x115e131d0>

# %% [markdown]
# We've stored all the trajectories we generated here; now we want to extract a path for each ensemble to use as a starting point for TIS. We'll choose to take the first path that satisfied each ensemble.

# %%
print "[ ",
for sample in bootstrap.globalstate:
    print str(sample.trajectory)+" ",
print "]"
# Out:
# [  Trajectory[41]  Trajectory[42]  Trajectory[56]  Trajectory[62]  Trajectory[66]  Trajectory[55]  ]

# %% [markdown]
# Let's go ahead and visualize where each of those trajectories are:

# %%
plot.plot([sample.trajectory for sample in bootstrap.globalstate])

# %% [markdown]
# ## Equilibration in the Path Ensemble
#
# At the end of the bootstrapping process, we have a set of paths which we can use to start TIS sampling. Before doing a production run, we should let these paths equilibrate within the ensembles. If you generate your initial path through dynamics that aren't the true dynamics (e.g., using high temperature runs or using metadynamics), this stage is **extremely** important. It's important here as well, but less so than if your initial path is non-physical.
#
# This will be an example of a "normal" TIS run, i.e., TIS without replica exchange. We will sampling using only shooter movers (the same ones defined for the bootstrapping) and path reversal movers. First we define these path reveral movers:

# %%
from opentis.pathmover import PathReversalSet
reversal_movers = PathReversalSet(interface_ensemble_set)

# %% [markdown]
# Next we define global moves: we'll set this up so that each move either does a shooting move on all replicas, or does a path reversal move on all replicas. You can similarly set it up so that each move operates on only on one replica at a time.

# %%
from opentis.pathmover import RandomChoiceMover
shooting_chooser = RandomChoiceMover(shooting_movers)
reversal_chooser = RandomChoiceMover(reversal_movers)
equilibration_movers = RandomChoiceMover([shooting_chooser, reversal_chooser])

# %% [markdown]
# Now we're ready to set up a TIS run:

# %%
from opentis.calculation import PathSampling
equilibration = PathSampling(storage=None, engine=sim, root_mover=equilibration_movers, globalstate=bootstrap.globalstate)

# %%
for sample in equilibration.globalstate:
    print sample.details
# Out:
# result = Trajectory[41]
# inputs = [Trajectory[41]]
# trial = Trajectory[41]
# mover_path = []
# mover = <opentis.pathmover.PathMover object at 0x108b8f710>
# accepted = True
# acceptance_probability = 1.0
#
# result = Trajectory[42]
# inputs = [Trajectory[42]]
# trial = Trajectory[42]
# mover_path = []
# mover = <opentis.pathmover.PathMover object at 0x116721a50>
# accepted = True
# acceptance_probability = 1.0
#
# result = Trajectory[56]
# inputs = [Trajectory[56]]
# trial = Trajectory[56]
# mover_path = []
# mover = <opentis.pathmover.PathMover object at 0x116721a90>
# accepted = True
# acceptance_probability = 1.0
#
# result = Trajectory[62]
# inputs = [Trajectory[62]]
# trial = Trajectory[62]
# mover_path = []
# mover = <opentis.pathmover.PathMover object at 0x116721c90>
# accepted = True
# acceptance_probability = 1.0
#
# result = Trajectory[66]
# inputs = [Trajectory[66]]
# trial = Trajectory[66]
# mover_path = []
# mover = <opentis.pathmover.PathMover object at 0x116721d10>
# accepted = True
# acceptance_probability = 1.0
#
# result = Trajectory[55]
# inputs = [Trajectory[55]]
# trial = Trajectory[55]
# mover_path = []
# mover = <opentis.pathmover.PathMover object at 0x1167219d0>
# accepted = True
# acceptance_probability = 1.0

# %%
s = equilibration.globalstate[0]
print s
print paths.MoveDetails.initialization(s.trajectory, s.ensemble)
# Out:
# Step: -1
# Replica: 0
# Trajectory: Trajectory[41]
# Ensemble: <opentis.ensemble.SequentialEnsemble object at 0x10934cbd0>
# Details: result = Trajectory[41]
# inputs = [Trajectory[41]]
# trial = Trajectory[41]
# mover_path = []
# mover = <opentis.pathmover.PathMover object at 0x108b8f710>
# accepted = True
# acceptance_probability = 1.0
#
#
# result = Trajectory[41]
# inputs = [Trajectory[41]]
# trial = Trajectory[41]
# mover_path = []
# mover = <opentis.pathmover.PathMover object at 0x1167101d0>
# accepted = True
# acceptance_probability = 1.0

# %% [markdown]
# And now we run it. We'll do 100 equilibration steps.

# %%
equilibration.run(100)
# Out:
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 13 in [0:55]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 44 in [0:55]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 0.981818181818 / random : 0.447621900098
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# PathReversal move accepted: False
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# PathReversal move accepted: False
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# PathReversal move accepted: False
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:54]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Finished trajectory, length: 52
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 54 in [0:56]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.0 / random : 0.149827348155
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 35 in [0:41]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 28
# Proposal probability 0.645161290323 / random : 0.753268474249
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 38 in [0:61]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 37
# Proposal probability 0.810810810811 / random : 0.201241313286
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 37 in [0:41]
# Starting trajectory
# Finished trajectory, length: 4
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 60 in [0:75]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 16
# Proposal probability 0.986666666667 / random : 0.543816937316
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 23 in [0:41]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 30
# Proposal probability 0.769230769231 / random : 0.0477786317335
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 5 in [0:56]
# Starting trajectory
# Finished trajectory, length: 4
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 22 in [0:65]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 24
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:53]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 0.881355932203 / random : 0.739518047601
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# PathReversal move accepted: False
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 30 in [0:65]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 28
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 47 in [0:54]
# Starting trajectory
# Finished trajectory, length: 5
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 49 in [0:56]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 0.982142857143 / random : 0.62747351854
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# PathReversal move accepted: False
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 26 in [0:54]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 44
# Proposal probability 0.746478873239 / random : 0.301929758077
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 40 in [0:65]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 7 in [0:40]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 42
# Proposal probability 0.8125 / random : 0.963993547945
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 32 in [0:65]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 40
# Proposal probability 0.901408450704 / random : 0.625818079747
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# PathReversal move accepted: False
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 72 in [0:76]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 1.0 / random : 0.82631518038
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 25 in [0:57]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Proposal probability 1.21739130435 / random : 0.676471126736
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 29 in [0:76]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Finished trajectory, length: 53
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 15 in [0:40]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 1.02631578947 / random : 0.0521588159282
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# PathReversal move accepted: False
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 15 in [0:39]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Proposal probability 1.0 / random : 0.732811532089
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 7 in [0:72]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 36
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 48 in [0:60]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 16
# Proposal probability 2.18518518519 / random : 0.275660917387
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 63 in [0:72]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 37
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 39 in [0:47]
# Starting trajectory
# Finished trajectory, length: 7
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 62 in [0:72]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 16 in [0:72]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 39
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 12 in [0:28]
# Starting trajectory
# Finished trajectory, length: 7
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 73 in [0:76]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 42
# Proposal probability 0.657894736842 / random : 0.615054116382
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 53 in [0:72]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 31
# Proposal probability 0.855421686747 / random : 0.467821493296
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 16 in [0:28]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Proposal probability 0.84375 / random : 0.228163959438
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 104 in [0:115]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 43
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:33]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 26
# Proposal probability 0.571428571429 / random : 0.281007136327
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# PathReversal move accepted: False
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 73 in [0:115]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# Proposal probability 1.15151515152 / random : 0.12471206696
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 37 in [0:57]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 30
# Proposal probability 1.14285714286 / random : 0.514686802048
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 15 in [0:100]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 36
# Proposal probability 1.98 / random : 0.389618985976
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 5 in [0:51]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 36
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 73 in [0:84]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 1.0375 / random : 0.678838611552
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 31 in [0:51]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 36
# Proposal probability 0.909090909091 / random : 0.0852301958182
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 23 in [0:47]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 20
# Proposal probability 1.06976744186 / random : 0.245529699816
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 45 in [0:56]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 33
# Proposal probability 1.27906976744 / random : 0.268022196448
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:44]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 43
# Proposal probability 0.524390243902 / random : 0.792102934746
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 23 in [0:39]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 1.1875 / random : 0.519670066856
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:50]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 35
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 10 in [0:44]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 27 in [0:44]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 28
# Proposal probability 0.796296296296 / random : 0.840640851913
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:81]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.0 / random : 0.0223180674821
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 3 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 10 in [0:72]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Finished trajectory, length: 62
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 4 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 45 in [0:72]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 35
# Proposal probability 0.898734177215 / random : 0.312977007982
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (PathReversalMover)
# PathReversal move accepted: True

# %% [markdown]
# Now let's take a look at where the trajectories are after they've had a chance to equilibrate:

# %%
plot.plot([sample.trajectory for sample in equilibration.globalstate])

# %% [markdown]
# ## RETIS: Production run
#
# With everything else set up, we can set up the replica exchange movers, and reuse the other movers.

# %%
from opentis.pathmover import NeighborEnsembleReplicaExchange
repex_movers = NeighborEnsembleReplicaExchange(interface_ensemble_set)
repex_chooser = RandomChoiceMover(repex_movers)

# %% [markdown]
# We'll also set up the minus ensemble and minus move:

# %%
minus_ensemble = paths.MinusInterfaceEnsemble(state_vol=stateA,
                                              innermost_vol=line_volume_set[0],
                                              n_l=2)
minus_move = paths.MinusMover(minus_ensemble=minus_ensemble,
                              innermost_ensemble=interface_ensemble_set[0])

# %% [markdown]
# We also have to create a path which is valid for the minus ensemble.

# %%
minus_segment = equilibration.globalstate[0].trajectory
last_frame = minus_segment[-1]
extension = sim.generate(last_frame, [minus_ensemble.can_append])
first_minus = minus_segment + extension[1:]
minus_samp = paths.Sample(
    replica=-1,
    trajectory=first_minus,
    ensemble=minus_ensemble,
    details=paths.MoveDetails.initialization(first_minus, minus_ensemble)
)
start_gs = equilibration.globalstate.apply_samples([minus_samp])
# Out:
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Through frame: 70
# Through frame: 80
# Through frame: 90
# Through frame: 100
# Through frame: 110
# Through frame: 120
# Through frame: 130
# Through frame: 140
# Through frame: 150
# Through frame: 160
# Through frame: 170
# Through frame: 180
# Through frame: 190
# Through frame: 200
# Through frame: 210
# Through frame: 220
# Through frame: 230
# Through frame: 240
# Through frame: 250
# Through frame: 260
# Through frame: 270
# Through frame: 280
# Through frame: 290
# Through frame: 300
# Through frame: 310
# Through frame: 320
# Through frame: 330
# Through frame: 340
# Through frame: 350
# Through frame: 360
# Through frame: 370
# Through frame: 380
# Through frame: 390
# Through frame: 400
# Through frame: 410
# Through frame: 420
# Through frame: 430
# Through frame: 440
# Through frame: 450
# Through frame: 460
# Through frame: 470
# Through frame: 480
# Through frame: 490
# Through frame: 500
# Through frame: 510
# Through frame: 520
# Through frame: 530
# Through frame: 540
# Through frame: 550
# Through frame: 560
# Through frame: 570
# Through frame: 580
# Through frame: 590
# Through frame: 600
# Through frame: 610
# Through frame: 620
# Through frame: 630
# Through frame: 640
# Through frame: 650
# Through frame: 660
# Through frame: 670
# Through frame: 680
# Through frame: 690
# Through frame: 700
# Through frame: 710
# Through frame: 720
# Through frame: 730
# Through frame: 740
# Through frame: 750
# Through frame: 760
# Through frame: 770
# Through frame: 780
# Through frame: 790
# Through frame: 800
# Through frame: 810
# Through frame: 820
# Through frame: 830
# Through frame: 840
# Through frame: 850
# Through frame: 860
# Through frame: 870
# Through frame: 880
# Through frame: 890
# Through frame: 900
# Finished trajectory, length: 901

# %%
plot.plot([first_minus])

# %% [markdown]
# Finally, we set up a production run; this is very similar to the setup for the TIS equilibration run. However, up until now, we have not used file storage; before this run we will set up a storage file. The single storage file will save all the trajectories as well as all the details of the RETIS simulation (what movers are used, the acceptance of each trial, etc.)

# %%
storage = paths.storage.Storage('toy_tis.nc', mode='w', template=initial_snapshot)
# Out:
# Setup netCDF file and create variables
# Saving topology
# Create initial template snapshot
# Finished setting up netCDF file

# %%
retis_root_mover = RandomChoiceMover([shooting_chooser, reversal_chooser, repex_chooser, minus_move])
production = PathSampling(storage=storage, engine=sim, root_mover=retis_root_mover, globalstate=start_gs)

# %% [markdown]
# We'll run the production calculation for 50 MC steps.

# %%
production.run(10)
# Out:
# RandomChoiceMover (PathSamplingRoot) selecting mover index 3 (MinusMover)
# MinusMover starting mover index 0 (MinusSubtrajectoryChooser)
# RandomChoiceMover (MinusSubtrajectoryChooser) selecting mover index 1 (FinalSubtrajectorySelectMover)
# MinusMover starting mover index 1 (ReplicaExchangeMover)
# MinusMover starting mover index 2 (ForceEnsembleChangeMover)
# MinusMover starting mover index 3 (MinusExtensionDirectionChooser)
# RandomChoiceMover (MinusExtensionDirectionChooser) selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 0 in [0:33]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Through frame: 70
# Through frame: 80
# Through frame: 90
# Finished trajectory, length: 95
# Proposal probability 1.0 / random : 0.815702290134
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-ba716a166e33> in <module>()
# ----> 1 production.run(10)
#
# /Users/dwhs/Dropbox/msm-tis/opentis/calculation.pyc in run(self, nsteps)
#     260                                                               step=step)
#     261             if self.storage is not None:
# --> 262                 self.globalstate.save_samples(self.storage)
#     263                 self.globalstate.save(self.storage)
#     264                 self.storage.sync()
#
# /Users/dwhs/Dropbox/msm-tis/opentis/sample.pyc in save_samples(self, storage)
#     172             the underlying netcdf file to be used for storage
#     173         """
# --> 174         map(storage.sample.save, self.samples)
#     175
#     176     def sanity_check(self):
#
# /Users/dwhs/Dropbox/msm-tis/opentis/storage/object_storage.pyc in inner(self, obj, idx, *args, **kwargs)
#     977     def inner(self, obj, idx = None, *args, **kwargs):
#     978         # call the normal storage
# --> 979         func(obj, idx, *args, **kwargs)
#     980         idx = obj.idx[self.storage]
#     981
#
# /Users/dwhs/Dropbox/msm-tis/opentis/storage/object_storage.pyc in inner(self, obj, idx, *args, **kwargs)
#    1052
#    1053         obj.idx[storage] = idx
# -> 1054         func(obj, idx, *args, **kwargs)
#    1055
#    1056     return inner
#
# /Users/dwhs/Dropbox/msm-tis/opentis/storage/sample_store.pyc in save(self, sample, idx)
#      20             self.save_variable('sample_replica', idx, sample.replica)
#      21
# ---> 22             self.storage.movedetails.save(sample.details)
#      23             self.set_object('sample_details', idx, sample.details)
#      24
#
# /Users/dwhs/Dropbox/msm-tis/opentis/storage/object_storage.pyc in inner(self, obj, idx, *args, **kwargs)
#     977     def inner(self, obj, idx = None, *args, **kwargs):
#     978         # call the normal storage
# --> 979         func(obj, idx, *args, **kwargs)
#     980         idx = obj.idx[self.storage]
#     981
#
# /Users/dwhs/Dropbox/msm-tis/opentis/storage/object_storage.pyc in inner(self, obj, idx, *args, **kwargs)
#    1052
#    1053         obj.idx[storage] = idx
# -> 1054         func(obj, idx, *args, **kwargs)
#    1055
#    1056     return inner
#
# /Users/dwhs/Dropbox/msm-tis/opentis/storage/object_storage.pyc in save(self, obj, idx)
#     410             self.storage.variables[self.identifier][idx] = obj.name
#     411
# --> 412         self.save_object(self.idx_dimension + '_json', idx, obj)
#     413
#     414     def get_name(self, idx):
#
# /Users/dwhs/Dropbox/msm-tis/opentis/storage/object_storage.pyc in save_object(self, name, idx, obj)
#     719         """
#     720         if not hasattr(obj,'json'):
# --> 721             setattr(obj, 'json', self.object_to_json(obj))
#     722
#     723         self.storage.variables[name][idx] = obj.json
#
# /Users/dwhs/Dropbox/msm-tis/opentis/storage/object_storage.pyc in object_to_json(self, obj)
#     740             the JSON string
#     741         """
# --> 742         json_string = self.simplifier.to_json_object(obj, obj.base_cls_name)
#     743
#     744         return json_string
#
# /Users/dwhs/Dropbox/msm-tis/opentis/todict.pyc in to_json_object(self, obj, base_type)
#     110
#     111     def to_json_object(self, obj, base_type = ''):
# --> 112         simplified = self.simplify_object(obj, base_type)
#     113         return json.dumps(simplified)
#     114
#
# /Users/dwhs/Dropbox/msm-tis/opentis/todict.pyc in simplify_object(self, obj, base_type)
#      23
#      24     def simplify_object(self, obj, base_type = ''):
# ---> 25         return { '_cls' : obj.__class__.__name__, '_dict' : self.simplify(obj.to_dict(), obj.base_cls_name) }
#      26
#      27     def simplify(self, obj, base_type = ''):
#
# /Users/dwhs/Dropbox/msm-tis/opentis/storage/storage.pyc in simplify(self, obj, base_type)
#     508                 return { '_idx' : obj.idx[self.storage], '_cls' : obj.__class__.__name__ }
#     509
# --> 510         return super(StorableObjectJSON, self).simplify(obj, base_type)
#     511
#     512     def build(self,obj):
#
# /Users/dwhs/Dropbox/msm-tis/opentis/todict.pyc in simplify(self, obj, base_type)
#      46             return tuple([self.simplify(o, base_type) for o in obj])
#      47         elif type(obj) is dict:
# ---> 48             result = {key : self.simplify(o, base_type) for key, o in obj.iteritems() if type(key) is str and key not in self.excluded_keys }
#      49             return result
#      50         elif type(obj) is slice:
#
# /Users/dwhs/Dropbox/msm-tis/opentis/todict.pyc in <dictcomp>((key, o))
#      46             return tuple([self.simplify(o, base_type) for o in obj])
#      47         elif type(obj) is dict:
# ---> 48             result = {key : self.simplify(o, base_type) for key, o in obj.iteritems() if type(key) is str and key not in self.excluded_keys }
#      49             return result
#      50         elif type(obj) is slice:
#
# /Users/dwhs/Dropbox/msm-tis/opentis/storage/storage.pyc in simplify(self, obj, base_type)
#     508                 return { '_idx' : obj.idx[self.storage], '_cls' : obj.__class__.__name__ }
#     509
# --> 510         return super(StorableObjectJSON, self).simplify(obj, base_type)
#     511
#     512     def build(self,obj):
#
# /Users/dwhs/Dropbox/msm-tis/opentis/todict.pyc in simplify(self, obj, base_type)
#      42                 return None
#      43         elif type(obj) is list:
# ---> 44             return [self.simplify(o, base_type) for o in obj]
#      45         elif type(obj) is tuple:
#      46             return tuple([self.simplify(o, base_type) for o in obj])
#
# /Users/dwhs/Dropbox/msm-tis/opentis/storage/storage.pyc in simplify(self, obj, base_type)
#     505                 # store objects only if they are not creatable. If so they will only be created in their
#     506                 # top instance and we use the simplify from the super class ObjectJSON
# --> 507                 self.storage.save(obj)
#     508                 return { '_idx' : obj.idx[self.storage], '_cls' : obj.__class__.__name__ }
#     509
#
# /Users/dwhs/Dropbox/msm-tis/opentis/storage/storage.pyc in save(self, obj, *args, **kwargs)
#     355             if obj.base_cls in self._storages:
#     356                 store = self._storages[obj.base_cls]
# --> 357                 store.save(obj, *args, **kwargs)
#     358
#     359                 # save has been called, all is good
#
# /Users/dwhs/Dropbox/msm-tis/opentis/storage/object_storage.pyc in inner(self, obj, idx, *args, **kwargs)
#     977     def inner(self, obj, idx = None, *args, **kwargs):
#     978         # call the normal storage
# --> 979         func(obj, idx, *args, **kwargs)
#     980         idx = obj.idx[self.storage]
#     981
#
# /Users/dwhs/Dropbox/msm-tis/opentis/storage/object_storage.pyc in inner(self, obj, idx, *args, **kwargs)
#    1052
#    1053         obj.idx[storage] = idx
# -> 1054         func(obj, idx, *args, **kwargs)
#    1055
#    1056     return inner
#
# /Users/dwhs/Dropbox/msm-tis/opentis/storage/object_storage.pyc in save(self, obj, idx)
#     410             self.storage.variables[self.identifier][idx] = obj.name
#     411
# --> 412         self.save_object(self.idx_dimension + '_json', idx, obj)
#     413
#     414     def get_name(self, idx):
#
# /Users/dwhs/Dropbox/msm-tis/opentis/storage/object_storage.pyc in save_object(self, name, idx, obj)
#     719         """
#     720         if not hasattr(obj,'json'):
# --> 721             setattr(obj, 'json', self.object_to_json(obj))
#     722
#     723         self.storage.variables[name][idx] = obj.json
#
# /Users/dwhs/Dropbox/msm-tis/opentis/storage/object_storage.pyc in object_to_json(self, obj)
#     740             the JSON string
#     741         """
# --> 742         json_string = self.simplifier.to_json_object(obj, obj.base_cls_name)
#     743
#     744         return json_string
#
# /Users/dwhs/Dropbox/msm-tis/opentis/todict.pyc in to_json_object(self, obj, base_type)
#     110
#     111     def to_json_object(self, obj, base_type = ''):
# --> 112         simplified = self.simplify_object(obj, base_type)
#     113         return json.dumps(simplified)
#     114
#
# /Users/dwhs/Dropbox/msm-tis/opentis/todict.pyc in simplify_object(self, obj, base_type)
#      23
#      24     def simplify_object(self, obj, base_type = ''):
# ---> 25         return { '_cls' : obj.__class__.__name__, '_dict' : self.simplify(obj.to_dict(), obj.base_cls_name) }
#      26
#      27     def simplify(self, obj, base_type = ''):
#
# /Users/dwhs/Dropbox/msm-tis/opentis/storage/storage.pyc in simplify(self, obj, base_type)
#     508                 return { '_idx' : obj.idx[self.storage], '_cls' : obj.__class__.__name__ }
#     509
# --> 510         return super(StorableObjectJSON, self).simplify(obj, base_type)
#     511
#     512     def build(self,obj):
#
# /Users/dwhs/Dropbox/msm-tis/opentis/todict.pyc in simplify(self, obj, base_type)
#      46             return tuple([self.simplify(o, base_type) for o in obj])
#      47         elif type(obj) is dict:
# ---> 48             result = {key : self.simplify(o, base_type) for key, o in obj.iteritems() if type(key) is str and key not in self.excluded_keys }
#      49             return result
#      50         elif type(obj) is slice:
#
# /Users/dwhs/Dropbox/msm-tis/opentis/todict.pyc in <dictcomp>((key, o))
#      46             return tuple([self.simplify(o, base_type) for o in obj])
#      47         elif type(obj) is dict:
# ---> 48             result = {key : self.simplify(o, base_type) for key, o in obj.iteritems() if type(key) is str and key not in self.excluded_keys }
#      49             return result
#      50         elif type(obj) is slice:
#
# /Users/dwhs/Dropbox/msm-tis/opentis/storage/storage.pyc in simplify(self, obj, base_type)
#     508                 return { '_idx' : obj.idx[self.storage], '_cls' : obj.__class__.__name__ }
#     509
# --> 510         return super(StorableObjectJSON, self).simplify(obj, base_type)
#     511
#     512     def build(self,obj):
#
# /Users/dwhs/Dropbox/msm-tis/opentis/todict.pyc in simplify(self, obj, base_type)
#      42                 return None
#      43         elif type(obj) is list:
# ---> 44             return [self.simplify(o, base_type) for o in obj]
#      45         elif type(obj) is tuple:
#      46             return tuple([self.simplify(o, base_type) for o in obj])
#
# /Users/dwhs/Dropbox/msm-tis/opentis/storage/storage.pyc in simplify(self, obj, base_type)
#     505                 # store objects only if they are not creatable. If so they will only be created in their
#     506                 # top instance and we use the simplify from the super class ObjectJSON
# --> 507                 self.storage.save(obj)
#     508                 return { '_idx' : obj.idx[self.storage], '_cls' : obj.__class__.__name__ }
#     509
#
# /Users/dwhs/Dropbox/msm-tis/opentis/storage/storage.pyc in save(self, obj, *args, **kwargs)
#     355             if obj.base_cls in self._storages:
#     356                 store = self._storages[obj.base_cls]
# --> 357                 store.save(obj, *args, **kwargs)
#     358
#     359                 # save has been called, all is good
#
# /Users/dwhs/Dropbox/msm-tis/opentis/storage/object_storage.pyc in inner(self, obj, idx, *args, **kwargs)
#     977     def inner(self, obj, idx = None, *args, **kwargs):
#     978         # call the normal storage
# --> 979         func(obj, idx, *args, **kwargs)
#     980         idx = obj.idx[self.storage]
#     981
#
# /Users/dwhs/Dropbox/msm-tis/opentis/storage/object_storage.pyc in inner(self, obj, idx, *args, **kwargs)
#    1052
#    1053         obj.idx[storage] = idx
# -> 1054         func(obj, idx, *args, **kwargs)
#    1055
#    1056     return inner
#
# /Users/dwhs/Dropbox/msm-tis/opentis/storage/object_storage.pyc in save(self, obj, idx)
#     410             self.storage.variables[self.identifier][idx] = obj.name
#     411
# --> 412         self.save_object(self.idx_dimension + '_json', idx, obj)
#     413
#     414     def get_name(self, idx):
#
# /Users/dwhs/Dropbox/msm-tis/opentis/storage/object_storage.pyc in save_object(self, name, idx, obj)
#     719         """
#     720         if not hasattr(obj,'json'):
# --> 721             setattr(obj, 'json', self.object_to_json(obj))
#     722
#     723         self.storage.variables[name][idx] = obj.json
#
# /Users/dwhs/Dropbox/msm-tis/opentis/storage/object_storage.pyc in object_to_json(self, obj)
#     740             the JSON string
#     741         """
# --> 742         json_string = self.simplifier.to_json_object(obj, obj.base_cls_name)
#     743
#     744         return json_string
#
# /Users/dwhs/Dropbox/msm-tis/opentis/todict.pyc in to_json_object(self, obj, base_type)
#     110
#     111     def to_json_object(self, obj, base_type = ''):
# --> 112         simplified = self.simplify_object(obj, base_type)
#     113         return json.dumps(simplified)
#     114
#
# /Users/dwhs/Dropbox/msm-tis/opentis/todict.pyc in simplify_object(self, obj, base_type)
#      23
#      24     def simplify_object(self, obj, base_type = ''):
# ---> 25         return { '_cls' : obj.__class__.__name__, '_dict' : self.simplify(obj.to_dict(), obj.base_cls_name) }
#      26
#      27     def simplify(self, obj, base_type = ''):
#
# /Users/dwhs/Dropbox/msm-tis/opentis/storage/storage.pyc in simplify(self, obj, base_type)
#     508                 return { '_idx' : obj.idx[self.storage], '_cls' : obj.__class__.__name__ }
#     509
# --> 510         return super(StorableObjectJSON, self).simplify(obj, base_type)
#     511
#     512     def build(self,obj):
#
# /Users/dwhs/Dropbox/msm-tis/opentis/todict.pyc in simplify(self, obj, base_type)
#      46             return tuple([self.simplify(o, base_type) for o in obj])
#      47         elif type(obj) is dict:
# ---> 48             result = {key : self.simplify(o, base_type) for key, o in obj.iteritems() if type(key) is str and key not in self.excluded_keys }
#      49             return result
#      50         elif type(obj) is slice:
#
# /Users/dwhs/Dropbox/msm-tis/opentis/todict.pyc in <dictcomp>((key, o))
#      46             return tuple([self.simplify(o, base_type) for o in obj])
#      47         elif type(obj) is dict:
# ---> 48             result = {key : self.simplify(o, base_type) for key, o in obj.iteritems() if type(key) is str and key not in self.excluded_keys }
#      49             return result
#      50         elif type(obj) is slice:
#
# /Users/dwhs/Dropbox/msm-tis/opentis/storage/storage.pyc in simplify(self, obj, base_type)
#     508                 return { '_idx' : obj.idx[self.storage], '_cls' : obj.__class__.__name__ }
#     509
# --> 510         return super(StorableObjectJSON, self).simplify(obj, base_type)
#     511
#     512     def build(self,obj):
#
# /Users/dwhs/Dropbox/msm-tis/opentis/todict.pyc in simplify(self, obj, base_type)
#      42                 return None
#      43         elif type(obj) is list:
# ---> 44             return [self.simplify(o, base_type) for o in obj]
#      45         elif type(obj) is tuple:
#      46             return tuple([self.simplify(o, base_type) for o in obj])
#
# /Users/dwhs/Dropbox/msm-tis/opentis/storage/storage.pyc in simplify(self, obj, base_type)
#     505                 # store objects only if they are not creatable. If so they will only be created in their
#     506                 # top instance and we use the simplify from the super class ObjectJSON
# --> 507                 self.storage.save(obj)
#     508                 return { '_idx' : obj.idx[self.storage], '_cls' : obj.__class__.__name__ }
#     509
#
# /Users/dwhs/Dropbox/msm-tis/opentis/storage/storage.pyc in save(self, obj, *args, **kwargs)
#     355             if obj.base_cls in self._storages:
#     356                 store = self._storages[obj.base_cls]
# --> 357                 store.save(obj, *args, **kwargs)
#     358
#     359                 # save has been called, all is good
#
# /Users/dwhs/Dropbox/msm-tis/opentis/storage/object_storage.pyc in inner(self, obj, idx, *args, **kwargs)
#     977     def inner(self, obj, idx = None, *args, **kwargs):
#     978         # call the normal storage
# --> 979         func(obj, idx, *args, **kwargs)
#     980         idx = obj.idx[self.storage]
#     981
#
# /Users/dwhs/Dropbox/msm-tis/opentis/storage/object_storage.pyc in inner(self, obj, idx, *args, **kwargs)
#    1052
#    1053         obj.idx[storage] = idx
# -> 1054         func(obj, idx, *args, **kwargs)
#    1055
#    1056     return inner
#
# /Users/dwhs/Dropbox/msm-tis/opentis/storage/object_storage.pyc in save(self, obj, idx)
#     410             self.storage.variables[self.identifier][idx] = obj.name
#     411
# --> 412         self.save_object(self.idx_dimension + '_json', idx, obj)
#     413
#     414     def get_name(self, idx):
#
# /Users/dwhs/Dropbox/msm-tis/opentis/storage/object_storage.pyc in save_object(self, name, idx, obj)
#     719         """
#     720         if not hasattr(obj,'json'):
# --> 721             setattr(obj, 'json', self.object_to_json(obj))
#     722
#     723         self.storage.variables[name][idx] = obj.json
#
# /Users/dwhs/Dropbox/msm-tis/opentis/storage/object_storage.pyc in object_to_json(self, obj)
#     740             the JSON string
#     741         """
# --> 742         json_string = self.simplifier.to_json_object(obj, obj.base_cls_name)
#     743
#     744         return json_string
#
# /Users/dwhs/Dropbox/msm-tis/opentis/todict.pyc in to_json_object(self, obj, base_type)
#     111     def to_json_object(self, obj, base_type = ''):
#     112         simplified = self.simplify_object(obj, base_type)
# --> 113         return json.dumps(simplified)
#     114
#     115     def from_json(self, json_string):
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/__init__.pyc in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, encoding, default, sort_keys, **kw)
#     241         cls is None and indent is None and separators is None and
#     242         encoding == 'utf-8' and default is None and not sort_keys and not kw):
# --> 243         return _default_encoder.encode(obj)
#     244     if cls is None:
#     245         cls = JSONEncoder
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.pyc in encode(self, o)
#     205         # exceptions aren't as detailed.  The list call should be roughly
#     206         # equivalent to the PySequence_Fast that ''.join() would do.
# --> 207         chunks = self.iterencode(o, _one_shot=True)
#     208         if not isinstance(chunks, (list, tuple)):
#     209             chunks = list(chunks)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.pyc in iterencode(self, o, _one_shot)
#     268                 self.key_separator, self.item_separator, self.sort_keys,
#     269                 self.skipkeys, _one_shot)
# --> 270         return _iterencode(o, 0)
#     271
#     272 def _make_iterencode(markers, _default, _encoder, _indent, _floatstr,
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.pyc in default(self, o)
#     182
#     183         """
# --> 184         raise TypeError(repr(o) + " is not JSON serializable")
#     185
#     186     def encode(self, o):
#
# TypeError: <function <lambda> at 0x116c1e8c0> is not JSON serializable

# %%
production.run(10)
# Out:
# RandomChoiceMover (PathSamplingRoot) selecting mover index 3 (MinusMover)
# MinusMover starting mover index 0 (MinusSubtrajectoryChooser)
# RandomChoiceMover (MinusSubtrajectoryChooser) selecting mover index 0 (FirstSubtrajectorySelectMover)
# MinusMover starting mover index 1 (ReplicaExchangeMover)
# MinusMover starting mover index 2 (ForceEnsembleChangeMover)
# MinusMover starting mover index 3 (MinusExtensionDirectionChooser)
# RandomChoiceMover (MinusExtensionDirectionChooser) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 18 in [0:18]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Through frame: 70
# Through frame: 80
# Through frame: 90
# Through frame: 100
# Finished trajectory, length: 106
# Proposal probability 1.0 / random : 0.792914999258
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 5 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (PathReversalMover)
# PathReversal move accepted: True
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 13 in [0:50]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 20
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 43 in [0:44]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.375142465017
# RandomChoiceMover (PathSamplingRoot) selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover (OneWayShootingMover) selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 5 in [0:44]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 29
# RandomChoiceMover (PathSamplingRoot) selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover (RandomChoiceMover) selecting mover index 0 (ReplicaExchangeMover)
