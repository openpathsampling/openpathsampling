# %%
# Note: in practice, one should put all the imports at the top of a Python script. 
# But for educational purposes here, I put the import immediately before usage. 
# This Python block is just to set up some plotting stuff.

# Imports for plotting
# %matplotlib inline
import opentis as paths
import numpy as np
from toy_plot_helpers import ToyPlot
plot = ToyPlot()

# %% [markdown]
# # Setting up RETIS on a Toy Model
#
# This example shows how to set up a RETIS calculation. We do this on a simple 2D model so it can be fast enough for an interactive example, but the basic approach applies to larger systems as well. Although I'll describe everything here in terms of 2-state systems, all the ideas generalize when setting up multiple-state systems (you just need to find more initial paths).

# %% [markdown]
# ## Getting an initial path
#
# RETIS is a path sampling method: it requires that the user supply an input path for each path ensemble. This means that you must somehow generate a first input path. In general, getting the first input paths for RETIS boils down to solving two problems:
#
# 1. Getting a trajectory that samples the rare event.
# 2. Filling all the path ensembles with acceptable trajectories.
#
# Since transition paths satisfy all the path ensembles between two states, a common approach is to use the same initial path for all path ensembles (reversing it where necessary). This way, once you've solved problem 1, problem 2 is trivial.
#
# The first rare path can come from any number of sources. The obvious approach might be to find a transition path from a committor analysis, because this would give you a path that satisfies the true dynamics. However, the initial path doesn't need to satisfy the true dynamics of the system (later we will equilibrate the path ensemble anyway). This means that other approaches, such as high-temperature trajectories, can be used for the first path. One of the most widely-used methods to get an initial trajectory is to generate a transition trajectory using metadynamics. However, the downside of using paths that don't satisfy the true dynamics is that it might be harder to get them to equilibrate to the correct path ensemble. It seems that this has been more of a problem with paths from high temperature runs than with paths from metadynamics: a path from a modified potential energy surface at the correct temperature seems to equilibrate more easily than a path from the original potential energy surface at an incorrect temperature.
#
# In this example, we use a bootstrapping approach, which does create paths satisfying the true dynamics of the system. This bootstrapping is nice because it is quick and convenient, although it works best on smaller systems with less complicated transitions. It works by running normal MD to generate a path that satisfies the innermost interface, and then performing shooting moves in that interface's path ensemble until we have a path that crosses the next interface. Then we switch to the path ensemble for the next interface, and shoot until the path crossing the interface after that. The process continues until we have paths for all interfaces.

# %% [markdown]
# ### Basic system setup
#
# First we set up our system: for the toy dynamics, this involves defining a potential energy surface (PES), setting up an integrator, and giving the simulation an initial configuration. In real MD systems, the PES is handled by the combination of a topology file and a force field definition, and the initial configuration would come from a file instead of being described by hand.

# %%
from opentis.toy_dynamics.toy_engine import ToyEngine
from opentis.toy_dynamics.toy_integrators import LangevinBAOABIntegrator
from opentis.toy_dynamics.toy_pes import Gaussian, OuterWalls

import logging.config
logging.config.fileConfig("logging.conf", disable_existing_loggers=False)

# %% [markdown]
# ### Set up the toy system
# This includes the potential energy surface (PES), and an initial configuration

# %%
# Toy_PES supports adding/subtracting various PESs. The OuterWalls PES type gives an x^6+y^6 boundary to the system
pes = (OuterWalls([1.0, 1.0], [0.0, 0.0]) + 
       Gaussian(2.0, [1.0, 4.0], [0.0,1.0]) + 
       Gaussian(2.0, [25.0, 1.0], [0.0, -1.0])
      )
topology=paths.ToyTopology(
    n_spatial = 2,
    masses =[1.0, 1.0],
    pes = pes
)
template = paths.Snapshot(
    coordinates=np.array([[-0.5, 0.0]]), 
    velocities=np.array([[0.0,0.0]]),
    potential_energy = 0.0, # Important to set energies dimensionless otherwise kcal/mol is default
    kinetic_energy = 0.0,
    topology=topology
)

# %% [markdown]
# ### Setup engine

# %%
integ = LangevinBAOABIntegrator(dt=0.02, temperature=0.1, gamma=1.0)
options={
         'integ' : integ,
         'n_frames_max' : 5000,
         'nsteps_per_frame' : 10}
sim = ToyEngine(
        options=options,
        template=template
)

sim.current_snapshot = template

# %% [markdown]
# Now let's take a look at our PES and our initial configuration:

# %%
sim.current_snapshot.coordinates
# Out:
# array([[-0.5,  0. ]])

# %%
plot.add_pes(pes)
plot.add_initial_condition(sim.current_snapshot)
plot.plot()

# %% [markdown]
# ### Interface setup
#
# One downside of the bootstrapping approach is that we need to have defined our interfaces before we start. However, we can always easily change our initial interface guesses.
#
# We'll consider a couple different choices of order parameter to define our interfaces. First we'll look at lines at different values of $x$. That set will be called `line_set`. Later we'll also consider circles centered on (-0.5, -0.25), with different radii. We'll call this set of interfaces `circle_set`.
#
# In both cases, we need to define the order parameter, and then we need to create a set of volumes and a set of ensembles associated with those volumes.

# %%
from opentis.orderparameter import OP_Function
from opentis.volume import VolumeFactory as vf
from opentis.volume import LambdaVolume
from opentis.trajectory import Trajectory

# WTF? This is an extremely overcomplicated OP; shouldn't be so hard!
try:
    op_line = OP_Function(name="xval", 
                          fcn=lambda snap : snap.coordinates[0,0])
except ValueError:
    print "xval already made"
# this defines a set of LambdaVolumes for which the minimum is -1.0 and the maximum is given in the array
line_volume_set = vf.LambdaVolumeSet(op_line, minvals=-1.0, maxvals=[-0.30, -0.25, -0.20, -0.13, -0.05, 0.0])
stateA = LambdaVolume(op_line, -1.0, -0.3)
stateB = LambdaVolume(op_line, 0.3, 1.0)

# %%
plot.add_states([stateA, stateB])
plot.add_interfaces(line_volume_set)
plot.plot()

# %% [markdown]
# In this picture, the states are marked in blue, and the interfaces are drawn as red lines. The initial configuration is still the red dot.

# %% [markdown]
# ### First innermost interface path
#
# Now we have to create an initial path. This initial path shoud exit the state, cross the first interface, and then return to the state. We'll create this path by defining a special ensemble that, propagating forward from any initial snapshot, ends when the path ends with a segment in the appropriate interface.

# %%
from opentis.ensemble import EnsembleFactory as ef
from opentis.ensemble import LengthEnsemble, InXEnsemble, OutXEnsemble, SequentialEnsemble, OptionalEnsemble, SingleFrameEnsemble

interface0 = line_volume_set[0]
interface_ensemble_set = ef.TISEnsembleSet(stateA, stateB, line_volume_set)
first_traj_ensemble = SequentialEnsemble([
    OptionalEnsemble(OutXEnsemble(stateA)),
    InXEnsemble(stateA),
    OptionalEnsemble(OutXEnsemble(stateA) & InXEnsemble(interface0)),
    OptionalEnsemble(InXEnsemble(interface0)),
    OutXEnsemble(interface0),
    OptionalEnsemble(OutXEnsemble(stateA)),
    SingleFrameEnsemble(InXEnsemble(stateA))
])

# %% [markdown]
# This ensemble is a bit complicated, but works in the general case. To understand it, we'll look at the `SequentialEnsemble` segment by segment. One preliminary point is that we need the generated path ensemble to be the same as the accepted path ensemble in this case, meaning that we must define the ensemble entirely in terms of which volumes each segment is in (i.e., using `InXEnsemble` and `OutXEnsemble`, but not `LeaveXEnsemble` or `HitXEnsemble`).
#
# Start with the first two segments: we start with an optional ensemble outside the state, and then move to an ensemble that is in the state. Since our TIS segment must start in a state, these two ensembles allow us to either start outside the state and then evolve into the state, or to start inside the state. At the end of these two segments, we have the first frame of the TIS ensemble segment, i.e., the frame inside the state that begins the TIS path.
#
# Next we have a couple of optional ensembles, followed by an ensemble requiring the segment to be outside the interface. The optional interfaces here are only important if `stateA` and `interface0` represent different volumes. If they represent the same volume (which is the case here) these optional ensembles don't matter. However, if they are different volumes, then there is a space which is outside the state but inside the interface. So the first optional interface represents that space. The next optional interface says that you must then be inside `interface0`: this is in case there is a reentry into the state before you cross the interface. Next, we require that we cross the interface. The last optional ensemble is for segments ouside the state. If there is space between the interface and the state, then after you are no longer outside the interface you might still be outside the state. Finally, the path ends with one frame in the state.
#
# Following the logic of that, any path that begins anywhere and ends with a segment satisfying the innermost TIS ensemble will be accepted by this ensemble. Furthermore, since the ensemble is defined exclusively in terms of `InXEnsemble`s and `OutXEnsemble`s, the ensemble of paths generated by forward dynamics (`can_append`) is equivalent to the accepted path ensemble.

# %%
sim.initialized = True
first_traj = sim.generate(sim.current_snapshot, [first_traj_ensemble.can_append])
# Out:
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Through frame: 70
# Through frame: 80
# Through frame: 90
# Through frame: 100
# Through frame: 110
# Through frame: 120
# Through frame: 130
# Through frame: 140
# Through frame: 150
# Through frame: 160
# Through frame: 170
# Finished trajectory, length: 179

# %% [markdown]
# Next we use the `Ensemble.split` function to split the trajectory we found into segments satisfying the innermost interface TIS ensemble. There is only one such segment, and so we assign the first (and only) one found to `subtraj`, which is the first trajectory satisfying the innermost TIS interface.

# %%
subtraj = interface_ensemble_set[0].split(first_traj)[0]

# %%
plot.plot(bold=[first_traj], trajectories=[subtraj])

# %% [markdown]
# Now we see how the initial path evolves on this surface. The last part of the trajectory, which satisfies the path ensemble for the innermost interface, is highlighted in red. The whole trajectory is drawn in black.

# %% [markdown]
# ### Bootstrapping
#
# The bootstrapping approach takes a single trajectory which satisfies the innermost interface, and does shooting moves until it satisfies the next ensemble. Once it satisfies the next ensemble, we start shooting from within that ensemble. We keep building up like that until all ensembles have an initial path.
#
# To do this, we need to first create the appropriate shooting movers (one for each path ensemble). This is done quickly and efficiently with a factory function.

# %%
from opentis.pathmover import PathMoverFactory as mf
from opentis.shooting import UniformSelector

# might be nice to get rid of these two lines somehow
from opentis.pathmover import PathMover
PathMover.engine = sim

shooting_movers = mf.OneWayShootingSet(UniformSelector(), interface_ensemble_set)

# %% [markdown]
# Next we need to set up the Bootstrapping calculation:

# %%
from opentis.calculation import Bootstrapping

# TODO: add storage
bootstrap = Bootstrapping(storage=None,
                          engine=sim,
                          ensembles=interface_ensemble_set,
                          movers=shooting_movers,
                          trajectory=subtraj)

# %%
for rep in bootstrap.globalstate.replica_list():
    traj = bootstrap.globalstate[rep]
    print traj, 
    if traj is not None:
        print (op_line(bootstrap.globalstate[rep]))
    else:
        print
# Out:
# Step: -1
# Replica: 0
# Trajectory: Trajectory[16]
# Ensemble: <opentis.ensemble.SequentialEnsemble object at 0x110d12250>
# Details: result = None
# inputs = [Trajectory[16]]
# trial = Trajectory[16]
# mover_path = []
# mover = <opentis.pathmover.PathMover object at 0x11173af90>
# accepted = True
# acceptance_probability = 1.0
#
#  None

# %% [markdown]
# Now we run the bootstrapping. The number `50` means that we'll allow up to 50 shooting attempts per interface; if it takes more than that, you should probably adjust your interfaces (there's probably not much overlap for replica exchange).

# %%
bootstrap.run(300)

# %% [markdown]
# We've stored all the trajectories we generated here; now we want to extract a path for each ensemble to use as a starting point for TIS. We'll choose to take the first path that satisfied each ensemble.

# %%
print "[ ",
for sample in bootstrap.globalstate:
    print str(sample.trajectory)+" ",
print "]"
# Out:
# [  Trajectory[18]  Trajectory[25]  Trajectory[42]  Trajectory[41]  Trajectory[69]  Trajectory[68]  ]

# %% [markdown]
# Let's go ahead and visualize where each of those trajectories are:

# %%
plot.plot([sample.trajectory for sample in bootstrap.globalstate])

# %% [markdown]
# ## Equilibration in the Path Ensemble
#
# At the end of the bootstrapping process, we have a set of paths which we can use to start TIS sampling. Before doing a production run, we should let these paths equilibrate within the ensembles. If you generate your initial path through dynamics that aren't the true dynamics (e.g., using high temperature runs or using metadynamics), this stage is **extremely** important. It's important here as well, but less so than if your initial path is non-physical.
#
# This will be an example of a "normal" TIS run, i.e., TIS without replica exchange. We will sampling using only shooter movers (the same ones defined for the bootstrapping) and path reversal movers. First we define these path reveral movers:

# %%
from opentis.pathmover import PathReversalSet
reversal_movers = PathReversalSet(interface_ensemble_set)

# %% [markdown]
# Next we define global moves: we'll set this up so that each move either does a shooting move on all replicas, or does a path reversal move on all replicas. You can similarly set it up so that each move operates on only on one replica at a time.

# %%
from opentis.pathmover import RandomChoiceMover
shooting_chooser = RandomChoiceMover(shooting_movers)
reversal_chooser = RandomChoiceMover(reversal_movers)
equilibration_movers = RandomChoiceMover([shooting_chooser, reversal_chooser])

# %% [markdown]
# Now we're ready to set up a TIS run:

# %%
from opentis.calculation import PathSampling
equilibration = PathSampling(storage=None, engine=sim, root_mover=equilibration_movers, globalstate=bootstrap.globalstate)

# %% [markdown]
# And now we run it. We'll do 200 equilibration steps.

# %%
equilibration.run(200)

# %% [markdown]
# Now let's take a look at where the trajectories are after they've had a chance to equilibrate:

# %%
plot.plot([sample.trajectory for sample in equilibration.globalstate])

# %% [markdown]
# ## RETIS: Production run
#
# With everything else set up, we can set up the replica exchange movers, and reuse the other movers.

# %%
from opentis.pathmover import NeighborEnsembleReplicaExchange
repex_movers = NeighborEnsembleReplicaExchange(interface_ensemble_set)
repex_chooser = RandomChoiceMover(repex_movers)

# %% [markdown]
# We'll also set up the minus ensemble and minus move:

# %%
# minus_ensemble
# minus_move

# %% [markdown]
# Finally, we set up a production run; this is very similar to the setup for the TIS equilibration run. However, up until now, we have not used file storage; before this run we will set up a storage file. The single storage file will save all the trajectories as well as all the details of the RETIS simulation (what movers are used, the acceptance of each trial, etc.)

# %%
#storage = paths.storage.Storage(
#    filename="toy_tis.nc",
#    template=sim.current_snapshot # that's an ugly hack
#)

# %%
retis_root_mover = RandomChoiceMover([shooting_chooser, reversal_chooser, repex_chooser])
production = PathSampling(storage=None, engine=sim, root_mover=retis_root_mover, globalstate=equilibration.globalstate)

# %% [markdown]
# We'll run the production calculation for 500 MC steps.

# %%
production.run(500)
# Out:
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 43 in [0:78]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Through frame: 70
# Through frame: 80
# Finished trajectory, length: 89
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:35]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 33
# Proposal probability 0.971428571429 / random : 0.814779202671
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 18 in [0:27]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# Proposal probability 1.13043478261 / random : 0.507129492019
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 32 in [0:60]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 28
# Proposal probability 1.07272727273 / random : 0.469565809416
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 5 in [0:36]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 24
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 54 in [0:78]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 28
# Proposal probability 1.50980392157 / random : 0.329696092633
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 8 in [0:24]
# Starting trajectory
# Finished trajectory, length: 7
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 12 in [0:36]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 26
# Proposal probability 0.945945945946 / random : 0.695958664984
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 25 in [0:52]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 36
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 29 in [0:56]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Through frame: 70
# Finished trajectory, length: 75
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:24]
# Starting trajectory
# Finished trajectory, length: 2
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 56 in [0:65]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 0.984615384615 / random : 0.903871268538
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 6 in [0:24]
# Starting trajectory
# Finished trajectory, length: 5
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 25 in [0:56]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 26
# Proposal probability 0.982142857143 / random : 0.20011243101
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 41 in [0:52]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 30
# Proposal probability 0.728571428571 / random : 0.245913403646
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 29 in [0:66]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 28
# Proposal probability 1.015625 / random : 0.315906783751
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 10 in [0:13]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 16
# Proposal probability 0.666666666667 / random : 0.00567945616413
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 62 in [0:65]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 32
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 38 in [0:57]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Finished trajectory, length: 58
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 53 in [0:57]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Finished trajectory, length: 50
# Proposal probability 0.549019607843 / random : 0.48488600978
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 39 in [0:71]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 36
# Proposal probability 0.945945945946 / random : 0.998924933455
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 4 in [0:38]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 1.0 / random : 0.0322049600156
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 8 in [0:24]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 20
# Proposal probability 0.657142857143 / random : 0.0238646488401
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 64 in [0:103]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Finished trajectory, length: 53
# Proposal probability 1.12087912088 / random : 0.56378695215
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 33 in [0:65]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 26
# Proposal probability 1.10344827586 / random : 0.92303706043
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 16 in [0:36]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 1.25 / random : 0.324237491348
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 16 in [0:19]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 3.6 / random : 0.462970536368
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 23 in [0:29]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 24
# Proposal probability 0.608695652174 / random : 0.791880192919
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 82 in [0:92]
# Starting trajectory
# Finished trajectory, length: 9
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 5 in [0:29]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 0.965517241379 / random : 0.330255581564
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 8 in [0:59]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 1.0 / random : 0.0522581384109
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:59]
# Starting trajectory
# Finished trajectory, length: 4
# Proposal probability 0.983050847458 / random : 0.742002398355
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 84 in [0:92]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 20
# Proposal probability 0.883495145631 / random : 0.32091035299
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 76 in [0:104]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Finished trajectory, length: 44
# Proposal probability 0.865546218487 / random : 0.907258178946
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 51 in [0:71]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 63 in [0:104]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 23
# Proposal probability 1.21176470588 / random : 0.760669355186
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 24 in [0:30]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 2.63636363636 / random : 0.192722239731
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 56 in [0:60]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Finished trajectory, length: 51
# Proposal probability 0.556603773585 / random : 0.192710304258
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 40 in [0:86]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 19
# Proposal probability 1.46551724138 / random : 0.47915088097
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 6 in [0:12]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 19
# Proposal probability 0.458333333333 / random : 0.466695423758
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:6]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.0 / random : 0.537846470387
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 22 in [0:38]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 1.12121212121 / random : 0.21785170251
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 6 in [0:12]
# Starting trajectory
# Finished trajectory, length: 8
# Proposal probability 0.846153846154 / random : 0.18586453451
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 1 in [0:14]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.390974635717
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 41 in [0:71]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 31
# Proposal probability 0.985915492958 / random : 0.200160113774
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:6]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 23
# Proposal probability 0.192307692308 / random : 0.32039648727
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:6]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.66666666667 / random : 0.0520515206259
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 48 in [0:59]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 0.983050847458 / random : 0.194325672825
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:4]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 0.166666666667 / random : 0.523055029129
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 69 in [0:72]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.0 / random : 0.427479604492
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:4]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 0.166666666667 / random : 0.317361824588
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:4]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 23
# Proposal probability 0.130434782609 / random : 0.848894251391
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 28 in [0:72]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 22
# Proposal probability 1.09230769231 / random : 0.267497881946
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 10 in [0:34]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# Proposal probability 0.970588235294 / random : 0.0458187153333
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:14]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.08333333333 / random : 0.789356785603
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 3 in [0:4]
# Starting trajectory
# Finished trajectory, length: 1
# Proposal probability 1.0 / random : 0.8216345275
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 103 in [0:107]
# Starting trajectory
# Finished trajectory, length: 4
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 35 in [0:66]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# Proposal probability 1.10169491525 / random : 0.893604206386
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:4]
# Starting trajectory
# Finished trajectory, length: 2
# Proposal probability 1.0 / random : 0.81077527277
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 15 in [0:60]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 21
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 2 in [0:4]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Proposal probability 0.166666666667 / random : 0.358220982193
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 30 in [0:35]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 32
# Proposal probability 0.944444444444 / random : 0.0280195483634
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 35 in [0:60]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# Proposal probability 1.20408163265 / random : 0.400231766252
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 7 in [0:13]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 19
# Proposal probability 0.5 / random : 0.816866071726
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 13 in [0:37]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 17
# Proposal probability 0.9 / random : 0.53857696544
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 13 in [0:41]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 25
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 19 in [0:60]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 1.13461538462 / random : 0.192229248637
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 8 in [0:13]
# Starting trajectory
# Finished trajectory, length: 4
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 7 in [0:13]
# Starting trajectory
# Finished trajectory, length: 6
# Proposal probability 1.0 / random : 0.680969101555
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 19 in [0:50]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 36
# Proposal probability 0.907407407407 / random : 0.33658161196
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 22 in [0:41]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 1.02564102564 / random : 0.692510232124
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# ...
# Shooting forward from frame 43 in [0:78]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 1.42592592593 / random : 0.186929360427
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 63 in [0:92]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Finished trajectory, length: 51
# Proposal probability 1.15189873418 / random : 0.77521312587
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 23 in [0:92]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 14
# Proposal probability 1.10975609756 / random : 0.995067143486
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 69 in [0:83]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 13
# Proposal probability 1.01234567901 / random : 0.0943959509824
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 3 in [0:13]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.0 / random : 0.0862422314697
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 6 in [0:80]
# Starting trajectory
# Finished trajectory, length: 6
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 2 in [0:4]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 18
# Proposal probability 0.157894736842 / random : 0.615793601327
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 7 in [0:13]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 12
# Proposal probability 0.705882352941 / random : 0.468184588022
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 9 in [0:80]
# Starting trajectory
# Finished trajectory, length: 9
# Proposal probability 1.0 / random : 0.321715079987
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 36 in [0:82]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Through frame: 70
# Through frame: 80
# Finished trajectory, length: 81
# Proposal probability 0.698275862069 / random : 0.796323506704
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:18]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# Proposal probability 0.62962962963 / random : 0.456282419158
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 11 in [0:55]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Finished trajectory, length: 54
# Proposal probability 0.84375 / random : 0.4932013068
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 36 in [0:82]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 26
# Proposal probability 1.14084507042 / random : 0.535832419383
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 56 in [0:65]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Finished trajectory, length: 53
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 31 in [0:80]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 20
# Proposal probability 1.16176470588 / random : 0.721150580759
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 25 in [0:28]
# Starting trajectory
# Finished trajectory, length: 5
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 65 in [0:72]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Finished trajectory, length: 63
# Proposal probability 1.02898550725 / random : 0.269254460266
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 26 in [0:31]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Finished trajectory, length: 31
# Proposal probability 0.857142857143 / random : 0.764006211408
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 20 in [0:28]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 10
# Proposal probability 0.931034482759 / random : 0.318821483142
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 56 in [0:69]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 28
# Proposal probability 0.819277108434 / random : 0.876544501139
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 3 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 61 in [0:65]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 27
# Proposal probability 2.13333333333 / random : 0.293471751477
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 5 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 22 in [0:69]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Through frame: 30
# Through frame: 40
# Through frame: 50
# Through frame: 60
# Finished trajectory, length: 66
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 1 (BackwardShootMover)
# Shooting backward from frame 22 in [0:30]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 11
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 19 in [0:30]
# Starting trajectory
# Finished trajectory, length: 5
# Proposal probability 1.26086956522 / random : 0.69154220393
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:24]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 15
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 33 in [0:36]
# Starting trajectory
# Finished trajectory, length: 3
# Proposal probability 1.0 / random : 0.656459862518
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 24 in [0:70]
# Starting trajectory
# Through frame: 10
# Through frame: 20
# Finished trajectory, length: 24
# Proposal probability 1.46808510638 / random : 0.939073604558
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 2 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (ReplicaExchangeMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 2 (PathReversalMover)
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 1 (PathReversalMover)
# RandomChoiceMover selecting mover index 0 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 0 (OneWayShootingMover)
# RandomChoiceMover selecting mover index 0 (ForwardShootMover)
# Shooting forward from frame 1 in [0:4]
# Starting trajectory
# Through frame: 10
# Finished trajectory, length: 19
# Proposal probability 0.157894736842 / random : 0.153065981111
# RandomChoiceMover selecting mover index 1 (RandomChoiceMover)
# RandomChoiceMover selecting mover index 4 (PathReversalMover)
