# %%
# Note: in practice, one should put all the imports at the top of a Python script. 
# But for educational purposes here, I put the import immediately before usage. 
# This Python block is just to set up some plotting stuff.

# Imports for plotting
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
from matplotlib.legend_handler import HandlerLine2D
import numpy as np

# TODO: these visualization classes should be moved into some generic file
from opentis.snapshot import Snapshot

# A little class we use for visualizing these 2D PESs
class CallablePES(object):
    def __init__(self, pes):
        self.pes = pes
    
    def __call__(self, x, y):
        self.positions = [x, y]
        return self.pes.V(self)

class CallableVolume(object):
    def __init__(self, vol):
        self.vol = vol
    
    def __call__(self, x, y):
        snapshot = Snapshot(coordinates=np.array([[x,y,0.0]]))
        return 1.0 if self.vol(snapshot) else 0.0

# plot setup stuff
range_x = np.arange(-1.1, 1.1, 0.01)
range_y = np.arange(-1.1, 0.9, 0.01)
extent = [range_x[0], range_x[-1], range_y[0], range_y[-1]]
X, Y = np.meshgrid(range_x, range_y)
pylab.rcParams['figure.figsize'] = 9, 6

# %% [markdown]
# # Setting up RETIS on a Toy Model
#
# This example shows how to set up a RETIS calculation. We do this on a simple 2D model so it can be fast enough for an interactive example, but the basic approach applies to larger systems as well. Although I'll describe everything here in terms of 2-state systems, all the ideas generalize when setting up multiple-state systems (you just need to find more initial paths).

# %% [markdown]
# ## Getting an initial path
#
# RETIS is a path sampling method: it requires that the user supply an input path for each path ensemble. This means that you must somehow generate a first input path. In general, getting the first input paths for RETIS boils down to solving two problems:
#
# 1. Getting a trajectory that samples the rare event.
# 2. Filling all the path ensembles with acceptable trajectories.
#
# Since transition paths satisfy all the path ensembles between two states, a common approach is to use the same initial path for all path ensembles (reversing it where necessary). This way, once you've solved problem 1, problem 2 is trivial.
#
# The first rare path can come from any number of sources. The obvious approach might be to find a transition path from a committor analysis, because this would give you a path that satisfies the true dynamics. However, the initial path doesn't need to satisfy the true dynamics of the system (later we will equilibrate the path ensemble anyway). This means that other approaches, such as high-temperature trajectories, can be used for the first path. One of the most widely-used methods to get an initial trajectory is to generate a transition trajectory using metadynamics. However, the downside of using paths that don't satisfy the true dynamics is that it might be harder to get them to equilibrate to the correct path ensemble. It seems that this has been more of a problem with paths from high temperature runs than with paths from metadynamics: a path from a modified potential energy surface at the correct temperature seems to equilibrate more easily than a path from the original potential energy surface at an incorrect temperature.
#
# In this example, we use a bootstrapping approach, which does create paths satisfying the true dynamics of the system. This bootstrapping is nice because it is quick and convenient, although it works best on smaller systems with less complicated transitions. It works by running normal MD to generate a path that satisfies the innermost interface, and then performing shooting moves in that interface's path ensemble until we have a path that crosses the next interface. Then we switch to the path ensemble for the next interface, and shoot until the path crossing the interface after that. The process continues until we have paths for all interfaces.

# %% [markdown]
# ### Basic system setup
#
# First we set up our system: for the toy dynamics, this involves defining a potential energy surface (PES), setting up an integrator, and giving the simulation an initial configuration. In real MD systems, the PES is handled by the combination of a topology file and a force field definition, and the initial configuration would come from a file instead of being described by hand.

# %%
from opentis.toy_dynamics.toy_engine import ToyEngine
from opentis.toy_dynamics.toy_integrators import LangevinBAOABIntegrator
from opentis.toy_dynamics.toy_pes import Gaussian, OuterWalls

# %%
# Toy_PES supports adding/subtracting various PESs. The OuterWalls PES type gives an x^6+y^6 boundary to the system
pes = (OuterWalls([1.0, 1.0], [0.0, 0.0]) + 
       Gaussian(2.0, [1.0, 4.0], [0.0,1.0]) + 
       Gaussian(2.0, [25.0, 1.0], [0.0, -1.0])
      )
integ = LangevinBAOABIntegrator(dt=0.02, temperature=0.1, gamma=1.0)
sim = ToyEngine(filename=None,
                options={'pes' : pes, 
                         'integ' : integ,
                         'n_frames_max' : 5000,
                         'nsteps_per_frame' : 10}
               )

sim.mass = [1.0, 1.0]
sim.current_snapshot = Snapshot(coordinates=[-0.5, 0.0], velocities=[0.0,0.0])

# %% [markdown]
# Now let's take a look at our PES and our initial configuration:

# %%
pes_V = np.vectorize(CallablePES(pes))
# we load the coordinates into a snapshot instead of directly calling them 
# based on their implementation in `toy_simulation`. This is because the 
# snapshot approach will work independently of the underlying MD engine.
snap = sim.current_snapshot

fig, ax = plt.subplots()
CS = ax.contour(X, Y, pes_V(X,Y), levels=np.arange(0.0, 1.5, 0.1), colors='k', zorder=0)
ax.plot(snap.coordinates[0,0], snap.coordinates[0,1], 'ro', zorder=1);

# %% [markdown]
# ### Interface setup
#
# One downside of the bootstrapping approach is that we need to have defined our interfaces before we start. However, we can always easily change our initial interface guesses.
#
# We'll consider a couple different choices of order parameter to define our interfaces. First we'll look at lines at different values of $x$. That set will be called `line_set`. Later we'll also consider circles centered on (-0.5, -0.25), with different radii. We'll call this set of interfaces `circle_set`.
#
# In both cases, we need to define the order parameter, and then we need to create a set of volumes and a set of ensembles associated with those volumes.

# %%
from opentis.orderparameter import OP_Function
from opentis.volume import VolumeFactory as vf
from opentis.volume import LambdaVolume
from opentis.trajectory import Trajectory

# WTF? This is an extremely overcomplicated OP; shouldn't be so hard!
try:
    op_line = OP_Function(name="xval", 
                          fcn=lambda snap : Trajectory([snap])[0].coordinates()[0,0])
except ValueError:
    print "xval already made"
# this defines a set of LambdaVolumes for which the minimum is -1.0 and the maximum is given in the array
line_volume_set = vf.LambdaVolumeSet(op_line, minvals=-1.0, maxvals=[-0.30, -0.25, -0.20, -0.13, -0.05, 0.0])
stateA = LambdaVolume(op_line, -1.0, -0.3)
stateB = LambdaVolume(op_line, 0.3, 1.0)
# Out:
# xval already made

# %%
stateAmap = np.vectorize(CallableVolume(stateA))(X,Y)
stateBmap = np.vectorize(CallableVolume(stateB))(X,Y)
CS = plt.contour(X, Y, pes_V(X,Y), levels=np.arange(0.0, 1.5, 0.1), colors='k', zorder=0)
plt.imshow(stateAmap+stateBmap, extent=extent, cmap="Blues", interpolation='none', vmin=0.0, vmax=2.0, zorder=-1, aspect='auto')
for iface in line_volume_set:
    plt.contour(X,Y, np.vectorize(CallableVolume(iface))(X,Y), colors='r', interpolation='none', levels=[0.5], zorder=1)
plt.plot(snap.coordinates[0,0], snap.coordinates[0,1], 'ro', zorder=1);

# %% [markdown]
# In this picture, the states are marked in blue, and the interfaces are drawn as red lines. The initial configuration is still the red dot.

# %% [markdown]
# ### First innermost interface path
#
# Now we have to create an initial path. This initial path shoud exit the state, cross the first interface, and then return to the state. We'll create this path by defining a special ensemble that, propagating forward from any initial snapshot, ends when the path ends with a segment in the appropriate interface.

# %%
from opentis.ensemble import EnsembleFactory as ef
from opentis.ensemble import LengthEnsemble, InXEnsemble, OutXEnsemble, SequentialEnsemble, OptionalEnsemble

interface0 = line_volume_set[0]
interface_ensemble_set = ef.TISEnsembleSet(stateA, stateB, line_volume_set)
first_traj_ensemble = SequentialEnsemble([
    OptionalEnsemble(OutXEnsemble(stateA)),
    InXEnsemble(stateA),
    OptionalEnsemble(OutXEnsemble(stateA) & InXEnsemble(interface0)),
    OptionalEnsemble(InXEnsemble(interface0)),
    OutXEnsemble(interface0),
    OptionalEnsemble(OutXEnsemble(stateA)),
    InXEnsemble(stateA) & LengthEnsemble(1)
])

# %% [markdown]
# This ensemble is a bit complicated, but works in the general case. To understand it, we'll look at the `SequentialEnsemble` segment by segment. One preliminary point is that we need the generated path ensemble to be the same as the accepted path ensemble in this case, meaning that we must define the ensemble entirely in terms of which volumes each segment is in (i.e., using `InXEnsemble` and `OutXEnsemble`, but not `LeaveXEnsemble` or `HitXEnsemble`).
#
# Start with the first two segments: we start with an optional ensemble outside the state, and then move to an ensemble that is in the state. Since our TIS segment must start in a state, these two ensembles allow us to either start outside the state and then evolve into the state, or to start inside the state. At the end of these two segments, we have the first frame of the TIS ensemble segment, i.e., the frame inside the state that begins the TIS path.
#
# Next we have a couple of optional ensembles, followed by an ensemble requiring the segment to be outside the interface. The optional interfaces here are only important if `stateA` and `interface0` represent different volumes. If they represent the same volume (which is the case here) these optional ensembles don't matter. However, if they are different volumes, then there is a space which is outside the state but inside the interface. So the first optional interface represents that space. The next optional interface says that you must then be inside `interface0`: this is in case there is a reentry into the state before you cross the interface. Next, we require that we cross the interface. The last optional ensemble is for segments ouside the state. If there is space between the interface and the state, then after you are no longer outside the interface you might still be outside the state. Finally, the path ends with one frame in the state.
#
# Following the logic of that, any path that begins anywhere and ends with a segment satisfying the innermost TIS ensemble will be accepted by this ensemble. Furthermore, since the ensemble is defined exclusively in terms of `InXEnsemble`s and `OutXEnsemble`s, the ensemble of paths generated by forward dynamics (`can_append`) is equivalent to the accepted path ensemble.

# %%
sim.initialized = True
first_traj = sim.generate(snap, [first_traj_ensemble.can_append])

# %% [markdown]
# Next we use the `Ensemble.split` function to split the trajectory we found into segments satisfying the innermost interface TIS ensemble. There is only one such segment, and so we assign the first (and only) one found to `subtraj`, which is the first trajectory satisfying the innermost TIS interface.

# %%
subtraj = interface_ensemble_set[0].split(first_traj)[0]

# %%
plt.imshow(stateAmap+stateBmap, extent=extent, cmap="Blues", interpolation='nearest', vmin=0.0, vmax=2.0, aspect='auto')
CS = plt.contour(X, Y, pes_V(X,Y), levels=np.arange(0.0, 1.5, 0.1), colors='k')
for iface in line_volume_set:
    plt.contour(X,Y, np.vectorize(CallableVolume(iface))(X,Y), colors='r', interpolation='none', levels=[0.5])
plt.plot(first_traj.coordinates()[1,0,0], first_traj.coordinates()[1,0,1], 'ro');
plt.plot(first_traj.coordinates()[1:,0,0], first_traj.coordinates()[1:,0,1], 'k-', linewidth=2)
plt.plot(subtraj.coordinates()[:,0,0], subtraj.coordinates()[:,0,1], 'r-', linewidth=1);

# %% [markdown]
# Now we see how the initial path evolves on this surface. The last part of the trajectory, which satisfies the path ensemble for the innermost interface, is highlighted in red. The whole trajectory is drawn in black.

# %% [markdown]
# ### Bootstrapping
#
# The bootstrapping approach takes a single trajectory which satisfies the innermost interface, and does shooting moves until it satisfies the next ensemble. Once it satisfies the next ensemble, we start shooting from within that ensemble. We keep building up like that until all ensembles have an initial path.
#
# To do this, we need to first create the appropriate shooting movers (one for each path ensemble). This is done quickly and efficiently with a factory function.

# %%
from opentis.pathmover import PathMoverFactory as mf
from opentis.shooting import UniformSelector

# might be nice to get rid of these two lines somehow
from opentis.pathmover import PathMover
PathMover.engine = sim

shooting_movers = mf.OneWayShootingSet(UniformSelector(), interface_ensemble_set)

# %% [markdown]
# Next we need to set up the Bootstrapping calculation:

# %%
from opentis.calculation import Bootstrapping

# TODO: add storage
bootstrap = Bootstrapping(storage=None,
                          engine=sim,
                          ensembles=interface_ensemble_set,
                          movers=shooting_movers)

# set the initial trajectory for the bootstrap:
bootstrap.set_replicas([subtraj])

# %%
for rep in bootstrap.globalstate:
    traj = bootstrap.globalstate[rep]
    print traj, 
    if traj is not None:
        print (op_line(bootstrap.globalstate[0]))
    else:
        print
# Out:
# None
# None
# None
# None
# None
# Trajectory[16] [-0.30781782, -0.29953346, -0.29140449, -0.28342938, -0.27500728, -0.26605582, -0.25883168, -0.2545996, -0.25305349, -0.2540527, -0.25682765, -0.26174885, -0.26975554, -0.27937162, -0.29008159, -0.30205336]

# %% [markdown]
# Now we run the bootstrapping. The number `50` means that we'll allow up to 50 shooting attempts per interface; if it takes more than that, you should probably adjust your interfaces (there's probably not much overlap for replica exchange).

# %%
bootstrap.run(1000)
# Out:
# Shooting backward from frame 6
# Proposal probability 1.07692307692 / random : 0.0724849973006
# Shooting backward from frame 3
# Proposal probability 0.928571428571 / random : 0.215529767916
# Shooting backward from frame 1
# Proposal probability 1.0 / random : 0.534675458789
# Shooting backward from frame 3
# Proposal probability 1.0 / random : 0.0374194723005
# Shooting forward from frame 12
# Proposal probability 0.933333333333 / random : 0.408952419915
# Shooting backward from frame 5
# Proposal probability 0.6 / random : 0.980771749701
# Shooting backward from frame 3
# Proposal probability
#  1.0 / random : 0.661518888783
# Shooting forward from frame 13
# Proposal probability 1.07142857143 / random : 0.983417273401
# Shooting backward from frame 10
# Proposal probability 0.666666666667 / random : 0.632945030619
# Shooting backward from frame 12
# Proposal probability
#  1.10526315789 / random : 0.780554340628
# Shooting backward from frame 11
# Shooting forward from frame 18
# Proposal probability 0.95 / random : 0.54735740746
# Shooting forward from frame 14
# Proposal probability
#  0.645161290323 / random : 0.731016060959
# Shooting forward from frame 17
# Proposal probability 1.05263157895 / random : 0.498396988499
# Shooting backward from frame 12
# Shooting forward from frame 13
# Proposal probability
#  1.0 / random : 0.208981989898
# Shooting forward from frame 17
# Proposal probability 0.95 / random : 0.259773460915
# Shooting backward from frame 19
# Shooting forward from frame 14
# Proposal probability 1.0 / random : 0.377743014854
# Shooting backward from frame 5
# Proposal probability 0.909090909091 / random : 0.415799094204
# Shooting backward from frame 16
# Shooting backward from frame 8
# Proposal probability 0.88 / random : 0.424935304846
# Shooting backward from frame 3
# Proposal probability 1.0 / random : 0.996709694324
# Shooting forward from frame 10
# Proposal probability
#  1.31578947368 / random : 0.273619099413
# Shooting backward from frame 9
# Proposal probability 0.904761904762 / random : 0.216243243011
# Shooting backward from frame 12
# Proposal probability 1.4 / random : 0.155065913427
# Shooting backward from frame 3
# Proposal probability 0.9375 / random : 0.434807991558
# Shooting backward from frame 4
# Proposal probability
#  0.64 / random : 0.690053130448
# Shooting backward from frame 11
# Proposal probability 0.727272727273 / random : 0.121545882443
# Shooting backward from frame 21
# Proposal probability
#  1.04761904762 / random : 0.716222001706
# Shooting backward from frame 20
# Shooting backward from frame 3
# Proposal probability 1.0 / random : 0.108157320821
# Shooting backward from frame 1
# Proposal probability 1.0 / random : 0.303817316011
# Shooting forward from frame 19
# Proposal probability 1.05 / random : 0.733657800123
# Shooting forward from frame 14
# Proposal probability
#  0.714285714286 / random : 0.285449054617
# Shooting backward from frame 5
# Proposal probability 1.0 / random : 0.653727011598
# Shooting forward from frame 28
# Proposal probability 1.0 / random : 0.990685168895
# Shooting backward from frame 5
# Proposal probability
#  1.0 / random : 0.682856782215
# Shooting forward from frame 26
# Proposal probability 1.0 / random : 0.696726483032
# Shooting backward from frame 9
# Proposal probability 0.965517241379 / random : 0.866946564458
# Shooting forward from frame 15
# Proposal probability
#  0.966666666667 / random : 0.895906288819
# Shooting backward from frame 18
# Proposal probability 1.5 / random : 0.587554936356
# Shooting backward from frame 20
# Proposal probability
#  0.833333333333 / random : 0.453612121271
# Shooting backward from frame 20
# Shooting backward from frame 5
# Proposal probability 1.0 / random : 0.217797617853
# Shooting forward from frame 4
# Shooting forward from frame 13
# Proposal probability
#  0.96 / random : 0.929144375179
# Shooting forward from frame 25
# Proposal probability 1.0 / random : 0.526677240522
# Shooting backward from frame 10
# Proposal probability 0.862068965517 / random : 0.744291207174
# Shooting backward from frame 17
# Proposal probability
#  1.26086956522 / random : 0.359098806547
# Shooting backward from frame 23
# Proposal probability 1.0 / random : 0.303464354895
# Shooting backward from frame 12
# Proposal probability
#  1.0 / random : 0.342322478493
# Shooting forward from frame 11
# Proposal probability 0.851851851852 / random : 0.620361825159
# Shooting forward from frame 5
# Proposal probability
#  1.17391304348 / random : 0.735827692788
# Shooting backward from frame 19
# Shooting forward from frame 11
# Proposal probability
#  0.851851851852 / random : 0.357972906434
# Shooting backward from frame 17
# Proposal probability 1.28571428571 / random : 0.531356818728
# Shooting forward from frame 13
# Proposal probability 0.954545454545 / random : 0.475409862803
# Shooting forward from frame 4
# Shooting backward from frame 18
# Proposal probability 0.95652173913 / random : 0.973333563458
# Shooting backward from frame 13
# Proposal probability
#  0.785714285714 / random : 0.746295558285
# Shooting backward from frame 10
# Proposal probability
#  0.717948717949 / random : 0.261720043164
# Shooting backward from frame 20
# Proposal probability 1.39285714286 / random : 0.758249787965
# Shooting forward from frame 27
# Proposal probability 1.0 / random : 0.952856142763
# Shooting forward from frame 16
# Proposal probability 0.875 / random : 0.0417092033735
# Shooting backward from frame 19
# Proposal probability
#  1.23076923077 / random : 0.31438515266
# Shooting forward from frame 16
# Proposal probability 1.0 / random : 0.380686785978
# Shooting forward from frame 15
# Proposal probability
#  1.0 / random : 0.261677434434
# Shooting forward from frame 25
# Proposal probability 1.0 / random : 0.500250586709
# Shooting forward from frame 21
# Proposal probability
#  1.0 / random : 0.846066250221
# Shooting backward from frame 9
# Proposal probability 0.962962962963 / random : 0.955789327614
# Shooting backward from frame 22
# Proposal probability
#  1.35 / random : 0.905987647507
# Shooting backward from frame 13
# Proposal probability 0.869565217391 / random : 0.710652543057
# Shooting backward from frame 15
# Proposal probability 1.15 / random : 0.119108386556
# Shooting backward from frame 20
# Proposal probability 0.869565217391 / random : 0.286289032859
# Shooting forward from frame 14
# Proposal probability
#  0.851851851852 / random : 0.646920489569
# Shooting forward from frame 5
# Proposal probability 1.125 / random : 0.27616806626
# Shooting forward from frame 3
# Proposal probability
#  1.04347826087 / random : 0.727164126249
# Shooting backward from frame 9
# Proposal probability 0.958333333333 / random : 0.831478086661
# Shooting forward from frame 13
# Proposal probability
#  0.96 / random : 0.331057089056
# Shooting forward from frame 6
# Shooting backward from frame 6
# Proposal probability
#  0.714285714286 / random : 0.68893432761
# Shooting forward from frame 30
# Proposal probability 1.02941176471 / random : 0.897618152275
# Shooting backward from frame 5
# Proposal probability
#  0.971428571429 / random : 0.0730462414252
# Shooting forward from frame 7
# Shooting backward from frame 21
# Proposal probability
#  1.20689655172 / random : 0.174982727656
# Shooting backward from frame 18
# Proposal probability
#  1.07407407407 / random : 0.844022618408
# Shooting backward from frame 16
# Proposal probability 1.17391304348 / random : 0.921797980015
# Shooting forward from frame 11
# Proposal probability
#  1.15 / random : 0.961271914992
# Shooting backward from frame 12
# Proposal probability 1.11111111111 / random : 0.641727777379
# Shooting backward from frame 14
# Proposal probability
#  0.857142857143 / random : 0.858974670362
# Shooting backward from frame 7
# Proposal probability 1.05882352941 / random : 0.898873804795
# Shooting backward from frame 11
# Proposal probability 0.772727272727 / random : 0.975355647624
# Shooting backward from frame 7
# Proposal probability 0.772727272727 / random : 0.597844946288
# Shooting forward from frame 10
# Shooting backward from frame 10
# Proposal probability 0.88 / random : 0.128409146665
# Shooting backward from frame 10
# Proposal probability
#  0.925925925926 / random : 0.503754202062
# Shooting backward from frame 11
# Proposal probability
#  0.964285714286 / random : 0.276494818902
# Shooting forward from frame 24
# Proposal probability 1.0 / random : 0.102699663591
# Shooting backward from frame 4
# Proposal probability
#  0.651162790698 / random : 0.274069398675
# Shooting forward from frame 35
# Proposal probability
#  0.977272727273 / random : 0.217182186544
# Shooting forward from frame 15
# Shooting forward from frame 19
# Shooting backward from frame 31
# Proposal probability 1.83333333333 / random : 0.109110721291
# Shooting backward from frame 16
# Proposal probability
#  1.33333333333 / random : 0.211713407764
# Shooting forward from frame 10
# Proposal probability 0.72 / random : 0.785355533315
# Shooting forward from frame 15
# Proposal probability
#  1.0 / random : 0.730810897151
# Shooting forward from frame 9
# Proposal probability 0.857142857143 / random : 0.471983768884
# Shooting forward from frame 2
# Shooting backward from frame 14
# Proposal probability 0.875 / random : 0.657021918179
# Shooting forward from frame 14
# Proposal probability 0.857142857143 / random : 0.435411845942
# Shooting forward from frame 15
# Proposal probability
#  1.0 / random : 0.968508717852
# Shooting forward from frame 24
# Proposal probability 0.965517241379 / random : 0.323660897406
# Shooting backward from frame 16
# Proposal probability
#  1.16 / random : 0.356922693902
# Shooting forward from frame 15
# Proposal probability 1.04166666667 / random : 0.454202071228
# Shooting backward from frame 10
# Proposal probability
#  0.888888888889 / random : 0.335867902916
# Shooting backward from frame 4
# Proposal probability
#  0.710526315789 / random : 0.248267165814
# Shooting backward from frame 35
# Shooting backward from frame 3
# Proposal probability 0.974358974359 / random : 0.715986633383
# Shooting forward from frame 33
# Proposal probability
#  1.02631578947 / random : 0.891031189628
# Shooting backward from frame 20
# Proposal probability
#  1.02702702703 / random : 0.436586126902
# Shooting backward from frame 32
# Proposal probability 1.7619047619 / random : 0.123664761561
# Shooting forward from frame 7
# Proposal probability
#  0.913043478261 / random : 0.279441244317
# Shooting forward from frame 2
# Shooting forward from frame 19
# Proposal probability 1.04545454545 / random : 0.180611555927
# Shooting backward from frame 16
# Shooting backward from frame 18
# Shooting forward from frame 4
# Shooting forward from frame 6
# Shooting forward from frame 15
# Proposal probability
#  0.916666666667 / random : 0.489337423472
# Shooting backward from frame 24
# Shooting backward from frame 1
# Proposal probability 1.0 / random : 0.549794556425
# Shooting backward from frame 4
# Proposal probability
#  0.631578947368 / random : 0.274717100214
# Shooting forward from frame 15
# Proposal probability 1.9 / random : 0.406031624906
# Shooting forward from frame 12
# Proposal probability
#  0.769230769231 / random : 0.0569812556878
# Shooting forward from frame 6
# Shooting forward from frame 26
# Proposal probability 1.0 / random : 0.348796479055
# Shooting backward from frame 14
# Proposal probability
#  1.08333333333 / random : 0.736599175121
# Shooting forward from frame 11
# Proposal probability 1.04347826087 / random : 0.450941731138
# Shooting backward from frame 16
# Proposal probability
#  1.09523809524 / random : 0.174345295914
# Shooting backward from frame 7
# Proposal probability 1.0 / random : 0.52941525262
# Shooting forward from frame 7
# Proposal probability
#  0.84 / random : 0.672073589862
# Shooting forward from frame 7
# Proposal probability 1.04166666667 / random : 0.197981210637
# Shooting backward from frame 17
# Proposal probability
#  1.09090909091 / random : 0.429478326444
# Shooting forward from frame 16
# Proposal probability 0.95652173913 / random : 0.484223430516
# Shooting forward from frame 10
# Proposal probability 1.15 / random : 0.409254387736
# Shooting forward from frame 1
# Proposal probability 0.833333333333 / random : 0.973808412575
# Shooting backward from frame 5
# Proposal probability
#  1.0 / random : 0.760633136874
# Shooting backward from frame 19
# Proposal probability 0.869565217391 / random : 0.799530857417
# Shooting forward from frame 14
# Proposal probability
#  0.884615384615 / random : 0.0633057387641
# Shooting forward from frame 25
# Proposal probability 1.0 / random : 0.494800423717
# Shooting forward from frame 11
# Proposal probability 1.18181818182 / random : 0.673058593156
# Shooting backward from frame 14
# Proposal probability
#  1.15789473684 / random : 0.975029879728
# Shooting forward from frame 5
# Proposal probability 0.730769230769 / random : 0.516920053971
# Shooting backward from frame 6
# Proposal probability
#  1.0 / random : 0.429721624838
# Shooting forward from frame 7
# Proposal probability 1.08333333333 / random : 0.554515443042
# Shooting forward from frame 16
# Proposal probability
#  0.96 / random : 0.531037569054
# Shooting backward from frame 2
# Proposal probability
#  0.568181818182 / random : 0.0476605742492
# Shooting forward from frame 14
# Proposal probability 1.83333333333 / random : 0.890019986392
# Shooting backward from frame 18
# Shooting backward from frame 23
# Shooting backward from frame 2
# Proposal probability
#  0.521739130435 / random : 0.88505663694
# Shooting forward from frame 24
# Proposal probability 1.0 / random : 0.918591746906
# Shooting backward from frame 2
# Proposal probability
#  0.510638297872 / random : 0.273943149966
# Shooting forward from frame 11
# Proposal probability
#  1.95833333333 / random : 0.586545452843
# Shooting backward from frame 22
# Proposal probability 1.04347826087 / random : 0.798352572224
# Shooting backward from frame 12
# Proposal probability 0.958333333333 / random : 0.125900750804
# Shooting forward from frame 4
# Shooting forward from frame 10
# Proposal probability 1.14285714286 / random : 0.438334383705
# Shooting forward from frame 8
# Proposal probability
#  1.5 / random : 0.474590965517
# Shooting forward from frame 3
# Proposal probability
#  0.518518518519 / random : 0.741556631705
# Shooting backward from frame 4
# Proposal probability
#  0.466666666667 / random : 0.522428899584
# Shooting backward from frame 9
# Proposal probability 0.636363636364 / random : 0.670189489116
# Shooting forward from frame 12
# Proposal probability
#  0.933333333333 / random : 0.816097094196
# Shooting forward from frame 12
# Proposal probability 1.0 / random : 0.482363352737
# Shooting backward from frame 11
# Proposal probability
#  0.681818181818 / random : 0.597315976106
# Shooting backward from frame 15
# Proposal probability
#  0.95652173913 / random : 0.830121307812
# Shooting backward from frame 8
# Proposal probability
#  0.821428571429 / random : 0.469766147054
# Shooting forward from frame 6
# Shooting forward from frame 19
# Proposal probability
#  0.903225806452 / random : 0.918379724964
# Shooting backward from frame 12
# Proposal probability 1.03703703704 / random : 0.813687443867
# Shooting forward from frame 18
# Proposal probability
#  0.9 / random : 0.316329547131
# Shooting backward from frame 3
# Proposal probability 1.0 / random : 0.418477161558
# Shooting forward from frame 3
# Shooting forward from frame 12
# Proposal probability 1.57894736842 / random : 0.998113560326
# Shooting backward from frame 5
# Proposal probability 1.0 / random : 0.987796807592
# Shooting backward from frame 16
# Proposal probability 0.904761904762 / random : 0.305661043742
# Shooting forward from frame 12
# Proposal probability
#  0.954545454545 / random : 0.550533041453
# Shooting forward from frame 22
# Proposal probability 1.0 / random : 0.178934984682
# Shooting forward from frame 4
# Shooting backward from frame 8
# Proposal probability
#  0.814814814815 / random : 0.3693085151
# Shooting backward from frame 21
# Shooting forward from frame 26
# Proposal probability
#  1.0 / random : 0.499623019449
# Shooting forward from frame 3
# Shooting backward from frame 15
# Proposal probability
#  1.08 / random : 0.193943458178
# Shooting backward from frame 1
# Proposal probability 1.0 / random : 0.854308208891
# Shooting backward from frame 22
# Proposal probability
#  1.19047619048 / random : 0.725009845567
# Shooting forward from frame 1
# Shooting forward from frame 21
# Proposal probability
#  1.0 / random : 0.133949976717
# Shooting backward from frame 6
# Proposal probability
#  0.7 / random : 0.309892376499
# Shooting backward from frame 29
# Shooting forward from frame 22
# Proposal probability 1.0 / random : 0.820401320431
# Shooting forward from frame 24
# Proposal probability
#  1.03448275862 / random : 0.0958090715022
# Shooting forward from frame 6
# Shooting forward from frame 23
# Proposal probability
#  0.966666666667 / random : 0.389396614253
# Shooting backward from frame 10
# Proposal probability
#  0.909090909091 / random : 0.184189299166
# Shooting forward from frame 24
# Proposal probability
#  0.916666666667 / random : 0.49331203724
# Shooting backward from frame 33
# Proposal probability 1.71428571429 / random : 0.316283292782
# Shooting backward from frame 4
# Proposal probability
#  0.552631578947 / random : 0.998294338631
# Shooting forward from frame 2
# Shooting forward from frame 4
# Shooting forward from frame 16
# Proposal probability
#  0.7 / random : 0.654479382866
# Shooting backward from frame 27
# Shooting forward from frame 21
# Proposal probability 1.07142857143 / random : 0.613639472574
# Shooting forward from frame 2
# Shooting forward from frame 27
# Proposal probability
#  1.0 / random : 0.394136557648
# Shooting forward from frame 10
# Proposal probability 1.4 / random : 0.811758129469
# Shooting backward from frame 18
# Shooting forward from frame 16
# Proposal probability 1.05263157895 / random : 0.356544966126
# Shooting backward from frame 2
# Proposal probability
#  0.487179487179 / random : 0.904512148791
# Shooting backward from frame 3
# Proposal probability 1.0 / random : 0.804411073654
# Shooting backward from frame 13
# Proposal probability
#  0.826086956522 / random : 0.859207564533
# Shooting forward from frame 10
# Proposal probability 0.904761904762 / random : 0.617742030933
# Shooting forward from frame 10
# Proposal probability
#  1.0 / random : 0.392458148255
# Shooting forward from frame 14
# Proposal probability 0.913043478261 / random : 0.267503547976
# Shooting forward from frame 1
# Shooting forward from frame 6
# Shooting backward from frame 5
# Proposal probability 1.0 / random : 0.384468316502
# Shooting backward from frame 9
# Proposal probability
#  1.0 / random : 0.140211854339
# Shooting forward from frame 13
# Proposal probability 1.09523809524 / random : 0.89184432604
# Shooting forward from frame 5
# Proposal probability
#  0.807692307692 / random : 0.210187546402
# Shooting forward from frame 14
# Proposal probability 1.08333333333 / random : 0.298851907798
# Shooting forward from frame 6
# Proposal probability
#  1.0 / random : 0.165201324836
# Shooting backward from frame 5
# Proposal probability 1.0 / random : 0.458600419643
# Shooting backward from frame 10
# Proposal probability
#  1.04347826087 / random : 0.95714757704
# Shooting backward from frame 5
# Proposal probability 0.958333333333 / random : 0.696487131378
# Shooting forward from frame 7
# Shooting forward from frame 17
# Proposal probability 1.04347826087 / random : 0.538734601194
# Shooting forward from frame 12
# Proposal probability
#  1.04545454545 / random : 0.919217145762
# Shooting forward from frame 4
# Shooting backward from frame 17
# Proposal probability 0.88 / random : 0.676854005717
# Shooting backward from frame 1
# Proposal probability 1.0 / random : 0.184692035783
# Shooting forward from frame 24
# Proposal probability 1.0 / random : 0.872767136117
# Shooting backward from frame 23
# Proposal probability
#  1.0 / random : 0.873853969259
# Shooting forward from frame 11
# Proposal probability 1.0 / random : 0.0193182222249
# Shooting forward from frame 13
# Proposal probability
#  0.892857142857 / random : 0.366441612193
# Shooting forward from frame 3
# Proposal probability 1.12 / random : 0.333602272757
# Shooting backward from frame 10
# Proposal probability
#  0.961538461538 / random : 0.374407698309
# Shooting backward from frame 2
# Proposal probability
#  0.553191489362 / random : 0.0569802993918
# Shooting forward from frame 42
# Proposal probability 0.979166666667 / random : 0.884577917429
# Shooting forward from frame 34
# Proposal probability
#  1.02127659574 / random : 0.840761649134
# Shooting backward from frame 28
# Proposal probability 1.80769230769 / random : 0.227678803614
# Shooting backward from frame 1
# Proposal probability 1.0 / random : 0.350001034241
# Shooting forward from frame 26
# Proposal probability
#  1.0 / random : 0.760922475692
# Shooting forward from frame 13
# Proposal probability 0.962962962963 / random : 0.0270265030025
# Shooting forward from frame 14
# Proposal probability
#  0.9 / random : 0.820138377275
# Shooting forward from frame 7
# Shooting forward from frame 8
# Shooting backward from frame 6
# Proposal probability
#  0.681818181818 / random : 0.430787666135
# Shooting backward from frame 32
# Shooting forward from frame 4
# Shooting forward from frame 31
# Proposal probability
#  1.07317073171 / random : 0.73459305378
# Shooting forward from frame 6
# Shooting backward from frame 31
# Proposal probability
#  1.24242424242 / random : 0.697027207744
# Shooting forward from frame 31
# Proposal probability 1.0 / random : 0.104774487287
# Shooting backward from frame 7
# Proposal probability 1.0 / random : 0.0636626878133
# Shooting backward from frame 25
# Proposal probability 1.13793103448 / random : 0.130337051842
# Shooting forward from frame 25
# Proposal probability 0.966666666667 / random : 0.0961694184414
# Shooting forward from frame 5
# Shooting forward from frame 21
# Proposal probability 1.0 / random : 0.0966586834082
# Shooting backward from frame 16
# Proposal probability
#  1.11111111111 / random : 0.371867679635
# Shooting backward from frame 18
# Proposal probability 0.9 / random : 0.938074992664
# Shooting backward from frame 3
# Proposal probability
#  1.0 / random : 0.0824809036594
# Shooting backward from frame 15
# Proposal probability 1.03846153846 / random : 0.185616183949
# Shooting forward from frame 26
# Proposal probability
#  1.0 / random : 0.332104067804
# Shooting forward from frame 16
# Proposal probability
#  0.742857142857 / random : 0.483545487857
# Shooting backward from frame 9
# Proposal probability 1.02941176471 / random : 0.798146731982
# Shooting backward from frame 29
# Proposal probability
#  1.25925925926 / random : 0.268295794099
# Shooting backward from frame 13
# Proposal probability 0.870967741935 / random : 0.951051501864
# Shooting backward from frame 4
# Proposal probability
#  0.551020408163 / random : 0.0150667772248
# Shooting backward from frame 4
# Proposal probability
#  0.7 / random : 0.028384585556
# Shooting backward from frame 10
# Proposal probability
#  0.886075949367 / random : 0.942854316971
# Shooting backward from frame 46
# Proposal probability
#  1.66666666667 / random : 0.755779984857
# Shooting forward from frame 27
# Proposal probability 1.05 / random : 0.0884971654223
# Shooting forward from frame 31
# Proposal probability 1.02564102564 / random : 0.985150895149
# Shooting forward from frame 36
# Proposal probability
#  1.0 / random : 0.608507825861
# Shooting backward from frame 23
# Proposal probability 1.11428571429 / random : 0.436476251789
# Shooting forward from frame 30
# Proposal probability 1.02941176471 / random : 0.772723759887
# Shooting forward from frame 4
# Shooting backward from frame 23
# Proposal probability
#  1.1724137931 / random : 0.740714292315
# Shooting backward from frame 4
# Proposal probability
#  0.591836734694 / random : 0.689078066768
# Shooting forward from frame 20
# Proposal probability 1.0 / random : 0.853342308666
# Shooting backward from frame 26
# Proposal probability
#  0.966666666667 / random : 0.306843882145
# Shooting forward from frame 26
# Proposal probability
#  0.588235294118 / random : 0.160020819295
# Shooting backward from frame 43
# Proposal probability
#  1.7 / random : 0.654777943054
# Shooting forward from frame 15
# Proposal probability 1.15384615385 / random : 0.310964595063
# Shooting backward from frame 13
# Proposal probability
#  0.896551724138 / random : 0.341875365713
# Shooting forward from frame 16
# Proposal probability 0.935483870968 / random : 0.960553205243
# Shooting forward from frame 11
# Proposal probability
#  0.935483870968 / random : 0.0463338071161
# Shooting forward from frame 5
# Proposal probability
#  0.96875 / random : 0.486461526856
# Shooting forward from frame 4
# Shooting forward from frame 12
# Shooting forward from frame 11
# Shooting backward from frame 21
# Proposal probability
#  1.18518518519 / random : 0.430318679721
# Shooting backward from frame 5
# Proposal probability 1.0 / random : 0.842358351164
# Shooting backward from frame 7
# Proposal probability
#  1.0 / random : 0.920090959026
# Shooting backward from frame 13
# Proposal probability
#  0.931034482759 / random : 0.862265451486
# Shooting backward from frame 14
# Proposal probability
#  0.878787878788 / random : 0.524086838658
# Shooting forward from frame 24
# Proposal probability 1.0 / random : 0.784443999416
# Shooting forward from frame 3
# Shooting backward from frame 23
# Shooting forward from frame 27
# Proposal probability 1.03125 / random : 0.97358418408
# Shooting backward from frame 5
# Proposal probability
#  1.0 / random : 0.0758088181958
# Shooting backward from frame 25
# Proposal probability
#  1.14285714286 / random : 0.828226840568
# Shooting forward from frame 9
# Proposal probability
#  0.848484848485 / random : 0.509598074193
# Shooting backward from frame 13
# Proposal probability 1.0 / random : 0.384282854444
# Shooting backward from frame 11
# Proposal probability
#  0.970588235294 / random : 0.322868788385
# Shooting backward from frame 2
# Proposal probability
#  0.653846153846 / random : 0.35819092438
# Shooting backward from frame 7
# Proposal probability
#  0.945454545455 / random : 0.457789255792
# Shooting forward from frame 39
# Proposal probability
#  1.07843137255 / random : 0.703549015984
# Shooting backward from frame 4
# Proposal probability
#  0.83606557377 / random : 0.103866011401
# Shooting forward from frame 43
# Shooting forward from frame 29
# Shooting backward from frame 3
# Proposal probability 1.0 / random : 0.0760125353319
# Shooting backward from frame 13
# Proposal probability
#  0.924242424242 / random : 0.983601142631
# Shooting forward from frame 15
# Shooting forward from frame 36
# Shooting backward from frame 15
# Proposal probability 1.19607843137 / random : 0.90666198207
# Shooting forward from frame 12
# Shooting forward from frame 12
# Shooting forward from frame 2
# Shooting backward from frame 5
# Proposal probability
#  1.02 / random : 0.259060588871
# Shooting backward from frame 28
# Proposal probability
#  1.06382978723 / random : 0.591195083376
# Shooting forward from frame 16
# Shooting forward from frame 23
# Shooting backward from frame 26
# Proposal probability 1.62068965517 / random : 0.678511077846
# Shooting backward from frame 3
# Proposal probability
#  1.0 / random : 0.820246148842
# Shooting backward from frame 25
# Proposal probability
#  0.966666666667 / random : 0.605711093987
# Shooting forward from frame 21
# Proposal probability
#  0.967741935484 / random : 0.904924530927
# Shooting forward from frame 22
# Proposal probability 1.0 / random : 0.632040376121
# Shooting backward from frame 14
# Proposal probability
#  0.815789473684 / random : 0.41526855298
# Shooting forward from frame 28
# Proposal probability
#  0.974358974359 / random : 0.981745998894
# Shooting forward from frame 28
# Proposal probability 1.02702702703 / random : 0.326557116758
# Shooting backward from frame 19
# Proposal probability 1.15625 / random : 0.588948010188
# Shooting backward from frame 11
# Proposal probability
#  1.03225806452 / random : 0.93320966026
# Shooting forward from frame 26
# Proposal probability 1.03333333333 / random : 0.279150457682
# Shooting forward from frame 28
# Proposal probability 1.0 / random : 0.396734688815
# Shooting backward from frame 12
# Proposal probability 0.9375 / random : 0.875473288973
# Shooting forward from frame 3
# Proposal probability
#  1.06666666667 / random : 0.565216988932
# Shooting backward from frame 25
# Proposal probability
#  1.07142857143 / random : 0.780081006683
# Shooting forward from frame 23
# Proposal probability 1.0 / random : 0.47778291488
# Shooting forward from frame 11
# Proposal probability
#  1.0 / random : 0.902690323031
# Shooting forward from frame 14
# Proposal probability 0.965517241379 / random : 0.735198072481
# Shooting forward from frame 28
# Proposal probability
#  1.0 / random : 0.902977716481
# Shooting backward from frame 15
# Proposal probability 0.90625 / random : 0.354856754104
# Shooting backward from frame 27
# Proposal probability
#  1.10344827586 / random : 0.269679638635
# Shooting backward from frame 19
# Shooting forward from frame 19
# Proposal probability 0.935483870968 / random : 0.389466639935
# Shooting backward from frame 17
# Proposal probability 1.10714285714 / random : 0.841542915868
# Shooting backward from frame 28
# Shooting forward from frame 4
# Shooting backward from frame 9
# Proposal probability 1.03703703704 / random : 0.964745727165
# Shooting backward from frame 6
# Proposal probability
#  0.519230769231 / random : 0.341199062279
# Shooting backward from frame 40
# Proposal probability
#  1.67741935484 / random : 0.538941427454
# Shooting forward from frame 21
# Proposal probability
#  0.96875 / random : 0.802061691483
# Shooting forward from frame 15
# Proposal probability
#  1.10344827586 / random : 0.625650683021
# Shooting forward from frame 18
# Proposal probability 0.966666666667 / random : 0.0620658248191
# Shooting forward from frame 4
# Shooting backward from frame 18
# Proposal probability
#  1.07142857143 / random : 0.66375072606
# Shooting backward from frame 21
# Shooting forward from frame 8
# Shooting forward from frame 25
# Proposal probability
#  1.0 / random : 0.278918284424
# Shooting forward from frame 6
# Shooting forward from frame 9
# Proposal probability
#  0.875 / random : 0.548143229445
# Shooting forward from frame 29
# Proposal probability 1.0 / random : 0.600627788873
# Shooting backward from frame 24
# Proposal probability
#  1.0 / random : 0.0775488395975
# Shooting forward from frame 30
# Proposal probability 1.0 / random : 0.983054899537
# Shooting forward from frame 16
# Proposal probability
#  1.03225806452 / random : 0.737273666345
# Shooting backward from frame 4
# Proposal probability
#  0.62 / random : 0.309431654171
# Shooting backward from frame 31
# Proposal probability
#  1.16279069767 / random : 0.879456936966
# Shooting forward from frame 13
# Proposal probability
#  1.19444444444 / random : 0.138502429749
# Shooting forward from frame 5
# Proposal probability
#  1.33333333333 / random : 0.753727363802
# Shooting backward from frame 4
# Proposal probability
#  0.551020408163 / random : 0.363627497367
# Shooting forward from frame 34
# Proposal probability
#  1.0652173913 / random : 0.0465767544204
# Shooting backward from frame 24
# Proposal probability 1.58620689655 / random : 0.231919552463
# Shooting forward from frame 2
# Shooting backward from frame 17
# Proposal probability 1.20833333333 / random : 0.233281097524
# Shooting backward from frame 12
# Proposal probability
#  0.827586206897 / random : 0.621432394608
# Shooting backward from frame 2
# Proposal probability
#  0.547169811321 / random : 0.86371491816
# Shooting forward from frame 14
# Proposal probability 1.11538461538 / random : 0.0728478120219
# Shooting forward from frame 16
# Proposal probability 1.0 / random : 0.418972039499
# Shooting backward from frame 15
# Proposal probability
#  0.764705882353 / random : 0.348519426292
# Shooting backward from frame 19
# Proposal probability
#  1.0 / random : 0.607220345697
# Shooting forward from frame 1
# Shooting backward from frame 19
# Proposal probability
#  0.829268292683 / random : 0.0473521059661
# Shooting backward from frame 27
# Proposal probability 1.46428571429 / random : 0.798244624792
# Shooting forward from frame 17
# Proposal probability
#  0.933333333333 / random : 0.463297547557
# Shooting forward from frame 6
# Shooting forward from frame 15
# Proposal probability 1.2 / random : 0.686484785169
# Shooting backward from frame 24
# Shooting backward from frame 19
# Proposal probability 0.806451612903 / random : 0.60806830533
# Shooting backward from frame 31
# Shooting backward from frame 13
# Proposal probability 0.96875 / random : 0.500292085391
# Shooting backward from frame 18
# Proposal probability
#  0.941176470588 / random : 0.50711942342
# Shooting forward from frame 31
# Proposal probability 1.0 / random : 0.787072129105
# Shooting backward from frame 11
# Proposal probability
#  1.09677419355 / random : 0.439972117572
# Shooting forward from frame 6
# Shooting backward from frame 4
# Proposal probability
#  0.632653061224 / random : 0.111175231403
# Shooting backward from frame 11
# Proposal probability
#  0.924528301887 / random : 0.57012819157
# Shooting backward from frame 19
# Proposal probability
#  1.0 / random : 0.0139709458356
# Shooting backward from frame 17
# Proposal probability
#  1.01923076923 / random : 0.0750312158217
# Shooting forward from frame 7
# Shooting backward from frame 21
# Proposal probability
#  1.3 / random : 0.26778686586
# Shooting forward from frame 20
# Shooting forward from frame 12
# Shooting forward from frame 20
# Shooting backward from frame 12
# Proposal probability
#  0.727272727273 / random : 0.645673031827
# Shooting backward from frame 41
# Proposal probability
#  1.89655172414 / random : 0.00326948367321
# Shooting backward from frame 25
# Proposal probability
#  0.537037037037 / random : 0.551994641882
# Shooting forward from frame 23
# Proposal probability
#  0.935483870968 / random : 0.581670065531
# Shooting backward from frame 10
# Proposal probability
#  0.673913043478 / random : 0.0842488881501
# Shooting backward from frame 37
# Shooting backward from frame 7
# Proposal probability
#  1.02222222222 / random : 0.764984472976
# Shooting forward from frame 32
# Proposal probability
#  0.725806451613 / random : 0.246919040071
# Shooting forward from frame 46
# Proposal probability
#  1.03333333333 / random : 0.484395129633
# Shooting forward from frame 40
# Proposal probability
#  1.05263157895 / random : 0.0255544206294
# Shooting backward from frame 24
# Proposal probability
#  1.09615384615 / random : 0.561068443719
# Shooting forward from frame 1
# Proposal probability
#  1.20930232558 / random : 0.495038405474
# Shooting forward from frame 5
# Proposal probability
#  1.38709677419 / random : 0.954173142581

# %% [markdown]
# We've stored all the trajectories we generated here; now we want to extract a path for each ensemble to use as a starting point for TIS. We'll choose to take the first path that satisfied each ensemble.

# %%
print bootstrap.globalstate
# Out:
# [Trajectory[23], Trajectory[26], Trajectory[29], Trajectory[45], Trajectory[33], Trajectory[33]]

# %% [markdown]
# Let's go ahead and visualize where each of those trajectories are:

# %%
plt.imshow(stateAmap+stateBmap, extent=extent, cmap="Blues", interpolation='nearest', vmin=0.0, vmax=2.0, aspect='auto')
CS = plt.contour(X, Y, pes_V(X,Y), levels=np.arange(0.0, 1.5, 0.1), colors='k')
for iface in line_volume_set:
    plt.contour(X,Y, np.vectorize(CallableVolume(iface))(X,Y), colors='r', interpolation='none', levels=[0.5])
plt.plot(bootstrap.globalstate[0].coordinates()[:,0,0], bootstrap.globalstate[0].coordinates()[:,0,1], 'k-')
plt.plot(bootstrap.globalstate[1].coordinates()[:,0,0], bootstrap.globalstate[1].coordinates()[:,0,1], 'r-')
plt.plot(bootstrap.globalstate[2].coordinates()[:,0,0], bootstrap.globalstate[2].coordinates()[:,0,1], 'g-')
plt.plot(bootstrap.globalstate[3].coordinates()[:,0,0], bootstrap.globalstate[3].coordinates()[:,0,1], 'b-')
plt.plot(bootstrap.globalstate[4].coordinates()[:,0,0], bootstrap.globalstate[4].coordinates()[:,0,1], 'r-')
plt.plot(bootstrap.globalstate[5].coordinates()[:,0,0], bootstrap.globalstate[5].coordinates()[:,0,1], 'k-');

# %% [markdown]
# ## Equilibration in the Path Ensemble
#
# At the end of the bootstrapping process, we have a set of paths which we can use to start TIS sampling. Before doing a production run, we should let these paths equilibrate within the ensembles. If you generate your initial path through dynamics that aren't the true dynamics (e.g., using high temperature runs or using metadynamics), this stage is **extremely** important. It's important here as well, but less so than if your initial path is non-physical.
#
# This will be an example of a "normal" TIS run, i.e., TIS without replica exchange. We will sampling using only shooter movers (the same ones defined for the bootstrapping) and path reversal movers. First we define these path reveral movers:

# %%
#reversal_movers = mf.PathReversalSet(interface_ensemble_set)

# %% [markdown]
# Next we define global moves: we'll set this up so that each move either does a shooting move on all replicas, or does a path reversal move on all replicas. You can similarly set it up so that each move operates on only on one replica at a time.

# %%
#equilibration_movers = GeneralGlobalMover([shooting_movers, reversal_movers])

# %% [markdown]
# Now we're ready to set up a TIS run:

# %%
#equilibration = PathSampling(interface_ensemble_set, equilibration_movers)

# %% [markdown]
# And now we run it. We'll do 1000 equilibration steps.

# %%
#equilibration.run(1000)

# %% [markdown]
# ## RETIS: Production run
#
# With everything else set up, we can set up the replica exchange movers, and reuse the other movers.

# %%
#repex_movers = mf.NeighborReplicaExchange(interface_ensemble_set)

# %%
#all_movers = [shooting_movers, repex_movers, reversal_movers]
#production = PathSampling(interface_ensemble_set, all_movers)

# %%
#production.run(500000)
