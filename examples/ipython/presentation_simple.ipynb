# %%
# %matplotlib inline
from toy_plot_helpers import ToyPlot
plot = ToyPlot()

# %%
import openpathsampling as paths
import numpy as np

# %% [markdown]
# ## Setting up the system

# %%
import openpathsampling.toy_dynamics as toys
pes = (toys.toy_pes.OuterWalls([1.0, 1.0], [0.0, 0.0]) + 
       toys.toy_pes.Gaussian(2.0, [1.0, 4.0], [0.0,1.0]) + 
       toys.toy_pes.Gaussian(2.0, [25.0, 1.0], [0.0, -1.0])
      )
topology=paths.ToyTopology(
    n_spatial = 2,
    masses =[1.0, 1.0],
    pes = pes
)
template_snap = paths.Snapshot(
    coordinates=np.array([[0.0, 0.0]]), 
    velocities=np.array([[0.0,0.0]]),
    potential_energy = 0.0, # to set dimensionless energies for toy engine
    kinetic_energy = 0.0,
    topology=topology
)
integ = toys.toy_integrators.LangevinBAOABIntegrator(dt=0.02, temperature=0.1, gamma=1.0)
options={'integ' : integ,
         'n_frames_max' : 5000,
         'nsteps_per_frame' : 10
        }
sim = toys.toy_engine.ToyEngine(
        options=options,
        template=template_snap
)

paths.PathMover.engine = sim
sim.initialized = True

# %% [markdown]
# ## Load a trajectory

# %%
# TODO
storage = paths.storage.Storage('bootstrap.nc', mode='r')
traj = storage.sampleset[len(storage.sampleset)-1].samples[-1].trajectory

# %%
plot.add_pes(pes)

# %%
plot.plot([traj])

# %% [markdown]
# ## Defining states and interfaces

# %%
orderparameter = paths.OP_Function(name="xval",
                                   fcn=lambda snap : snap.xyz[0,0])

# %%
stateA = paths.LambdaVolume(orderparameter, float("-inf"), -0.3)
stateB = paths.LambdaVolume(orderparameter, 0.3, float("inf"))
interfaces = paths.VolumeFactory.LambdaVolumeSet(orderparameter, 
                                                 minvals=float("-inf"), 
                                                 maxvals=[-0.30, -0.25, -0.20, -0.13, -0.05, 0.0]
                                                )

# %%
plot.add_states([stateA, stateB])
plot.add_interfaces(interfaces)

# %%
plot.plot([traj])

# %% [markdown]
# ## Automatic preparation of TIS pathmovers and ensembles

# %%
tis = paths.analysis.TISTransition(stateA, stateB, orderparameter, interfaces)

# %%
tis.ensembles
# Out:
# [<openpathsampling.ensemble.SequentialEnsemble at 0x10c89bbd0>,
#  <openpathsampling.ensemble.SequentialEnsemble at 0x10c893c50>,
#  <openpathsampling.ensemble.SequentialEnsemble at 0x10c883c90>,
#  <openpathsampling.ensemble.SequentialEnsemble at 0x1163ab950>,
#  <openpathsampling.ensemble.SequentialEnsemble at 0x1093c8b10>,
#  <openpathsampling.ensemble.SequentialEnsemble at 0x1163a23d0>]

# %%
tis.movers
# Out:
# {'pathreversal': [<openpathsampling.pathmover.PathReversalMover at 0x116432490>,
#   <openpathsampling.pathmover.PathReversalMover at 0x1164324d0>,
#   <openpathsampling.pathmover.PathReversalMover at 0x116432510>,
#   <openpathsampling.pathmover.PathReversalMover at 0x116432550>,
#   <openpathsampling.pathmover.PathReversalMover at 0x116432590>,
#   <openpathsampling.pathmover.PathReversalMover at 0x1164325d0>],
#  'shooting': [<openpathsampling.pathmover.OneWayShootingMover at 0x1163b31d0>,
#   <openpathsampling.pathmover.OneWayShootingMover at 0x1163b35d0>,
#   <openpathsampling.pathmover.OneWayShootingMover at 0x1163b3c10>,
#   <openpathsampling.pathmover.OneWayShootingMover at 0x1163b3390>,
#   <openpathsampling.pathmover.OneWayShootingMover at 0x116432310>,
#   <openpathsampling.pathmover.OneWayShootingMover at 0x1164323d0>]}

# %% [markdown]
# ## Set up and run a TIS calculation

# %%
alltrajs = paths.SampleSet(
    [paths.Sample.initial_sample(replica=tis.ensembles.index(e), 
                                 trajectory=paths.Trajectory(traj), # makes a copy
                                 ensemble=e)
     for e in tis.ensembles]
)

# %%
tis_calc = paths.PathSampling(
    storage=None,
    engine=sim,
    root_mover=paths.SequentialMover(movers=tis.movers['shooting']),
    globalstate=alltrajs
)

# %%
tis_calc.run(20)

# %%
plot.plot([sample.trajectory for sample in tis_calc.globalstate])
