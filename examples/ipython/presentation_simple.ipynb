# %%
# %matplotlib inline
from toy_plot_helpers import ToyPlot
plot = ToyPlot()

# %%
import openpathsampling as paths
import numpy as np

# %% [markdown]
# ## Setting up the system

# %%
import openpathsampling.toy_dynamics as toys
pes = (toys.toy_pes.OuterWalls([1.0, 1.0], [0.0, 0.0]) + 
       toys.toy_pes.Gaussian(2.0, [1.0, 4.0], [0.0,1.0]) + 
       toys.toy_pes.Gaussian(2.0, [25.0, 1.0], [0.0, -1.0])
      )
topology=paths.ToyTopology(
    n_spatial = 2,
    masses =[1.0, 1.0],
    pes = pes
)
template_snap = paths.Snapshot(
    coordinates=np.array([[0.0, 0.0]]), 
    velocities=np.array([[0.0,0.0]]),
    potential_energy = 0.0, # to set dimensionless energies for toy engine
    kinetic_energy = 0.0,
    topology=topology
)
integ = toys.toy_integrators.LangevinBAOABIntegrator(dt=0.02, temperature=0.1, gamma=1.0)
options={'integ' : integ,
         'n_frames_max' : 5000,
         'nsteps_per_frame' : 10
        }
sim = toys.toy_engine.ToyEngine(
        options=options,
        template=template_snap
)

paths.PathMover.engine = sim
sim.initialized = True

# %% [markdown]
# ## Load a trajectory

# %%
# TODO
storage = paths.storage.Storage('bootstrap.nc', mode='r')
traj = storage.sampleset[len(storage.sampleset)-1].samples[-1].trajectory

# %%
traj[1].coordinates
# Out:
# Quantity(value=array([[-0.29458258,  0.40572435]], dtype=float32), unit=dimensionless)

# %%
plot.add_pes(pes)

# %%
plot.plot([traj])

# %% [markdown]
# ## Defining states and interfaces

# %%
orderparameter = paths.OP_Function(name="xval",
                                   fcn=lambda snap : snap.coordinates[0,0])

# %%
stateA = paths.LambdaVolume(orderparameter, float("-inf"), -0.3)
stateB = paths.LambdaVolume(orderparameter, 0.3, float("inf"))
interfaces = paths.VolumeFactory.LambdaVolumeSet(orderparameter, 
                                                 minvals=float("-inf"), 
                                                 maxvals=[-0.30, -0.25, -0.20, -0.13, -0.05, 0.0]
                                                )

# %%
plot.add_states([stateA, stateB])
plot.add_interfaces(interfaces)

# %%
plot.plot()

# %% [markdown]
# ## Automatic preparation of TIS pathmovers and ensembles

# %%
tis = paths.analysis.TISTransition(stateA, stateB, orderparameter, interfaces)

# %%
tis.ensembles
# Out:
# [<openpathsampling.ensemble.SequentialEnsemble at 0x119579590>,
#  <openpathsampling.ensemble.SequentialEnsemble at 0x119569110>,
#  <openpathsampling.ensemble.SequentialEnsemble at 0x119561e10>,
#  <openpathsampling.ensemble.SequentialEnsemble at 0x1230890d0>,
#  <openpathsampling.ensemble.SequentialEnsemble at 0x123078e10>,
#  <openpathsampling.ensemble.SequentialEnsemble at 0x1230911d0>]

# %%
tis.movers
# Out:
# {'pathreversal': [<openpathsampling.pathmover.PathReversalMover at 0x123111510>,
#   <openpathsampling.pathmover.PathReversalMover at 0x123111550>,
#   <openpathsampling.pathmover.PathReversalMover at 0x123111590>,
#   <openpathsampling.pathmover.PathReversalMover at 0x1231115d0>,
#   <openpathsampling.pathmover.PathReversalMover at 0x123111610>,
#   <openpathsampling.pathmover.PathReversalMover at 0x123111650>],
#  'shooting': [<openpathsampling.pathmover.OneWayShootingMover at 0x123091510>,
#   <openpathsampling.pathmover.OneWayShootingMover at 0x1230916d0>,
#   <openpathsampling.pathmover.OneWayShootingMover at 0x123091450>,
#   <openpathsampling.pathmover.OneWayShootingMover at 0x1231112d0>,
#   <openpathsampling.pathmover.OneWayShootingMover at 0x123111390>,
#   <openpathsampling.pathmover.OneWayShootingMover at 0x123111450>]}

# %% [markdown]
# ## Set up and run a TIS calculation

# %%
alltrajs = paths.SampleSet(
    [paths.Sample.initial_sample(replica=tis.ensembles.index(e), 
                                 trajectory=paths.Trajectory(traj), 
                                 ensemble=e)
     for e in tis.ensembles]
)

# %%
tis_calc = paths.PathSampling(
    storage=None,
    engine=sim,
    root_mover=paths.SequentialMover(movers=tis.movers['shooting']),
    globalstate=alltrajs
)

# %%
tis_calc.globalstate[4].trajectory[6].coordinates
# Out:
# Quantity(value=array([[-0.21408653,  0.41127425]], dtype=float32), unit=dimensionless)

# %%
tis_calc.run(20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-2a0bd6aa1846> in <module>()
# ----> 1 tis_calc.run(20)
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/calculation.pyc in run(self, nsteps)
#     234
#     235         for step in range(nsteps):
# --> 236             movepath = self._mover.move(self.globalstate, step=step)
#     237             samples = movepath.samples
#     238             self.globalstate = self.globalstate.apply_samples(samples, step=step)
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/pathmover.pyc in move(self, globalstate, step)
#    1235
#    1236     def move(self, globalstate, step=-1):
# -> 1237         return paths.CalculationMovePath(self.mover.move(globalstate), self.calculation, step=step, mover=self)
#    1238
#    1239 @restores_as_stub_object
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/pathmover.pyc in wrapper(self, *args, **kwargs)
#     157             return paths.FilterSamplesMovePath(movepath, selected_samples=keep_samples)
#     158         else:
# --> 159             movepath = func(self, *args, **kwargs)
#     160             return movepath
#     161
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/pathmover.pyc in move(self, globalstate)
#     617
#     618             # Run the sub mover
# --> 619             movepath = mover.move(subglobal)
#     620             samples = movepath.samples
#     621             subglobal = subglobal.apply_samples(samples)
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/pathmover.pyc in wrapper(self, *args, **kwargs)
#     157             return paths.FilterSamplesMovePath(movepath, selected_samples=keep_samples)
#     158         else:
# --> 159             movepath = func(self, *args, **kwargs)
#     160             return movepath
#     161
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/pathmover.pyc in move(self, globalstate)
#     541         mover = self.movers[idx]
#     542
# --> 543         path = paths.RandomChoiceMovePath(mover.move(globalstate), mover=self)
#     544
#     545         return path
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/pathmover.pyc in wrapper(self, *args, **kwargs)
#     157             return paths.FilterSamplesMovePath(movepath, selected_samples=keep_samples)
#     158         else:
# --> 159             movepath = func(self, *args, **kwargs)
#     160             return movepath
#     161
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/pathmover.pyc in move(self, globalstate)
#     390         setattr(details, 'final_point', None)
#     391
# --> 392         self._generate(details, dynamics_ensemble)
#     393
#     394         setattr(details, 'trial_is_in_ensemble',
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/pathmover.pyc in _generate(self, details, ensemble)
#     449                     details.start[0:details.start_point.index]
#     450                 ).can_append,
# --> 451                 self._length_stopper.can_append
#     452             ]
#     453         )
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/dynamics_engine.pyc in generate(self, snapshot, running)
#     279             # maybe we should stop before we even begin?
#     280             stop = self.stop_conditions(trajectory=trajectory,
# --> 281                                         continue_conditions=running)
#     282
#     283             logger.info("Starting trajectory")
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/dynamics_engine.pyc in stop_conditions(self, trajectory, continue_conditions)
#     233         if continue_conditions is not None:
#     234             for condition in continue_conditions:
# --> 235                 can_continue = condition(trajectory)
#     236                 self.running[condition] = can_continue # JHP: is this needed?
#     237                 stop = stop or not can_continue
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/ensemble.pyc in can_append(self, trajectory)
#    1142
#    1143     def can_append(self, trajectory):
# -> 1144         return self._new_ensemble.can_append(self._alter(trajectory))
#    1145
#    1146     def can_prepend(self, trajectory):
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/ensemble.pyc in can_append(self, trajectory)
#     769         while True: #  main loop, with various
#     770             subtraj_final = self._find_subtraj_final(trajectory,
# --> 771                                                      subtraj_first, ens_num)
#     772             logger.debug(
#     773                 str(ens_num) + " : " +
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/ensemble.pyc in _find_subtraj_final(self, traj, subtraj_first, ens_num)
#     721         # if we're in the ensemble or could eventually be in the ensemble,
#     722         # we keep building the subtrajectory
# --> 723         while ( (ens.can_append(subtraj) or ens(subtraj)) and
#     724                     subtraj_final < traj_final):
#     725             subtraj_final += 1
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/ensemble.pyc in __call__(self, trajectory, lazy)
#    1136
#    1137     def __call__(self, trajectory, lazy=None):
# -> 1138         return self._new_ensemble(self._alter(trajectory), lazy)
#    1139
#    1140     def _alter(self, trajectory):
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/ensemble.pyc in __call__(self, trajectory, lazy)
#     495                          " is "+str(a))
#     496             logger.debug("Combination: " + self.ensemble2.__class__.__name__ +
# --> 497                          " is " +str(self.ensemble2(trajectory, lazy)))
#     498             logger.debug("Combination: returning " +
#     499                          str(self.fnc(a,self.ensemble2(trajectory,lazy))))
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/ensemble.pyc in __call__(self, trajectory, lazy)
#    1002             return False
#    1003         for frame in trajectory:
# -> 1004             if not self._volume(frame):
#    1005                 return False
#    1006         return True
#
# /Users/dwhs/Dropbox/msm-tis/openpathsampling/volume.pyc in __call__(self, snapshot)
#     316     def __call__(self, snapshot):
#     317         l = self.orderparameter(snapshot)
# --> 318         return l >= self.lambda_min and l <= self.lambda_max
#     319
#     320     def __str__(self):
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/simtk/unit/quantity.pyc in __ge__(self, other)
#     283
#     284     def __ge__(self, other):
# --> 285         return self._value >= (other.value_in_unit(self.unit))
#     286     def __gt__(self, other):
#     287         return self._value > (other.value_in_unit(self.unit))
#
# AttributeError: 'float' object has no attribute 'value_in_unit'

# %%
plot.plot([sample.trajectory for sample in tis_calc.globalstate])
